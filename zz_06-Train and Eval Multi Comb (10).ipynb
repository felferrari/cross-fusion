# %%
# %load_ext autoreload
# %autoreload 2

# %%
#%autoreload # When utils.py is updated
from utils_unet_resunet import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from model.models import Model_4
from model.losses import WBCE
from model.callbacks import UpdateWeights

root_path = 'imgs/'

# %%
# Define data type 
img_type = 'FUSION'

if img_type == 'FUSION':
    image_array = np.load(root_path+'New_Images/fus_stack.npy')
    

if img_type == 'OPT':
    image_array = np.load(root_path+'New_Images/opt_stack.npy')
    
    
if img_type == 'SAR':
    image_array = np.load(root_path+'New_Images/sar_stack.npy')
print('Image stack:', image_array.shape)

final_mask1 = np.load(root_path+'New_Images/'+'final_mask1.npy')
print('Labels stack:', final_mask1.shape)

h_, w_, channels = image_array.shape
n_opt_layers = 20
# Out:
# Image stack: (10000, 7000, 24)
# Labels stack: (10000, 7000)

# %%
# Create tile mask
mask_tiles = create_mask(final_mask1.shape[0], final_mask1.shape[1], grid_size=(5, 4))
image_array = image_array[:mask_tiles.shape[0], :mask_tiles.shape[1],:]
final_mask1 = final_mask1[:mask_tiles.shape[0], :mask_tiles.shape[1]]

print('mask: ',mask_tiles.shape)
print('image stack: ', image_array.shape)
print('ref :', final_mask1.shape)
#plt.imshow(mask_tiles)
# Out:
# Tiles size:  2000 1750
# Mask size:  (10000, 7000)
# mask:  (10000, 7000)
# image stack:  (10000, 7000, 24)
# ref : (10000, 7000)

# %%
plt.figure(figsize=(10,5))
plt.imshow(final_mask1, cmap = 'jet')

# %%
# Define tiles for training, validation, and test sets
tiles_tr = [1,3,5,8,11,13,14,20]
tiles_val = [6,19]
tiles_ts = (list(set(np.arange(20)+1)-set(tiles_tr)-set(tiles_val)))

mask_tr_val = np.zeros((mask_tiles.shape)).astype('float32')
# Training and validation mask
for tr_ in tiles_tr:
    mask_tr_val[mask_tiles == tr_] = 1

for val_ in tiles_val:
    mask_tr_val[mask_tiles == val_] = 2

mask_amazon_ts = np.zeros((mask_tiles.shape)).astype('float32')
for ts_ in tiles_ts:
    mask_amazon_ts[mask_tiles == ts_] = 1

# %%
# Create ixd image to extract patches
overlap = 0.7
patch_size = 128
batch_size = 32
im_idx = create_idx_image(final_mask1)
patches_idx = extract_patches(im_idx, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1,patch_size, patch_size)
patches_mask = extract_patches(mask_tr_val, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1, patch_size, patch_size)
del im_idx

# %%
# Selecting index trn val and test patches idx
idx_trn = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==patch_size**2))
idx_val = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==2*patch_size**2))
del patches_mask

patches_idx_trn = patches_idx[idx_trn]
patches_idx_val = patches_idx[idx_val]
del idx_trn, idx_val

print('Number of training patches:  ', len(patches_idx_trn), 'Number of validation patches', len(patches_idx_val))
# Out:
# Number of training patches:   17110 Number of validation patches 4116

# %%
# Extract patches with at least 2% of deforestation class
X_train = retrieve_idx_percentage(final_mask1, patches_idx_trn, patch_size, pertentage = 2)
X_valid = retrieve_idx_percentage(final_mask1, patches_idx_val, patch_size, pertentage = 2)
print(X_train.shape, X_valid.shape)
del patches_idx_trn, patches_idx_val
# Out:
# (1158, 128, 128) (341, 128, 128)

# %%
def batch_generator(batches, image, reference, target_size, number_class):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    image = image.reshape(-1, image.shape[-1])
    reference = reference.reshape(final_mask1.shape[0]*final_mask1.shape[1])
    while True:
        batch_x, batch_y = next(batches)
        batch_x = np.squeeze(batch_x.astype('int64'))
        #print(batch_x.shape)
        batch_img = np.zeros((batch_x.shape[0], target_size, target_size, image.shape[-1]))
        batch_ref = np.zeros((batch_x.shape[0], target_size, target_size, number_class))
        
        for i in range(batch_x.shape[0]):
            if np.random.rand()>0.5:
                batch_x[i] = np.rot90(batch_x[i], 1)
            batch_img[i] = image[batch_x[i]] 
            batch_ref[i] = tf.keras.utils.to_categorical(reference[batch_x[i]] , number_class)
                       
        yield (batch_img, batch_ref)

train_datagen = ImageDataGenerator(horizontal_flip = True,
                                   vertical_flip = True)
valid_datagen = ImageDataGenerator(horizontal_flip = True, 
                                   vertical_flip = True)

y_train = np.zeros((len(X_train)))
y_valid = np.zeros((len(X_valid)))

train_gen = train_datagen.flow(np.expand_dims(X_train, axis = -1), y_train,
                              batch_size=batch_size,
                              shuffle=True)

valid_gen = valid_datagen.flow(np.expand_dims(X_valid, axis = -1), y_valid,
                              batch_size=batch_size,
                              shuffle=False)

number_class = 3
train_gen_crops = batch_generator(train_gen, image_array, final_mask1, patch_size, number_class)
valid_gen_crops = batch_generator(valid_gen, image_array, final_mask1, patch_size, number_class)

# %%
exp = 3
path_exp = root_path+'experiments/exp'+str(exp)
path_models = path_exp+'/models'
path_maps = path_exp+'/pred_maps'

if not os.path.exists(path_exp):
    os.makedirs(path_exp)   
if not os.path.exists(path_models):
    os.makedirs(path_models)   
if not os.path.exists(path_maps):
    os.makedirs(path_maps)

# %%
# Define model
input_shape = (patch_size, patch_size, channels)
nb_filters = [32, 64, 128]

method = 'unet'
if method == 'unet':
   model = build_unet(input_shape, nb_filters, number_class)

if method == 'resunet':
   model = build_resunet(input_shape, nb_filters, number_class)

model = Model_4(nb_filters, number_class, n_opt_layers)

# %%
# Parameters of the model
weights = [0.2, 0.8, 0]
adam = Adam(lr = 1e-4 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
#loss = WBCE(weights = weights)
#loss = WBCE(weights = weights, class_indexes = [0, 1])

# %%
metrics_all = []
times=5
for tm in range(0,times):
    print('time: ', tm)

    rows = patch_size
    cols = patch_size
    adam = Adam(lr = 1e-4 , beta_1=0.9)
    
    loss = weighted_categorical_crossentropy(weights)
    #loss = WBCE(weights = weights)
    #loss = WBCE(weights = weights, class_indexes = [0, 1])

    #if method == 'unet':
    #   model = build_unet(input_shape, nb_filters, number_class)

    #if method == 'resunet':
    #   model = build_resunet(input_shape, nb_filters, number_class)
    
    model = Model_4(nb_filters, number_class, n_opt_layers)
    model.build((None,)+input_shape)
    
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    model.summary()

    earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
    #earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min') ---- val_accuracy
    #checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
    lr_reduce = ReduceLROnPlateau(factor=0.9, min_delta=0.0001, patience=5, verbose=1)
    updateWeights = UpdateWeights()
    callbacks_list = [earlystop, checkpoint, updateWeights]
    # train the model
    start_training = time.time()
    history = model.fit(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    end_training = time.time() - start_training
    metrics_all.append(end_training)
    del model, history
# Out:
# time:  0
# Model: "model_4_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 34s - opt_accuracy: 0.5861 - sar_accuracy: 0.6572 - fus_accuracy: 0.6250 - opt_loss: 0.2153 - sar_loss: 0.1728 - fusion_loss: 0.9830 - loss: 1.3711WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1230s vs `on_train_batch_end` time: 0.1766s). Check your callbacks.
# 108/108 [==============================] - 53s 391ms/step - opt_accuracy: 0.7834 - sar_accuracy: 0.7216 - fus_accuracy: 0.7008 - opt_loss: 0.1221 - sar_loss: 0.1474 - fusion_loss: 0.3012 - loss: 0.5706 - val_opt_accuracy: 0.8616 - val_sar_accuracy: 0.7901 - val_fus_accuracy: 0.7318 - val_opt_loss: 0.1045 - val_sar_loss: 0.1222 - val_fusion_loss: 0.2222 - val_loss: 0.4489
#
# Epoch 00001: val_loss improved from inf to 0.44892, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 2/100
# 108/108 [==============================] - 39s 359ms/step - opt_accuracy: 0.8545 - sar_accuracy: 0.7704 - fus_accuracy: 0.7388 - opt_loss: 0.0861 - sar_loss: 0.1298 - fusion_loss: 0.1573 - loss: 0.3733 - val_opt_accuracy: 0.8640 - val_sar_accuracy: 0.7963 - val_fus_accuracy: 0.7369 - val_opt_loss: 0.0906 - val_sar_loss: 0.1217 - val_fusion_loss: 0.1859 - val_loss: 0.3983
#
# Epoch 00002: val_loss improved from 0.44892 to 0.39830, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 3/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.8632 - sar_accuracy: 0.7911 - fus_accuracy: 0.7469 - opt_loss: 0.0799 - sar_loss: 0.1187 - fusion_loss: 0.1395 - loss: 0.3381 - val_opt_accuracy: 0.8569 - val_sar_accuracy: 0.8064 - val_fus_accuracy: 0.7594 - val_opt_loss: 0.0834 - val_sar_loss: 0.1177 - val_fusion_loss: 0.1950 - val_loss: 0.3961
#
# Epoch 00003: val_loss improved from 0.39830 to 0.39610, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 4/100
# 108/108 [==============================] - 39s 361ms/step - opt_accuracy: 0.8663 - sar_accuracy: 0.8043 - fus_accuracy: 0.7925 - opt_loss: 0.0773 - sar_loss: 0.1110 - fusion_loss: 0.1306 - loss: 0.3188 - val_opt_accuracy: 0.8627 - val_sar_accuracy: 0.8088 - val_fus_accuracy: 0.7904 - val_opt_loss: 0.0779 - val_sar_loss: 0.1093 - val_fusion_loss: 0.1849 - val_loss: 0.3721
#
# Epoch 00004: val_loss improved from 0.39610 to 0.37213, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 5/100
# 108/108 [==============================] - 39s 361ms/step - opt_accuracy: 0.8723 - sar_accuracy: 0.8116 - fus_accuracy: 0.8323 - opt_loss: 0.0740 - sar_loss: 0.1071 - fusion_loss: 0.1258 - loss: 0.3070 - val_opt_accuracy: 0.8651 - val_sar_accuracy: 0.7990 - val_fus_accuracy: 0.8143 - val_opt_loss: 0.0866 - val_sar_loss: 0.1095 - val_fusion_loss: 0.1985 - val_loss: 0.3946
#
# Epoch 00005: val_loss did not improve from 0.37213
# Epoch 6/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8739 - sar_accuracy: 0.8165 - fus_accuracy: 0.8444 - opt_loss: 0.0726 - sar_loss: 0.1024 - fusion_loss: 0.1224 - loss: 0.2974 - val_opt_accuracy: 0.8507 - val_sar_accuracy: 0.8105 - val_fus_accuracy: 0.8374 - val_opt_loss: 0.0902 - val_sar_loss: 0.1224 - val_fusion_loss: 0.1719 - val_loss: 0.3845
#
# Epoch 00006: val_loss did not improve from 0.37213
# Epoch 7/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.8785 - sar_accuracy: 0.8208 - fus_accuracy: 0.8518 - opt_loss: 0.0696 - sar_loss: 0.0998 - fusion_loss: 0.1195 - loss: 0.2889 - val_opt_accuracy: 0.8518 - val_sar_accuracy: 0.8096 - val_fus_accuracy: 0.8352 - val_opt_loss: 0.0939 - val_sar_loss: 0.1177 - val_fusion_loss: 0.1657 - val_loss: 0.3773
#
# Epoch 00007: val_loss did not improve from 0.37213
# Epoch 8/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.8807 - sar_accuracy: 0.8259 - fus_accuracy: 0.8564 - opt_loss: 0.0693 - sar_loss: 0.0965 - fusion_loss: 0.1171 - loss: 0.2830 - val_opt_accuracy: 0.8549 - val_sar_accuracy: 0.8172 - val_fus_accuracy: 0.8478 - val_opt_loss: 0.1012 - val_sar_loss: 0.1142 - val_fusion_loss: 0.1904 - val_loss: 0.4058
#
# Epoch 00008: val_loss did not improve from 0.37213
# Epoch 9/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8837 - sar_accuracy: 0.8293 - fus_accuracy: 0.8588 - opt_loss: 0.0668 - sar_loss: 0.0938 - fusion_loss: 0.1147 - loss: 0.2753 - val_opt_accuracy: 0.8551 - val_sar_accuracy: 0.8194 - val_fus_accuracy: 0.8477 - val_opt_loss: 0.1127 - val_sar_loss: 0.1136 - val_fusion_loss: 0.1853 - val_loss: 0.4116
#
# Epoch 00009: val_loss did not improve from 0.37213
# Epoch 10/100
# 108/108 [==============================] - 40s 367ms/step - opt_accuracy: 0.8863 - sar_accuracy: 0.8288 - fus_accuracy: 0.8591 - opt_loss: 0.0650 - sar_loss: 0.0941 - fusion_loss: 0.1146 - loss: 0.2738 - val_opt_accuracy: 0.8538 - val_sar_accuracy: 0.8207 - val_fus_accuracy: 0.8460 - val_opt_loss: 0.1230 - val_sar_loss: 0.1170 - val_fusion_loss: 0.1847 - val_loss: 0.4247
#
# Epoch 00010: val_loss did not improve from 0.37213
# Epoch 11/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8867 - sar_accuracy: 0.8332 - fus_accuracy: 0.8617 - opt_loss: 0.0639 - sar_loss: 0.0904 - fusion_loss: 0.1120 - loss: 0.2663 - val_opt_accuracy: 0.8495 - val_sar_accuracy: 0.8207 - val_fus_accuracy: 0.8480 - val_opt_loss: 0.1187 - val_sar_loss: 0.1161 - val_fusion_loss: 0.1950 - val_loss: 0.4298
#
# Epoch 00011: val_loss did not improve from 0.37213
# Epoch 12/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8906 - sar_accuracy: 0.8372 - fus_accuracy: 0.8645 - opt_loss: 0.0607 - sar_loss: 0.0882 - fusion_loss: 0.1102 - loss: 0.2591 - val_opt_accuracy: 0.8548 - val_sar_accuracy: 0.7993 - val_fus_accuracy: 0.8365 - val_opt_loss: 0.1244 - val_sar_loss: 0.1329 - val_fusion_loss: 0.2135 - val_loss: 0.4708
#
# Epoch 00012: val_loss did not improve from 0.37213
# Epoch 13/100
# 108/108 [==============================] - 39s 365ms/step - opt_accuracy: 0.8910 - sar_accuracy: 0.8403 - fus_accuracy: 0.8667 - opt_loss: 0.0605 - sar_loss: 0.0864 - fusion_loss: 0.1087 - loss: 0.2556 - val_opt_accuracy: 0.8567 - val_sar_accuracy: 0.8219 - val_fus_accuracy: 0.8484 - val_opt_loss: 0.1278 - val_sar_loss: 0.1397 - val_fusion_loss: 0.1906 - val_loss: 0.4581
#
# Epoch 00013: val_loss did not improve from 0.37213
# Epoch 14/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8939 - sar_accuracy: 0.8441 - fus_accuracy: 0.8691 - opt_loss: 0.0582 - sar_loss: 0.0842 - fusion_loss: 0.1062 - loss: 0.2486 - val_opt_accuracy: 0.8600 - val_sar_accuracy: 0.8175 - val_fus_accuracy: 0.8476 - val_opt_loss: 0.1114 - val_sar_loss: 0.1295 - val_fusion_loss: 0.2236 - val_loss: 0.4646
#
# Epoch 00014: val_loss did not improve from 0.37213
# Epoch 00014: early stopping
# time:  1
# Model: "model_4_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 29s - opt_accuracy: 0.6289 - sar_accuracy: 0.6615 - fus_accuracy: 0.6137 - opt_loss: 0.2174 - sar_loss: 0.1813 - fusion_loss: 0.8427 - loss: 1.2414WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1081s vs `on_train_batch_end` time: 0.1889s). Check your callbacks.
# 108/108 [==============================] - 43s 372ms/step - opt_accuracy: 0.7720 - sar_accuracy: 0.7247 - fus_accuracy: 0.6089 - opt_loss: 0.1260 - sar_loss: 0.1474 - fusion_loss: 0.2475 - loss: 0.5210 - val_opt_accuracy: 0.8614 - val_sar_accuracy: 0.7757 - val_fus_accuracy: 0.6292 - val_opt_loss: 0.0865 - val_sar_loss: 0.1205 - val_fusion_loss: 0.1821 - val_loss: 0.3892
#
# Epoch 00001: val_loss improved from inf to 0.38915, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 2/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.8500 - sar_accuracy: 0.7658 - fus_accuracy: 0.6189 - opt_loss: 0.0875 - sar_loss: 0.1284 - fusion_loss: 0.1475 - loss: 0.3633 - val_opt_accuracy: 0.8641 - val_sar_accuracy: 0.7947 - val_fus_accuracy: 0.6599 - val_opt_loss: 0.0869 - val_sar_loss: 0.1143 - val_fusion_loss: 0.1816 - val_loss: 0.3828
#
# Epoch 00002: val_loss improved from 0.38915 to 0.38283, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 3/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.8624 - sar_accuracy: 0.7861 - fus_accuracy: 0.6401 - opt_loss: 0.0807 - sar_loss: 0.1185 - fusion_loss: 0.1388 - loss: 0.3379 - val_opt_accuracy: 0.8584 - val_sar_accuracy: 0.7885 - val_fus_accuracy: 0.6813 - val_opt_loss: 0.0900 - val_sar_loss: 0.1241 - val_fusion_loss: 0.1775 - val_loss: 0.3916
#
# Epoch 00003: val_loss did not improve from 0.38283
# Epoch 4/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8686 - sar_accuracy: 0.8000 - fus_accuracy: 0.7180 - opt_loss: 0.0772 - sar_loss: 0.1122 - fusion_loss: 0.1317 - loss: 0.3211 - val_opt_accuracy: 0.8586 - val_sar_accuracy: 0.7952 - val_fus_accuracy: 0.7332 - val_opt_loss: 0.1017 - val_sar_loss: 0.1243 - val_fusion_loss: 0.1621 - val_loss: 0.3882
#
# Epoch 00004: val_loss did not improve from 0.38283
# Epoch 5/100
# 108/108 [==============================] - 39s 366ms/step - opt_accuracy: 0.8748 - sar_accuracy: 0.8110 - fus_accuracy: 0.7963 - opt_loss: 0.0727 - sar_loss: 0.1056 - fusion_loss: 0.1260 - loss: 0.3043 - val_opt_accuracy: 0.8561 - val_sar_accuracy: 0.8017 - val_fus_accuracy: 0.8074 - val_opt_loss: 0.1140 - val_sar_loss: 0.1165 - val_fusion_loss: 0.1655 - val_loss: 0.3959
#
# Epoch 00005: val_loss did not improve from 0.38283
# Epoch 6/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.8778 - sar_accuracy: 0.8162 - fus_accuracy: 0.8371 - opt_loss: 0.0713 - sar_loss: 0.1042 - fusion_loss: 0.1233 - loss: 0.2987 - val_opt_accuracy: 0.8571 - val_sar_accuracy: 0.8049 - val_fus_accuracy: 0.8228 - val_opt_loss: 0.1098 - val_sar_loss: 0.1155 - val_fusion_loss: 0.1746 - val_loss: 0.3999
#
# Epoch 00006: val_loss did not improve from 0.38283
# Epoch 7/100
# 108/108 [==============================] - 40s 373ms/step - opt_accuracy: 0.8810 - sar_accuracy: 0.8197 - fus_accuracy: 0.8522 - opt_loss: 0.0679 - sar_loss: 0.1005 - fusion_loss: 0.1199 - loss: 0.2883 - val_opt_accuracy: 0.8591 - val_sar_accuracy: 0.8121 - val_fus_accuracy: 0.8374 - val_opt_loss: 0.1148 - val_sar_loss: 0.1199 - val_fusion_loss: 0.1694 - val_loss: 0.4042
#
# Epoch 00007: val_loss did not improve from 0.38283
# Epoch 8/100
# 108/108 [==============================] - 40s 366ms/step - opt_accuracy: 0.8829 - sar_accuracy: 0.8275 - fus_accuracy: 0.8580 - opt_loss: 0.0667 - sar_loss: 0.0965 - fusion_loss: 0.1166 - loss: 0.2798 - val_opt_accuracy: 0.8592 - val_sar_accuracy: 0.8159 - val_fus_accuracy: 0.8444 - val_opt_loss: 0.1108 - val_sar_loss: 0.1119 - val_fusion_loss: 0.1658 - val_loss: 0.3886
#
# Epoch 00008: val_loss did not improve from 0.38283
# Epoch 9/100
# 108/108 [==============================] - 40s 374ms/step - opt_accuracy: 0.8852 - sar_accuracy: 0.8279 - fus_accuracy: 0.8592 - opt_loss: 0.0647 - sar_loss: 0.0958 - fusion_loss: 0.1158 - loss: 0.2763 - val_opt_accuracy: 0.8574 - val_sar_accuracy: 0.8154 - val_fus_accuracy: 0.8417 - val_opt_loss: 0.1015 - val_sar_loss: 0.1157 - val_fusion_loss: 0.1961 - val_loss: 0.4133
#
# Epoch 00009: val_loss did not improve from 0.38283
# Epoch 10/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8877 - sar_accuracy: 0.8317 - fus_accuracy: 0.8611 - opt_loss: 0.0626 - sar_loss: 0.0933 - fusion_loss: 0.1137 - loss: 0.2696 - val_opt_accuracy: 0.8573 - val_sar_accuracy: 0.8125 - val_fus_accuracy: 0.8456 - val_opt_loss: 0.1087 - val_sar_loss: 0.1127 - val_fusion_loss: 0.1809 - val_loss: 0.4023
#
# Epoch 00010: val_loss did not improve from 0.38283
# Epoch 11/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8892 - sar_accuracy: 0.8333 - fus_accuracy: 0.8626 - opt_loss: 0.0616 - sar_loss: 0.0911 - fusion_loss: 0.1118 - loss: 0.2645 - val_opt_accuracy: 0.8613 - val_sar_accuracy: 0.8200 - val_fus_accuracy: 0.8469 - val_opt_loss: 0.1123 - val_sar_loss: 0.1130 - val_fusion_loss: 0.1786 - val_loss: 0.4039
#
# Epoch 00011: val_loss did not improve from 0.38283
# Epoch 12/100
# 108/108 [==============================] - 40s 373ms/step - opt_accuracy: 0.8930 - sar_accuracy: 0.8418 - fus_accuracy: 0.8668 - opt_loss: 0.0583 - sar_loss: 0.0866 - fusion_loss: 0.1083 - loss: 0.2533 - val_opt_accuracy: 0.8632 - val_sar_accuracy: 0.8212 - val_fus_accuracy: 0.8466 - val_opt_loss: 0.0905 - val_sar_loss: 0.1111 - val_fusion_loss: 0.1950 - val_loss: 0.3965
#
# Epoch 00012: val_loss did not improve from 0.38283
# Epoch 00012: early stopping
# time:  2
# Model: "model_4_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 29s - opt_accuracy: 0.6440 - sar_accuracy: 0.6318 - fus_accuracy: 0.5652 - opt_loss: 0.1724 - sar_loss: 0.1807 - fusion_loss: 0.9952 - loss: 1.3483WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1105s vs `on_train_batch_end` time: 0.1892s). Check your callbacks.
# 108/108 [==============================] - 43s 371ms/step - opt_accuracy: 0.8023 - sar_accuracy: 0.7068 - fus_accuracy: 0.6447 - opt_loss: 0.1133 - sar_loss: 0.1523 - fusion_loss: 0.3222 - loss: 0.5879 - val_opt_accuracy: 0.8654 - val_sar_accuracy: 0.7865 - val_fus_accuracy: 0.6833 - val_opt_loss: 0.0891 - val_sar_loss: 0.1287 - val_fusion_loss: 0.2162 - val_loss: 0.4340
#
# Epoch 00001: val_loss improved from inf to 0.43403, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 2/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.8599 - sar_accuracy: 0.7599 - fus_accuracy: 0.6769 - opt_loss: 0.0861 - sar_loss: 0.1357 - fusion_loss: 0.1630 - loss: 0.3848 - val_opt_accuracy: 0.8653 - val_sar_accuracy: 0.7936 - val_fus_accuracy: 0.6939 - val_opt_loss: 0.0897 - val_sar_loss: 0.1412 - val_fusion_loss: 0.1661 - val_loss: 0.3969
#
# Epoch 00002: val_loss improved from 0.43403 to 0.39693, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 3/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8701 - sar_accuracy: 0.7666 - fus_accuracy: 0.7386 - opt_loss: 0.0793 - sar_loss: 0.1316 - fusion_loss: 0.1469 - loss: 0.3578 - val_opt_accuracy: 0.8631 - val_sar_accuracy: 0.7970 - val_fus_accuracy: 0.7920 - val_opt_loss: 0.0928 - val_sar_loss: 0.1366 - val_fusion_loss: 0.1658 - val_loss: 0.3952
#
# Epoch 00003: val_loss improved from 0.39693 to 0.39520, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 4/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8737 - sar_accuracy: 0.7835 - fus_accuracy: 0.7968 - opt_loss: 0.0763 - sar_loss: 0.1230 - fusion_loss: 0.1377 - loss: 0.3370 - val_opt_accuracy: 0.8639 - val_sar_accuracy: 0.7985 - val_fus_accuracy: 0.8214 - val_opt_loss: 0.0939 - val_sar_loss: 0.1202 - val_fusion_loss: 0.1586 - val_loss: 0.3727
#
# Epoch 00004: val_loss improved from 0.39520 to 0.37273, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 5/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8777 - sar_accuracy: 0.7974 - fus_accuracy: 0.8156 - opt_loss: 0.0722 - sar_loss: 0.1140 - fusion_loss: 0.1315 - loss: 0.3177 - val_opt_accuracy: 0.8631 - val_sar_accuracy: 0.7952 - val_fus_accuracy: 0.8260 - val_opt_loss: 0.0896 - val_sar_loss: 0.1172 - val_fusion_loss: 0.1686 - val_loss: 0.3755
#
# Epoch 00005: val_loss did not improve from 0.37273
# Epoch 6/100
# 108/108 [==============================] - 39s 364ms/step - opt_accuracy: 0.8788 - sar_accuracy: 0.8053 - fus_accuracy: 0.8263 - opt_loss: 0.0705 - sar_loss: 0.1086 - fusion_loss: 0.1270 - loss: 0.3061 - val_opt_accuracy: 0.8676 - val_sar_accuracy: 0.8058 - val_fus_accuracy: 0.8425 - val_opt_loss: 0.0973 - val_sar_loss: 0.1190 - val_fusion_loss: 0.1668 - val_loss: 0.3832
#
# Epoch 00006: val_loss did not improve from 0.37273
# Epoch 7/100
# 108/108 [==============================] - 39s 364ms/step - opt_accuracy: 0.8811 - sar_accuracy: 0.8102 - fus_accuracy: 0.8352 - opt_loss: 0.0686 - sar_loss: 0.1051 - fusion_loss: 0.1237 - loss: 0.2975 - val_opt_accuracy: 0.8594 - val_sar_accuracy: 0.8135 - val_fus_accuracy: 0.8405 - val_opt_loss: 0.0927 - val_sar_loss: 0.1335 - val_fusion_loss: 0.1771 - val_loss: 0.4033
#
# Epoch 00007: val_loss did not improve from 0.37273
# Epoch 8/100
# 108/108 [==============================] - 39s 364ms/step - opt_accuracy: 0.8821 - sar_accuracy: 0.8151 - fus_accuracy: 0.8405 - opt_loss: 0.0682 - sar_loss: 0.1025 - fusion_loss: 0.1215 - loss: 0.2922 - val_opt_accuracy: 0.8630 - val_sar_accuracy: 0.8127 - val_fus_accuracy: 0.8419 - val_opt_loss: 0.0961 - val_sar_loss: 0.1190 - val_fusion_loss: 0.1692 - val_loss: 0.3843
#
# Epoch 00008: val_loss did not improve from 0.37273
# Epoch 9/100
# 108/108 [==============================] - 39s 364ms/step - opt_accuracy: 0.8834 - sar_accuracy: 0.8200 - fus_accuracy: 0.8446 - opt_loss: 0.0672 - sar_loss: 0.1001 - fusion_loss: 0.1197 - loss: 0.2869 - val_opt_accuracy: 0.8563 - val_sar_accuracy: 0.8138 - val_fus_accuracy: 0.8485 - val_opt_loss: 0.1058 - val_sar_loss: 0.1240 - val_fusion_loss: 0.1878 - val_loss: 0.4175
#
# Epoch 00009: val_loss did not improve from 0.37273
# Epoch 10/100
# 108/108 [==============================] - 39s 364ms/step - opt_accuracy: 0.8860 - sar_accuracy: 0.8262 - fus_accuracy: 0.8499 - opt_loss: 0.0647 - sar_loss: 0.0959 - fusion_loss: 0.1164 - loss: 0.2769 - val_opt_accuracy: 0.8568 - val_sar_accuracy: 0.8139 - val_fus_accuracy: 0.8463 - val_opt_loss: 0.0988 - val_sar_loss: 0.1361 - val_fusion_loss: 0.1926 - val_loss: 0.4274
#
# Epoch 00010: val_loss did not improve from 0.37273
# Epoch 11/100
# 108/108 [==============================] - 39s 364ms/step - opt_accuracy: 0.8876 - sar_accuracy: 0.8282 - fus_accuracy: 0.8535 - opt_loss: 0.0638 - sar_loss: 0.0946 - fusion_loss: 0.1152 - loss: 0.2736 - val_opt_accuracy: 0.8677 - val_sar_accuracy: 0.8109 - val_fus_accuracy: 0.8473 - val_opt_loss: 0.0862 - val_sar_loss: 0.1205 - val_fusion_loss: 0.1721 - val_loss: 0.3788
#
# Epoch 00011: val_loss did not improve from 0.37273
# Epoch 12/100
# 108/108 [==============================] - 40s 367ms/step - opt_accuracy: 0.8887 - sar_accuracy: 0.8314 - fus_accuracy: 0.8562 - opt_loss: 0.0626 - sar_loss: 0.0930 - fusion_loss: 0.1137 - loss: 0.2693 - val_opt_accuracy: 0.8574 - val_sar_accuracy: 0.8181 - val_fus_accuracy: 0.8457 - val_opt_loss: 0.0954 - val_sar_loss: 0.1189 - val_fusion_loss: 0.1812 - val_loss: 0.3956
#
# Epoch 00012: val_loss did not improve from 0.37273
# Epoch 13/100
# 108/108 [==============================] - 40s 371ms/step - opt_accuracy: 0.8913 - sar_accuracy: 0.8356 - fus_accuracy: 0.8606 - opt_loss: 0.0607 - sar_loss: 0.0914 - fusion_loss: 0.1119 - loss: 0.2640 - val_opt_accuracy: 0.8564 - val_sar_accuracy: 0.8147 - val_fus_accuracy: 0.8445 - val_opt_loss: 0.0959 - val_sar_loss: 0.1384 - val_fusion_loss: 0.1867 - val_loss: 0.4210
#
# Epoch 00013: val_loss did not improve from 0.37273
# Epoch 14/100
# 108/108 [==============================] - 39s 365ms/step - opt_accuracy: 0.8929 - sar_accuracy: 0.8366 - fus_accuracy: 0.8615 - opt_loss: 0.0592 - sar_loss: 0.0899 - fusion_loss: 0.1106 - loss: 0.2597 - val_opt_accuracy: 0.8598 - val_sar_accuracy: 0.8193 - val_fus_accuracy: 0.8476 - val_opt_loss: 0.1022 - val_sar_loss: 0.1236 - val_fusion_loss: 0.1943 - val_loss: 0.4201
#
# Epoch 00014: val_loss did not improve from 0.37273
# Epoch 00014: early stopping
# time:  3
# Model: "model_4_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 30s - opt_accuracy: 0.6226 - sar_accuracy: 0.6661 - fus_accuracy: 0.5752 - opt_loss: 0.1874 - sar_loss: 0.1776 - fusion_loss: 0.9806 - loss: 1.3457WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1137s vs `on_train_batch_end` time: 0.1889s). Check your callbacks.
# 108/108 [==============================] - 43s 371ms/step - opt_accuracy: 0.7944 - sar_accuracy: 0.7167 - fus_accuracy: 0.6606 - opt_loss: 0.1172 - sar_loss: 0.1488 - fusion_loss: 0.3090 - loss: 0.5750 - val_opt_accuracy: 0.8612 - val_sar_accuracy: 0.7923 - val_fus_accuracy: 0.7281 - val_opt_loss: 0.1067 - val_sar_loss: 0.1354 - val_fusion_loss: 0.2665 - val_loss: 0.5085
#
# Epoch 00001: val_loss improved from inf to 0.50851, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 2/100
# 108/108 [==============================] - 39s 365ms/step - opt_accuracy: 0.8601 - sar_accuracy: 0.7654 - fus_accuracy: 0.6281 - opt_loss: 0.0833 - sar_loss: 0.1292 - fusion_loss: 0.1616 - loss: 0.3742 - val_opt_accuracy: 0.8598 - val_sar_accuracy: 0.7999 - val_fus_accuracy: 0.6520 - val_opt_loss: 0.0980 - val_sar_loss: 0.1313 - val_fusion_loss: 0.2255 - val_loss: 0.4547
#
# Epoch 00002: val_loss improved from 0.50851 to 0.45475, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 3/100
# 108/108 [==============================] - 39s 365ms/step - opt_accuracy: 0.8671 - sar_accuracy: 0.7808 - fus_accuracy: 0.6418 - opt_loss: 0.0787 - sar_loss: 0.1230 - fusion_loss: 0.1453 - loss: 0.3470 - val_opt_accuracy: 0.8567 - val_sar_accuracy: 0.7963 - val_fus_accuracy: 0.6660 - val_opt_loss: 0.1087 - val_sar_loss: 0.1216 - val_fusion_loss: 0.2077 - val_loss: 0.4379
#
# Epoch 00003: val_loss improved from 0.45475 to 0.43793, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 4/100
# 108/108 [==============================] - 39s 366ms/step - opt_accuracy: 0.8730 - sar_accuracy: 0.7970 - fus_accuracy: 0.7272 - opt_loss: 0.0730 - sar_loss: 0.1121 - fusion_loss: 0.1342 - loss: 0.3193 - val_opt_accuracy: 0.8581 - val_sar_accuracy: 0.8120 - val_fus_accuracy: 0.7325 - val_opt_loss: 0.1032 - val_sar_loss: 0.1363 - val_fusion_loss: 0.2015 - val_loss: 0.4410
#
# Epoch 00004: val_loss did not improve from 0.43793
# Epoch 5/100
# 108/108 [==============================] - 40s 366ms/step - opt_accuracy: 0.8754 - sar_accuracy: 0.8058 - fus_accuracy: 0.7794 - opt_loss: 0.0708 - sar_loss: 0.1070 - fusion_loss: 0.1269 - loss: 0.3047 - val_opt_accuracy: 0.8534 - val_sar_accuracy: 0.8080 - val_fus_accuracy: 0.7467 - val_opt_loss: 0.1028 - val_sar_loss: 0.1196 - val_fusion_loss: 0.2032 - val_loss: 0.4257
#
# Epoch 00005: val_loss improved from 0.43793 to 0.42565, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 6/100
# 108/108 [==============================] - 39s 365ms/step - opt_accuracy: 0.8797 - sar_accuracy: 0.8145 - fus_accuracy: 0.8333 - opt_loss: 0.0686 - sar_loss: 0.1024 - fusion_loss: 0.1228 - loss: 0.2939 - val_opt_accuracy: 0.8554 - val_sar_accuracy: 0.8110 - val_fus_accuracy: 0.8125 - val_opt_loss: 0.1308 - val_sar_loss: 0.1280 - val_fusion_loss: 0.1944 - val_loss: 0.4532
#
# Epoch 00006: val_loss did not improve from 0.42565
# Epoch 7/100
# 108/108 [==============================] - 40s 366ms/step - opt_accuracy: 0.8819 - sar_accuracy: 0.8176 - fus_accuracy: 0.8509 - opt_loss: 0.0666 - sar_loss: 0.0992 - fusion_loss: 0.1191 - loss: 0.2850 - val_opt_accuracy: 0.8620 - val_sar_accuracy: 0.8124 - val_fus_accuracy: 0.8197 - val_opt_loss: 0.1191 - val_sar_loss: 0.1200 - val_fusion_loss: 0.1835 - val_loss: 0.4226
#
# Epoch 00007: val_loss improved from 0.42565 to 0.42263, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 8/100
# 108/108 [==============================] - 40s 367ms/step - opt_accuracy: 0.8843 - sar_accuracy: 0.8218 - fus_accuracy: 0.8550 - opt_loss: 0.0650 - sar_loss: 0.0988 - fusion_loss: 0.1180 - loss: 0.2817 - val_opt_accuracy: 0.8702 - val_sar_accuracy: 0.8192 - val_fus_accuracy: 0.8400 - val_opt_loss: 0.1013 - val_sar_loss: 0.1176 - val_fusion_loss: 0.1754 - val_loss: 0.3943
#
# Epoch 00008: val_loss improved from 0.42263 to 0.39425, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 9/100
# 108/108 [==============================] - 40s 366ms/step - opt_accuracy: 0.8858 - sar_accuracy: 0.8238 - fus_accuracy: 0.8588 - opt_loss: 0.0637 - sar_loss: 0.0969 - fusion_loss: 0.1154 - loss: 0.2760 - val_opt_accuracy: 0.8570 - val_sar_accuracy: 0.8033 - val_fus_accuracy: 0.8328 - val_opt_loss: 0.1139 - val_sar_loss: 0.1213 - val_fusion_loss: 0.1789 - val_loss: 0.4140
#
# Epoch 00009: val_loss did not improve from 0.39425
# Epoch 10/100
# 108/108 [==============================] - 40s 368ms/step - opt_accuracy: 0.8882 - sar_accuracy: 0.8289 - fus_accuracy: 0.8607 - opt_loss: 0.0612 - sar_loss: 0.0928 - fusion_loss: 0.1126 - loss: 0.2667 - val_opt_accuracy: 0.8632 - val_sar_accuracy: 0.8093 - val_fus_accuracy: 0.8361 - val_opt_loss: 0.1242 - val_sar_loss: 0.1354 - val_fusion_loss: 0.1932 - val_loss: 0.4529
#
# Epoch 00010: val_loss did not improve from 0.39425
# Epoch 11/100
# 108/108 [==============================] - 40s 370ms/step - opt_accuracy: 0.8893 - sar_accuracy: 0.8290 - fus_accuracy: 0.8601 - opt_loss: 0.0604 - sar_loss: 0.0924 - fusion_loss: 0.1125 - loss: 0.2653 - val_opt_accuracy: 0.8581 - val_sar_accuracy: 0.8144 - val_fus_accuracy: 0.8409 - val_opt_loss: 0.1219 - val_sar_loss: 0.1206 - val_fusion_loss: 0.1981 - val_loss: 0.4406
#
# Epoch 00011: val_loss did not improve from 0.39425
# Epoch 12/100
# 108/108 [==============================] - 40s 367ms/step - opt_accuracy: 0.8926 - sar_accuracy: 0.8331 - fus_accuracy: 0.8615 - opt_loss: 0.0576 - sar_loss: 0.0902 - fusion_loss: 0.1102 - loss: 0.2580 - val_opt_accuracy: 0.8594 - val_sar_accuracy: 0.8149 - val_fus_accuracy: 0.8396 - val_opt_loss: 0.1481 - val_sar_loss: 0.1352 - val_fusion_loss: 0.2123 - val_loss: 0.4955
#
# Epoch 00012: val_loss did not improve from 0.39425
# Epoch 13/100
# 108/108 [==============================] - 40s 367ms/step - opt_accuracy: 0.8942 - sar_accuracy: 0.8348 - fus_accuracy: 0.8633 - opt_loss: 0.0564 - sar_loss: 0.0882 - fusion_loss: 0.1076 - loss: 0.2523 - val_opt_accuracy: 0.8544 - val_sar_accuracy: 0.8138 - val_fus_accuracy: 0.8401 - val_opt_loss: 0.1369 - val_sar_loss: 0.1272 - val_fusion_loss: 0.2224 - val_loss: 0.4865
#
# Epoch 00013: val_loss did not improve from 0.39425
# Epoch 14/100
# 108/108 [==============================] - 40s 373ms/step - opt_accuracy: 0.8968 - sar_accuracy: 0.8350 - fus_accuracy: 0.8639 - opt_loss: 0.0542 - sar_loss: 0.0892 - fusion_loss: 0.1087 - loss: 0.2521 - val_opt_accuracy: 0.8591 - val_sar_accuracy: 0.8129 - val_fus_accuracy: 0.8396 - val_opt_loss: 0.1337 - val_sar_loss: 0.1167 - val_fusion_loss: 0.2123 - val_loss: 0.4627
#
# Epoch 00014: val_loss did not improve from 0.39425
# Epoch 15/100
# 108/108 [==============================] - 40s 369ms/step - opt_accuracy: 0.8993 - sar_accuracy: 0.8418 - fus_accuracy: 0.8674 - opt_loss: 0.0518 - sar_loss: 0.0835 - fusion_loss: 0.1036 - loss: 0.2390 - val_opt_accuracy: 0.8629 - val_sar_accuracy: 0.8142 - val_fus_accuracy: 0.8447 - val_opt_loss: 0.1438 - val_sar_loss: 0.1346 - val_fusion_loss: 0.2184 - val_loss: 0.4968
#
# Epoch 00015: val_loss did not improve from 0.39425
# Epoch 16/100
# 108/108 [==============================] - 40s 368ms/step - opt_accuracy: 0.9010 - sar_accuracy: 0.8455 - fus_accuracy: 0.8692 - opt_loss: 0.0512 - sar_loss: 0.0814 - fusion_loss: 0.1024 - loss: 0.2350 - val_opt_accuracy: 0.8635 - val_sar_accuracy: 0.8236 - val_fus_accuracy: 0.8457 - val_opt_loss: 0.1254 - val_sar_loss: 0.1435 - val_fusion_loss: 0.2370 - val_loss: 0.5058
#
# Epoch 00016: val_loss did not improve from 0.39425
# Epoch 17/100
# 108/108 [==============================] - 40s 370ms/step - opt_accuracy: 0.9020 - sar_accuracy: 0.8486 - fus_accuracy: 0.8708 - opt_loss: 0.0495 - sar_loss: 0.0793 - fusion_loss: 0.1007 - loss: 0.2295 - val_opt_accuracy: 0.8643 - val_sar_accuracy: 0.8230 - val_fus_accuracy: 0.8447 - val_opt_loss: 0.1462 - val_sar_loss: 0.1455 - val_fusion_loss: 0.2006 - val_loss: 0.4922
#
# Epoch 00017: val_loss did not improve from 0.39425
# Epoch 18/100
# 108/108 [==============================] - 40s 368ms/step - opt_accuracy: 0.9038 - sar_accuracy: 0.8504 - fus_accuracy: 0.8721 - opt_loss: 0.0485 - sar_loss: 0.0784 - fusion_loss: 0.1006 - loss: 0.2275 - val_opt_accuracy: 0.8668 - val_sar_accuracy: 0.8203 - val_fus_accuracy: 0.8442 - val_opt_loss: 0.1164 - val_sar_loss: 0.1386 - val_fusion_loss: 0.2220 - val_loss: 0.4770
#
# Epoch 00018: val_loss did not improve from 0.39425
# Epoch 00018: early stopping
# time:  4
# Model: "model_4_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 35s - opt_accuracy: 0.6669 - sar_accuracy: 0.6512 - fus_accuracy: 0.6305 - opt_loss: 0.1669 - sar_loss: 0.1733 - fusion_loss: 0.9254 - loss: 1.2656WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1322s vs `on_train_batch_end` time: 0.2170s). Check your callbacks.
# 108/108 [==============================] - 43s 374ms/step - opt_accuracy: 0.7949 - sar_accuracy: 0.7257 - fus_accuracy: 0.7001 - opt_loss: 0.1116 - sar_loss: 0.1458 - fusion_loss: 0.2675 - loss: 0.5249 - val_opt_accuracy: 0.8587 - val_sar_accuracy: 0.7873 - val_fus_accuracy: 0.7146 - val_opt_loss: 0.0868 - val_sar_loss: 0.1181 - val_fusion_loss: 0.1837 - val_loss: 0.3886
#
# Epoch 00001: val_loss improved from inf to 0.38855, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 2/100
# 108/108 [==============================] - 40s 370ms/step - opt_accuracy: 0.8605 - sar_accuracy: 0.7659 - fus_accuracy: 0.7012 - opt_loss: 0.0814 - sar_loss: 0.1292 - fusion_loss: 0.1511 - loss: 0.3617 - val_opt_accuracy: 0.8607 - val_sar_accuracy: 0.7813 - val_fus_accuracy: 0.7336 - val_opt_loss: 0.0911 - val_sar_loss: 0.1269 - val_fusion_loss: 0.1846 - val_loss: 0.4026
#
# Epoch 00002: val_loss did not improve from 0.38855
# Epoch 3/100
# 108/108 [==============================] - 40s 371ms/step - opt_accuracy: 0.8673 - sar_accuracy: 0.7819 - fus_accuracy: 0.7343 - opt_loss: 0.0771 - sar_loss: 0.1189 - fusion_loss: 0.1379 - loss: 0.3339 - val_opt_accuracy: 0.8544 - val_sar_accuracy: 0.7849 - val_fus_accuracy: 0.7231 - val_opt_loss: 0.1087 - val_sar_loss: 0.1273 - val_fusion_loss: 0.1865 - val_loss: 0.4224
#
# Epoch 00003: val_loss did not improve from 0.38855
# Epoch 4/100
# 108/108 [==============================] - 40s 370ms/step - opt_accuracy: 0.8721 - sar_accuracy: 0.7946 - fus_accuracy: 0.7662 - opt_loss: 0.0740 - sar_loss: 0.1126 - fusion_loss: 0.1299 - loss: 0.3165 - val_opt_accuracy: 0.8603 - val_sar_accuracy: 0.7999 - val_fus_accuracy: 0.7689 - val_opt_loss: 0.0941 - val_sar_loss: 0.1201 - val_fusion_loss: 0.1771 - val_loss: 0.3913
#
# Epoch 00004: val_loss did not improve from 0.38855
# Epoch 5/100
# 108/108 [==============================] - 40s 372ms/step - opt_accuracy: 0.8757 - sar_accuracy: 0.8078 - fus_accuracy: 0.8230 - opt_loss: 0.0726 - sar_loss: 0.1068 - fusion_loss: 0.1251 - loss: 0.3045 - val_opt_accuracy: 0.8589 - val_sar_accuracy: 0.8084 - val_fus_accuracy: 0.8169 - val_opt_loss: 0.0984 - val_sar_loss: 0.1206 - val_fusion_loss: 0.1620 - val_loss: 0.3810
#
# Epoch 00005: val_loss improved from 0.38855 to 0.38100, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 6/100
# 108/108 [==============================] - 41s 380ms/step - opt_accuracy: 0.8805 - sar_accuracy: 0.8157 - fus_accuracy: 0.8475 - opt_loss: 0.0692 - sar_loss: 0.1021 - fusion_loss: 0.1209 - loss: 0.2921 - val_opt_accuracy: 0.8552 - val_sar_accuracy: 0.8069 - val_fus_accuracy: 0.8357 - val_opt_loss: 0.1052 - val_sar_loss: 0.1167 - val_fusion_loss: 0.1603 - val_loss: 0.3821
#
# Epoch 00006: val_loss did not improve from 0.38100
# Epoch 7/100
# 108/108 [==============================] - 40s 373ms/step - opt_accuracy: 0.8824 - sar_accuracy: 0.8194 - fus_accuracy: 0.8511 - opt_loss: 0.0678 - sar_loss: 0.1009 - fusion_loss: 0.1195 - loss: 0.2881 - val_opt_accuracy: 0.8512 - val_sar_accuracy: 0.8084 - val_fus_accuracy: 0.8377 - val_opt_loss: 0.0992 - val_sar_loss: 0.1153 - val_fusion_loss: 0.1715 - val_loss: 0.3859
#
# Epoch 00007: val_loss did not improve from 0.38100
# Epoch 8/100
# 108/108 [==============================] - 40s 373ms/step - opt_accuracy: 0.8842 - sar_accuracy: 0.8248 - fus_accuracy: 0.8546 - opt_loss: 0.0670 - sar_loss: 0.0984 - fusion_loss: 0.1187 - loss: 0.2842 - val_opt_accuracy: 0.8579 - val_sar_accuracy: 0.8113 - val_fus_accuracy: 0.8409 - val_opt_loss: 0.1021 - val_sar_loss: 0.1304 - val_fusion_loss: 0.1785 - val_loss: 0.4111
#
# Epoch 00008: val_loss did not improve from 0.38100
# Epoch 9/100
# 108/108 [==============================] - 40s 373ms/step - opt_accuracy: 0.8865 - sar_accuracy: 0.8269 - fus_accuracy: 0.8561 - opt_loss: 0.0647 - sar_loss: 0.0963 - fusion_loss: 0.1160 - loss: 0.2770 - val_opt_accuracy: 0.8519 - val_sar_accuracy: 0.8189 - val_fus_accuracy: 0.8428 - val_opt_loss: 0.1076 - val_sar_loss: 0.1198 - val_fusion_loss: 0.1867 - val_loss: 0.4141
#
# Epoch 00009: val_loss did not improve from 0.38100
# Epoch 10/100
# 108/108 [==============================] - 40s 374ms/step - opt_accuracy: 0.8881 - sar_accuracy: 0.8318 - fus_accuracy: 0.8575 - opt_loss: 0.0626 - sar_loss: 0.0935 - fusion_loss: 0.1130 - loss: 0.2691 - val_opt_accuracy: 0.8570 - val_sar_accuracy: 0.8183 - val_fus_accuracy: 0.8429 - val_opt_loss: 0.0993 - val_sar_loss: 0.1294 - val_fusion_loss: 0.1748 - val_loss: 0.4035
#
# Epoch 00010: val_loss did not improve from 0.38100
# Epoch 11/100
# 108/108 [==============================] - 40s 374ms/step - opt_accuracy: 0.8894 - sar_accuracy: 0.8359 - fus_accuracy: 0.8606 - opt_loss: 0.0613 - sar_loss: 0.0914 - fusion_loss: 0.1120 - loss: 0.2647 - val_opt_accuracy: 0.8588 - val_sar_accuracy: 0.8219 - val_fus_accuracy: 0.8506 - val_opt_loss: 0.1036 - val_sar_loss: 0.1209 - val_fusion_loss: 0.2191 - val_loss: 0.4436
#
# Epoch 00011: val_loss did not improve from 0.38100
# Epoch 12/100
# 108/108 [==============================] - 41s 376ms/step - opt_accuracy: 0.8917 - sar_accuracy: 0.8387 - fus_accuracy: 0.8629 - opt_loss: 0.0594 - sar_loss: 0.0886 - fusion_loss: 0.1095 - loss: 0.2575 - val_opt_accuracy: 0.8618 - val_sar_accuracy: 0.8141 - val_fus_accuracy: 0.8464 - val_opt_loss: 0.0898 - val_sar_loss: 0.1145 - val_fusion_loss: 0.1997 - val_loss: 0.4039
#
# Epoch 00012: val_loss did not improve from 0.38100
# Epoch 13/100
# 108/108 [==============================] - 41s 376ms/step - opt_accuracy: 0.8940 - sar_accuracy: 0.8424 - fus_accuracy: 0.8648 - opt_loss: 0.0580 - sar_loss: 0.0870 - fusion_loss: 0.1080 - loss: 0.2530 - val_opt_accuracy: 0.8544 - val_sar_accuracy: 0.8198 - val_fus_accuracy: 0.8458 - val_opt_loss: 0.0955 - val_sar_loss: 0.1202 - val_fusion_loss: 0.1951 - val_loss: 0.4108
#
# Epoch 00013: val_loss did not improve from 0.38100
# Epoch 14/100
# 108/108 [==============================] - 41s 375ms/step - opt_accuracy: 0.8959 - sar_accuracy: 0.8393 - fus_accuracy: 0.8646 - opt_loss: 0.0552 - sar_loss: 0.0874 - fusion_loss: 0.1066 - loss: 0.2492 - val_opt_accuracy: 0.8547 - val_sar_accuracy: 0.8166 - val_fus_accuracy: 0.8412 - val_opt_loss: 0.1303 - val_sar_loss: 0.1239 - val_fusion_loss: 0.1856 - val_loss: 0.4398
#
# Epoch 00014: val_loss did not improve from 0.38100
# Epoch 15/100
# 108/108 [==============================] - 40s 374ms/step - opt_accuracy: 0.8976 - sar_accuracy: 0.8449 - fus_accuracy: 0.8669 - opt_loss: 0.0546 - sar_loss: 0.0853 - fusion_loss: 0.1058 - loss: 0.2458 - val_opt_accuracy: 0.8482 - val_sar_accuracy: 0.8196 - val_fus_accuracy: 0.8426 - val_opt_loss: 0.1148 - val_sar_loss: 0.1313 - val_fusion_loss: 0.1955 - val_loss: 0.4416
#
# Epoch 00015: val_loss did not improve from 0.38100
# Epoch 00015: early stopping

# %%
# Test loop
time_ts = []
n_pool = 3
n_rows = 20 #5
n_cols = 16 #4
rows, cols = image_array.shape[:2]
pad_rows = rows - np.ceil(rows/(n_rows*2**n_pool))*n_rows*2**n_pool
pad_cols = cols - np.ceil(cols/(n_cols*2**n_pool))*n_cols*2**n_pool
print(pad_rows, pad_cols)

npad = ((0, int(abs(pad_rows))), (0, int(abs(pad_cols))), (0, 0))
image1_pad = np.pad(image_array, pad_width=npad, mode='reflect')

h, w, c = image1_pad.shape
patch_size_rows = h//n_rows
patch_size_cols = w//n_cols
num_patches_x = int(h/patch_size_rows)
num_patches_y = int(w/patch_size_cols)

input_shape=(patch_size_rows,patch_size_cols, c)

#if method == 'unet':
#   new_model = build_unet(input_shape, nb_filters, number_class)

#if method == 'resunet':
#   new_model = build_resunet(input_shape, nb_filters, number_class)

new_model = Model_4(nb_filters, number_class, n_opt_layers)
new_model.build((None,)+input_shape)
adam = Adam(lr = 1e-3 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
new_model.compile(optimizer=adam, loss=loss, metrics=['accuracy'], run_eagerly=True)

for tm in range(0,times):
    print('time: ', tm)
    #model = load_model(path_models+ '/' + method +'_'+str(tm)+'.h5', compile=False)
    
    #for l in range(1, len(model.layers)):
    #    new_model.layers[l].set_weights(model.layers[l].get_weights())
    new_model.load_weights(path_models+ '/' + method +'_'+str(tm)+'.h5')
    
    start_test = time.time()
    patch_opt = []
    patch_sar = []
    patch_fus = []
    patch_comb = []
    
    for i in range(0,num_patches_y):
        for j in range(0,num_patches_x):
            patch = image1_pad[patch_size_rows*j:patch_size_rows*(j+1), patch_size_cols*i:patch_size_cols*(i+1), :]
            pred_opt, pred_sar, pred_fus, pred_comb = new_model.predict(np.expand_dims(patch, axis=0))
            del patch 
            patch_opt.append(pred_opt[:,:,:,1])
            patch_sar.append(pred_sar[:,:,:,1])
            patch_fus.append(pred_fus[:,:,:,1])
            patch_comb.append(pred_comb[:,:,:,1])
            del pred_opt, pred_sar, pred_fus, pred_comb
    end_test =  time.time() - start_test

    patches_pred_opt = np.asarray(patch_opt).astype(np.float32)
    patches_pred_sar = np.asarray(patch_sar).astype(np.float32)
    patches_pred_fus = np.asarray(patch_fus).astype(np.float32)
    patches_pred_comb = np.asarray(patch_comb).astype(np.float32)

    prob_recontructed_opt = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_opt)
    prob_recontructed_sar = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_sar)
    prob_recontructed_fus = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_fus)
    prob_recontructed_comb = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_comb)

    del patches_pred_opt, patches_pred_sar, patches_pred_fus, patches_pred_comb
    np.save(path_maps+'/'+'prob_opt_'+str(tm)+'.npy',prob_recontructed_opt) 
    np.save(path_maps+'/'+'prob_sar_'+str(tm)+'.npy',prob_recontructed_sar) 
    np.save(path_maps+'/'+'prob_fus_'+str(tm)+'.npy',prob_recontructed_fus) 
    np.save(path_maps+'/'+'prob_comb_'+str(tm)+'.npy',prob_recontructed_comb) 

    time_ts.append(end_test)
    del prob_recontructed_opt, prob_recontructed_sar, prob_recontructed_fus, prob_recontructed_comb
    #del model
time_ts_array = np.asarray(time_ts)
# Save test time
np.save(path_exp+'/metrics_ts.npy', time_ts_array)
# Out:
# -80.0 -40.0
# time:  0
# time:  1
# time:  2
# time:  3
# time:  4

# %%
# Compute mean of the tm predictions maps
prob_rec_opt = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_sar = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_fus = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_comb = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))

for tm in range (0, times):
    print(tm)
    prob_rec_opt[:,:,tm] = np.load(path_maps+'/'+'prob_opt_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_sar[:,:,tm] = np.load(path_maps+'/'+'prob_sar_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_fus[:,:,tm] = np.load(path_maps+'/'+'prob_fus_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_comb[:,:,tm] = np.load(path_maps+'/'+'prob_comb_'+str(tm)+'.npy').astype(np.float32)

mean_prob_opt = np.mean(prob_rec_opt, axis = -1)
mean_prob_sar = np.mean(prob_rec_sar, axis = -1)
mean_prob_fus = np.mean(prob_rec_fus, axis = -1)
mean_prob_comb = np.mean(prob_rec_comb, axis = -1)

np.save(path_maps+'/prob_mean_opt.npy', mean_prob_opt)
np.save(path_maps+'/prob_mean_sar.npy', mean_prob_sar)
np.save(path_maps+'/prob_mean_fus.npy', mean_prob_fus)
np.save(path_maps+'/prob_mean_comb.npy', mean_prob_comb)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Plot mean map and reference
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(151)
plt.title('OPT Prediction')
ax1.imshow(mean_prob_opt, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(152)
plt.title('SAR Prediction')
ax1.imshow(mean_prob_sar, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(153)
plt.title('FUSION Prediction')
ax1.imshow(mean_prob_fus, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(154)
plt.title('COMBINATION Prediction')
ax1.imshow(mean_prob_comb, cmap ='jet')
ax1.axis('off')

ax2 = fig.add_subplot(155)
plt.title('Reference')
ax2.imshow(tf.keras.utils.to_categorical(final_mask1, 3)[:,:,1], cmap ='jet')
ax2.axis('off')
# Out:
# (-0.5, 6999.5, 9999.5, -0.5)

# %%
# Computing metrics
mean_prob_opt = mean_prob_opt[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_sar = mean_prob_sar[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_fus = mean_prob_fus[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_comb = mean_prob_comb[:final_mask1.shape[0], :final_mask1.shape[1]]

ref1 = np.ones_like(final_mask1).astype(np.float32)

ref1 [final_mask1 == 2] = 0
TileMask = mask_amazon_ts * ref1
GTTruePositives = final_mask1==1
    
Npoints = 50

Pmax_opt = np.max(mean_prob_opt[GTTruePositives * TileMask ==1])
ProbList_opt = np.linspace(Pmax_opt,0,Npoints)

Pmax_sar = np.max(mean_prob_sar[GTTruePositives * TileMask ==1])
ProbList_sar = np.linspace(Pmax_sar,0,Npoints)

Pmax_fus = np.max(mean_prob_fus[GTTruePositives * TileMask ==1])
ProbList_fus = np.linspace(Pmax_fus,0,Npoints)

Pmax_comb = np.max(mean_prob_comb[GTTruePositives * TileMask ==1])
ProbList_comb = np.linspace(Pmax_comb,0,Npoints)


from multiprocessing.pool import Pool
pool = Pool(processes=4)

async_result_opt = pool.apply_async(matrics_AA_recall, (ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625))
async_result_sar = pool.apply_async(matrics_AA_recall, (ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625))
async_result_fus = pool.apply_async(matrics_AA_recall, (ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625))
async_result_comb = pool.apply_async(matrics_AA_recall, (ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625))

metrics_opt = async_result_opt.get()
metrics_sar = async_result_sar.get()
metrics_fus = async_result_fus.get()
metrics_comb = async_result_comb.get()
    
#metrics_opt = matrics_AA_recall(ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625)
#metrics_sar = matrics_AA_recall(ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625)
#metrics_fus = matrics_AA_recall(ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625)
#metrics_comb = matrics_AA_recall(ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625)

np.save(path_exp+'/acc_metrics_opt.npy',metrics_opt)
np.save(path_exp+'/acc_metrics_sar.npy',metrics_sar)
np.save(path_exp+'/acc_metrics_fus.npy',metrics_fus)
np.save(path_exp+'/acc_metrics_comb.npy',metrics_comb)

# %%
# Complete NaN values
metrics_copy_opt = metrics_opt.copy()
metrics_copy_opt = complete_nan_values(metrics_copy_opt)

metrics_copy_sar = metrics_sar.copy()
metrics_copy_sar = complete_nan_values(metrics_copy_sar)

metrics_copy_fus = metrics_fus.copy()
metrics_copy_fus = complete_nan_values(metrics_copy_fus)

metrics_copy_comb = metrics_comb.copy()
metrics_copy_comb = complete_nan_values(metrics_copy_comb)

# %%
# Comput Mean Average Precision (mAP) score 
Recall_opt = metrics_copy_opt[:,0]
Precision_opt = metrics_copy_opt[:,1]
AA_opt = metrics_copy_opt[:,2]

Recall_sar = metrics_copy_sar[:,0]
Precision_sar = metrics_copy_sar[:,1]
AA_sar = metrics_copy_sar[:,2]

Recall_fus = metrics_copy_fus[:,0]
Precision_fus = metrics_copy_fus[:,1]
AA_fus = metrics_copy_fus[:,2]

Recall_comb = metrics_copy_comb[:,0]
Precision_comb = metrics_copy_comb[:,1]
AA_comb = metrics_copy_comb[:,2]
    
DeltaR_opt = Recall_opt[1:]-Recall_opt[:-1]
AP_opt = np.sum(Precision_opt[:-1]*DeltaR_opt)
print('OPT mAP', AP_opt)

DeltaR_sar = Recall_sar[1:]-Recall_sar[:-1]
AP_sar = np.sum(Precision_sar[:-1]*DeltaR_sar)
print('SAR mAP', AP_sar)

DeltaR_fus = Recall_fus[1:]-Recall_fus[:-1]
AP_fus = np.sum(Precision_fus[:-1]*DeltaR_fus)
print('FUSION mAP', AP_fus)

DeltaR_comb = Recall_comb[1:]-Recall_comb[:-1]
AP_comb = np.sum(Precision_comb[:-1]*DeltaR_comb)
print('COMBINATION mAP', AP_comb)

# Plot Recall vs. Precision curve
plt.figure(figsize=(7,7))
plt.plot(metrics_copy_opt[:,0],metrics_copy_opt[:,1], 'r-', label = f'OPT (AP: {AP_opt:.4f})')
plt.plot(metrics_copy_sar[:,0],metrics_copy_sar[:,1], 'g-', label = f'SAR (AP: {AP_sar:.4f})')
plt.plot(metrics_copy_fus[:,0],metrics_copy_fus[:,1], 'b-', label = f'FUSION (AP: {AP_fus:.4f})')
plt.plot(metrics_copy_comb[:,0],metrics_copy_comb[:,1], 'k-', label = f'COMBINATION (AP: {AP_comb:.4f})')
plt.legend(loc="lower left")
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([0,1])
#plt.plot(metrics_copy[:,0],metrics_copy[:,2])
plt.grid()
# Out:
# OPT mAP 0.9556114617156337
# SAR mAP 0.8582330920783677
# FUSION mAP 0.962051902906724
# COMBINATION mAP 0.9586253434598909
