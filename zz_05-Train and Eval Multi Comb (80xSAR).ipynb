# %%
# %load_ext autoreload
# %autoreload 2

# %%
#%autoreload # When utils.py is updated
from utils_unet_resunet import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from model.models import Model_3
from model.losses import WBCE
from model.callbacks import UpdateWeights
from multiprocessing.pool import Pool

root_path = 'imgs/'

# %%
# Define data type 
img_type = 'FUSION'

if img_type == 'FUSION':
    image_array = np.load(root_path+'New_Images/fus_stack.npy')
    

if img_type == 'OPT':
    image_array = np.load(root_path+'New_Images/opt_stack.npy')
    
    
if img_type == 'SAR':
    image_array = np.load(root_path+'New_Images/sar_stack.npy')
print('Image stack:', image_array.shape)

final_mask1 = np.load(root_path+'New_Images/'+'final_mask1.npy')
print('Labels stack:', final_mask1.shape)

h_, w_, channels = image_array.shape
n_opt_layers = 20
# Out:
# Image stack: (10000, 7000, 24)
# Labels stack: (10000, 7000)

# %%
# Create tile mask
mask_tiles = create_mask(final_mask1.shape[0], final_mask1.shape[1], grid_size=(5, 4))
image_array = image_array[:mask_tiles.shape[0], :mask_tiles.shape[1],:]
final_mask1 = final_mask1[:mask_tiles.shape[0], :mask_tiles.shape[1]]

print('mask: ',mask_tiles.shape)
print('image stack: ', image_array.shape)
print('ref :', final_mask1.shape)
#plt.imshow(mask_tiles)
# Out:
# Tiles size:  2000 1750
# Mask size:  (10000, 7000)
# mask:  (10000, 7000)
# image stack:  (10000, 7000, 24)
# ref : (10000, 7000)

# %%
plt.figure(figsize=(10,5))
plt.imshow(final_mask1, cmap = 'jet')

# %%
# Define tiles for training, validation, and test sets
tiles_tr = [1,3,5,8,11,13,14,20]
tiles_val = [6,19]
tiles_ts = (list(set(np.arange(20)+1)-set(tiles_tr)-set(tiles_val)))

mask_tr_val = np.zeros((mask_tiles.shape)).astype('float32')
# Training and validation mask
for tr_ in tiles_tr:
    mask_tr_val[mask_tiles == tr_] = 1

for val_ in tiles_val:
    mask_tr_val[mask_tiles == val_] = 2

mask_amazon_ts = np.zeros((mask_tiles.shape)).astype('float32')
for ts_ in tiles_ts:
    mask_amazon_ts[mask_tiles == ts_] = 1

# %%
# Create ixd image to extract patches
overlap = 0.7
patch_size = 128
batch_size = 32
im_idx = create_idx_image(final_mask1)
patches_idx = extract_patches(im_idx, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1,patch_size, patch_size)
patches_mask = extract_patches(mask_tr_val, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1, patch_size, patch_size)
del im_idx

# %%
# Selecting index trn val and test patches idx
idx_trn = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==patch_size**2))
idx_val = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==2*patch_size**2))
del patches_mask

patches_idx_trn = patches_idx[idx_trn]
patches_idx_val = patches_idx[idx_val]
del idx_trn, idx_val

print('Number of training patches:  ', len(patches_idx_trn), 'Number of validation patches', len(patches_idx_val))
# Out:
# Number of training patches:   17110 Number of validation patches 4116

# %%
# Extract patches with at least 2% of deforestation class
X_train = retrieve_idx_percentage(final_mask1, patches_idx_trn, patch_size, pertentage = 2)
X_valid = retrieve_idx_percentage(final_mask1, patches_idx_val, patch_size, pertentage = 2)
print(X_train.shape, X_valid.shape)
del patches_idx_trn, patches_idx_val
# Out:
# (1158, 128, 128) (341, 128, 128)

# %%
def batch_generator(batches, image, reference, target_size, number_class):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    image = image.reshape(-1, image.shape[-1])
    reference = reference.reshape(final_mask1.shape[0]*final_mask1.shape[1])
    while True:
        batch_x, batch_y = next(batches)
        batch_x = np.squeeze(batch_x.astype('int64'))
        #print(batch_x.shape)
        batch_img = np.zeros((batch_x.shape[0], target_size, target_size, image.shape[-1]))
        batch_ref = np.zeros((batch_x.shape[0], target_size, target_size, number_class))
        
        for i in range(batch_x.shape[0]):
            if np.random.rand()>0.5:
                batch_x[i] = np.rot90(batch_x[i], 1)
            batch_img[i] = image[batch_x[i]] 
            batch_ref[i] = tf.keras.utils.to_categorical(reference[batch_x[i]] , number_class)
                       
        yield (batch_img, batch_ref)

train_datagen = ImageDataGenerator(horizontal_flip = True,
                                   vertical_flip = True)
valid_datagen = ImageDataGenerator(horizontal_flip = True, 
                                   vertical_flip = True)

y_train = np.zeros((len(X_train)))
y_valid = np.zeros((len(X_valid)))

train_gen = train_datagen.flow(np.expand_dims(X_train, axis = -1), y_train,
                              batch_size=batch_size,
                              shuffle=True)

valid_gen = valid_datagen.flow(np.expand_dims(X_valid, axis = -1), y_valid,
                              batch_size=batch_size,
                              shuffle=False)

number_class = 3
train_gen_crops = batch_generator(train_gen, image_array, final_mask1, patch_size, number_class)
valid_gen_crops = batch_generator(valid_gen, image_array, final_mask1, patch_size, number_class)

# %%
exp = 3
path_exp = root_path+'experiments/exp'+str(exp)
path_models = path_exp+'/models'
path_maps = path_exp+'/pred_maps'

if not os.path.exists(path_exp):
    os.makedirs(path_exp)   
if not os.path.exists(path_models):
    os.makedirs(path_models)   
if not os.path.exists(path_maps):
    os.makedirs(path_maps)

# %%
# Define model
input_shape = (patch_size, patch_size, channels)
nb_filters = [32, 64, 128]

method = 'unet'
if method == 'unet':
   model = build_unet(input_shape, nb_filters, number_class)

if method == 'resunet':
   model = build_resunet(input_shape, nb_filters, number_class)

model = Model_3(nb_filters, number_class, n_opt_layers)

# %%
# Parameters of the model
weights = [0.2, 0.8, 0]
adam = Adam(lr = 1e-5 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
#loss = WBCE(weights = weights)
#loss = WBCE(weights = weights, class_indexes = [0, 1])

# %%
metrics_all = []
times=5
for tm in range(0,times):
    print('time: ', tm)

    rows = patch_size
    cols = patch_size
    adam = Adam(lr = 1e-5 , beta_1=0.9)
    
    loss = weighted_categorical_crossentropy(weights)
    #loss = WBCE(weights = weights)
    #loss = WBCE(weights = weights, class_indexes = [0, 1])

    #if method == 'unet':
    #   model = build_unet(input_shape, nb_filters, number_class)

    #if method == 'resunet':
    #   model = build_resunet(input_shape, nb_filters, number_class)
    
    model = Model_3(nb_filters, number_class, n_opt_layers)
    model.build((None,)+input_shape)
    
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    model.summary()

    earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
    #earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min') ---- val_accuracy
    #checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
    lr_reduce = ReduceLROnPlateau(factor=0.9, min_delta=0.0001, patience=5, verbose=1)
    updateWeights = UpdateWeights()
    callbacks_list = [earlystop, checkpoint, updateWeights]
    # train the model
    start_training = time.time()
    history = model.fit(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    end_training = time.time() - start_training
    metrics_all.append(end_training)
    del model, history
# Out:
# time:  0
# Model: "model_3_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 27s 165ms/step - opt_accuracy: 0.6815 - sar_accuracy: 0.6451 - fus_accuracy: 0.6076 - opt_loss: 0.1790 - sar_loss: 13.9242 - fusion_loss: 0.2406 - loss: 14.3438 - val_opt_accuracy: 0.7894 - val_sar_accuracy: 0.6906 - val_fus_accuracy: 0.6595 - val_opt_loss: 0.1186 - val_sar_loss: 11.0707 - val_fusion_loss: 0.1457 - val_loss: 11.3349
#
# Epoch 00001: val_loss improved from inf to 11.33492, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 2/100
# 108/108 [==============================] - 15s 141ms/step - opt_accuracy: 0.7373 - sar_accuracy: 0.6690 - fus_accuracy: 0.6683 - opt_loss: 0.1433 - sar_loss: 12.7440 - fusion_loss: 0.1909 - loss: 13.0782 - val_opt_accuracy: 0.8427 - val_sar_accuracy: 0.7116 - val_fus_accuracy: 0.6714 - val_opt_loss: 0.1055 - val_sar_loss: 10.5515 - val_fusion_loss: 0.1322 - val_loss: 10.7892
#
# Epoch 00002: val_loss improved from 11.33492 to 10.78918, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 3/100
# 108/108 [==============================] - 15s 142ms/step - opt_accuracy: 0.7765 - sar_accuracy: 0.6924 - fus_accuracy: 0.6896 - opt_loss: 0.1211 - sar_loss: 12.1752 - fusion_loss: 0.1697 - loss: 12.4659 - val_opt_accuracy: 0.8570 - val_sar_accuracy: 0.7617 - val_fus_accuracy: 0.6910 - val_opt_loss: 0.0969 - val_sar_loss: 9.9243 - val_fusion_loss: 0.1217 - val_loss: 10.1429
# Epoch 9/100
# 108/108 [==============================] - 15s 142ms/step - opt_accuracy: 0.8329 - sar_accuracy: 0.7313 - fus_accuracy: 0.7492 - opt_loss: 0.0974 - sar_loss: 11.0819 - fusion_loss: 0.1306 - loss: 11.3099 - val_opt_accuracy: 0.8624 - val_sar_accuracy: 0.7834 - val_fus_accuracy: 0.7810 - val_opt_loss: 0.1060 - val_sar_loss: 9.5447 - val_fusion_loss: 0.1358 - val_loss: 9.7865
#
# Epoch 00009: val_loss improved from 9.79759 to 9.78649, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 10/100
# 108/108 [==============================] - 15s 143ms/step - opt_accuracy: 0.8365 - sar_accuracy: 0.7345 - fus_accuracy: 0.7560 - opt_loss: 0.0950 - sar_loss: 10.8889 - fusion_loss: 0.1265 - loss: 11.1104 - val_opt_accuracy: 0.8625 - val_sar_accuracy: 0.7872 - val_fus_accuracy: 0.7969 - val_opt_loss: 0.1081 - val_sar_loss: 9.5386 - val_fusion_loss: 0.1350 - val_loss: 9.7817
#
# Epoch 00010: val_loss improved from 9.78649 to 9.78167, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 11/100
# 108/108 [==============================] - 15s 142ms/step - opt_accuracy: 0.8394 - sar_accuracy: 0.7364 - fus_accuracy: 0.7620 - opt_loss: 0.0943 - sar_loss: 10.8513 - fusion_loss: 0.1238 - loss: 11.0695 - val_opt_accuracy: 0.8619 - val_sar_accuracy: 0.7865 - val_fus_accuracy: 0.8094 - val_opt_loss: 0.1093 - val_sar_loss: 9.5199 - val_fusion_loss: 0.1324 - val_loss: 9.7617
#
# Epoch 00011: val_loss improved from 9.78167 to 9.76166, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 12/100
# 108/108 [==============================] - 15s 142ms/step - opt_accuracy: 0.8402 - sar_accuracy: 0.7394 - fus_accuracy: 0.7677 - opt_loss: 0.0930 - sar_loss: 10.6886 - fusion_loss: 0.1202 - loss: 10.9018 - val_opt_accuracy: 0.8625 - val_sar_accuracy: 0.7900 - val_fus_accuracy: 0.8167 - val_opt_loss: 0.1109 - val_sar_loss: 9.2937 - val_fusion_loss: 0.1395 - val_loss: 9.5441
#
# Epoch 00012: val_loss improved from 9.76166 to 9.54409, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 13/100
# 108/108 [==============================] - 15s 143ms/step - opt_accuracy: 0.8425 - sar_accuracy: 0.7421 - fus_accuracy: 0.7729 - opt_loss: 0.0918 - sar_loss: 10.5592 - fusion_loss: 0.1176 - loss: 10.7687 - val_opt_accuracy: 0.8647 - val_sar_accuracy: 0.7893 - val_fus_accuracy: 0.8278 - val_opt_loss: 0.1100 - val_sar_loss: 9.4593 - val_fusion_loss: 0.1351 - val_loss: 9.7044
#
# Epoch 00013: val_loss did not improve from 9.54409
# Epoch 14/100
2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 12s - opt_accuracy: 0.5899 - sar_accuracy: 0.6666 - fus_accuracy: 0.6417 - opt_loss: 0.2208 - sar_loss: 13.9784 - fusion_loss: 0.1774 - loss: 14.3766WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0555s vs `on_train_batch_end` time: 0.0690s). Check your callbacks.
# 108/108 [==============================] - 18s 151ms/step - opt_accuracy: 0.6262 - sar_accuracy: 0.6787 - fus_accuracy: 0.6691 - opt_loss: 0.1850 - sar_loss: 13.1055 - fusion_loss: 0.1596 - loss: 13.4502 - val_opt_accuracy: 0.7147 - val_sar_accuracy: 0.7299 - val_fus_accuracy: 0.8106 - val_opt_loss: 0.1144 - val_sar_loss: 10.1495 - val_fusion_loss: 0.1016 - val_loss: 10.3656
#
# Epoch 00001: val_loss improved from inf to 10.36559, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 2/100
# 108/108 [==============================] - 16s 145ms/step - opt_accuracy: 0.7236 - sar_accuracy: 0.7094 - fus_accuracy: 0.7330 - opt_loss: 0.1309 - sar_loss: 12.2423 - fusion_loss: 0.1336 - loss: 12.5067 - val_opt_accuracy: 0.8235 - val_sar_accuracy: 0.7562 - val_fus_accuracy: 0.8556 - val_opt_loss: 0.0943 - val_sar_loss: 9.8481 - val_fusion_loss: 0.0915 - val_loss: 10.0338
#
# Epoch 00002: val_loss improved from 10.36559 to 10.03384, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 3/100
# 108/108 [==============================] - 16s 146ms/step - opt_accuracy: 0.7646 - sar_accuracy: 0.7230 - fus_accuracy: 0.7582 - opt_loss: 0.1136 - sar_loss: 11.8355 - fusion_loss: 0.1224 - loss: 12.0715 - val_opt_accuracy: 0.8452 - val_sar_accuracy: 0.7595 - val_fus_accuracy: 0.8536 - val_opt_loss: 0.0937 - val_sar_loss: 9.9033 - val_fusion_loss: 0.0950 - val_loss: 10.0921
#
# Epoch 00003: val_loss did not improve from 10.03384
# Epoch 4/100
# 108/108 [==============================] - 16s 146ms/step - opt_accuracy: 0.7855 - sar_accuracy: 0.7255 - fus_accuracy: 0.7681 - opt_loss: 0.1056 - sar_loss: 11.5687 - fusion_loss: 0.1173 - loss: 11.7915 - val_opt_accuracy: 0.8504 - val_sar_accuracy: 0.7647 - val_fus_accuracy: 0.8542 - val_opt_loss: 0.0929 - val_sar_loss: 9.8828 - val_fusion_loss: 0.0946 - val_loss: 10.0702
#
# Epoch 00004: val_loss did not improve from 10.03384
# Epoch 5/100
# 108/108 [==============================] - 16s 147ms/step - opt_accuracy: 0.7996 - sar_accuracy: 0.7297 - fus_accuracy: 0.7725 - opt_loss: 0.0994 - sar_loss: 11.1953 - fusion_loss: 0.1143 - loss: 11.4090 - val_opt_accuracy: 0.8580 - val_sar_accuracy: 0.7733 - val_fus_accuracy: 0.8543 - val_opt_loss: 0.0926 - val_sar_loss: 9.4910 - val_fusion_loss: 0.0974 - val_loss: 9.6810
#
# Epoch 00005: val_loss improved from 10.03384 to 9.68099, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 6/100
# 108/108 [==============================] - 16s 146ms/step - opt_accuracy: 0.8109 - sar_accuracy: 0.7336 - fus_accuracy: 0.7783 - opt_loss: 0.0967 - sar_loss: 11.1289 - fusion_loss: 0.1134 - loss: 11.3390 - val_opt_accuracy: 0.8591 - val_sar_accuracy: 0.7804 - val_fus_accuracy: 0.8578 - val_opt_loss: 0.0930 - val_sar_loss: 9.4623 - val_fusion_loss: 0.0936 - val_loss: 9.6489
#
# Epoch 00006: val_loss improved from 9.68099 to 9.64891, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 7/100
# 108/108 [==============================] - 16s 147ms/step - opt_accuracy: 0.8193 - sar_accuracy: 0.7395 - fus_accuracy: 0.7851 - opt_loss: 0.0927 - sar_loss: 10.7909 - fusion_loss: 0.1099 - loss: 10.9935 - val_opt_accuracy: 0.8595 - val_sar_accuracy: 0.7841 - val_fus_accuracy: 0.8600 - val_opt_loss: 0.0936 - val_sar_loss: 9.5170 - val_fusion_loss: 0.0922 - val_loss: 9.7027
#
# Epoch 00007: val_loss did not improve from 9.64891
# Epoch 8/100
# 108/108 [==============================] - 16s 147ms/step - opt_accuracy: 0.8233 - sar_accuracy: 0.7410 - fus_accuracy: 0.7898 - opt_loss: 0.0917 - sar_loss: 10.7405 - fusion_loss: 0.1085 - loss: 10.9407 - val_opt_accuracy: 0.8597 - val_sar_accuracy: 0.7833 - val_fus_accuracy: 0.8606 - val_opt_loss: 0.0972 - val_sar_loss: 9.4853 - val_fusion_loss: 0.0934 - val_loss: 9.6759
#
# Epoch 00008: val_loss did not improve from 9.64891
# Epoch 9/100
# 108/108 [==============================] - 16s 147ms/step - opt_accuracy: 0.8281 - sar_accuracy: 0.7437 - fus_accuracy: 0.7955 - opt_loss: 0.0895 - sar_loss: 10.6656 - fusion_loss: 0.1063 - loss: 10.8614 - val_opt_accuracy: 0.8578 - val_sar_accuracy: 0.7854 - val_fus_accuracy: 0.8604 - val_opt_loss: 0.1025 - val_sar_loss: 9.4236 - val_fusion_loss: 0.0962 - val_loss: 9.6223
#
# Epoch 00009: val_loss improved from 9.64891 to 9.62230, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 10/100
# Epoch 00021: val_loss did not improve from 9.09240
# Epoch 22/100
# 108/108 [==============================] - 16s 152ms/step - opt_accuracy: 0.8560 - sar_accuracy: 0.7687 - fus_accuracy: 0.8326 - opt_loss: 0.0762 - sar_loss: 9.8096 - fusion_loss: 0.0891 - loss: 9.9749 - val_opt_accuracy: 0.8574 - val_sar_accuracy: 0.7971 - val_fus_accuracy: 0.8616 - val_opt_loss: 0.1061 - val_sar_loss: 9.0071 - val_fusion_loss: 0.1013 - val_loss: 9.2145
#
# Epoch 00022: val_loss did not improve from 9.09240
# Epoch 00022: early stopping
# time:  2
# Model: "model_3_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 13s - opt_accuracy: 0.6432 - sar_accuracy: 0.6259 - fus_accuracy: 0.5748 - opt_loss: 0.1838 - sar_loss: 16.3609 - fusion_loss: 0.2541 - loss: 16.7988WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0590s vs `on_train_batch_end` time: 0.0692s). Check your callbacks.
# 108/108 [==============================] - 19s 153ms/step - opt_accuracy: 0.6746 - sar_accuracy: 0.6473 - fus_accuracy: 0.6367 - opt_loss: 0.1612 - sar_loss: 13.8645 - fusion_loss: 0.1973 - loss: 14.2229 - val_opt_accuracy: 0.7966 - val_sar_accuracy: 0.6893 - val_fus_accuracy: 0.7697 - val_opt_loss: 0.1109 - val_sar_loss: 10.5992 - val_fusion_loss: 0.1129 - val_loss: 10.8231
#
# Epoch 00001: val_loss improved from inf to 10.82311, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 2/100
# 108/108 [==============================] - 16s 151ms/step - opt_accuracy: 0.7725 - sar_accuracy: 0.6645 - fus_accuracy: 0.7260 - opt_loss: 0.1193 - sar_loss: 12.7166 - fusion_loss: 0.1482 - loss: 12.9841 - val_opt_accuracy: 0.8550 - val_sar_accuracy: 0.7199 - val_fus_accuracy: 0.8481 - val_opt_loss: 0.0944 - val_sar_loss: 10.0566 - val_fusion_loss: 0.0942 - val_loss: 10.2452
#
# Epoch 00002: val_loss improved from 10.82311 to 10.24524, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 3/100
# 108/108 [==============================] - 16s 151ms/step - opt_accuracy: 0.8099 - sar_accuracy: 0.6938 - fus_accuracy: 0.7697 - opt_loss: 0.1029 - sar_loss: 12.1992 - fusion_loss: 0.1285 - loss: 12.4306 - val_opt_accuracy: 0.8529 - val_sar_accuracy: 0.7656 - val_fus_accuracy: 0.8525 - val_opt_loss: 0.0969 - val_sar_loss: 10.0479 - val_fusion_loss: 0.0913 - val_loss: 10.2361
#
# Epoch 00031: val_loss did not improve from 9.34055
# Epoch 32/100
# 108/108 [==============================] - 18s 165ms/step - opt_accuracy: 0.8707 - sar_accuracy: 0.7689 - fus_accuracy: 0.8525 - opt_loss: 0.0707 - sar_loss: 10.0072 - fusion_loss: 0.0814 - loss: 10.1593 - val_opt_accuracy: 0.8690 - val_sar_accuracy: 0.8002 - val_fus_accuracy: 0.8671 - val_opt_loss: 0.1074 - val_sar_loss: 9.3819 - val_fusion_loss: 0.1037 - val_loss: 9.5930
#
# Epoch 00032: val_loss did not improve from 9.34055
# Epoch 33/100
# 108/108 [==============================] - 18s 164ms/step - opt_accuracy: 0.8723 - sar_accuracy: 0.7698 - fus_accuracy: 0.8538 - opt_loss: 0.0700 - sar_loss: 10.0002 - fusion_loss: 0.0805 - loss: 10.1508 - val_opt_accuracy: 0.8690 - val_sar_accuracy: 0.7981 - val_fus_accuracy: 0.8670 - val_opt_loss: 0.1016 - val_sar_loss: 9.3325 - val_fusion_loss: 0.0989 - val_loss: 9.5330
#
# Epoch 00033: val_loss did not improve from 9.34055
# Epoch 00033: early stopping
# time:  3
# Model: "model_3_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 22s 178ms/step - opt_accuracy: 0.6219 - sar_accuracy: 0.6794 - fus_accuracy: 0.6422 - opt_loss: 0.1708 - sar_loss: 13.0574 - fusion_loss: 0.2211 - loss: 13.4493 - val_opt_accuracy: 0.7988 - val_sar_accuracy: 0.7200 - val_fus_accuracy: 0.7255 - val_opt_loss: 0.1059 - val_sar_loss: 10.0687 - val_fusion_loss: 0.1190 - val_loss: 10.2937
#
# Epoch 00001: val_loss improved from inf to 10.29366, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 2/100
# 108/108 [==============================] - 18s 166ms/step - opt_accuracy: 0.7591 - sar_accuracy: 0.6963 - fus_accuracy: 0.7223 - opt_loss: 0.1244 - sar_loss: 11.9909 - fusion_loss: 0.1580 - loss: 12.2733 - val_opt_accuracy: 0.8451 - val_sar_accuracy: 0.7517 - val_fus_accuracy: 0.8284 - val_opt_loss: 0.0921 - val_sar_loss: 9.6977 - val_fusion_loss: 0.1001 - val_loss: 9.8900
#
# Epoch 00002: val_loss improved from 10.29366 to 9.88996, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 3/100
# 108/108 [==============================] - 18s 167ms/step - opt_accuracy: 0.8009 - sar_accuracy: 0.7095 - fus_accuracy: 0.7616 - opt_loss: 0.1074 - sar_loss: 11.5791 - fusion_loss: 0.1349 - loss: 11.8214 - val_opt_accuracy: 0.8508 - val_sar_accuracy: 0.7660 - val_fus_accuracy: 0.8443 - val_opt_loss: 0.0925 - val_sar_loss: 9.8823 - val_fusion_loss: 0.0998 - val_loss: 10.0746
# 108/108 [==============================] - 18s 170ms/step - opt_accuracy: 0.8399 - sar_accuracy: 0.7407 - fus_accuracy: 0.8100 - opt_loss: 0.0882 - sar_loss: 10.4069 - fusion_loss: 0.1075 - loss: 10.6025 - val_opt_accuracy: 0.8597 - val_sar_accuracy: 0.7892 - val_fus_accuracy: 0.8562 - val_opt_loss: 0.0944 - val_sar_loss: 9.4914 - val_fusion_loss: 0.0978 - val_loss: 9.6836
#
# Epoch 00009: val_loss improved from 9.77141 to 9.68361, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 10/100
# 108/108 [==============================] - 19s 172ms/step - opt_accuracy: 0.8419 - sar_accuracy: 0.7435 - fus_accuracy: 0.8110 - opt_loss: 0.0864 - sar_loss: 10.2974 - fusion_loss: 0.1058 - loss: 10.4896 - val_opt_accuracy: 0.8595 - val_sar_accuracy: 0.7860 - val_fus_accuracy: 0.8572 - val_opt_loss: 0.0919 - val_sar_loss: 9.5011 - val_fusion_loss: 0.0928 - val_loss: 9.6858
#
# Epoch 00010: val_loss did not improve from 9.68361
# Epoch 11/100
# ...
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 22s 186ms/step - opt_accuracy: 0.6235 - sar_accuracy: 0.6585 - fus_accuracy: 0.6294 - opt_loss: 0.1576 - sar_loss: 13.1866 - fusion_loss: 0.1998 - loss: 13.5439 - val_opt_accuracy: 0.6987 - val_sar_accuracy: 0.7306 - val_fus_accuracy: 0.7741 - val_opt_loss: 0.1109 - val_sar_loss: 10.2901 - val_fusion_loss: 0.1090 - val_loss: 10.5100
#
# Epoch 00001: val_loss improved from inf to 10.50998, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 2/100
# 108/108 [==============================] - 20s 182ms/step - opt_accuracy: 0.7420 - sar_accuracy: 0.7094 - fus_accuracy: 0.7267 - opt_loss: 0.1188 - sar_loss: 12.0050 - fusion_loss: 0.1490 - loss: 12.2729 - val_opt_accuracy: 0.8532 - val_sar_accuracy: 0.7684 - val_fus_accuracy: 0.8467 - val_opt_loss: 0.0960 - val_sar_loss: 9.5070 - val_fusion_loss: 0.0960 - val_loss: 9.6991
#
# Epoch 00002: val_loss improved from 10.50998 to 9.69906, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 3/100
# 108/108 [==============================] - 20s 185ms/step - opt_accuracy: 0.8081 - sar_accuracy: 0.7295 - fus_accuracy: 0.7688 - opt_loss: 0.0999 - sar_loss: 11.6165 - fusion_loss: 0.1261 - loss: 11.8426 - val_opt_accuracy: 0.8553 - val_sar_accuracy: 0.7735 - val_fus_accuracy: 0.8501 - val_opt_loss: 0.0933 - val_sar_loss: 9.6314 - val_fusion_loss: 0.0923 - val_loss: 9.8171
#
# Epoch 00003: val_loss did not improve from 9.69906
# Epoch 4/100
#
# Epoch 00009: val_loss did not improve from 9.66936
# Epoch 10/100
# 108/108 [==============================] - 20s 190ms/step - opt_accuracy: 0.8524 - sar_accuracy: 0.7555 - fus_accuracy: 0.8276 - opt_loss: 0.0806 - sar_loss: 10.4029 - fusion_loss: 0.0955 - loss: 10.5790 - val_opt_accuracy: 0.8621 - val_sar_accuracy: 0.7917 - val_fus_accuracy: 0.8626 - val_opt_loss: 0.1047 - val_sar_loss: 9.3643 - val_fusion_loss: 0.1002 - val_loss: 9.5692
#
# Epoch 00010: val_loss improved from 9.66936 to 9.56924, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 11/100
# 108/108 [==============================] - 21s 198ms/step - opt_accuracy: 0.8535 - sar_accuracy: 0.7579 - fus_accuracy: 0.8295 - opt_loss: 0.0799 - sar_loss: 10.3036 - fusion_loss: 0.0943 - loss: 10.4779 - val_opt_accuracy: 0.8599 - val_sar_accuracy: 0.7831 - val_fus_accuracy: 0.8613 - val_opt_loss: 0.0970 - val_sar_loss: 9.4703 - val_fusion_loss: 0.0909 - val_loss: 9.6582
#
# Epoch 00011: val_loss did not improve from 9.56924
# Epoch 12/100
# 108/108 [==============================] - 21s 197ms/step - opt_accuracy: 0.8561 - sar_accuracy: 0.7605 - fus_accuracy: 0.8322 - opt_loss: 0.0786 - sar_loss: 10.2380 - fusion_loss: 0.0929 - loss: 10.4095 - val_opt_accuracy: 0.8618 - val_sar_accuracy: 0.7847 - val_fus_accuracy: 0.8627 - val_opt_loss: 0.0908 - val_sar_loss: 9.1499 - val_fusion_loss: 0.0865 - val_loss: 9.3272
#
# Epoch 00012: val_loss improved from 9.56924 to 9.32716, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 13/100
# 108/108 [==============================] - 21s 198ms/step - opt_accuracy: 0.8572 - sar_accuracy: 0.7626 - fus_accuracy: 0.8336 - opt_loss: 0.0783 - sar_loss: 10.1709 - fusion_loss: 0.0921 - loss: 10.3414 - val_opt_accuracy: 0.8653 - val_sar_accuracy: 0.7975 - val_fus_accuracy: 0.8645 - val_opt_loss: 0.0896 - val_sar_loss: 8.9866 - val_fusion_loss: 0.0901 - val_loss: 9.1663
#
# Epoch 00013: val_loss improved from 9.32716 to 9.16632, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 14/100
# 108/108 [==============================] - 22s 202ms/step - opt_accuracy: 0.8588 - sar_accuracy: 0.7658 - fus_accuracy: 0.8354 - opt_loss: 0.0773 - sar_loss: 10.0637 - fusion_loss: 0.0907 - loss: 10.2317 - val_opt_accuracy: 0.8583 - val_sar_accuracy: 0.7954 - val_fus_accuracy: 0.8611 - val_opt_loss: 0.1123 - val_sar_loss: 9.3051 - val_fusion_loss: 0.1046 - val_loss: 9.5220
#
# Epoch 00014: val_loss did not improve from 9.16632
# Epoch 15/100
#
# Epoch 00031: val_loss did not improve from 8.84998
# Epoch 32/100
# 108/108 [==============================] - 25s 228ms/step - opt_accuracy: 0.8745 - sar_accuracy: 0.7841 - fus_accuracy: 0.8581 - opt_loss: 0.0682 - sar_loss: 9.3254 - fusion_loss: 0.0766 - loss: 9.4702 - val_opt_accuracy: 0.8657 - val_sar_accuracy: 0.8071 - val_fus_accuracy: 0.8657 - val_opt_loss: 0.1067 - val_sar_loss: 9.1085 - val_fusion_loss: 0.1054 - val_loss: 9.3207
#
# Epoch 00032: val_loss did not improve from 8.84998
# Epoch 33/100
# 108/108 [==============================] - 25s 228ms/step - opt_accuracy: 0.8756 - sar_accuracy: 0.7861 - fus_accuracy: 0.8592 - opt_loss: 0.0677 - sar_loss: 9.3157 - fusion_loss: 0.0759 - loss: 9.4592 - val_opt_accuracy: 0.8655 - val_sar_accuracy: 0.8049 - val_fus_accuracy: 0.8662 - val_opt_loss: 0.1057 - val_sar_loss: 9.1296 - val_fusion_loss: 0.1036 - val_loss: 9.3390
#
# Epoch 00033: val_loss did not improve from 8.84998
# Epoch 00033: early stopping

# %%
# Test loop
time_ts = []
n_pool = 3
n_rows = 5
n_cols = 4
rows, cols = image_array.shape[:2]
pad_rows = rows - np.ceil(rows/(n_rows*2**n_pool))*n_rows*2**n_pool
pad_cols = cols - np.ceil(cols/(n_cols*2**n_pool))*n_cols*2**n_pool
print(pad_rows, pad_cols)

npad = ((0, int(abs(pad_rows))), (0, int(abs(pad_cols))), (0, 0))
image1_pad = np.pad(image_array, pad_width=npad, mode='reflect')

h, w, c = image1_pad.shape
patch_size_rows = h//n_rows
patch_size_cols = w//n_cols
num_patches_x = int(h/patch_size_rows)
num_patches_y = int(w/patch_size_cols)

input_shape=(patch_size_rows,patch_size_cols, c)

#if method == 'unet':
#   new_model = build_unet(input_shape, nb_filters, number_class)

#if method == 'resunet':
#   new_model = build_resunet(input_shape, nb_filters, number_class)

new_model = Model_3(nb_filters, number_class, n_opt_layers)
new_model.build((None,)+input_shape)
adam = Adam(lr = 1e-5 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
new_model.compile(optimizer=adam, loss=loss, metrics=['accuracy'], run_eagerly=True)

for tm in range(0,times):
    print('time: ', tm)
    #model = load_model(path_models+ '/' + method +'_'+str(tm)+'.h5', compile=False)
    
    #for l in range(1, len(model.layers)):
    #    new_model.layers[l].set_weights(model.layers[l].get_weights())
    new_model.load_weights(path_models+ '/' + method +'_'+str(tm)+'.h5')
    
    start_test = time.time()
    patch_opt = []
    patch_sar = []
    patch_fus = []
    patch_comb = []
    
    for i in range(0,num_patches_y):
        for j in range(0,num_patches_x):
            patch = image1_pad[patch_size_rows*j:patch_size_rows*(j+1), patch_size_cols*i:patch_size_cols*(i+1), :]
            pred_opt, pred_sar, pred_fus, pred_comb = new_model.predict(np.expand_dims(patch, axis=0))
            del patch 
            patch_opt.append(pred_opt[:,:,:,1])
            patch_sar.append(pred_sar[:,:,:,1])
            patch_fus.append(pred_fus[:,:,:,1])
            patch_comb.append(pred_comb[:,:,:,1])
            del pred_opt, pred_sar, pred_fus, pred_comb
    end_test =  time.time() - start_test

    patches_pred_opt = np.asarray(patch_opt).astype(np.float32)
    patches_pred_sar = np.asarray(patch_sar).astype(np.float32)
    patches_pred_fus = np.asarray(patch_fus).astype(np.float32)
    patches_pred_comb = np.asarray(patch_comb).astype(np.float32)

    prob_recontructed_opt = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_opt)
    prob_recontructed_sar = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_sar)
    prob_recontructed_fus = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_fus)
    prob_recontructed_comb = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_comb)

    del patches_pred_opt, patches_pred_sar, patches_pred_fus, patches_pred_comb
    np.save(path_maps+'/'+'prob_opt_'+str(tm)+'.npy',prob_recontructed_opt) 
    np.save(path_maps+'/'+'prob_sar_'+str(tm)+'.npy',prob_recontructed_sar) 
    np.save(path_maps+'/'+'prob_fus_'+str(tm)+'.npy',prob_recontructed_fus) 
    np.save(path_maps+'/'+'prob_comb_'+str(tm)+'.npy',prob_recontructed_comb) 

    time_ts.append(end_test)
    del prob_recontructed_opt, prob_recontructed_sar, prob_recontructed_fus, prob_recontructed_comb
    #del model
time_ts_array = np.asarray(time_ts)
# Save test time
np.save(path_exp+'/metrics_ts.npy', time_ts_array)
# Out:
# 0.0 -8.0
# time:  0
# time:  1
# time:  2
# time:  3
# time:  4

# %%
# Compute mean of the tm predictions maps
prob_rec_opt = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_sar = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_fus = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_comb = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))

for tm in range (0, times):
    print(tm)
    prob_rec_opt[:,:,tm] = np.load(path_maps+'/'+'prob_opt_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_sar[:,:,tm] = np.load(path_maps+'/'+'prob_sar_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_fus[:,:,tm] = np.load(path_maps+'/'+'prob_fus_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_comb[:,:,tm] = np.load(path_maps+'/'+'prob_comb_'+str(tm)+'.npy').astype(np.float32)

mean_prob_opt = np.mean(prob_rec_opt, axis = -1)
mean_prob_sar = np.mean(prob_rec_sar, axis = -1)
mean_prob_fus = np.mean(prob_rec_fus, axis = -1)
mean_prob_comb = np.mean(prob_rec_comb, axis = -1)

np.save(path_maps+'/prob_mean_opt.npy', mean_prob_opt)
np.save(path_maps+'/prob_mean_sar.npy', mean_prob_sar)
np.save(path_maps+'/prob_mean_fus.npy', mean_prob_fus)
np.save(path_maps+'/prob_mean_comb.npy', mean_prob_comb)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Plot mean map and reference
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(151)
plt.title('OPT Prediction')
ax1.imshow(mean_prob_opt, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(152)
plt.title('SAR Prediction')
ax1.imshow(mean_prob_sar, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(153)
plt.title('FUSION Prediction')
ax1.imshow(mean_prob_fus, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(154)
plt.title('COMBINATION Prediction')
ax1.imshow(mean_prob_comb, cmap ='jet')
ax1.axis('off')

ax2 = fig.add_subplot(155)
plt.title('Reference')
ax2.imshow(tf.keras.utils.to_categorical(final_mask1, 3)[:,:,1], cmap ='jet')
ax2.axis('off')
# Out:
# (-0.5, 6999.5, 9999.5, -0.5)

# %%
# Computing metrics
mean_prob_opt = mean_prob_opt[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_sar = mean_prob_sar[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_fus = mean_prob_fus[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_comb = mean_prob_comb[:final_mask1.shape[0], :final_mask1.shape[1]]

ref1 = np.ones_like(final_mask1).astype(np.float32)

ref1 [final_mask1 == 2] = 0
TileMask = mask_amazon_ts * ref1
GTTruePositives = final_mask1==1
    
Npoints = 50

Pmax_opt = np.max(mean_prob_opt[GTTruePositives * TileMask ==1])
ProbList_opt = np.linspace(Pmax_opt,0,Npoints)

Pmax_sar = np.max(mean_prob_sar[GTTruePositives * TileMask ==1])
ProbList_sar = np.linspace(Pmax_sar,0,Npoints)

Pmax_fus = np.max(mean_prob_fus[GTTruePositives * TileMask ==1])
ProbList_fus = np.linspace(Pmax_fus,0,Npoints)

Pmax_comb = np.max(mean_prob_comb[GTTruePositives * TileMask ==1])
ProbList_comb = np.linspace(Pmax_comb,0,Npoints)


from multiprocessing.pool import Pool
pool = Pool(processes=4)

async_result_opt = pool.apply_async(matrics_AA_recall, (ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625))
async_result_sar = pool.apply_async(matrics_AA_recall, (ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625))
async_result_fus = pool.apply_async(matrics_AA_recall, (ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625))
async_result_comb = pool.apply_async(matrics_AA_recall, (ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625))

metrics_opt = async_result_opt.get()
metrics_sar = async_result_sar.get()
metrics_fus = async_result_fus.get()
metrics_comb = async_result_comb.get()
    
#metrics_opt = matrics_AA_recall(ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625)
#metrics_sar = matrics_AA_recall(ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625)
#metrics_fus = matrics_AA_recall(ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625)
#metrics_comb = matrics_AA_recall(ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625)

np.save(path_exp+'/acc_metrics_opt.npy',metrics_opt)
np.save(path_exp+'/acc_metrics_sar.npy',metrics_sar)
np.save(path_exp+'/acc_metrics_fus.npy',metrics_fus)
np.save(path_exp+'/acc_metrics_comb.npy',metrics_comb)

# %%
# Complete NaN values
metrics_copy_opt = metrics_opt.copy()
metrics_copy_opt = complete_nan_values(metrics_copy_opt)

metrics_copy_sar = metrics_sar.copy()
metrics_copy_sar = complete_nan_values(metrics_copy_sar)

metrics_copy_fus = metrics_fus.copy()
metrics_copy_fus = complete_nan_values(metrics_copy_fus)

metrics_copy_comb = metrics_comb.copy()
metrics_copy_comb = complete_nan_values(metrics_copy_comb)

# %%
# Comput Mean Average Precision (mAP) score 
Recall_opt = metrics_copy_opt[:,0]
Precision_opt = metrics_copy_opt[:,1]
AA_opt = metrics_copy_opt[:,2]

Recall_sar = metrics_copy_sar[:,0]
Precision_sar = metrics_copy_sar[:,1]
AA_sar = metrics_copy_sar[:,2]

Recall_fus = metrics_copy_fus[:,0]
Precision_fus = metrics_copy_fus[:,1]
AA_fus = metrics_copy_fus[:,2]

Recall_comb = metrics_copy_comb[:,0]
Precision_comb = metrics_copy_comb[:,1]
AA_comb = metrics_copy_comb[:,2]
    
DeltaR_opt = Recall_opt[1:]-Recall_opt[:-1]
AP_opt = np.sum(Precision_opt[:-1]*DeltaR_opt)
print('OPT mAP', AP_opt)

DeltaR_sar = Recall_sar[1:]-Recall_sar[:-1]
AP_sar = np.sum(Precision_sar[:-1]*DeltaR_sar)
print('SAR mAP', AP_sar)

DeltaR_fus = Recall_fus[1:]-Recall_fus[:-1]
AP_fus = np.sum(Precision_fus[:-1]*DeltaR_fus)
print('FUSION mAP', AP_fus)

DeltaR_comb = Recall_comb[1:]-Recall_comb[:-1]
AP_comb = np.sum(Precision_comb[:-1]*DeltaR_comb)
print('COMBINATION mAP', AP_comb)

# Plot Recall vs. Precision curve
plt.figure(figsize=(7,7))
plt.plot(metrics_copy_opt[:,0],metrics_copy_opt[:,1], 'r-', label = f'OPT (AP: {AP_opt:.4f})')
plt.plot(metrics_copy_sar[:,0],metrics_copy_sar[:,1], 'g-', label = f'SAR (AP: {AP_sar:.4f})')
plt.plot(metrics_copy_fus[:,0],metrics_copy_fus[:,1], 'b-', label = f'FUSION (AP: {AP_fus:.4f})')
plt.plot(metrics_copy_comb[:,0],metrics_copy_comb[:,1], 'k-', label = f'COMBINATION (AP: {AP_comb:.4f})')
plt.legend(loc="lower left")
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([0,1])
#plt.plot(metrics_copy[:,0],metrics_copy[:,2])
plt.grid()
# Out:
# OPT mAP 0.9295408212991891
# SAR mAP 0.7061056203272388
# FUSION mAP 0.9392051110848051
# COMBINATION mAP 0.9385653156680647
