# %%
# %load_ext autoreload
# %autoreload 2

# %%
#%autoreload # When utils.py is updated
from utils_unet_resunet import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from model.models import Model_3
from model.losses import WBCE
from model.callbacks import UpdateWeights

root_path = 'imgs/'

# %%
# Define data type 
img_type = 'FUSION'

if img_type == 'FUSION':
    image_array = np.load(root_path+'New_Images/fus_stack.npy')
    

if img_type == 'OPT':
    image_array = np.load(root_path+'New_Images/opt_stack.npy')
    
    
if img_type == 'SAR':
    image_array = np.load(root_path+'New_Images/sar_stack.npy')
print('Image stack:', image_array.shape)

final_mask1 = np.load(root_path+'New_Images/'+'final_mask1.npy')
print('Labels stack:', final_mask1.shape)

h_, w_, channels = image_array.shape
n_opt_layers = 20
# Out:
# Image stack: (10000, 7000, 24)
# Labels stack: (10000, 7000)

# %%
# Create tile mask
mask_tiles = create_mask(final_mask1.shape[0], final_mask1.shape[1], grid_size=(5, 4))
image_array = image_array[:mask_tiles.shape[0], :mask_tiles.shape[1],:]
final_mask1 = final_mask1[:mask_tiles.shape[0], :mask_tiles.shape[1]]

print('mask: ',mask_tiles.shape)
print('image stack: ', image_array.shape)
print('ref :', final_mask1.shape)
#plt.imshow(mask_tiles)
# Out:
# Tiles size:  2000 1750
# Mask size:  (10000, 7000)
# mask:  (10000, 7000)
# image stack:  (10000, 7000, 24)
# ref : (10000, 7000)

# %%
plt.figure(figsize=(10,5))
plt.imshow(final_mask1, cmap = 'jet')

# %%
# Define tiles for training, validation, and test sets
tiles_tr = [1,3,5,8,11,13,14,20]
tiles_val = [6,19]
tiles_ts = (list(set(np.arange(20)+1)-set(tiles_tr)-set(tiles_val)))

mask_tr_val = np.zeros((mask_tiles.shape)).astype('float32')
# Training and validation mask
for tr_ in tiles_tr:
    mask_tr_val[mask_tiles == tr_] = 1

for val_ in tiles_val:
    mask_tr_val[mask_tiles == val_] = 2

mask_amazon_ts = np.zeros((mask_tiles.shape)).astype('float32')
for ts_ in tiles_ts:
    mask_amazon_ts[mask_tiles == ts_] = 1

# %%
# Create ixd image to extract patches
overlap = 0.7
patch_size = 128
batch_size = 32
im_idx = create_idx_image(final_mask1)
patches_idx = extract_patches(im_idx, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1,patch_size, patch_size)
patches_mask = extract_patches(mask_tr_val, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1, patch_size, patch_size)
del im_idx

# %%
# Selecting index trn val and test patches idx
idx_trn = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==patch_size**2))
idx_val = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==2*patch_size**2))
del patches_mask

patches_idx_trn = patches_idx[idx_trn]
patches_idx_val = patches_idx[idx_val]
del idx_trn, idx_val

print('Number of training patches:  ', len(patches_idx_trn), 'Number of validation patches', len(patches_idx_val))
# Out:
# Number of training patches:   17110 Number of validation patches 4116

# %%
# Extract patches with at least 2% of deforestation class
X_train = retrieve_idx_percentage(final_mask1, patches_idx_trn, patch_size, pertentage = 2)
X_valid = retrieve_idx_percentage(final_mask1, patches_idx_val, patch_size, pertentage = 2)
print(X_train.shape, X_valid.shape)
del patches_idx_trn, patches_idx_val
# Out:
# (1158, 128, 128) (341, 128, 128)

# %%
def batch_generator(batches, image, reference, target_size, number_class):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    image = image.reshape(-1, image.shape[-1])
    reference = reference.reshape(final_mask1.shape[0]*final_mask1.shape[1])
    while True:
        batch_x, batch_y = next(batches)
        batch_x = np.squeeze(batch_x.astype('int64'))
        #print(batch_x.shape)
        batch_img = np.zeros((batch_x.shape[0], target_size, target_size, image.shape[-1]))
        batch_ref = np.zeros((batch_x.shape[0], target_size, target_size, number_class))
        
        for i in range(batch_x.shape[0]):
            if np.random.rand()>0.5:
                batch_x[i] = np.rot90(batch_x[i], 1)
            batch_img[i] = image[batch_x[i]] 
            batch_ref[i] = tf.keras.utils.to_categorical(reference[batch_x[i]] , number_class)
                       
        yield (batch_img, batch_ref)

train_datagen = ImageDataGenerator(horizontal_flip = True,
                                   vertical_flip = True)
valid_datagen = ImageDataGenerator(horizontal_flip = True, 
                                   vertical_flip = True)

y_train = np.zeros((len(X_train)))
y_valid = np.zeros((len(X_valid)))

train_gen = train_datagen.flow(np.expand_dims(X_train, axis = -1), y_train,
                              batch_size=batch_size,
                              shuffle=True)

valid_gen = valid_datagen.flow(np.expand_dims(X_valid, axis = -1), y_valid,
                              batch_size=batch_size,
                              shuffle=False)

number_class = 3
train_gen_crops = batch_generator(train_gen, image_array, final_mask1, patch_size, number_class)
valid_gen_crops = batch_generator(valid_gen, image_array, final_mask1, patch_size, number_class)

# %%
exp = 3
path_exp = root_path+'experiments/exp'+str(exp)
path_models = path_exp+'/models'
path_maps = path_exp+'/pred_maps'

if not os.path.exists(path_exp):
    os.makedirs(path_exp)   
if not os.path.exists(path_models):
    os.makedirs(path_models)   
if not os.path.exists(path_maps):
    os.makedirs(path_maps)

# %%
# Define model
input_shape = (patch_size, patch_size, channels)
nb_filters = [32, 64, 128]

method = 'unet'
if method == 'unet':
   model = build_unet(input_shape, nb_filters, number_class)

if method == 'resunet':
   model = build_resunet(input_shape, nb_filters, number_class)

model = Model_3(nb_filters, number_class, n_opt_layers)

# %%
# Parameters of the model
weights = [0.2, 0.8, 0]
adam = Adam(lr = 1e-3 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
#loss = WBCE(weights = weights)
#loss = WBCE(weights = weights, class_indexes = [0, 1])

# %%
metrics_all = []
times=5
for tm in range(0,times):
    print('time: ', tm)

    rows = patch_size
    cols = patch_size
    adam = Adam(lr = 1e-3 , beta_1=0.9)
    
    loss = weighted_categorical_crossentropy(weights)
    
    model = Model_3(nb_filters, number_class, n_opt_layers)
    model.build((None,)+input_shape)
    
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    model.summary()

    
    # train the model
    start_training = time.time()
    
    #train OPT
    earlystop = EarlyStopping(monitor='val_opt_loss', min_delta=0.0001, patience=5, verbose=1, mode='min', restore_best_weights=True)
    callbacks_list = [earlystop]
    model.set_loss_streams([True, False, False])
    history = model.fit(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    
    #train SAR
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    earlystop = EarlyStopping(monitor='val_sar_loss', min_delta=0.0001, patience=5, verbose=1, mode='min', restore_best_weights=True)
    callbacks_list = [earlystop]
    model.set_loss_streams([False, True, False])
    history = model.fit(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    
    #train FUS
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    earlystop = EarlyStopping(monitor='val_fus_loss', min_delta=0.0001, patience=5, verbose=1, mode='min')
    updateWeights = UpdateWeights()
    checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_fus_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
    callbacks_list = [earlystop, checkpoint, updateWeights]
    model.set_loss_streams([False, False, True])
    history = model.fit(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    
    end_training = time.time() - start_training
    metrics_all.append(end_training)
    del model, history
# Out:
# time:  0
# Model: "model_3_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,741,786
# Trainable params: 1,741,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 19s 108ms/step - opt_accuracy: 0.8725 - sar_accuracy: 0.6452 - fus_accuracy: 0.5263 - opt_loss: 0.0769 - sar_loss: 0.2061 - fus_loss: 0.3380 - loss: 0.6209 - val_opt_accuracy: 0.8454 - val_sar_accuracy: 0.6435 - val_fus_accuracy: 0.5270 - val_opt_loss: 0.1177 - val_sar_loss: 0.2034 - val_fus_loss: 0.3272 - val_loss: 0.64830 - fus_accuracy: 0.5868 - opt_loss: 0.0863 - sar_loss: 0.2063 - fus_loss: 0.2541 - loss: 0 - ETA: 4s - opt_accuracy: 0.8583 - sar_accuracy: 0.6451 - fus_accuracy: 0.5791 - opt_loss: 0.0853 - sar_lo - ETA: 0s - opt_accuracy: 0.8714 - sar_accuracy: 0.6451 - fus_accuracy: 0.5284 - opt_loss: 0.0778 - sar_loss: 0.2061 - fus_loss: 0.3338 - los
# Epoch 2/100
# 108/108 [==============================] - 10s 89ms/step - opt_accuracy: 0.8901 - sar_accuracy: 0.6452 - fus_accuracy: 0.4895 - opt_loss: 0.0633 - sar_loss: 0.2061 - fus_loss: 0.4593 - loss: 0.7286 - val_opt_accuracy: 0.8541 - val_sar_accuracy: 0.6434 - val_fus_accuracy: 0.4997 - val_opt_loss: 0.1077 - val_sar_loss: 0.2041 - val_fus_loss: 0.3803 - val_loss: 0.6921.8868 - sar_accuracy: 0.6450 - fus_accuracy: 0.4954 - opt_loss: 0.0653 - sar_loss: 0.20 - ETA: 2s - opt_accuracy: 0.8887 - sar_accuracy: 0.6451 - fus_accuracy: 0.4932 - opt_loss: 0.0640 - sar_loss: 0.2061 - fu - ETA: 0s - opt_accuracy: 0.8899 - sar_accuracy: 0.6451 - fus_accuracy: 0.4901 - opt_loss: 0.0633 - sar_loss: 0.2060 - fus_loss: 0.4584 - loss: 0.7
# Epoch 3/100
# 108/108 [==============================] - 10s 90ms/step - opt_accuracy: 0.8954 - sar_accuracy: 0.6451 - fus_accuracy: 0.4632 - opt_loss: 0.0593 - sar_loss: 0.2060 - fus_loss: 0.5164 - loss: 0.7817 - val_opt_accuracy: 0.8548 - val_sar_accuracy: 0.6438 - val_fus_accuracy: 0.4721 - val_opt_loss: 0.1037 - val_sar_loss: 0.2034 - val_fus_loss: 0.4766 - val_loss: 0.7837
# Epoch 4/100
# 108/108 [==============================] - 10s 90ms/step - opt_accuracy: 0.8988 - sar_accuracy: 0.6450 - fus_accuracy: 0.4448 - opt_loss: 0.0562 - sar_loss: 0.2059 - fus_loss: 0.5535 - loss: 0.8156 - val_opt_accuracy: 0.8619 - val_sar_accuracy: 0.6444 - val_fus_accuracy: 0.4396 - val_opt_loss: 0.1032 - val_sar_loss: 0.2021 - val_fus_loss: 0.5162 - val_loss: 0.8215
# Epoch 5/100
# 108/108 [==============================] - 10s 90ms/step - opt_accuracy: 0.9012 - sar_accuracy: 0.6451 - fus_accuracy: 0.4273 - opt_loss: 0.0547 - sar_loss: 0.2061 - fus_loss: 0.5945 - loss: 0.8553 - val_opt_accuracy: 0.8610 - val_sar_accuracy: 0.6441 - val_fus_accuracy: 0.4402 - val_opt_loss: 0.1026 - val_sar_loss: 0.2030 - val_fus_loss: 0.5237 - val_loss: 0.8292
# Epoch 6/100
# 108/108 [==============================] - 10s 91ms/step - opt_accuracy: 0.9060 - sar_accuracy: 0.6452 - fus_accuracy: 0.4062 - opt_loss: 0.0503 - sar_loss: 0.2059 - fus_loss: 0.6652 - loss: 0.9214 - val_opt_accuracy: 0.8648 - val_sar_accuracy: 0.6435 - val_fus_accuracy: 0.4041 - val_opt_loss: 0.1423 - val_sar_loss: 0.2041 - val_fus_loss: 0.7013 - val_loss: 1.0477
# Epoch 7/100
# 108/108 [==============================] - 10s 92ms/step - opt_accuracy: 0.9120 - sar_accuracy: 0.6450 - fus_accuracy: 0.3828 - opt_loss: 0.0447 - sar_loss: 0.2063 - fus_loss: 0.7996 - loss: 1.0507 - val_opt_accuracy: 0.8564 - val_sar_accuracy: 0.6430 - val_fus_accuracy: 0.4082 - val_opt_loss: 0.1445 - val_sar_loss: 0.2046 - val_fus_loss: 0.7525 - val_loss: 1.1016cy: 0.6449 - fus_accuracy: 0.3852 - o
# Epoch 8/100
# 108/108 [==============================] - 10s 92ms/step - opt_accuracy: 0.9146 - sar_accuracy: 0.6451 - fus_accuracy: 0.3761 - opt_loss: 0.0422 - sar_loss: 0.2063 - fus_loss: 0.8521 - loss: 1.1006 - val_opt_accuracy: 0.8635 - val_sar_accuracy: 0.6431 - val_fus_accuracy: 0.3933 - val_opt_loss: 0.1712 - val_sar_loss: 0.2046 - val_fus_loss: 0.8954 - val_loss: 1.2712
# Epoch 9/100
# 108/108 [==============================] - 10s 94ms/step - opt_accuracy: 0.9188 - sar_accuracy: 0.6451 - fus_accuracy: 0.3704 - opt_loss: 0.0391 - sar_loss: 0.2061 - fus_loss: 0.9346 - loss: 1.1798 - val_opt_accuracy: 0.8590 - val_sar_accuracy: 0.6436 - val_fus_accuracy: 0.3960 - val_opt_loss: 0.1623 - val_sar_loss: 0.2041 - val_fus_loss: 0.8695 - val_loss: 1.2359uracy: 0.6452 - fus_accuracy: 0.3705 - opt_loss: 0.0388 - sar_loss: 0.2057 - fus_loss: 0.9497 - l - ETA: 1s - opt_accuracy: 0.9188 - sar_accuracy: 0.6451 - fus_accuracy: 0.3707 - opt_loss: 0.0390 - sar_loss: 0.2058 - fus_loss: 0.93
# Epoch 10/100
# 108/108 [==============================] - 10s 93ms/step - opt_accuracy: 0.9241 - sar_accuracy: 0.6452 - fus_accuracy: 0.3658 - opt_loss: 0.0346 - sar_loss: 0.2060 - fus_loss: 1.0263 - loss: 1.2670 - val_opt_accuracy: 0.8595 - val_sar_accuracy: 0.6435 - val_fus_accuracy: 0.3880 - val_opt_loss: 0.1912 - val_sar_loss: 0.2044 - val_fus_loss: 1.0494 - val_loss: 1.4450232 - sar_accuracy: 0.6451 - fus_accuracy: 0.3662 - opt_loss: 0.0354 - sar_loss: 0.2061 - fus_loss: 0.9985 - loss: 1.24 - ETA: 2s - opt_accuracy: 0.9234 - sar_accuracy: 0.6452 - fus_accuracy: 0.3662 - opt_loss: 0.0353 - sar_loss: 0.2060 - fus_loss: 1.0002 - loss: 1.2 - ETA: 2s - opt_accuracy: 0.9231 - sar_accuracy: 0.6451 - fus_accuracy: 0.3663 - opt_loss: 0.0353 - sar_loss: 0.2060 - fus_loss: - ETA: 1s - opt_accuracy: 0.9239 - sar_accuracy: 0.6452 - fus_accuracy: 0.3658 - opt_loss: 0.0349 - sar_loss: 0.2061 - fus_loss: 1.018
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# Epoch 1/100
# 108/108 [==============================] - 12s 96ms/step - opt_accuracy: 0.9042 - sar_accuracy: 0.7720 - fus_accuracy: 0.4185 - opt_loss: 0.0519 - sar_loss: 0.1315 - fus_loss: 0.6873 - loss: 0.8707 - val_opt_accuracy: 0.8565 - val_sar_accuracy: 0.7917 - val_fus_accuracy: 0.4484 - val_opt_loss: 0.1144 - val_sar_loss: 0.1182 - val_fus_loss: 0.5685 - val_loss: 0.8011 0.9041 - sar_accuracy: 0.7467 - fus_accuracy: 0.4
# Epoch 2/100
# 108/108 [==============================] - 10s 94ms/step - opt_accuracy: 0.9049 - sar_accuracy: 0.8077 - fus_accuracy: 0.4339 - opt_loss: 0.0518 - sar_loss: 0.1132 - fus_loss: 0.6968 - loss: 0.8618 - val_opt_accuracy: 0.8562 - val_sar_accuracy: 0.8027 - val_fus_accuracy: 0.4671 - val_opt_loss: 0.1139 - val_sar_loss: 0.1231 - val_fus_loss: 0.6080 - val_loss: 0.8450
# Epoch 3/100
# 108/108 [==============================] - 10s 95ms/step - opt_accuracy: 0.9044 - sar_accuracy: 0.8300 - fus_accuracy: 0.4366 - opt_loss: 0.0519 - sar_loss: 0.0974 - fus_loss: 0.7067 - loss: 0.8560 - val_opt_accuracy: 0.8581 - val_sar_accuracy: 0.8026 - val_fus_accuracy: 0.4704 - val_opt_loss: 0.1132 - val_sar_loss: 0.1147 - val_fus_loss: 0.5908 - val_loss: 0.8187
# Epoch 4/100
# 108/108 [==============================] - 10s 96ms/step - opt_accuracy: 0.9045 - sar_accuracy: 0.8375 - fus_accuracy: 0.4492 - opt_loss: 0.0516 - sar_loss: 0.0907 - fus_loss: 0.6994 - loss: 0.8417 - val_opt_accuracy: 0.8591 - val_sar_accuracy: 0.8121 - val_fus_accuracy: 0.4780 - val_opt_loss: 0.1091 - val_sar_loss: 0.1281 - val_fus_loss: 0.6217 - val_loss: 0.8589
# Epoch 5/100
# 108/108 [==============================] - 10s 97ms/step - opt_accuracy: 0.9045 - sar_accuracy: 0.8434 - fus_accuracy: 0.4515 - opt_loss: 0.0518 - sar_loss: 0.0858 - fus_loss: 0.6854 - loss: 0.8229 - val_opt_accuracy: 0.8617 - val_sar_accuracy: 0.8168 - val_fus_accuracy: 0.4709 - val_opt_loss: 0.0981 - val_sar_loss: 0.1131 - val_fus_loss: 0.5930 - val_loss: 0.8041
# Epoch 6/100
# 108/108 [==============================] - 10s 96ms/step - opt_accuracy: 0.9046 - sar_accuracy: 0.8470 - fus_accuracy: 0.4463 - opt_loss: 0.0521 - sar_loss: 0.0831 - fus_loss: 0.6942 - loss: 0.8294 - val_opt_accuracy: 0.8610 - val_sar_accuracy: 0.8141 - val_fus_accuracy: 0.4622 - val_opt_loss: 0.1024 - val_sar_loss: 0.1092 - val_fus_loss: 0.5841 - val_loss: 0.7957
# Epoch 7/100
# 108/108 [==============================] - 11s 99ms/step - opt_accuracy: 0.9047 - sar_accuracy: 0.8534 - fus_accuracy: 0.4453 - opt_loss: 0.0516 - sar_loss: 0.0773 - fus_loss: 0.7014 - loss: 0.8302 - val_opt_accuracy: 0.8552 - val_sar_accuracy: 0.8115 - val_fus_accuracy: 0.4811 - val_opt_loss: 0.1142 - val_sar_loss: 0.1222 - val_fus_loss: 0.5473 - val_loss: 0.7836
# Epoch 8/100
# 108/108 [==============================] - 11s 98ms/step - opt_accuracy: 0.9049 - sar_accuracy: 0.8569 - fus_accuracy: 0.4529 - opt_loss: 0.0518 - sar_loss: 0.0761 - fus_loss: 0.6958 - loss: 0.8238 - val_opt_accuracy: 0.8564 - val_sar_accuracy: 0.8155 - val_fus_accuracy: 0.4688 - val_opt_loss: 0.1135 - val_sar_loss: 0.1287 - val_fus_loss: 0.6166 - val_loss: 0.8588
# Epoch 9/100
# 108/108 [==============================] - 11s 100ms/step - opt_accuracy: 0.9047 - sar_accuracy: 0.8656 - fus_accuracy: 0.4650 - opt_loss: 0.0516 - sar_loss: 0.0674 - fus_loss: 0.6946 - loss: 0.8136 - val_opt_accuracy: 0.8576 - val_sar_accuracy: 0.8186 - val_fus_accuracy: 0.4852 - val_opt_loss: 0.1123 - val_sar_loss: 0.1323 - val_fus_loss: 0.6098 - val_loss: 0.8544ccuracy: 0.4650 - opt_loss: 0.0516 - sar_loss: 0.0674 - fus_loss: 0.6946 - loss: 0.813
# Epoch 10/100
# 108/108 [==============================] - 11s 101ms/step - opt_accuracy: 0.9048 - sar_accuracy: 0.8685 - fus_accuracy: 0.4659 - opt_loss: 0.0520 - sar_loss: 0.0672 - fus_loss: 0.6896 - loss: 0.8088 - val_opt_accuracy: 0.8558 - val_sar_accuracy: 0.8148 - val_fus_accuracy: 0.5093 - val_opt_loss: 0.1144 - val_sar_loss: 0.1570 - val_fus_loss: 0.6066 - val_loss: 0.8780
# Epoch 11/100
# 108/108 [==============================] - 11s 101ms/step - opt_accuracy: 0.9043 - sar_accuracy: 0.8781 - fus_accuracy: 0.4734 - opt_loss: 0.0519 - sar_loss: 0.0588 - fus_loss: 0.6910 - loss: 0.8017 - val_opt_accuracy: 0.8559 - val_sar_accuracy: 0.8114 - val_fus_accuracy: 0.5075 - val_opt_loss: 0.1141 - val_sar_loss: 0.1536 - val_fus_loss: 0.5808 - val_loss: 0.8485
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Epoch 1/100
# 108/108 [==============================] - 13s 105ms/step - opt_accuracy: 0.7041 - sar_accuracy: 0.6660 - fus_accuracy: 0.8756 - opt_loss: 0.1668 - sar_loss: 0.1765 - fus_loss: 0.0760 - loss: 0.4192 - val_opt_accuracy: 0.6777 - val_sar_accuracy: 0.6916 - val_fus_accuracy: 0.8648 - val_opt_loss: 0.1806 - val_sar_loss: 0.1525 - val_fus_loss: 0.1111 - val_loss: 0.4443
#
# Epoch 00001: val_fus_loss improved from inf to 0.11107, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 2/100
# 108/108 [==============================] - 11s 103ms/step - opt_accuracy: 0.6666 - sar_accuracy: 0.6620 - fus_accuracy: 0.9021 - opt_loss: 0.1684 - sar_loss: 0.1505 - fus_loss: 0.0530 - loss: 0.3719 - val_opt_accuracy: 0.6301 - val_sar_accuracy: 0.6464 - val_fus_accuracy: 0.8535 - val_opt_loss: 0.2040 - val_sar_loss: 0.1420 - val_fus_loss: 0.1619 - val_loss: 0.5080
#
# Epoch 00002: val_fus_loss did not improve from 0.11107
# Epoch 3/100
# 108/108 [==============================] - 11s 104ms/step - opt_accuracy: 0.6512 - sar_accuracy: 0.6657 - fus_accuracy: 0.9091 - opt_loss: 0.1633 - sar_loss: 0.1441 - fus_loss: 0.0470 - loss: 0.3545 - val_opt_accuracy: 0.6375 - val_sar_accuracy: 0.6836 - val_fus_accuracy: 0.8654 - val_opt_loss: 0.2088 - val_sar_loss: 0.1310 - val_fus_loss: 0.1619 - val_loss: 0.5017
#
# Epoch 00003: val_fus_loss did not improve from 0.11107
# Epoch 4/100
# 108/108 [==============================] - 11s 106ms/step - opt_accuracy: 0.6463 - sar_accuracy: 0.6688 - fus_accuracy: 0.9143 - opt_loss: 0.1662 - sar_loss: 0.1446 - fus_loss: 0.0422 - loss: 0.3530 - val_opt_accuracy: 0.6213 - val_sar_accuracy: 0.6767 - val_fus_accuracy: 0.8639 - val_opt_loss: 0.2335 - val_sar_loss: 0.1422 - val_fus_loss: 0.1832 - val_loss: 0.5588
#
# Epoch 00004: val_fus_loss did not improve from 0.11107
# Epoch 5/100
# 108/108 [==============================] - 11s 106ms/step - opt_accuracy: 0.6651 - sar_accuracy: 0.6762 - fus_accuracy: 0.9181 - opt_loss: 0.1581 - sar_loss: 0.1381 - fus_loss: 0.0393 - loss: 0.3355 - val_opt_accuracy: 0.6651 - val_sar_accuracy: 0.6833 - val_fus_accuracy: 0.8661 - val_opt_loss: 0.1746 - val_sar_loss: 0.1385 - val_fus_loss: 0.1240 - val_loss: 0.4372
#
# Epoch 00005: val_fus_loss did not improve from 0.11107
# Epoch 6/100
# 108/108 [==============================] - 12s 108ms/step - opt_accuracy: 0.6591 - sar_accuracy: 0.6694 - fus_accuracy: 0.9234 - opt_loss: 0.1560 - sar_loss: 0.1418 - fus_loss: 0.0347 - loss: 0.3325 - val_opt_accuracy: 0.6278 - val_sar_accuracy: 0.6628 - val_fus_accuracy: 0.8600 - val_opt_loss: 0.2124 - val_sar_loss: 0.1404 - val_fus_loss: 0.1638 - val_loss: 0.5167
#
# Epoch 00006: val_fus_loss did not improve from 0.11107
# Epoch 00006: early stopping
# time:  1
# Model: "model_3_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,741,786
# Trainable params: 1,741,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 13s 109ms/step - opt_accuracy: 0.8688 - sar_accuracy: 0.6666 - fus_accuracy: 0.5345 - opt_loss: 0.0791 - sar_loss: 0.1762 - fus_loss: 0.2578 - loss: 0.5130 - val_opt_accuracy: 0.8499 - val_sar_accuracy: 0.6670 - val_fus_accuracy: 0.5334 - val_opt_loss: 0.1119 - val_sar_loss: 0.1687 - val_fus_loss: 0.2426 - val_loss: 0.5233
# Epoch 2/100
# 108/108 [==============================] - 11s 107ms/step - opt_accuracy: 0.8907 - sar_accuracy: 0.6666 - fus_accuracy: 0.6021 - opt_loss: 0.0628 - sar_loss: 0.1752 - fus_loss: 0.2006 - loss: 0.4386 - val_opt_accuracy: 0.8527 - val_sar_accuracy: 0.6670 - val_fus_accuracy: 0.6766 - val_opt_loss: 0.1139 - val_sar_loss: 0.1694 - val_fus_loss: 0.1807 - val_loss: 0.4640
# Epoch 3/100
# 108/108 [==============================] - 12s 109ms/step - opt_accuracy: 0.8943 - sar_accuracy: 0.6666 - fus_accuracy: 0.7003 - opt_loss: 0.0596 - sar_loss: 0.1757 - fus_loss: 0.1816 - loss: 0.4169 - val_opt_accuracy: 0.8550 - val_sar_accuracy: 0.6672 - val_fus_accuracy: 0.7391 - val_opt_loss: 0.1033 - val_sar_loss: 0.1692 - val_fus_loss: 0.1651 - val_loss: 0.4376
# Epoch 4/100
# 108/108 [==============================] - 12s 109ms/step - opt_accuracy: 0.8974 - sar_accuracy: 0.6666 - fus_accuracy: 0.7046 - opt_loss: 0.0574 - sar_loss: 0.1761 - fus_loss: 0.1936 - loss: 0.4271 - val_opt_accuracy: 0.8484 - val_sar_accuracy: 0.6672 - val_fus_accuracy: 0.6557 - val_opt_loss: 0.1392 - val_sar_loss: 0.1684 - val_fus_loss: 0.2269 - val_loss: 0.5344
# Epoch 5/100
# 108/108 [==============================] - 12s 109ms/step - opt_accuracy: 0.9018 - sar_accuracy: 0.6666 - fus_accuracy: 0.6926 - opt_loss: 0.0528 - sar_loss: 0.1758 - fus_loss: 0.2324 - loss: 0.4610 - val_opt_accuracy: 0.8475 - val_sar_accuracy: 0.6674 - val_fus_accuracy: 0.6902 - val_opt_loss: 0.1393 - val_sar_loss: 0.1686 - val_fus_loss: 0.2152 - val_loss: 0.5231
# Epoch 6/100
# 108/108 [==============================] - 12s 110ms/step - opt_accuracy: 0.9069 - sar_accuracy: 0.6666 - fus_accuracy: 0.6867 - opt_loss: 0.0493 - sar_loss: 0.1759 - fus_loss: 0.2765 - loss: 0.5016 - val_opt_accuracy: 0.8599 - val_sar_accuracy: 0.6673 - val_fus_accuracy: 0.6933 - val_opt_loss: 0.1424 - val_sar_loss: 0.1683 - val_fus_loss: 0.2226 - val_loss: 0.5332
# Epoch 7/100
# 108/108 [==============================] - 12s 111ms/step - opt_accuracy: 0.9098 - sar_accuracy: 0.6666 - fus_accuracy: 0.6677 - opt_loss: 0.0461 - sar_loss: 0.1758 - fus_loss: 0.3122 - loss: 0.5341 - val_opt_accuracy: 0.8645 - val_sar_accuracy: 0.6671 - val_fus_accuracy: 0.6017 - val_opt_loss: 0.1577 - val_sar_loss: 0.1681 - val_fus_loss: 0.3183 - val_loss: 0.6442
# Epoch 8/100
# 108/108 [==============================] - 12s 113ms/step - opt_accuracy: 0.9127 - sar_accuracy: 0.6665 - fus_accuracy: 0.6698 - opt_loss: 0.0443 - sar_loss: 0.1758 - fus_loss: 0.3294 - loss: 0.5495 - val_opt_accuracy: 0.8590 - val_sar_accuracy: 0.6671 - val_fus_accuracy: 0.5955 - val_opt_loss: 0.1633 - val_sar_loss: 0.1690 - val_fus_loss: 0.3180 - val_loss: 0.6503
# Restoring model weights from the end of the best epoch.
# Epoch 00008: early stopping
# Epoch 1/100
# 108/108 [==============================] - 14s 117ms/step - opt_accuracy: 0.8945 - sar_accuracy: 0.7858 - fus_accuracy: 0.7422 - opt_loss: 0.0613 - sar_loss: 0.1249 - fus_loss: 0.1606 - loss: 0.3469 - val_opt_accuracy: 0.8576 - val_sar_accuracy: 0.7975 - val_fus_accuracy: 0.7260 - val_opt_loss: 0.0992 - val_sar_loss: 0.1177 - val_fus_loss: 0.1501 - val_loss: 0.3669
# Epoch 2/100
# 108/108 [==============================] - 12s 115ms/step - opt_accuracy: 0.8948 - sar_accuracy: 0.8182 - fus_accuracy: 0.7165 - opt_loss: 0.0611 - sar_loss: 0.1052 - fus_loss: 0.1627 - loss: 0.3290 - val_opt_accuracy: 0.8589 - val_sar_accuracy: 0.8019 - val_fus_accuracy: 0.6979 - val_opt_loss: 0.0914 - val_sar_loss: 0.1163 - val_fus_loss: 0.1560 - val_loss: 0.3637
# Epoch 3/100
# 108/108 [==============================] - 12s 115ms/step - opt_accuracy: 0.8952 - sar_accuracy: 0.8305 - fus_accuracy: 0.7035 - opt_loss: 0.0613 - sar_loss: 0.0976 - fus_loss: 0.1603 - loss: 0.3191 - val_opt_accuracy: 0.8577 - val_sar_accuracy: 0.8031 - val_fus_accuracy: 0.6871 - val_opt_loss: 0.0948 - val_sar_loss: 0.1147 - val_fus_loss: 0.1487 - val_loss: 0.3582
# Epoch 4/100
# 108/108 [==============================] - 13s 117ms/step - opt_accuracy: 0.8950 - sar_accuracy: 0.8400 - fus_accuracy: 0.7016 - opt_loss: 0.0613 - sar_loss: 0.0903 - fus_loss: 0.1604 - loss: 0.3119 - val_opt_accuracy: 0.8533 - val_sar_accuracy: 0.8098 - val_fus_accuracy: 0.6818 - val_opt_loss: 0.1036 - val_sar_loss: 0.1169 - val_fus_loss: 0.1480 - val_loss: 0.3685
# Epoch 5/100
# 108/108 [==============================] - 13s 117ms/step - opt_accuracy: 0.8947 - sar_accuracy: 0.8433 - fus_accuracy: 0.6976 - opt_loss: 0.0612 - sar_loss: 0.0870 - fus_loss: 0.1574 - loss: 0.3055 - val_opt_accuracy: 0.8542 - val_sar_accuracy: 0.8108 - val_fus_accuracy: 0.6837 - val_opt_loss: 0.1037 - val_sar_loss: 0.1139 - val_fus_loss: 0.1451 - val_loss: 0.3626
# Epoch 6/100
# 108/108 [==============================] - 13s 118ms/step - opt_accuracy: 0.8952 - sar_accuracy: 0.8491 - fus_accuracy: 0.6957 - opt_loss: 0.0615 - sar_loss: 0.0831 - fus_loss: 0.1572 - loss: 0.3018 - val_opt_accuracy: 0.8551 - val_sar_accuracy: 0.8005 - val_fus_accuracy: 0.6798 - val_opt_loss: 0.1033 - val_sar_loss: 0.1272 - val_fus_loss: 0.1428 - val_loss: 0.3734
# Epoch 7/100
# 108/108 [==============================] - 13s 120ms/step - opt_accuracy: 0.8950 - sar_accuracy: 0.8523 - fus_accuracy: 0.6909 - opt_loss: 0.0613 - sar_loss: 0.0792 - fus_loss: 0.1556 - loss: 0.2961 - val_opt_accuracy: 0.8536 - val_sar_accuracy: 0.8115 - val_fus_accuracy: 0.6582 - val_opt_loss: 0.1035 - val_sar_loss: 0.1318 - val_fus_loss: 0.1481 - val_loss: 0.3834 fus_accuracy: 0.6949 - opt_l
# Epoch 8/100
# 108/108 [==============================] - 13s 121ms/step - opt_accuracy: 0.8947 - sar_accuracy: 0.8595 - fus_accuracy: 0.6843 - opt_loss: 0.0614 - sar_loss: 0.0740 - fus_loss: 0.1547 - loss: 0.2902 - val_opt_accuracy: 0.8536 - val_sar_accuracy: 0.8153 - val_fus_accuracy: 0.6733 - val_opt_loss: 0.1036 - val_sar_loss: 0.1254 - val_fus_loss: 0.1481 - val_loss: 0.3772_accuracy: 0.6871 - opt_loss: 0.0612 - sar_loss: 0.073 - ETA: 2s - opt_accuracy: 0.8955 - sar_accuracy: 0.8621 - fus_accuracy: 0.6834 - opt_loss: 0.0610 - sar_loss: 0.0726 - fu
# Epoch 9/100
# 108/108 [==============================] - 13s 122ms/step - opt_accuracy: 0.8952 - sar_accuracy: 0.8676 - fus_accuracy: 0.6772 - opt_loss: 0.0611 - sar_loss: 0.0679 - fus_loss: 0.1536 - loss: 0.2825 - val_opt_accuracy: 0.8543 - val_sar_accuracy: 0.8055 - val_fus_accuracy: 0.6707 - val_opt_loss: 0.1038 - val_sar_loss: 0.1334 - val_fus_loss: 0.1489 - val_loss: 0.3861
# Epoch 10/100
# 108/108 [==============================] - 13s 124ms/step - opt_accuracy: 0.8952 - sar_accuracy: 0.8712 - fus_accuracy: 0.6720 - opt_loss: 0.0610 - sar_loss: 0.0646 - fus_loss: 0.1537 - loss: 0.2794 - val_opt_accuracy: 0.8541 - val_sar_accuracy: 0.8168 - val_fus_accuracy: 0.6604 - val_opt_loss: 0.1033 - val_sar_loss: 0.1357 - val_fus_loss: 0.1492 - val_loss: 0.3881- fus_accuracy: 0.6744 - opt
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# Epoch 1/100
# 108/108 [==============================] - 15s 127ms/step - opt_accuracy: 0.8675 - sar_accuracy: 0.7122 - fus_accuracy: 0.8894 - opt_loss: 0.0847 - sar_loss: 0.1271 - fus_loss: 0.0628 - loss: 0.2746 - val_opt_accuracy: 0.8399 - val_sar_accuracy: 0.7054 - val_fus_accuracy: 0.8542 - val_opt_loss: 0.0965 - val_sar_loss: 0.1210 - val_fus_loss: 0.1239 - val_loss: 0.34151 - fus_accuracy: 0.8857 - opt_loss: 0.0848 - sar_loss: 0.1285 - fus_loss: 0.0660 - ETA: 1s - opt_accuracy: 0.8692 - sar_accuracy: 0.7141 - fus_accuracy: 0.8876 - opt_loss: 0.0848 - sar_loss: 0.1274 - fus_loss: 0
#
# Epoch 00001: val_fus_loss improved from inf to 0.12394, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 2/100
# 108/108 [==============================] - 13s 125ms/step - opt_accuracy: 0.8589 - sar_accuracy: 0.7225 - fus_accuracy: 0.8999 - opt_loss: 0.0799 - sar_loss: 0.1258 - fus_loss: 0.0530 - loss: 0.2587 - val_opt_accuracy: 0.8461 - val_sar_accuracy: 0.6804 - val_fus_accuracy: 0.8542 - val_opt_loss: 0.0983 - val_sar_loss: 0.1249 - val_fus_loss: 0.1262 - val_loss: 0.3493ccuracy: 0.7309 - fus_accuracy: 0.8986 - opt_loss: 0.0814 - sar_loss: 0.1238 - fus_loss: 0.0536 - loss: 0.25 - ETA: 7s - opt_accuracy: 0.8603 - sar_accuracy: 0.7312 - fus_accuracy: 0
#
# Epoch 00002: val_fus_loss did not improve from 0.12394
# Epoch 3/100
# 108/108 [==============================] - 14s 128ms/step - opt_accuracy: 0.8576 - sar_accuracy: 0.6914 - fus_accuracy: 0.9037 - opt_loss: 0.0787 - sar_loss: 0.1284 - fus_loss: 0.0510 - loss: 0.2581 - val_opt_accuracy: 0.8354 - val_sar_accuracy: 0.6531 - val_fus_accuracy: 0.8473 - val_opt_loss: 0.0954 - val_sar_loss: 0.1620 - val_fus_loss: 0.1326 - val_loss: 0.3900
#
# Epoch 00003: val_fus_loss did not improve from 0.12394
# Epoch 4/100
# 108/108 [==============================] - 14s 129ms/step - opt_accuracy: 0.8388 - sar_accuracy: 0.7014 - fus_accuracy: 0.9115 - opt_loss: 0.0792 - sar_loss: 0.1294 - fus_loss: 0.0438 - loss: 0.2523 - val_opt_accuracy: 0.8480 - val_sar_accuracy: 0.6626 - val_fus_accuracy: 0.8531 - val_opt_loss: 0.0979 - val_sar_loss: 0.1516 - val_fus_loss: 0.1336 - val_loss: 0.3831
#
# Epoch 00004: val_fus_loss did not improve from 0.12394
# Epoch 5/100
# 108/108 [==============================] - 14s 129ms/step - opt_accuracy: 0.8141 - sar_accuracy: 0.7102 - fus_accuracy: 0.9149 - opt_loss: 0.0868 - sar_loss: 0.1275 - fus_loss: 0.0410 - loss: 0.2553 - val_opt_accuracy: 0.8060 - val_sar_accuracy: 0.7037 - val_fus_accuracy: 0.8532 - val_opt_loss: 0.1135 - val_sar_loss: 0.1370 - val_fus_loss: 0.1474 - val_loss: 0.3980
#
# Epoch 00005: val_fus_loss did not improve from 0.12394
# Epoch 6/100
# 108/108 [==============================] - 14s 129ms/step - opt_accuracy: 0.7980 - sar_accuracy: 0.7017 - fus_accuracy: 0.9225 - opt_loss: 0.0949 - sar_loss: 0.1304 - fus_loss: 0.0352 - loss: 0.2604 - val_opt_accuracy: 0.7689 - val_sar_accuracy: 0.6844 - val_fus_accuracy: 0.8532 - val_opt_loss: 0.1469 - val_sar_loss: 0.1394 - val_fus_loss: 0.1992 - val_loss: 0.4854
#
# Epoch 00006: val_fus_loss did not improve from 0.12394
# Epoch 00006: early stopping
# time:  2
# Model: "model_3_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,741,786
# Trainable params: 1,741,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 16s 132ms/step - opt_accuracy: 0.8758 - sar_accuracy: 0.6575 - fus_accuracy: 0.5827 - opt_loss: 0.0738 - sar_loss: 0.1855 - fus_loss: 0.1868 - loss: 0.4461 - val_opt_accuracy: 0.8603 - val_sar_accuracy: 0.6563 - val_fus_accuracy: 0.6024 - val_opt_loss: 0.1077 - val_sar_loss: 0.1818 - val_fus_loss: 0.1791 - val_loss: 0.4686
# Epoch 2/100
# 108/108 [==============================] - 14s 130ms/step - opt_accuracy: 0.8923 - sar_accuracy: 0.6575 - fus_accuracy: 0.5451 - opt_loss: 0.0610 - sar_loss: 0.1854 - fus_loss: 0.2036 - loss: 0.4500 - val_opt_accuracy: 0.8537 - val_sar_accuracy: 0.6564 - val_fus_accuracy: 0.5627 - val_opt_loss: 0.1310 - val_sar_loss: 0.1814 - val_fus_loss: 0.1903 - val_loss: 0.5027
# Epoch 3/100
# 108/108 [==============================] - 14s 130ms/step - opt_accuracy: 0.8965 - sar_accuracy: 0.6575 - fus_accuracy: 0.5442 - opt_loss: 0.0578 - sar_loss: 0.1854 - fus_loss: 0.2105 - loss: 0.4537 - val_opt_accuracy: 0.8516 - val_sar_accuracy: 0.6562 - val_fus_accuracy: 0.5574 - val_opt_loss: 0.1184 - val_sar_loss: 0.1817 - val_fus_loss: 0.1946 - val_loss: 0.4947
# Epoch 4/100
# 108/108 [==============================] - 14s 131ms/step - opt_accuracy: 0.9011 - sar_accuracy: 0.6574 - fus_accuracy: 0.5412 - opt_loss: 0.0536 - sar_loss: 0.1853 - fus_loss: 0.2237 - loss: 0.4626 - val_opt_accuracy: 0.8672 - val_sar_accuracy: 0.6563 - val_fus_accuracy: 0.5792 - val_opt_loss: 0.1184 - val_sar_loss: 0.1813 - val_fus_loss: 0.2069 - val_loss: 0.5065cy: 0.6574 - fus_accuracy: 0.5450 - opt_loss: 0.0543 - sar_loss: 0
# Epoch 5/100
# 108/108 [==============================] - 14s 133ms/step - opt_accuracy: 0.9053 - sar_accuracy: 0.6575 - fus_accuracy: 0.5339 - opt_loss: 0.0507 - sar_loss: 0.1861 - fus_loss: 0.2286 - loss: 0.4654 - val_opt_accuracy: 0.8602 - val_sar_accuracy: 0.6563 - val_fus_accuracy: 0.5570 - val_opt_loss: 0.1343 - val_sar_loss: 0.1809 - val_fus_loss: 0.2190 - val_loss: 0.5342s: 0.0509 - sar_loss: 0.1860 - fus_loss: 0.2272 - los
# Epoch 6/100
# 108/108 [==============================] - 15s 136ms/step - opt_accuracy: 0.9107 - sar_accuracy: 0.6575 - fus_accuracy: 0.5201 - opt_loss: 0.0453 - sar_loss: 0.1851 - fus_loss: 0.2340 - loss: 0.4644 - val_opt_accuracy: 0.8570 - val_sar_accuracy: 0.6563 - val_fus_accuracy: 0.5590 - val_opt_loss: 0.1227 - val_sar_loss: 0.1814 - val_fus_loss: 0.2143 - val_loss: 0.5184racy: 0.5192 - opt_loss: 0.0460 - sar_loss: 0.1850 - fus_ - ETA: 1s - opt_accuracy: 0.9109 - sar_accuracy: 0.6575 - fus_accuracy: 0.5180 - opt_loss: 0.0453 - sar_loss: 0.1852 - fus_loss: 0.2334
# Restoring model weights from the end of the best epoch.
# Epoch 00006: early stopping
# Epoch 1/100
# 108/108 [==============================] - 18s 151ms/step - opt_accuracy: 0.8860 - sar_accuracy: 0.7733 - fus_accuracy: 0.6028 - opt_loss: 0.0642 - sar_loss: 0.1297 - fus_loss: 0.1869 - loss: 0.3808 - val_opt_accuracy: 0.8626 - val_sar_accuracy: 0.7979 - val_fus_accuracy: 0.6617 - val_opt_loss: 0.1023 - val_sar_loss: 0.1176 - val_fus_loss: 0.1500 - val_loss: 0.3699
# Epoch 2/100
# 108/108 [==============================] - 15s 140ms/step - opt_accuracy: 0.8856 - sar_accuracy: 0.8117 - fus_accuracy: 0.6516 - opt_loss: 0.0644 - sar_loss: 0.1078 - fus_loss: 0.1603 - loss: 0.3325 - val_opt_accuracy: 0.8644 - val_sar_accuracy: 0.8110 - val_fus_accuracy: 0.6862 - val_opt_loss: 0.0925 - val_sar_loss: 0.1083 - val_fus_loss: 0.1355 - val_loss: 0.3364
# Epoch 3/100
# 108/108 [==============================] - 15s 141ms/step - opt_accuracy: 0.8857 - sar_accuracy: 0.8268 - fus_accuracy: 0.6582 - opt_loss: 0.0636 - sar_loss: 0.0977 - fus_loss: 0.1593 - loss: 0.3207 - val_opt_accuracy: 0.8636 - val_sar_accuracy: 0.8085 - val_fus_accuracy: 0.6762 - val_opt_loss: 0.0972 - val_sar_loss: 0.1123 - val_fus_loss: 0.1444 - val_loss: 0.3539
# Epoch 4/100
# 108/108 [==============================] - 16s 145ms/step - opt_accuracy: 0.8855 - sar_accuracy: 0.8325 - fus_accuracy: 0.6545 - opt_loss: 0.0643 - sar_loss: 0.0956 - fus_loss: 0.1643 - loss: 0.3242 - val_opt_accuracy: 0.8588 - val_sar_accuracy: 0.8088 - val_fus_accuracy: 0.6812 - val_opt_loss: 0.1080 - val_sar_loss: 0.1167 - val_fus_loss: 0.1473 - val_loss: 0.3721
# Epoch 5/100
# 108/108 [==============================] - 16s 145ms/step - opt_accuracy: 0.8857 - sar_accuracy: 0.8393 - fus_accuracy: 0.6606 - opt_loss: 0.0644 - sar_loss: 0.0902 - fus_loss: 0.1615 - loss: 0.3161 - val_opt_accuracy: 0.8593 - val_sar_accuracy: 0.8048 - val_fus_accuracy: 0.6887 - val_opt_loss: 0.1082 - val_sar_loss: 0.1217 - val_fus_loss: 0.1451 - val_loss: 0.3750
# Epoch 6/100
# 108/108 [==============================] - 16s 149ms/step - opt_accuracy: 0.8852 - sar_accuracy: 0.8452 - fus_accuracy: 0.6605 - opt_loss: 0.0645 - sar_loss: 0.0847 - fus_loss: 0.1637 - loss: 0.3129 - val_opt_accuracy: 0.8604 - val_sar_accuracy: 0.8175 - val_fus_accuracy: 0.6928 - val_opt_loss: 0.1074 - val_sar_loss: 0.1199 - val_fus_loss: 0.1495 - val_loss: 0.3768
# Epoch 7/100
# 108/108 [==============================] - 16s 147ms/step - opt_accuracy: 0.8859 - sar_accuracy: 0.8482 - fus_accuracy: 0.6615 - opt_loss: 0.0639 - sar_loss: 0.0826 - fus_loss: 0.1646 - loss: 0.3112 - val_opt_accuracy: 0.8597 - val_sar_accuracy: 0.8160 - val_fus_accuracy: 0.6904 - val_opt_loss: 0.1077 - val_sar_loss: 0.1226 - val_fus_loss: 0.1468 - val_loss: 0.3771
# Restoring model weights from the end of the best epoch.
# Epoch 00007: early stopping
# Epoch 1/100
# 108/108 [==============================] - 18s 153ms/step - opt_accuracy: 0.7311 - sar_accuracy: 0.6467 - fus_accuracy: 0.8833 - opt_loss: 0.0900 - sar_loss: 0.2114 - fus_loss: 0.0669 - loss: 0.3682 - val_opt_accuracy: 0.7525 - val_sar_accuracy: 0.6813 - val_fus_accuracy: 0.8536 - val_opt_loss: 0.1317 - val_sar_loss: 0.1954 - val_fus_loss: 0.1221 - val_loss: 0.4491
#
# Epoch 00001: val_fus_loss improved from inf to 0.12209, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 2/100
# 108/108 [==============================] - 16s 150ms/step - opt_accuracy: 0.7487 - sar_accuracy: 0.6614 - fus_accuracy: 0.8953 - opt_loss: 0.0820 - sar_loss: 0.2012 - fus_loss: 0.0588 - loss: 0.3420 - val_opt_accuracy: 0.7132 - val_sar_accuracy: 0.6627 - val_fus_accuracy: 0.8624 - val_opt_loss: 0.1214 - val_sar_loss: 0.1942 - val_fus_loss: 0.1105 - val_loss: 0.4261
#
# Epoch 00002: val_fus_loss improved from 0.12209 to 0.11055, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 3/100
# 108/108 [==============================] - 16s 151ms/step - opt_accuracy: 0.7836 - sar_accuracy: 0.6455 - fus_accuracy: 0.9003 - opt_loss: 0.0757 - sar_loss: 0.2029 - fus_loss: 0.0546 - loss: 0.3332 - val_opt_accuracy: 0.7510 - val_sar_accuracy: 0.5938 - val_fus_accuracy: 0.8651 - val_opt_loss: 0.1234 - val_sar_loss: 0.2060 - val_fus_loss: 0.1210 - val_loss: 0.4504
#
# Epoch 00003: val_fus_loss did not improve from 0.11055
# Epoch 4/100
# 108/108 [==============================] - 17s 155ms/step - opt_accuracy: 0.7870 - sar_accuracy: 0.6357 - fus_accuracy: 0.9047 - opt_loss: 0.0728 - sar_loss: 0.2079 - fus_loss: 0.0508 - loss: 0.3315 - val_opt_accuracy: 0.7762 - val_sar_accuracy: 0.6653 - val_fus_accuracy: 0.8701 - val_opt_loss: 0.1193 - val_sar_loss: 0.1911 - val_fus_loss: 0.1207 - val_loss: 0.4311
#
# Epoch 00004: val_fus_loss did not improve from 0.11055
# Epoch 5/100
# 108/108 [==============================] - 17s 155ms/step - opt_accuracy: 0.7902 - sar_accuracy: 0.6257 - fus_accuracy: 0.9099 - opt_loss: 0.0721 - sar_loss: 0.2071 - fus_loss: 0.0464 - loss: 0.3256 - val_opt_accuracy: 0.7629 - val_sar_accuracy: 0.6156 - val_fus_accuracy: 0.8672 - val_opt_loss: 0.1364 - val_sar_loss: 0.2129 - val_fus_loss: 0.1370 - val_loss: 0.4863
#
# Epoch 00005: val_fus_loss did not improve from 0.11055
# Epoch 6/100
# 108/108 [==============================] - 17s 158ms/step - opt_accuracy: 0.8178 - sar_accuracy: 0.6362 - fus_accuracy: 0.9145 - opt_loss: 0.0679 - sar_loss: 0.2059 - fus_loss: 0.0420 - loss: 0.3159 - val_opt_accuracy: 0.7868 - val_sar_accuracy: 0.6000 - val_fus_accuracy: 0.8644 - val_opt_loss: 0.1316 - val_sar_loss: 0.2167 - val_fus_loss: 0.1368 - val_loss: 0.4851
#
# Epoch 00006: val_fus_loss did not improve from 0.11055
# Epoch 7/100
# 108/108 [==============================] - 17s 159ms/step - opt_accuracy: 0.8153 - sar_accuracy: 0.6219 - fus_accuracy: 0.9180 - opt_loss: 0.0682 - sar_loss: 0.2100 - fus_loss: 0.0391 - loss: 0.3173 - val_opt_accuracy: 0.7952 - val_sar_accuracy: 0.6037 - val_fus_accuracy: 0.8589 - val_opt_loss: 0.1159 - val_sar_loss: 0.2241 - val_fus_loss: 0.1183 - val_loss: 0.4583
#
# Epoch 00007: val_fus_loss did not improve from 0.11055
# Epoch 00007: early stopping
# time:  3
# Model: "model_3_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,741,786
# Trainable params: 1,741,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 18s 158ms/step - opt_accuracy: 0.8694 - sar_accuracy: 0.6477 - fus_accuracy: 0.6233 - opt_loss: 0.0788 - sar_loss: 0.1806 - fus_loss: 0.2274 - loss: 0.4867 - val_opt_accuracy: 0.8580 - val_sar_accuracy: 0.6435 - val_fus_accuracy: 0.6114 - val_opt_loss: 0.1005 - val_sar_loss: 0.1748 - val_fus_loss: 0.2795 - val_loss: 0.5548
# Epoch 2/100
# 108/108 [==============================] - 17s 156ms/step - opt_accuracy: 0.8919 - sar_accuracy: 0.6476 - fus_accuracy: 0.6018 - opt_loss: 0.0624 - sar_loss: 0.1803 - fus_loss: 0.2933 - loss: 0.5360 - val_opt_accuracy: 0.8503 - val_sar_accuracy: 0.6429 - val_fus_accuracy: 0.6081 - val_opt_loss: 0.1008 - val_sar_loss: 0.1755 - val_fus_loss: 0.2407 - val_loss: 0.5171
# Epoch 3/100
# 108/108 [==============================] - 17s 157ms/step - opt_accuracy: 0.8966 - sar_accuracy: 0.6477 - fus_accuracy: 0.5720 - opt_loss: 0.0577 - sar_loss: 0.1807 - fus_loss: 0.3184 - loss: 0.5568 - val_opt_accuracy: 0.8533 - val_sar_accuracy: 0.6427 - val_fus_accuracy: 0.5970 - val_opt_loss: 0.1316 - val_sar_loss: 0.1754 - val_fus_loss: 0.2572 - val_loss: 0.5642
# Epoch 4/100
# 108/108 [==============================] - 17s 159ms/step - opt_accuracy: 0.8993 - sar_accuracy: 0.6479 - fus_accuracy: 0.5635 - opt_loss: 0.0560 - sar_loss: 0.1806 - fus_loss: 0.3254 - loss: 0.5619 - val_opt_accuracy: 0.8631 - val_sar_accuracy: 0.6434 - val_fus_accuracy: 0.5979 - val_opt_loss: 0.1064 - val_sar_loss: 0.1746 - val_fus_loss: 0.2676 - val_loss: 0.5486
# Epoch 5/100
# 108/108 [==============================] - 17s 161ms/step - opt_accuracy: 0.9026 - sar_accuracy: 0.6477 - fus_accuracy: 0.5732 - opt_loss: 0.0525 - sar_loss: 0.1804 - fus_loss: 0.3398 - loss: 0.5728 - val_opt_accuracy: 0.8620 - val_sar_accuracy: 0.6429 - val_fus_accuracy: 0.6019 - val_opt_loss: 0.1309 - val_sar_loss: 0.1750 - val_fus_loss: 0.2609 - val_loss: 0.5668
# Epoch 6/100
# 108/108 [==============================] - 18s 163ms/step - opt_accuracy: 0.9049 - sar_accuracy: 0.6477 - fus_accuracy: 0.5682 - opt_loss: 0.0502 - sar_loss: 0.1805 - fus_loss: 0.3651 - loss: 0.5957 - val_opt_accuracy: 0.8635 - val_sar_accuracy: 0.6432 - val_fus_accuracy: 0.6110 - val_opt_loss: 0.1362 - val_sar_loss: 0.1745 - val_fus_loss: 0.2765 - val_loss: 0.5872
# Restoring model weights from the end of the best epoch.
# Epoch 00006: early stopping
# Epoch 1/100
# 108/108 [==============================] - 22s 185ms/step - opt_accuracy: 0.8826 - sar_accuracy: 0.7806 - fus_accuracy: 0.5473 - opt_loss: 0.0687 - sar_loss: 0.1228 - fus_loss: 0.4831 - loss: 0.6746 - val_opt_accuracy: 0.8593 - val_sar_accuracy: 0.7972 - val_fus_accuracy: 0.5653 - val_opt_loss: 0.0997 - val_sar_loss: 0.1197 - val_fus_loss: 0.5101 - val_loss: 0.7295
# Epoch 2/100
# 108/108 [==============================] - 19s 175ms/step - opt_accuracy: 0.8823 - sar_accuracy: 0.8160 - fus_accuracy: 0.5282 - opt_loss: 0.0687 - sar_loss: 0.1043 - fus_loss: 0.5734 - loss: 0.7464 - val_opt_accuracy: 0.8609 - val_sar_accuracy: 0.7963 - val_fus_accuracy: 0.5446 - val_opt_loss: 0.0993 - val_sar_loss: 0.1191 - val_fus_loss: 0.4928 - val_loss: 0.7111
# Epoch 3/100
# 108/108 [==============================] - 19s 176ms/step - opt_accuracy: 0.8822 - sar_accuracy: 0.8291 - fus_accuracy: 0.5213 - opt_loss: 0.0690 - sar_loss: 0.0955 - fus_loss: 0.6060 - loss: 0.7705 - val_opt_accuracy: 0.8616 - val_sar_accuracy: 0.8151 - val_fus_accuracy: 0.5430 - val_opt_loss: 0.0953 - val_sar_loss: 0.1120 - val_fus_loss: 0.6063 - val_loss: 0.8136
# Epoch 4/100
# 108/108 [==============================] - 19s 181ms/step - opt_accuracy: 0.8826 - sar_accuracy: 0.8389 - fus_accuracy: 0.5118 - opt_loss: 0.0683 - sar_loss: 0.0893 - fus_loss: 0.6414 - loss: 0.7990 - val_opt_accuracy: 0.8633 - val_sar_accuracy: 0.8138 - val_fus_accuracy: 0.5495 - val_opt_loss: 0.0875 - val_sar_loss: 0.1045 - val_fus_loss: 0.5344 - val_loss: 0.7264
# Epoch 5/100
# 108/108 [==============================] - 20s 182ms/step - opt_accuracy: 0.8821 - sar_accuracy: 0.8427 - fus_accuracy: 0.5096 - opt_loss: 0.0684 - sar_loss: 0.0871 - fus_loss: 0.6459 - loss: 0.8014 - val_opt_accuracy: 0.8628 - val_sar_accuracy: 0.8132 - val_fus_accuracy: 0.5449 - val_opt_loss: 0.0918 - val_sar_loss: 0.1105 - val_fus_loss: 0.5656 - val_loss: 0.7679
# Epoch 6/100
# 108/108 [==============================] - 20s 182ms/step - opt_accuracy: 0.8827 - sar_accuracy: 0.8474 - fus_accuracy: 0.4983 - opt_loss: 0.0691 - sar_loss: 0.0834 - fus_loss: 0.6602 - loss: 0.8127 - val_opt_accuracy: 0.8580 - val_sar_accuracy: 0.8134 - val_fus_accuracy: 0.5242 - val_opt_loss: 0.1005 - val_sar_loss: 0.1178 - val_fus_loss: 0.6050 - val_loss: 0.8232
# Epoch 7/100
# 108/108 [==============================] - 20s 183ms/step - opt_accuracy: 0.8822 - sar_accuracy: 0.8540 - fus_accuracy: 0.4930 - opt_loss: 0.0696 - sar_loss: 0.0794 - fus_loss: 0.6824 - loss: 0.8314 - val_opt_accuracy: 0.8579 - val_sar_accuracy: 0.8195 - val_fus_accuracy: 0.5188 - val_opt_loss: 0.1005 - val_sar_loss: 0.1232 - val_fus_loss: 0.7151 - val_loss: 0.9388
# Epoch 8/100
# 108/108 [==============================] - 20s 187ms/step - opt_accuracy: 0.8817 - sar_accuracy: 0.8630 - fus_accuracy: 0.4775 - opt_loss: 0.0693 - sar_loss: 0.0719 - fus_loss: 0.7284 - loss: 0.8696 - val_opt_accuracy: 0.8590 - val_sar_accuracy: 0.8248 - val_fus_accuracy: 0.5041 - val_opt_loss: 0.1000 - val_sar_loss: 0.1164 - val_fus_loss: 0.6608 - val_loss: 0.8773
# Epoch 9/100
# 108/108 [==============================] - 20s 187ms/step - opt_accuracy: 0.8826 - sar_accuracy: 0.8712 - fus_accuracy: 0.4698 - opt_loss: 0.0686 - sar_loss: 0.0666 - fus_loss: 0.7691 - loss: 0.9042 - val_opt_accuracy: 0.8585 - val_sar_accuracy: 0.8191 - val_fus_accuracy: 0.5170 - val_opt_loss: 0.1001 - val_sar_loss: 0.1348 - val_fus_loss: 0.7403 - val_loss: 0.9752
# Restoring model weights from the end of the best epoch.
# Epoch 00009: early stopping
# Epoch 1/100
# 108/108 [==============================] - 22s 191ms/step - opt_accuracy: 0.6412 - sar_accuracy: 0.7010 - fus_accuracy: 0.8700 - opt_loss: 0.1698 - sar_loss: 0.1612 - fus_loss: 0.0759 - loss: 0.4069 - val_opt_accuracy: 0.6121 - val_sar_accuracy: 0.7090 - val_fus_accuracy: 0.8608 - val_opt_loss: 0.2124 - val_sar_loss: 0.1557 - val_fus_loss: 0.1001 - val_loss: 0.4682
#
# Epoch 00001: val_fus_loss improved from inf to 0.10008, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 2/100
# 108/108 [==============================] - 21s 192ms/step - opt_accuracy: 0.6231 - sar_accuracy: 0.6893 - fus_accuracy: 0.8947 - opt_loss: 0.2002 - sar_loss: 0.1672 - fus_loss: 0.0593 - loss: 0.4266 - val_opt_accuracy: 0.6176 - val_sar_accuracy: 0.6846 - val_fus_accuracy: 0.8632 - val_opt_loss: 0.2096 - val_sar_loss: 0.1623 - val_fus_loss: 0.0987 - val_loss: 0.4706
#
# Epoch 00002: val_fus_loss improved from 0.10008 to 0.09872, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 3/100
# 108/108 [==============================] - 21s 191ms/step - opt_accuracy: 0.6252 - sar_accuracy: 0.6848 - fus_accuracy: 0.8989 - opt_loss: 0.2081 - sar_loss: 0.1664 - fus_loss: 0.0555 - loss: 0.4300 - val_opt_accuracy: 0.6175 - val_sar_accuracy: 0.6883 - val_fus_accuracy: 0.8659 - val_opt_loss: 0.2312 - val_sar_loss: 0.1614 - val_fus_loss: 0.0999 - val_loss: 0.4925
#
# Epoch 00003: val_fus_loss did not improve from 0.09872
# Epoch 4/100
# 108/108 [==============================] - 21s 193ms/step - opt_accuracy: 0.6235 - sar_accuracy: 0.6819 - fus_accuracy: 0.9038 - opt_loss: 0.2176 - sar_loss: 0.1659 - fus_loss: 0.0514 - loss: 0.4348 - val_opt_accuracy: 0.6112 - val_sar_accuracy: 0.6778 - val_fus_accuracy: 0.8570 - val_opt_loss: 0.2553 - val_sar_loss: 0.1603 - val_fus_loss: 0.1462 - val_loss: 0.5618
#
# Epoch 00004: val_fus_loss did not improve from 0.09872
# Epoch 5/100
# 108/108 [==============================] - 21s 195ms/step - opt_accuracy: 0.6219 - sar_accuracy: 0.6848 - fus_accuracy: 0.9063 - opt_loss: 0.2367 - sar_loss: 0.1679 - fus_loss: 0.0492 - loss: 0.4538 - val_opt_accuracy: 0.6222 - val_sar_accuracy: 0.6698 - val_fus_accuracy: 0.8667 - val_opt_loss: 0.2511 - val_sar_loss: 0.1625 - val_fus_loss: 0.1208 - val_loss: 0.5344
#
# Epoch 00005: val_fus_loss did not improve from 0.09872
# Epoch 6/100
# 108/108 [==============================] - 21s 198ms/step - opt_accuracy: 0.6199 - sar_accuracy: 0.6776 - fus_accuracy: 0.9106 - opt_loss: 0.2460 - sar_loss: 0.1672 - fus_loss: 0.0451 - loss: 0.4583 - val_opt_accuracy: 0.6253 - val_sar_accuracy: 0.6638 - val_fus_accuracy: 0.8690 - val_opt_loss: 0.2365 - val_sar_loss: 0.1642 - val_fus_loss: 0.1093 - val_loss: 0.5100
#
# Epoch 00006: val_fus_loss did not improve from 0.09872
# Epoch 7/100
# 108/108 [==============================] - 21s 196ms/step - opt_accuracy: 0.6165 - sar_accuracy: 0.6742 - fus_accuracy: 0.9160 - opt_loss: 0.2800 - sar_loss: 0.1664 - fus_loss: 0.0404 - loss: 0.4868 - val_opt_accuracy: 0.6178 - val_sar_accuracy: 0.6489 - val_fus_accuracy: 0.8689 - val_opt_loss: 0.3176 - val_sar_loss: 0.1606 - val_fus_loss: 0.1431 - val_loss: 0.6214
#
# Epoch 00007: val_fus_loss did not improve from 0.09872
# Epoch 00007: early stopping
# time:  4
# Model: "model_3_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,741,786
# Trainable params: 1,741,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 23s 202ms/step - opt_accuracy: 0.8758 - sar_accuracy: 0.6628 - fus_accuracy: 0.8341 - opt_loss: 0.0756 - sar_loss: 0.1850 - fus_loss: 0.1109 - loss: 0.3715 - val_opt_accuracy: 0.8517 - val_sar_accuracy: 0.6627 - val_fus_accuracy: 0.8417 - val_opt_loss: 0.1085 - val_sar_loss: 0.1814 - val_fus_loss: 0.1040 - val_loss: 0.3940
# Epoch 2/100
# 108/108 [==============================] - 21s 194ms/step - opt_accuracy: 0.8906 - sar_accuracy: 0.6628 - fus_accuracy: 0.8525 - opt_loss: 0.0623 - sar_loss: 0.1846 - fus_loss: 0.0951 - loss: 0.3420 - val_opt_accuracy: 0.8548 - val_sar_accuracy: 0.6627 - val_fus_accuracy: 0.8461 - val_opt_loss: 0.1051 - val_sar_loss: 0.1820 - val_fus_loss: 0.0979 - val_loss: 0.3849
# Epoch 3/100
# 108/108 [==============================] - 21s 199ms/step - opt_accuracy: 0.8949 - sar_accuracy: 0.6628 - fus_accuracy: 0.8553 - opt_loss: 0.0591 - sar_loss: 0.1851 - fus_loss: 0.0924 - loss: 0.3366 - val_opt_accuracy: 0.8565 - val_sar_accuracy: 0.6626 - val_fus_accuracy: 0.8537 - val_opt_loss: 0.1071 - val_sar_loss: 0.1822 - val_fus_loss: 0.0985 - val_loss: 0.3878
# Epoch 4/100
# 108/108 [==============================] - 22s 202ms/step - opt_accuracy: 0.8977 - sar_accuracy: 0.6627 - fus_accuracy: 0.8570 - opt_loss: 0.0574 - sar_loss: 0.1846 - fus_loss: 0.0912 - loss: 0.3331 - val_opt_accuracy: 0.8656 - val_sar_accuracy: 0.6626 - val_fus_accuracy: 0.8437 - val_opt_loss: 0.1124 - val_sar_loss: 0.1817 - val_fus_loss: 0.1027 - val_loss: 0.3968
# Epoch 5/100
# 108/108 [==============================] - 22s 202ms/step - opt_accuracy: 0.9014 - sar_accuracy: 0.6628 - fus_accuracy: 0.8685 - opt_loss: 0.0535 - sar_loss: 0.1848 - fus_loss: 0.0843 - loss: 0.3227 - val_opt_accuracy: 0.8495 - val_sar_accuracy: 0.6625 - val_fus_accuracy: 0.8495 - val_opt_loss: 0.1122 - val_sar_loss: 0.1819 - val_fus_loss: 0.1000 - val_loss: 0.3942
# Epoch 6/100
# 108/108 [==============================] - 22s 204ms/step - opt_accuracy: 0.9067 - sar_accuracy: 0.6628 - fus_accuracy: 0.8748 - opt_loss: 0.0488 - sar_loss: 0.1850 - fus_loss: 0.0784 - loss: 0.3122 - val_opt_accuracy: 0.8593 - val_sar_accuracy: 0.6625 - val_fus_accuracy: 0.8466 - val_opt_loss: 0.1224 - val_sar_loss: 0.1816 - val_fus_loss: 0.1069 - val_loss: 0.4110acy: 0.8737 - opt_loss: 0.
# Epoch 7/100
# 108/108 [==============================] - 22s 204ms/step - opt_accuracy: 0.9103 - sar_accuracy: 0.6627 - fus_accuracy: 0.8795 - opt_loss: 0.0459 - sar_loss: 0.1848 - fus_loss: 0.0751 - loss: 0.3058 - val_opt_accuracy: 0.8638 - val_sar_accuracy: 0.6624 - val_fus_accuracy: 0.8523 - val_opt_loss: 0.1507 - val_sar_loss: 0.1815 - val_fus_loss: 0.1043 - val_loss: 0.4364
# Restoring model weights from the end of the best epoch.
# Epoch 00007: early stopping
# Epoch 1/100
# 108/108 [==============================] - 26s 228ms/step - opt_accuracy: 0.8947 - sar_accuracy: 0.7796 - fus_accuracy: 0.8552 - opt_loss: 0.0586 - sar_loss: 0.1273 - fus_loss: 0.0868 - loss: 0.2727 - val_opt_accuracy: 0.8572 - val_sar_accuracy: 0.8026 - val_fus_accuracy: 0.8571 - val_opt_loss: 0.1041 - val_sar_loss: 0.1180 - val_fus_loss: 0.0898 - val_loss: 0.3119
# Epoch 2/100
# 108/108 [==============================] - 23s 217ms/step - opt_accuracy: 0.8943 - sar_accuracy: 0.8128 - fus_accuracy: 0.8631 - opt_loss: 0.0590 - sar_loss: 0.1078 - fus_loss: 0.0824 - loss: 0.2492 - val_opt_accuracy: 0.8581 - val_sar_accuracy: 0.8086 - val_fus_accuracy: 0.8591 - val_opt_loss: 0.1005 - val_sar_loss: 0.1136 - val_fus_loss: 0.0868 - val_loss: 0.3009
# Epoch 3/100
# 108/108 [==============================] - 23s 215ms/step - opt_accuracy: 0.8945 - sar_accuracy: 0.8294 - fus_accuracy: 0.8673 - opt_loss: 0.0588 - sar_loss: 0.0978 - fus_loss: 0.0802 - loss: 0.2368 - val_opt_accuracy: 0.8604 - val_sar_accuracy: 0.8075 - val_fus_accuracy: 0.8581 - val_opt_loss: 0.0914 - val_sar_loss: 0.1124 - val_fus_loss: 0.0851 - val_loss: 0.2888
# Epoch 4/100
# 108/108 [==============================] - 24s 221ms/step - opt_accuracy: 0.8943 - sar_accuracy: 0.8398 - fus_accuracy: 0.8668 - opt_loss: 0.0591 - sar_loss: 0.0895 - fus_loss: 0.0795 - loss: 0.2281 - val_opt_accuracy: 0.8595 - val_sar_accuracy: 0.8138 - val_fus_accuracy: 0.8601 - val_opt_loss: 0.0950 - val_sar_loss: 0.1154 - val_fus_loss: 0.0851 - val_loss: 0.2955
# Epoch 5/100
# 108/108 [==============================] - 23s 219ms/step - opt_accuracy: 0.8948 - sar_accuracy: 0.8432 - fus_accuracy: 0.8671 - opt_loss: 0.0589 - sar_loss: 0.0868 - fus_loss: 0.0794 - loss: 0.2252 - val_opt_accuracy: 0.8541 - val_sar_accuracy: 0.8134 - val_fus_accuracy: 0.8575 - val_opt_loss: 0.1053 - val_sar_loss: 0.1146 - val_fus_loss: 0.0900 - val_loss: 0.3099
# Epoch 6/100
# 108/108 [==============================] - 24s 223ms/step - opt_accuracy: 0.8941 - sar_accuracy: 0.8486 - fus_accuracy: 0.8666 - opt_loss: 0.0589 - sar_loss: 0.0825 - fus_loss: 0.0792 - loss: 0.2206 - val_opt_accuracy: 0.8548 - val_sar_accuracy: 0.8134 - val_fus_accuracy: 0.8578 - val_opt_loss: 0.1050 - val_sar_loss: 0.1229 - val_fus_loss: 0.0895 - val_loss: 0.3174
# Epoch 7/100
# 108/108 [==============================] - 24s 225ms/step - opt_accuracy: 0.8946 - sar_accuracy: 0.8539 - fus_accuracy: 0.8643 - opt_loss: 0.0589 - sar_loss: 0.0781 - fus_loss: 0.0808 - loss: 0.2178 - val_opt_accuracy: 0.8557 - val_sar_accuracy: 0.8187 - val_fus_accuracy: 0.8594 - val_opt_loss: 0.1046 - val_sar_loss: 0.1180 - val_fus_loss: 0.0897 - val_loss: 0.3123
# Epoch 8/100
# 108/108 [==============================] - 24s 224ms/step - opt_accuracy: 0.8943 - sar_accuracy: 0.8577 - fus_accuracy: 0.8657 - opt_loss: 0.0594 - sar_loss: 0.0760 - fus_loss: 0.0810 - loss: 0.2163 - val_opt_accuracy: 0.8549 - val_sar_accuracy: 0.8107 - val_fus_accuracy: 0.8592 - val_opt_loss: 0.1050 - val_sar_loss: 0.1333 - val_fus_loss: 0.0900 - val_loss: 0.3283
# Restoring model weights from the end of the best epoch.
# Epoch 00008: early stopping
# Epoch 1/100
# 108/108 [==============================] - 27s 233ms/step - opt_accuracy: 0.8893 - sar_accuracy: 0.7530 - fus_accuracy: 0.8921 - opt_loss: 0.0644 - sar_loss: 0.1314 - fus_loss: 0.0605 - loss: 0.2563 - val_opt_accuracy: 0.8540 - val_sar_accuracy: 0.7410 - val_fus_accuracy: 0.8586 - val_opt_loss: 0.1669 - val_sar_loss: 0.1374 - val_fus_loss: 0.1251 - val_loss: 0.429305 - fus_accuracy: 0.8880 - opt_loss: 0.0667 - sar_loss - ETA: 1s - opt_accuracy: 0.8885 - sar_accuracy: 0.7548 - fus_accuracy: 0.8914 - opt_loss: 0.0650 - sar_loss: 0.1311 - fus_loss: 0.0610 - loss: 0. - ETA: 0s - opt_accuracy: 0.8886 - sar_accuracy: 0.7541 - fus_accuracy: 0.8915 - opt_loss: 0.0649 - sar_loss: 0.1312 - fus_loss: 0.0609 - loss:
#
# Epoch 00001: val_fus_loss improved from inf to 0.12506, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 2/100
# 108/108 [==============================] - 25s 229ms/step - opt_accuracy: 0.8924 - sar_accuracy: 0.7338 - fus_accuracy: 0.8990 - opt_loss: 0.0615 - sar_loss: 0.1347 - fus_loss: 0.0549 - loss: 0.2512 - val_opt_accuracy: 0.8411 - val_sar_accuracy: 0.7218 - val_fus_accuracy: 0.8519 - val_opt_loss: 0.1745 - val_sar_loss: 0.1304 - val_fus_loss: 0.1316 - val_loss: 0.4365ccuracy: 0.8983 - o
#
# Epoch 00002: val_fus_loss did not improve from 0.12506
# Epoch 3/100
# 108/108 [==============================] - 25s 230ms/step - opt_accuracy: 0.8951 - sar_accuracy: 0.7148 - fus_accuracy: 0.9041 - opt_loss: 0.0598 - sar_loss: 0.1384 - fus_loss: 0.0512 - loss: 0.2495 - val_opt_accuracy: 0.8600 - val_sar_accuracy: 0.6536 - val_fus_accuracy: 0.8634 - val_opt_loss: 0.1361 - val_sar_loss: 0.1533 - val_fus_loss: 0.1101 - val_loss: 0.3995
#
# Epoch 00003: val_fus_loss improved from 0.12506 to 0.11015, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 4/100
# 108/108 [==============================] - 25s 232ms/step - opt_accuracy: 0.8951 - sar_accuracy: 0.7005 - fus_accuracy: 0.9066 - opt_loss: 0.0594 - sar_loss: 0.1384 - fus_loss: 0.0488 - loss: 0.2466 - val_opt_accuracy: 0.8647 - val_sar_accuracy: 0.6818 - val_fus_accuracy: 0.8652 - val_opt_loss: 0.1408 - val_sar_loss: 0.1420 - val_fus_loss: 0.1263 - val_loss: 0.4090
#
# Epoch 00004: val_fus_loss did not improve from 0.11015
# Epoch 5/100
# 108/108 [==============================] - 25s 232ms/step - opt_accuracy: 0.8993 - sar_accuracy: 0.6923 - fus_accuracy: 0.9127 - opt_loss: 0.0557 - sar_loss: 0.1350 - fus_loss: 0.0433 - loss: 0.2340 - val_opt_accuracy: 0.8666 - val_sar_accuracy: 0.6683 - val_fus_accuracy: 0.8688 - val_opt_loss: 0.1518 - val_sar_loss: 0.1506 - val_fus_loss: 0.1300 - val_loss: 0.4324
#
# Epoch 00005: val_fus_loss did not improve from 0.11015
# Epoch 6/100
# 108/108 [==============================] - 26s 240ms/step - opt_accuracy: 0.9036 - sar_accuracy: 0.6762 - fus_accuracy: 0.9212 - opt_loss: 0.0535 - sar_loss: 0.1383 - fus_loss: 0.0367 - loss: 0.2285 - val_opt_accuracy: 0.8670 - val_sar_accuracy: 0.6727 - val_fus_accuracy: 0.8687 - val_opt_loss: 0.1436 - val_sar_loss: 0.1378 - val_fus_loss: 0.1298 - val_loss: 0.4113accuracy: 0.6890 - fus_accuracy: 0.9208 - opt_loss: 0.0538 - sar_loss: 0.1381 - fus_loss: 0.0377 - loss:  - ETA: 16s - opt_accuracy: 0.9039 - sar_accuracy: 0.6940 - fus_accuracy: 0.9208 - opt_loss: 0.0538 - sar_loss: 0.1372 - fus_loss: 0.0376 - loss:  - ETA: 15s - opt_accuracy: 0.9044 - sar_accuracy: 0.6931 - fus_accuracy: 0.9209 - opt_loss: 0.053 - ETA: 10s - opt_accuracy: 0.9038 - sar_accuracy: 0.6844 - fus_accuracy: 0.9208 - opt_loss: 0.
#
# Epoch 00006: val_fus_loss did not improve from 0.11015
# Epoch 7/100
# 108/108 [==============================] - 26s 240ms/step - opt_accuracy: 0.9045 - sar_accuracy: 0.6733 - fus_accuracy: 0.9231 - opt_loss: 0.0522 - sar_loss: 0.1365 - fus_loss: 0.0348 - loss: 0.2236 - val_opt_accuracy: 0.8619 - val_sar_accuracy: 0.6608 - val_fus_accuracy: 0.8586 - val_opt_loss: 0.1424 - val_sar_loss: 0.1554 - val_fus_loss: 0.1336 - val_loss: 0.4314- sar_accuracy: 0.6745 - fus_accuracy: 0.9227 - opt_loss: 0.0524 - sar_loss: 0.1356 - fus_loss: 0
#
# Epoch 00007: val_fus_loss did not improve from 0.11015
# Epoch 8/100
# 108/108 [==============================] - 26s 245ms/step - opt_accuracy: 0.9075 - sar_accuracy: 0.6719 - fus_accuracy: 0.9288 - opt_loss: 0.0505 - sar_loss: 0.1375 - fus_loss: 0.0309 - loss: 0.2190 - val_opt_accuracy: 0.8589 - val_sar_accuracy: 0.6498 - val_fus_accuracy: 0.8580 - val_opt_loss: 0.1549 - val_sar_loss: 0.1412 - val_fus_loss: 0.1469 - val_loss: 0.4431loss: 0.0501 - sar_loss: 0.1378 - fus_loss: 0.0325 - loss - ETA: 12s - opt_accuracy: 0.9089 - sar_accuracy: 0.6795 - fus_accur
#
# Epoch 00008: val_fus_loss did not improve from 0.11015
# Epoch 00008: early stopping

# %%
# Test loop
time_ts = []
n_pool = 3
n_rows = 20 #5
n_cols = 16 #4
rows, cols = image_array.shape[:2]
pad_rows = rows - np.ceil(rows/(n_rows*2**n_pool))*n_rows*2**n_pool
pad_cols = cols - np.ceil(cols/(n_cols*2**n_pool))*n_cols*2**n_pool
print(pad_rows, pad_cols)

npad = ((0, int(abs(pad_rows))), (0, int(abs(pad_cols))), (0, 0))
image1_pad = np.pad(image_array, pad_width=npad, mode='reflect')

h, w, c = image1_pad.shape
patch_size_rows = h//n_rows
patch_size_cols = w//n_cols
num_patches_x = int(h/patch_size_rows)
num_patches_y = int(w/patch_size_cols)

input_shape=(patch_size_rows,patch_size_cols, c)

#if method == 'unet':
#   new_model = build_unet(input_shape, nb_filters, number_class)

#if method == 'resunet':
#   new_model = build_resunet(input_shape, nb_filters, number_class)

new_model = Model_3(nb_filters, number_class, n_opt_layers)
new_model.build((None,)+input_shape)
adam = Adam(lr = 1e-3 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
new_model.compile(optimizer=adam, loss=loss, metrics=['accuracy'], run_eagerly=True)

for tm in range(0,times):
    print('time: ', tm)
    #model = load_model(path_models+ '/' + method +'_'+str(tm)+'.h5', compile=False)
    
    #for l in range(1, len(model.layers)):
    #    new_model.layers[l].set_weights(model.layers[l].get_weights())
    new_model.load_weights(path_models+ '/' + method +'_'+str(tm)+'.h5')
    
    start_test = time.time()
    patch_opt = []
    patch_sar = []
    patch_fus = []
    patch_comb = []
    
    for i in range(0,num_patches_y):
        for j in range(0,num_patches_x):
            patch = image1_pad[patch_size_rows*j:patch_size_rows*(j+1), patch_size_cols*i:patch_size_cols*(i+1), :]
            pred_opt, pred_sar, pred_fus, pred_comb = new_model.predict(np.expand_dims(patch, axis=0))
            del patch 
            patch_opt.append(pred_opt[:,:,:,1])
            patch_sar.append(pred_sar[:,:,:,1])
            patch_fus.append(pred_fus[:,:,:,1])
            patch_comb.append(pred_comb[:,:,:,1])
            del pred_opt, pred_sar, pred_fus, pred_comb
    end_test =  time.time() - start_test

    patches_pred_opt = np.asarray(patch_opt).astype(np.float32)
    patches_pred_sar = np.asarray(patch_sar).astype(np.float32)
    patches_pred_fus = np.asarray(patch_fus).astype(np.float32)
    patches_pred_comb = np.asarray(patch_comb).astype(np.float32)

    prob_recontructed_opt = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_opt)
    prob_recontructed_sar = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_sar)
    prob_recontructed_fus = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_fus)
    prob_recontructed_comb = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_comb)

    del patches_pred_opt, patches_pred_sar, patches_pred_fus, patches_pred_comb
    np.save(path_maps+'/'+'prob_opt_'+str(tm)+'.npy',prob_recontructed_opt) 
    np.save(path_maps+'/'+'prob_sar_'+str(tm)+'.npy',prob_recontructed_sar) 
    np.save(path_maps+'/'+'prob_fus_'+str(tm)+'.npy',prob_recontructed_fus) 
    np.save(path_maps+'/'+'prob_comb_'+str(tm)+'.npy',prob_recontructed_comb) 

    time_ts.append(end_test)
    del prob_recontructed_opt, prob_recontructed_sar, prob_recontructed_fus, prob_recontructed_comb
    #del model
time_ts_array = np.asarray(time_ts)
# Save test time
np.save(path_exp+'/metrics_ts.npy', time_ts_array)
# Out:
# -80.0 -40.0
# time:  0
# time:  1
# time:  2
# time:  3
# time:  4

# %%
# Compute mean of the tm predictions maps
prob_rec_opt = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_sar = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_fus = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_comb = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))

for tm in range (0, times):
    print(tm)
    prob_rec_opt[:,:,tm] = np.load(path_maps+'/'+'prob_opt_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_sar[:,:,tm] = np.load(path_maps+'/'+'prob_sar_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_fus[:,:,tm] = np.load(path_maps+'/'+'prob_fus_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_comb[:,:,tm] = np.load(path_maps+'/'+'prob_comb_'+str(tm)+'.npy').astype(np.float32)

mean_prob_opt = np.mean(prob_rec_opt, axis = -1)
mean_prob_sar = np.mean(prob_rec_sar, axis = -1)
mean_prob_fus = np.mean(prob_rec_fus, axis = -1)
mean_prob_comb = np.mean(prob_rec_comb, axis = -1)

np.save(path_maps+'/prob_mean_opt.npy', mean_prob_opt)
np.save(path_maps+'/prob_mean_sar.npy', mean_prob_sar)
np.save(path_maps+'/prob_mean_fus.npy', mean_prob_fus)
np.save(path_maps+'/prob_mean_comb.npy', mean_prob_comb)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Plot mean map and reference
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(151)
plt.title('OPT Prediction')
ax1.imshow(mean_prob_opt, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(152)
plt.title('SAR Prediction')
ax1.imshow(mean_prob_sar, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(153)
plt.title('FUSION Prediction')
ax1.imshow(mean_prob_fus, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(154)
plt.title('COMBINATION Prediction')
ax1.imshow(mean_prob_comb, cmap ='jet')
ax1.axis('off')

ax2 = fig.add_subplot(155)
plt.title('Reference')
ax2.imshow(tf.keras.utils.to_categorical(final_mask1, 3)[:,:,1], cmap ='jet')
ax2.axis('off')
# Out:
# (-0.5, 6999.5, 9999.5, -0.5)

# %%
# Computing metrics
mean_prob_opt = mean_prob_opt[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_sar = mean_prob_sar[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_fus = mean_prob_fus[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_comb = mean_prob_comb[:final_mask1.shape[0], :final_mask1.shape[1]]

ref1 = np.ones_like(final_mask1).astype(np.float32)

ref1 [final_mask1 == 2] = 0
TileMask = mask_amazon_ts * ref1
GTTruePositives = final_mask1==1
    
Npoints = 50

Pmax_opt = np.max(mean_prob_opt[GTTruePositives * TileMask ==1])
ProbList_opt = np.linspace(Pmax_opt,0,Npoints)

Pmax_sar = np.max(mean_prob_sar[GTTruePositives * TileMask ==1])
ProbList_sar = np.linspace(Pmax_sar,0,Npoints)

Pmax_fus = np.max(mean_prob_fus[GTTruePositives * TileMask ==1])
ProbList_fus = np.linspace(Pmax_fus,0,Npoints)

Pmax_comb = np.max(mean_prob_comb[GTTruePositives * TileMask ==1])
ProbList_comb = np.linspace(Pmax_comb,0,Npoints)


from multiprocessing.pool import Pool
pool = Pool(processes=4)

async_result_opt = pool.apply_async(matrics_AA_recall, (ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625))
async_result_sar = pool.apply_async(matrics_AA_recall, (ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625))
async_result_fus = pool.apply_async(matrics_AA_recall, (ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625))
async_result_comb = pool.apply_async(matrics_AA_recall, (ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625))

metrics_opt = async_result_opt.get()
metrics_sar = async_result_sar.get()
metrics_fus = async_result_fus.get()
metrics_comb = async_result_comb.get()
    
#metrics_opt = matrics_AA_recall(ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625)
#metrics_sar = matrics_AA_recall(ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625)
#metrics_fus = matrics_AA_recall(ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625)
#metrics_comb = matrics_AA_recall(ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625)

np.save(path_exp+'/acc_metrics_opt.npy',metrics_opt)
np.save(path_exp+'/acc_metrics_sar.npy',metrics_sar)
np.save(path_exp+'/acc_metrics_fus.npy',metrics_fus)
np.save(path_exp+'/acc_metrics_comb.npy',metrics_comb)

# %%
# Complete NaN values
metrics_copy_opt = metrics_opt.copy()
metrics_copy_opt = complete_nan_values(metrics_copy_opt)

metrics_copy_sar = metrics_sar.copy()
metrics_copy_sar = complete_nan_values(metrics_copy_sar)

metrics_copy_fus = metrics_fus.copy()
metrics_copy_fus = complete_nan_values(metrics_copy_fus)

metrics_copy_comb = metrics_comb.copy()
metrics_copy_comb = complete_nan_values(metrics_copy_comb)

# %%
# Comput Mean Average Precision (mAP) score 
Recall_opt = metrics_copy_opt[:,0]
Precision_opt = metrics_copy_opt[:,1]
AA_opt = metrics_copy_opt[:,2]

Recall_sar = metrics_copy_sar[:,0]
Precision_sar = metrics_copy_sar[:,1]
AA_sar = metrics_copy_sar[:,2]

Recall_fus = metrics_copy_fus[:,0]
Precision_fus = metrics_copy_fus[:,1]
AA_fus = metrics_copy_fus[:,2]

Recall_comb = metrics_copy_comb[:,0]
Precision_comb = metrics_copy_comb[:,1]
AA_comb = metrics_copy_comb[:,2]
    
DeltaR_opt = Recall_opt[1:]-Recall_opt[:-1]
AP_opt = np.sum(Precision_opt[:-1]*DeltaR_opt)
print('OPT mAP', AP_opt)

DeltaR_sar = Recall_sar[1:]-Recall_sar[:-1]
AP_sar = np.sum(Precision_sar[:-1]*DeltaR_sar)
print('SAR mAP', AP_sar)

DeltaR_fus = Recall_fus[1:]-Recall_fus[:-1]
AP_fus = np.sum(Precision_fus[:-1]*DeltaR_fus)
print('FUSION mAP', AP_fus)

DeltaR_comb = Recall_comb[1:]-Recall_comb[:-1]
AP_comb = np.sum(Precision_comb[:-1]*DeltaR_comb)
print('COMBINATION mAP', AP_comb)

# Plot Recall vs. Precision curve
plt.figure(figsize=(7,7))
plt.plot(metrics_copy_opt[:,0],metrics_copy_opt[:,1], 'r-', label = f'OPT (AP: {AP_opt:.4f})')
plt.plot(metrics_copy_sar[:,0],metrics_copy_sar[:,1], 'g-', label = f'SAR (AP: {AP_sar:.4f})')
plt.plot(metrics_copy_fus[:,0],metrics_copy_fus[:,1], 'b-', label = f'FUSION (AP: {AP_fus:.4f})')
plt.plot(metrics_copy_comb[:,0],metrics_copy_comb[:,1], 'k-', label = f'COMBINATION (AP: {AP_comb:.4f})')
plt.legend(loc="lower left")
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([0,1])
#plt.plot(metrics_copy[:,0],metrics_copy[:,2])
plt.grid()
# Out:
# OPT mAP 0.9089974428497767
# SAR mAP 0.10555029096925583
# FUSION mAP 0.9380595927185859
# COMBINATION mAP 0.931197169223415
