# %%
# %load_ext autoreload
# %autoreload 2

# %%
#%autoreload # When utils.py is updated
from utils_unet_resunet import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from model.models import Model_3
from model.losses import WBCE
from model.callbacks import UpdateWeights
from multiprocessing.pool import Pool

root_path = 'imgs/'

# %%
# Define data type 
img_type = 'FUSION'

if img_type == 'FUSION':
    image_array = np.load(root_path+'New_Images/fus_stack.npy')
    

if img_type == 'OPT':
    image_array = np.load(root_path+'New_Images/opt_stack.npy')
    
    
if img_type == 'SAR':
    image_array = np.load(root_path+'New_Images/sar_stack.npy')
print('Image stack:', image_array.shape)

final_mask1 = np.load(root_path+'New_Images/'+'final_mask1.npy')
print('Labels stack:', final_mask1.shape)

h_, w_, channels = image_array.shape
n_opt_layers = 20
# Out:
# Image stack: (10000, 7000, 24)
# Labels stack: (10000, 7000)

# %%
# Create tile mask
mask_tiles = create_mask(final_mask1.shape[0], final_mask1.shape[1], grid_size=(5, 4))
image_array = image_array[:mask_tiles.shape[0], :mask_tiles.shape[1],:]
final_mask1 = final_mask1[:mask_tiles.shape[0], :mask_tiles.shape[1]]

print('mask: ',mask_tiles.shape)
print('image stack: ', image_array.shape)
print('ref :', final_mask1.shape)
#plt.imshow(mask_tiles)
# Out:
# Tiles size:  2000 1750
# Mask size:  (10000, 7000)
# mask:  (10000, 7000)
# image stack:  (10000, 7000, 24)
# ref : (10000, 7000)

# %%
plt.figure(figsize=(10,5))
plt.imshow(final_mask1, cmap = 'jet')

# %%
# Define tiles for training, validation, and test sets
tiles_tr = [1,3,5,8,11,13,14,20]
tiles_val = [6,19]
tiles_ts = (list(set(np.arange(20)+1)-set(tiles_tr)-set(tiles_val)))

mask_tr_val = np.zeros((mask_tiles.shape)).astype('float32')
# Training and validation mask
for tr_ in tiles_tr:
    mask_tr_val[mask_tiles == tr_] = 1

for val_ in tiles_val:
    mask_tr_val[mask_tiles == val_] = 2

mask_amazon_ts = np.zeros((mask_tiles.shape)).astype('float32')
for ts_ in tiles_ts:
    mask_amazon_ts[mask_tiles == ts_] = 1

# %%
# Create ixd image to extract patches
overlap = 0.7
patch_size = 128
batch_size = 32
im_idx = create_idx_image(final_mask1)
patches_idx = extract_patches(im_idx, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1,patch_size, patch_size)
patches_mask = extract_patches(mask_tr_val, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1, patch_size, patch_size)
del im_idx

# %%
# Selecting index trn val and test patches idx
idx_trn = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==patch_size**2))
idx_val = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==2*patch_size**2))
del patches_mask

patches_idx_trn = patches_idx[idx_trn]
patches_idx_val = patches_idx[idx_val]
del idx_trn, idx_val

print('Number of training patches:  ', len(patches_idx_trn), 'Number of validation patches', len(patches_idx_val))
# Out:
# Number of training patches:   17110 Number of validation patches 4116

# %%
# Extract patches with at least 2% of deforestation class
X_train = retrieve_idx_percentage(final_mask1, patches_idx_trn, patch_size, pertentage = 2)
X_valid = retrieve_idx_percentage(final_mask1, patches_idx_val, patch_size, pertentage = 2)
print(X_train.shape, X_valid.shape)
del patches_idx_trn, patches_idx_val
# Out:
# (1158, 128, 128) (341, 128, 128)

# %%
def batch_generator(batches, image, reference, target_size, number_class):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    image = image.reshape(-1, image.shape[-1])
    reference = reference.reshape(final_mask1.shape[0]*final_mask1.shape[1])
    while True:
        batch_x, batch_y = next(batches)
        batch_x = np.squeeze(batch_x.astype('int64'))
        #print(batch_x.shape)
        batch_img = np.zeros((batch_x.shape[0], target_size, target_size, image.shape[-1]))
        batch_ref = np.zeros((batch_x.shape[0], target_size, target_size, number_class))
        
        for i in range(batch_x.shape[0]):
            if np.random.rand()>0.5:
                batch_x[i] = np.rot90(batch_x[i], 1)
            batch_img[i] = image[batch_x[i]] 
            batch_ref[i] = tf.keras.utils.to_categorical(reference[batch_x[i]] , number_class)
                       
        yield (batch_img, batch_ref)

train_datagen = ImageDataGenerator(horizontal_flip = True,
                                   vertical_flip = True)
valid_datagen = ImageDataGenerator(horizontal_flip = True, 
                                   vertical_flip = True)

y_train = np.zeros((len(X_train)))
y_valid = np.zeros((len(X_valid)))

train_gen = train_datagen.flow(np.expand_dims(X_train, axis = -1), y_train,
                              batch_size=batch_size,
                              shuffle=True)

valid_gen = valid_datagen.flow(np.expand_dims(X_valid, axis = -1), y_valid,
                              batch_size=batch_size,
                              shuffle=False)

number_class = 3
train_gen_crops = batch_generator(train_gen, image_array, final_mask1, patch_size, number_class)
valid_gen_crops = batch_generator(valid_gen, image_array, final_mask1, patch_size, number_class)

# %%
exp = 3
path_exp = root_path+'experiments/exp'+str(exp)
path_models = path_exp+'/models'
path_maps = path_exp+'/pred_maps'

if not os.path.exists(path_exp):
    os.makedirs(path_exp)   
if not os.path.exists(path_models):
    os.makedirs(path_models)   
if not os.path.exists(path_maps):
    os.makedirs(path_maps)

# %%
# Define model
input_shape = (patch_size, patch_size, channels)
nb_filters = [32, 64, 128]

method = 'unet'
if method == 'unet':
   model = build_unet(input_shape, nb_filters, number_class)

if method == 'resunet':
   model = build_resunet(input_shape, nb_filters, number_class)

model = Model_3(nb_filters, number_class, n_opt_layers)

# %%
# Parameters of the model
weights = [0.2, 0.8, 0]
adam = Adam(lr = 1e-4 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
#loss = WBCE(weights = weights)
#loss = WBCE(weights = weights, class_indexes = [0, 1])

# %%
metrics_all = []
times=5
for tm in range(0,times):
    print('time: ', tm)

    rows = patch_size
    cols = patch_size
    adam = Adam(lr = 1e-4 , beta_1=0.9)
    
    loss = weighted_categorical_crossentropy(weights)
    #loss = WBCE(weights = weights)
    #loss = WBCE(weights = weights, class_indexes = [0, 1])

    #if method == 'unet':
    #   model = build_unet(input_shape, nb_filters, number_class)

    #if method == 'resunet':
    #   model = build_resunet(input_shape, nb_filters, number_class)
    
    model = Model_3(nb_filters, number_class, n_opt_layers)
    model.build((None,)+input_shape)
    
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    model.summary()

    earlystop = EarlyStopping(monitor='val_sar_loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
    #earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min') ---- val_accuracy
    #checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_sar_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
    lr_reduce = ReduceLROnPlateau(factor=0.9, min_delta=0.0001, patience=5, verbose=1)
    updateWeights = UpdateWeights()
    callbacks_list = [earlystop, checkpoint, updateWeights]
    # train the model
    start_training = time.time()
    history = model.fit(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    end_training = time.time() - start_training
    metrics_all.append(end_training)
    del model, history
# Out:
# time:  0
# Model: "model_3_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 12s 98ms/step - opt_accuracy: 0.6227 - sar_accuracy: 0.7498 - fus_accuracy: 0.6041 - opt_loss: 0.1905 - sar_loss: 0.1366 - fusion_loss: 0.2318 - loss: 0.5588 - val_opt_accuracy: 0.6279 - val_sar_accuracy: 0.7975 - val_fus_accuracy: 0.6023 - val_opt_loss: 0.1932 - val_sar_loss: 0.1199 - val_fusion_loss: 0.2339 - val_loss: 0.5470
#
# Epoch 00001: val_sar_loss improved from inf to 0.11993, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 2/100
# 108/108 [==============================] - 10s 95ms/step - opt_accuracy: 0.6363 - sar_accuracy: 0.8000 - fus_accuracy: 0.6068 - opt_loss: 0.1865 - sar_loss: 0.1160 - fusion_loss: 0.2336 - loss: 0.5361 - val_opt_accuracy: 0.6451 - val_sar_accuracy: 0.7958 - val_fus_accuracy: 0.6056 - val_opt_loss: 0.1743 - val_sar_loss: 0.1237 - val_fusion_loss: 0.2368 - val_loss: 0.5348
#
# Epoch 00002: val_sar_loss did not improve from 0.11993
# Epoch 3/100
# 108/108 [==============================] - 10s 95ms/step - opt_accuracy: 0.6438 - sar_accuracy: 0.8125 - fus_accuracy: 0.6046 - opt_loss: 0.1767 - sar_loss: 0.1070 - fusion_loss: 0.2549 - loss: 0.5386 - val_opt_accuracy: 0.6464 - val_sar_accuracy: 0.8008 - val_fus_accuracy: 0.6079 - val_opt_loss: 0.1665 - val_sar_loss: 0.1243 - val_fusion_loss: 0.2591 - val_loss: 0.5499
#
# Epoch 00003: val_sar_loss did not improve from 0.11993
# Epoch 4/100
# 108/108 [==============================] - 10s 97ms/step - opt_accuracy: 0.6430 - sar_accuracy: 0.8183 - fus_accuracy: 0.6054 - opt_loss: 0.1710 - sar_loss: 0.1028 - fusion_loss: 0.2653 - loss: 0.5390 - val_opt_accuracy: 0.6421 - val_sar_accuracy: 0.8028 - val_fus_accuracy: 0.6008 - val_opt_loss: 0.1540 - val_sar_loss: 0.1143 - val_fusion_loss: 0.2787 - val_loss: 0.5470
#
# Epoch 00004: val_sar_loss improved from 0.11993 to 0.11428, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 5/100
# 108/108 [==============================] - 11s 98ms/step - opt_accuracy: 0.6369 - sar_accuracy: 0.8227 - fus_accuracy: 0.6068 - opt_loss: 0.1671 - sar_loss: 0.1006 - fusion_loss: 0.2720 - loss: 0.5396 - val_opt_accuracy: 0.6358 - val_sar_accuracy: 0.7980 - val_fus_accuracy: 0.6062 - val_opt_loss: 0.1510 - val_sar_loss: 0.1185 - val_fusion_loss: 0.2860 - val_loss: 0.5555
#
# Epoch 00005: val_sar_loss did not improve from 0.11428
# Epoch 6/100
# 108/108 [==============================] - 10s 97ms/step - opt_accuracy: 0.6346 - sar_accuracy: 0.8301 - fus_accuracy: 0.6085 - opt_loss: 0.1645 - sar_loss: 0.0958 - fusion_loss: 0.2759 - loss: 0.5362 - val_opt_accuracy: 0.6316 - val_sar_accuracy: 0.8019 - val_fus_accuracy: 0.6162 - val_opt_loss: 0.1470 - val_sar_loss: 0.1108 - val_fusion_loss: 0.2693 - val_loss: 0.5271
#
# Epoch 00006: val_sar_loss improved from 0.11428 to 0.11081, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 7/100
# 108/108 [==============================] - 11s 99ms/step - opt_accuracy: 0.6284 - sar_accuracy: 0.8356 - fus_accuracy: 0.6121 - opt_loss: 0.1644 - sar_loss: 0.0929 - fusion_loss: 0.2730 - loss: 0.5303 - val_opt_accuracy: 0.6299 - val_sar_accuracy: 0.7953 - val_fus_accuracy: 0.6101 - val_opt_loss: 0.1459 - val_sar_loss: 0.1217 - val_fusion_loss: 0.2796 - val_loss: 0.5472
#
# Epoch 00007: val_sar_loss did not improve from 0.11081
# Epoch 8/100
# 108/108 [==============================] - 11s 98ms/step - opt_accuracy: 0.6247 - sar_accuracy: 0.8350 - fus_accuracy: 0.6122 - opt_loss: 0.1629 - sar_loss: 0.0925 - fusion_loss: 0.2737 - loss: 0.5290 - val_opt_accuracy: 0.6251 - val_sar_accuracy: 0.7997 - val_fus_accuracy: 0.6073 - val_opt_loss: 0.1483 - val_sar_loss: 0.1199 - val_fusion_loss: 0.2710 - val_loss: 0.5392
#
# Epoch 00008: val_sar_loss did not improve from 0.11081
# Epoch 9/100
# 108/108 [==============================] - 11s 100ms/step - opt_accuracy: 0.6212 - sar_accuracy: 0.8410 - fus_accuracy: 0.6134 - opt_loss: 0.1632 - sar_loss: 0.0894 - fusion_loss: 0.2726 - loss: 0.5253 - val_opt_accuracy: 0.6178 - val_sar_accuracy: 0.8065 - val_fus_accuracy: 0.5999 - val_opt_loss: 0.1464 - val_sar_loss: 0.1255 - val_fusion_loss: 0.2930 - val_loss: 0.5649
#
# Epoch 00009: val_sar_loss did not improve from 0.11081
# Epoch 10/100
# 108/108 [==============================] - 11s 101ms/step - opt_accuracy: 0.6105 - sar_accuracy: 0.8408 - fus_accuracy: 0.6140 - opt_loss: 0.1627 - sar_loss: 0.0893 - fusion_loss: 0.2735 - loss: 0.5255 - val_opt_accuracy: 0.6141 - val_sar_accuracy: 0.8092 - val_fus_accuracy: 0.5985 - val_opt_loss: 0.1454 - val_sar_loss: 0.1208 - val_fusion_loss: 0.2915 - val_loss: 0.5576
#
# Epoch 00010: val_sar_loss did not improve from 0.11081
# Epoch 11/100
# 108/108 [==============================] - 11s 102ms/step - opt_accuracy: 0.6027 - sar_accuracy: 0.8436 - fus_accuracy: 0.6170 - opt_loss: 0.1622 - sar_loss: 0.0868 - fusion_loss: 0.2745 - loss: 0.5236 - val_opt_accuracy: 0.6024 - val_sar_accuracy: 0.7975 - val_fus_accuracy: 0.6032 - val_opt_loss: 0.1434 - val_sar_loss: 0.1210 - val_fusion_loss: 0.2828 - val_loss: 0.5472
#
# Epoch 00011: val_sar_loss did not improve from 0.11081
# Epoch 12/100
# 108/108 [==============================] - 11s 102ms/step - opt_accuracy: 0.5886 - sar_accuracy: 0.8482 - fus_accuracy: 0.6164 - opt_loss: 0.1642 - sar_loss: 0.0838 - fusion_loss: 0.2771 - loss: 0.5251 - val_opt_accuracy: 0.5860 - val_sar_accuracy: 0.8087 - val_fus_accuracy: 0.5982 - val_opt_loss: 0.1439 - val_sar_loss: 0.1164 - val_fusion_loss: 0.2931 - val_loss: 0.5534
#
# Epoch 00012: val_sar_loss did not improve from 0.11081
# Epoch 13/100
# 108/108 [==============================] - 11s 104ms/step - opt_accuracy: 0.5831 - sar_accuracy: 0.8471 - fus_accuracy: 0.6164 - opt_loss: 0.1642 - sar_loss: 0.0839 - fusion_loss: 0.2783 - loss: 0.5265 - val_opt_accuracy: 0.5842 - val_sar_accuracy: 0.8148 - val_fus_accuracy: 0.6040 - val_opt_loss: 0.1465 - val_sar_loss: 0.1342 - val_fusion_loss: 0.2955 - val_loss: 0.5763
#
# Epoch 00013: val_sar_loss did not improve from 0.11081
# Epoch 14/100
# 108/108 [==============================] - 11s 104ms/step - opt_accuracy: 0.5844 - sar_accuracy: 0.8508 - fus_accuracy: 0.6199 - opt_loss: 0.1660 - sar_loss: 0.0816 - fusion_loss: 0.2756 - loss: 0.5231 - val_opt_accuracy: 0.5847 - val_sar_accuracy: 0.8137 - val_fus_accuracy: 0.6056 - val_opt_loss: 0.1488 - val_sar_loss: 0.1193 - val_fusion_loss: 0.2914 - val_loss: 0.5595
#
# Epoch 00014: val_sar_loss did not improve from 0.11081
# Epoch 15/100
# 108/108 [==============================] - 11s 104ms/step - opt_accuracy: 0.5819 - sar_accuracy: 0.8519 - fus_accuracy: 0.6175 - opt_loss: 0.1669 - sar_loss: 0.0803 - fusion_loss: 0.2775 - loss: 0.5247 - val_opt_accuracy: 0.5811 - val_sar_accuracy: 0.8104 - val_fus_accuracy: 0.5995 - val_opt_loss: 0.1509 - val_sar_loss: 0.1283 - val_fusion_loss: 0.3063 - val_loss: 0.5855
#
# Epoch 00015: val_sar_loss did not improve from 0.11081
# Epoch 16/100
# 108/108 [==============================] - 11s 107ms/step - opt_accuracy: 0.5841 - sar_accuracy: 0.8522 - fus_accuracy: 0.6177 - opt_loss: 0.1682 - sar_loss: 0.0803 - fusion_loss: 0.2798 - loss: 0.5283 - val_opt_accuracy: 0.5865 - val_sar_accuracy: 0.8061 - val_fus_accuracy: 0.6074 - val_opt_loss: 0.1523 - val_sar_loss: 0.1193 - val_fusion_loss: 0.2845 - val_loss: 0.5561
#
# Epoch 00016: val_sar_loss did not improve from 0.11081
# Epoch 00016: early stopping
# time:  1
# Model: "model_3_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 13s 110ms/step - opt_accuracy: 0.7092 - sar_accuracy: 0.7571 - fus_accuracy: 0.6312 - opt_loss: 0.1435 - sar_loss: 0.1340 - fusion_loss: 0.1727 - loss: 0.4502 - val_opt_accuracy: 0.6958 - val_sar_accuracy: 0.7854 - val_fus_accuracy: 0.6288 - val_opt_loss: 0.1371 - val_sar_loss: 0.1164 - val_fusion_loss: 0.1807 - val_loss: 0.4342
#
# Epoch 00001: val_sar_loss improved from inf to 0.11643, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 2/100
# 108/108 [==============================] - 12s 107ms/step - opt_accuracy: 0.6991 - sar_accuracy: 0.7989 - fus_accuracy: 0.6264 - opt_loss: 0.1497 - sar_loss: 0.1150 - fusion_loss: 0.1926 - loss: 0.4573 - val_opt_accuracy: 0.6871 - val_sar_accuracy: 0.7866 - val_fus_accuracy: 0.6150 - val_opt_loss: 0.1463 - val_sar_loss: 0.1228 - val_fusion_loss: 0.2153 - val_loss: 0.4843
#
# Epoch 00002: val_sar_loss did not improve from 0.11643
# Epoch 3/100
# 108/108 [==============================] - 12s 108ms/step - opt_accuracy: 0.6964 - sar_accuracy: 0.8141 - fus_accuracy: 0.6281 - opt_loss: 0.1550 - sar_loss: 0.1063 - fusion_loss: 0.1929 - loss: 0.4542 - val_opt_accuracy: 0.6856 - val_sar_accuracy: 0.7890 - val_fus_accuracy: 0.6172 - val_opt_loss: 0.1516 - val_sar_loss: 0.1178 - val_fusion_loss: 0.1978 - val_loss: 0.4672
#
# Epoch 00003: val_sar_loss did not improve from 0.11643
# Epoch 4/100
# 108/108 [==============================] - 12s 109ms/step - opt_accuracy: 0.6934 - sar_accuracy: 0.8228 - fus_accuracy: 0.6364 - opt_loss: 0.1604 - sar_loss: 0.1000 - fusion_loss: 0.1870 - loss: 0.4474 - val_opt_accuracy: 0.6906 - val_sar_accuracy: 0.7913 - val_fus_accuracy: 0.6146 - val_opt_loss: 0.1563 - val_sar_loss: 0.1157 - val_fusion_loss: 0.1972 - val_loss: 0.4691
#
# Epoch 00004: val_sar_loss improved from 0.11643 to 0.11569, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 5/100
# 108/108 [==============================] - 12s 110ms/step - opt_accuracy: 0.6906 - sar_accuracy: 0.8299 - fus_accuracy: 0.6412 - opt_loss: 0.1642 - sar_loss: 0.0957 - fusion_loss: 0.1861 - loss: 0.4461 - val_opt_accuracy: 0.6909 - val_sar_accuracy: 0.7999 - val_fus_accuracy: 0.6115 - val_opt_loss: 0.1601 - val_sar_loss: 0.1163 - val_fusion_loss: 0.1980 - val_loss: 0.4744
#
# Epoch 00005: val_sar_loss did not improve from 0.11569
# Epoch 6/100
# 108/108 [==============================] - 12s 109ms/step - opt_accuracy: 0.6892 - sar_accuracy: 0.8343 - fus_accuracy: 0.6387 - opt_loss: 0.1678 - sar_loss: 0.0931 - fusion_loss: 0.1912 - loss: 0.4521 - val_opt_accuracy: 0.6823 - val_sar_accuracy: 0.7880 - val_fus_accuracy: 0.6206 - val_opt_loss: 0.1629 - val_sar_loss: 0.1165 - val_fusion_loss: 0.1967 - val_loss: 0.4762
#
# Epoch 00006: val_sar_loss did not improve from 0.11569
# Epoch 7/100
# 108/108 [==============================] - 12s 111ms/step - opt_accuracy: 0.6823 - sar_accuracy: 0.8375 - fus_accuracy: 0.6425 - opt_loss: 0.1722 - sar_loss: 0.0918 - fusion_loss: 0.1926 - loss: 0.4565 - val_opt_accuracy: 0.6732 - val_sar_accuracy: 0.8033 - val_fus_accuracy: 0.6121 - val_opt_loss: 0.1702 - val_sar_loss: 0.1172 - val_fusion_loss: 0.2067 - val_loss: 0.4941
#
# Epoch 00007: val_sar_loss did not improve from 0.11569
# Epoch 8/100
# 108/108 [==============================] - 12s 112ms/step - opt_accuracy: 0.6728 - sar_accuracy: 0.8375 - fus_accuracy: 0.6442 - opt_loss: 0.1778 - sar_loss: 0.0902 - fusion_loss: 0.1943 - loss: 0.4623 - val_opt_accuracy: 0.6562 - val_sar_accuracy: 0.8030 - val_fus_accuracy: 0.6132 - val_opt_loss: 0.1772 - val_sar_loss: 0.1244 - val_fusion_loss: 0.2149 - val_loss: 0.5166
#
# Epoch 00008: val_sar_loss did not improve from 0.11569
# Epoch 9/100
# 108/108 [==============================] - 12s 114ms/step - opt_accuracy: 0.6643 - sar_accuracy: 0.8393 - fus_accuracy: 0.6448 - opt_loss: 0.1809 - sar_loss: 0.0911 - fusion_loss: 0.1977 - loss: 0.4698 - val_opt_accuracy: 0.6507 - val_sar_accuracy: 0.8063 - val_fus_accuracy: 0.6151 - val_opt_loss: 0.1777 - val_sar_loss: 0.1207 - val_fusion_loss: 0.2136 - val_loss: 0.5121
#
# Epoch 00009: val_sar_loss did not improve from 0.11569
# Epoch 10/100
# 108/108 [==============================] - 12s 115ms/step - opt_accuracy: 0.6501 - sar_accuracy: 0.8419 - fus_accuracy: 0.6447 - opt_loss: 0.1860 - sar_loss: 0.0878 - fusion_loss: 0.1990 - loss: 0.4727 - val_opt_accuracy: 0.6338 - val_sar_accuracy: 0.8069 - val_fus_accuracy: 0.6137 - val_opt_loss: 0.1857 - val_sar_loss: 0.1176 - val_fusion_loss: 0.2123 - val_loss: 0.5156
#
# Epoch 00010: val_sar_loss did not improve from 0.11569
# Epoch 11/100
# 108/108 [==============================] - 13s 117ms/step - opt_accuracy: 0.6288 - sar_accuracy: 0.8450 - fus_accuracy: 0.6475 - opt_loss: 0.1923 - sar_loss: 0.0860 - fusion_loss: 0.2017 - loss: 0.4799 - val_opt_accuracy: 0.6184 - val_sar_accuracy: 0.7968 - val_fus_accuracy: 0.6211 - val_opt_loss: 0.1891 - val_sar_loss: 0.1188 - val_fusion_loss: 0.2156 - val_loss: 0.5235
#
# Epoch 00011: val_sar_loss did not improve from 0.11569
# Epoch 12/100
# 108/108 [==============================] - 12s 116ms/step - opt_accuracy: 0.6193 - sar_accuracy: 0.8487 - fus_accuracy: 0.6449 - opt_loss: 0.1953 - sar_loss: 0.0828 - fusion_loss: 0.2068 - loss: 0.4850 - val_opt_accuracy: 0.5984 - val_sar_accuracy: 0.8059 - val_fus_accuracy: 0.6247 - val_opt_loss: 0.1944 - val_sar_loss: 0.1179 - val_fusion_loss: 0.2177 - val_loss: 0.5300
#
# Epoch 00012: val_sar_loss did not improve from 0.11569
# Epoch 13/100
# 108/108 [==============================] - 13s 118ms/step - opt_accuracy: 0.6093 - sar_accuracy: 0.8486 - fus_accuracy: 0.6459 - opt_loss: 0.1984 - sar_loss: 0.0824 - fusion_loss: 0.2089 - loss: 0.4897 - val_opt_accuracy: 0.5926 - val_sar_accuracy: 0.8089 - val_fus_accuracy: 0.6179 - val_opt_loss: 0.1979 - val_sar_loss: 0.1127 - val_fusion_loss: 0.2216 - val_loss: 0.5321
#
# Epoch 00013: val_sar_loss improved from 0.11569 to 0.11265, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 14/100
# 108/108 [==============================] - 13s 119ms/step - opt_accuracy: 0.5949 - sar_accuracy: 0.8522 - fus_accuracy: 0.6433 - opt_loss: 0.2036 - sar_loss: 0.0795 - fusion_loss: 0.2122 - loss: 0.4953 - val_opt_accuracy: 0.5857 - val_sar_accuracy: 0.8013 - val_fus_accuracy: 0.6133 - val_opt_loss: 0.2019 - val_sar_loss: 0.1372 - val_fusion_loss: 0.2336 - val_loss: 0.5726
#
# Epoch 00014: val_sar_loss did not improve from 0.11265
# Epoch 15/100
# 108/108 [==============================] - 13s 121ms/step - opt_accuracy: 0.5934 - sar_accuracy: 0.8530 - fus_accuracy: 0.6447 - opt_loss: 0.2037 - sar_loss: 0.0790 - fusion_loss: 0.2125 - loss: 0.4952 - val_opt_accuracy: 0.5975 - val_sar_accuracy: 0.8115 - val_fus_accuracy: 0.6051 - val_opt_loss: 0.1992 - val_sar_loss: 0.1398 - val_fusion_loss: 0.2375 - val_loss: 0.5765
#
# Epoch 00015: val_sar_loss did not improve from 0.11265
# Epoch 16/100
# 108/108 [==============================] - 13s 122ms/step - opt_accuracy: 0.5960 - sar_accuracy: 0.8550 - fus_accuracy: 0.6409 - opt_loss: 0.2037 - sar_loss: 0.0776 - fusion_loss: 0.2164 - loss: 0.4976 - val_opt_accuracy: 0.5928 - val_sar_accuracy: 0.8104 - val_fus_accuracy: 0.6029 - val_opt_loss: 0.2018 - val_sar_loss: 0.1304 - val_fusion_loss: 0.2369 - val_loss: 0.5692
#
# Epoch 00016: val_sar_loss did not improve from 0.11265
# Epoch 17/100
# 108/108 [==============================] - 14s 129ms/step - opt_accuracy: 0.5836 - sar_accuracy: 0.8585 - fus_accuracy: 0.6433 - opt_loss: 0.2078 - sar_loss: 0.0747 - fusion_loss: 0.2152 - loss: 0.4976 - val_opt_accuracy: 0.5820 - val_sar_accuracy: 0.8112 - val_fus_accuracy: 0.6052 - val_opt_loss: 0.2050 - val_sar_loss: 0.1349 - val_fusion_loss: 0.2397 - val_loss: 0.5795
#
# Epoch 00017: val_sar_loss did not improve from 0.11265
# Epoch 18/100
# 108/108 [==============================] - 13s 123ms/step - opt_accuracy: 0.5775 - sar_accuracy: 0.8594 - fus_accuracy: 0.6429 - opt_loss: 0.2105 - sar_loss: 0.0741 - fusion_loss: 0.2181 - loss: 0.5027 - val_opt_accuracy: 0.5684 - val_sar_accuracy: 0.8052 - val_fus_accuracy: 0.6048 - val_opt_loss: 0.2119 - val_sar_loss: 0.1198 - val_fusion_loss: 0.2347 - val_loss: 0.5664
#
# Epoch 00018: val_sar_loss did not improve from 0.11265
# Epoch 19/100
# 108/108 [==============================] - 13s 125ms/step - opt_accuracy: 0.5701 - sar_accuracy: 0.8641 - fus_accuracy: 0.6425 - opt_loss: 0.2130 - sar_loss: 0.0715 - fusion_loss: 0.2200 - loss: 0.5045 - val_opt_accuracy: 0.5675 - val_sar_accuracy: 0.8047 - val_fus_accuracy: 0.6062 - val_opt_loss: 0.2109 - val_sar_loss: 0.1322 - val_fusion_loss: 0.2427 - val_loss: 0.5859
#
# Epoch 00019: val_sar_loss did not improve from 0.11265
# Epoch 20/100
# 108/108 [==============================] - 14s 127ms/step - opt_accuracy: 0.5489 - sar_accuracy: 0.8643 - fus_accuracy: 0.6428 - opt_loss: 0.2219 - sar_loss: 0.0700 - fusion_loss: 0.2171 - loss: 0.5090 - val_opt_accuracy: 0.5356 - val_sar_accuracy: 0.8069 - val_fus_accuracy: 0.6093 - val_opt_loss: 0.2257 - val_sar_loss: 0.1360 - val_fusion_loss: 0.2384 - val_loss: 0.6001
#
# Epoch 00020: val_sar_loss did not improve from 0.11265
# Epoch 21/100
# 108/108 [==============================] - 14s 126ms/step - opt_accuracy: 0.5509 - sar_accuracy: 0.8672 - fus_accuracy: 0.6410 - opt_loss: 0.2211 - sar_loss: 0.0683 - fusion_loss: 0.2208 - loss: 0.5103 - val_opt_accuracy: 0.5408 - val_sar_accuracy: 0.8170 - val_fus_accuracy: 0.6043 - val_opt_loss: 0.2242 - val_sar_loss: 0.1319 - val_fusion_loss: 0.2439 - val_loss: 0.6000
#
# Epoch 00021: val_sar_loss did not improve from 0.11265
# Epoch 22/100
# 108/108 [==============================] - 14s 129ms/step - opt_accuracy: 0.5364 - sar_accuracy: 0.8678 - fus_accuracy: 0.6408 - opt_loss: 0.2275 - sar_loss: 0.0666 - fusion_loss: 0.2205 - loss: 0.5146 - val_opt_accuracy: 0.5253 - val_sar_accuracy: 0.8035 - val_fus_accuracy: 0.6079 - val_opt_loss: 0.2313 - val_sar_loss: 0.1291 - val_fusion_loss: 0.2404 - val_loss: 0.600856 - sar_accuracy: 0.8692 - fus_accuracy: 0.6435 - opt_loss: 0.2276 - sar_loss: 0.0667 - fusion - ETA: 5s - opt_accuracy: 0.5354 - sar_accuracy: 0.8674 - fus_accuracy: 0.6437 - opt_loss - ETA: 2s - opt_accuracy: 0.5377 - sar_accuracy: 0.8678 - fus_accuracy: 0.6400 - opt_loss: 0.2269 - sar_loss: 0.0671 - fusion_loss: 0 - ETA: 1s - opt_accuracy: 0.5374 - sar_accuracy: 0.8680 - fus_accuracy: 0.6405 - opt_loss: 0.2271 - sar_loss: 0.0669 - fusion_loss: 0
#
# Epoch 00022: val_sar_loss did not improve from 0.11265
# Epoch 23/100
# 108/108 [==============================] - 14s 130ms/step - opt_accuracy: 0.5353 - sar_accuracy: 0.8706 - fus_accuracy: 0.6394 - opt_loss: 0.2284 - sar_loss: 0.0658 - fusion_loss: 0.2213 - loss: 0.5155 - val_opt_accuracy: 0.5214 - val_sar_accuracy: 0.8091 - val_fus_accuracy: 0.6199 - val_opt_loss: 0.2296 - val_sar_loss: 0.1219 - val_fusion_loss: 0.2335 - val_loss: 0.5850
#
# Epoch 00023: val_sar_loss did not improve from 0.11265
# Epoch 00023: early stopping
# time:  2
# Model: "model_3_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 16s 133ms/step - opt_accuracy: 0.4496 - sar_accuracy: 0.7586 - fus_accuracy: 0.4484 - opt_loss: 0.3239 - sar_loss: 0.1369 - fusion_loss: 0.3911 - loss: 0.8519 - val_opt_accuracy: 0.4095 - val_sar_accuracy: 0.7924 - val_fus_accuracy: 0.4042 - val_opt_loss: 0.3617 - val_sar_loss: 0.1141 - val_fusion_loss: 0.4362 - val_loss: 0.9120
#
# Epoch 00001: val_sar_loss improved from inf to 0.11410, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 2/100
# 108/108 [==============================] - 14s 130ms/step - opt_accuracy: 0.4514 - sar_accuracy: 0.7944 - fus_accuracy: 0.4338 - opt_loss: 0.3228 - sar_loss: 0.1189 - fusion_loss: 0.4340 - loss: 0.8758 - val_opt_accuracy: 0.4165 - val_sar_accuracy: 0.7876 - val_fus_accuracy: 0.4172 - val_opt_loss: 0.3446 - val_sar_loss: 0.1221 - val_fusion_loss: 0.4439 - val_loss: 0.9106
#
# Epoch 00002: val_sar_loss did not improve from 0.11410
# Epoch 3/100
# 108/108 [==============================] - 14s 132ms/step - opt_accuracy: 0.4322 - sar_accuracy: 0.8097 - fus_accuracy: 0.4306 - opt_loss: 0.3486 - sar_loss: 0.1084 - fusion_loss: 0.4558 - loss: 0.9128 - val_opt_accuracy: 0.4020 - val_sar_accuracy: 0.7891 - val_fus_accuracy: 0.4015 - val_opt_loss: 0.3762 - val_sar_loss: 0.1224 - val_fusion_loss: 0.5244 - val_loss: 1.0230
#
# Epoch 00003: val_sar_loss did not improve from 0.11410
# Epoch 4/100
# 108/108 [==============================] - 14s 132ms/step - opt_accuracy: 0.4282 - sar_accuracy: 0.8157 - fus_accuracy: 0.4270 - opt_loss: 0.3621 - sar_loss: 0.1043 - fusion_loss: 0.4687 - loss: 0.9350 - val_opt_accuracy: 0.3996 - val_sar_accuracy: 0.7989 - val_fus_accuracy: 0.4107 - val_opt_loss: 0.3851 - val_sar_loss: 0.1231 - val_fusion_loss: 0.4737 - val_loss: 0.9819
#
# Epoch 00004: val_sar_loss did not improve from 0.11410
# Epoch 5/100
# 108/108 [==============================] - 14s 135ms/step - opt_accuracy: 0.4206 - sar_accuracy: 0.8226 - fus_accuracy: 0.4273 - opt_loss: 0.3977 - sar_loss: 0.1001 - fusion_loss: 0.4445 - loss: 0.9422 - val_opt_accuracy: 0.3949 - val_sar_accuracy: 0.8004 - val_fus_accuracy: 0.4288 - val_opt_loss: 0.4063 - val_sar_loss: 0.1136 - val_fusion_loss: 0.4132 - val_loss: 0.9330
#
# Epoch 00005: val_sar_loss improved from 0.11410 to 0.11360, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 6/100
# 108/108 [==============================] - 14s 135ms/step - opt_accuracy: 0.4185 - sar_accuracy: 0.8281 - fus_accuracy: 0.4346 - opt_loss: 0.4034 - sar_loss: 0.0957 - fusion_loss: 0.4265 - loss: 0.9256 - val_opt_accuracy: 0.3925 - val_sar_accuracy: 0.8103 - val_fus_accuracy: 0.4317 - val_opt_loss: 0.4312 - val_sar_loss: 0.1173 - val_fusion_loss: 0.4214 - val_loss: 0.9699
#
# Epoch 00006: val_sar_loss did not improve from 0.11360
# Epoch 7/100
# 108/108 [==============================] - 15s 136ms/step - opt_accuracy: 0.4191 - sar_accuracy: 0.8339 - fus_accuracy: 0.4422 - opt_loss: 0.4241 - sar_loss: 0.0938 - fusion_loss: 0.4132 - loss: 0.9310 - val_opt_accuracy: 0.3911 - val_sar_accuracy: 0.8052 - val_fus_accuracy: 0.4571 - val_opt_loss: 0.4487 - val_sar_loss: 0.1172 - val_fusion_loss: 0.3804 - val_loss: 0.9464
#
# Epoch 00007: val_sar_loss did not improve from 0.11360
# Epoch 8/100
# 108/108 [==============================] - 15s 138ms/step - opt_accuracy: 0.4187 - sar_accuracy: 0.8375 - fus_accuracy: 0.4417 - opt_loss: 0.4242 - sar_loss: 0.0916 - fusion_loss: 0.4179 - loss: 0.9337 - val_opt_accuracy: 0.3907 - val_sar_accuracy: 0.7992 - val_fus_accuracy: 0.4529 - val_opt_loss: 0.4513 - val_sar_loss: 0.1188 - val_fusion_loss: 0.3894 - val_loss: 0.9595
#
# Epoch 00008: val_sar_loss did not improve from 0.11360
# Epoch 9/100
# 108/108 [==============================] - 15s 140ms/step - opt_accuracy: 0.4170 - sar_accuracy: 0.8353 - fus_accuracy: 0.4387 - opt_loss: 0.4325 - sar_loss: 0.0928 - fusion_loss: 0.4265 - loss: 0.9517 - val_opt_accuracy: 0.3912 - val_sar_accuracy: 0.8091 - val_fus_accuracy: 0.4310 - val_opt_loss: 0.4629 - val_sar_loss: 0.1229 - val_fusion_loss: 0.4361 - val_loss: 1.0219
#
# Epoch 00009: val_sar_loss did not improve from 0.11360
# Epoch 10/100
# 108/108 [==============================] - 15s 140ms/step - opt_accuracy: 0.4185 - sar_accuracy: 0.8418 - fus_accuracy: 0.4563 - opt_loss: 0.4353 - sar_loss: 0.0881 - fusion_loss: 0.4033 - loss: 0.9267 - val_opt_accuracy: 0.3893 - val_sar_accuracy: 0.8010 - val_fus_accuracy: 0.4733 - val_opt_loss: 0.4766 - val_sar_loss: 0.1205 - val_fusion_loss: 0.3763 - val_loss: 0.9734
#
# Epoch 00010: val_sar_loss did not improve from 0.11360
# Epoch 11/100
# 108/108 [==============================] - 15s 143ms/step - opt_accuracy: 0.4174 - sar_accuracy: 0.8416 - fus_accuracy: 0.4755 - opt_loss: 0.4510 - sar_loss: 0.0885 - fusion_loss: 0.3796 - loss: 0.9191 - val_opt_accuracy: 0.3847 - val_sar_accuracy: 0.8039 - val_fus_accuracy: 0.4865 - val_opt_loss: 0.5062 - val_sar_loss: 0.1083 - val_fusion_loss: 0.3434 - val_loss: 0.9579
#
# Epoch 00011: val_sar_loss improved from 0.11360 to 0.10827, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 12/100
# 108/108 [==============================] - 16s 145ms/step - opt_accuracy: 0.4174 - sar_accuracy: 0.8457 - fus_accuracy: 0.4765 - opt_loss: 0.4491 - sar_loss: 0.0852 - fusion_loss: 0.3802 - loss: 0.9145 - val_opt_accuracy: 0.3868 - val_sar_accuracy: 0.8066 - val_fus_accuracy: 0.4971 - val_opt_loss: 0.4955 - val_sar_loss: 0.1077 - val_fusion_loss: 0.3383 - val_loss: 0.9416
#
# Epoch 00012: val_sar_loss improved from 0.10827 to 0.10773, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 13/100
# 108/108 [==============================] - 16s 147ms/step - opt_accuracy: 0.4156 - sar_accuracy: 0.8457 - fus_accuracy: 0.4869 - opt_loss: 0.4643 - sar_loss: 0.0846 - fusion_loss: 0.3702 - loss: 0.9191 - val_opt_accuracy: 0.3913 - val_sar_accuracy: 0.8076 - val_fus_accuracy: 0.5133 - val_opt_loss: 0.4772 - val_sar_loss: 0.1248 - val_fusion_loss: 0.3276 - val_loss: 0.9296
#
# Epoch 00013: val_sar_loss did not improve from 0.10773
# Epoch 14/100
# 108/108 [==============================] - 16s 148ms/step - opt_accuracy: 0.4174 - sar_accuracy: 0.8492 - fus_accuracy: 0.5094 - opt_loss: 0.4711 - sar_loss: 0.0825 - fusion_loss: 0.3477 - loss: 0.9013 - val_opt_accuracy: 0.3908 - val_sar_accuracy: 0.8083 - val_fus_accuracy: 0.5325 - val_opt_loss: 0.5090 - val_sar_loss: 0.1170 - val_fusion_loss: 0.2967 - val_loss: 0.9226
#
# Epoch 00014: val_sar_loss did not improve from 0.10773
# Epoch 15/100
# 108/108 [==============================] - 16s 149ms/step - opt_accuracy: 0.4171 - sar_accuracy: 0.8503 - fus_accuracy: 0.5316 - opt_loss: 0.4635 - sar_loss: 0.0819 - fusion_loss: 0.3298 - loss: 0.8751 - val_opt_accuracy: 0.3911 - val_sar_accuracy: 0.8003 - val_fus_accuracy: 0.5325 - val_opt_loss: 0.4734 - val_sar_loss: 0.1247 - val_fusion_loss: 0.2946 - val_loss: 0.8926
#
# Epoch 00015: val_sar_loss did not improve from 0.10773
# Epoch 16/100
# 108/108 [==============================] - 16s 153ms/step - opt_accuracy: 0.4169 - sar_accuracy: 0.8539 - fus_accuracy: 0.5531 - opt_loss: 0.4608 - sar_loss: 0.0786 - fusion_loss: 0.3158 - loss: 0.8551 - val_opt_accuracy: 0.3894 - val_sar_accuracy: 0.8099 - val_fus_accuracy: 0.5474 - val_opt_loss: 0.5048 - val_sar_loss: 0.1306 - val_fusion_loss: 0.2925 - val_loss: 0.9279
#
# Epoch 00016: val_sar_loss did not improve from 0.10773
# Epoch 17/100
# 108/108 [==============================] - 17s 154ms/step - opt_accuracy: 0.4176 - sar_accuracy: 0.8555 - fus_accuracy: 0.5666 - opt_loss: 0.4506 - sar_loss: 0.0773 - fusion_loss: 0.3100 - loss: 0.8379 - val_opt_accuracy: 0.3906 - val_sar_accuracy: 0.8157 - val_fus_accuracy: 0.5540 - val_opt_loss: 0.4787 - val_sar_loss: 0.1196 - val_fusion_loss: 0.2781 - val_loss: 0.8764
#
# Epoch 00017: val_sar_loss did not improve from 0.10773
# Epoch 18/100
# 108/108 [==============================] - 17s 156ms/step - opt_accuracy: 0.4178 - sar_accuracy: 0.8588 - fus_accuracy: 0.5721 - opt_loss: 0.4502 - sar_loss: 0.0751 - fusion_loss: 0.3107 - loss: 0.8360 - val_opt_accuracy: 0.3894 - val_sar_accuracy: 0.8144 - val_fus_accuracy: 0.5736 - val_opt_loss: 0.5113 - val_sar_loss: 0.1272 - val_fusion_loss: 0.2731 - val_loss: 0.9117
#
# Epoch 00018: val_sar_loss did not improve from 0.10773
# Epoch 19/100
# 108/108 [==============================] - 17s 158ms/step - opt_accuracy: 0.4187 - sar_accuracy: 0.8583 - fus_accuracy: 0.5797 - opt_loss: 0.4474 - sar_loss: 0.0748 - fusion_loss: 0.3078 - loss: 0.8300 - val_opt_accuracy: 0.3904 - val_sar_accuracy: 0.8150 - val_fus_accuracy: 0.5913 - val_opt_loss: 0.4768 - val_sar_loss: 0.1248 - val_fusion_loss: 0.2602 - val_loss: 0.8617
#
# Epoch 00019: val_sar_loss did not improve from 0.10773
# Epoch 20/100
# 108/108 [==============================] - 17s 160ms/step - opt_accuracy: 0.4228 - sar_accuracy: 0.8619 - fus_accuracy: 0.5835 - opt_loss: 0.4178 - sar_loss: 0.0727 - fusion_loss: 0.3087 - loss: 0.7992 - val_opt_accuracy: 0.3934 - val_sar_accuracy: 0.8110 - val_fus_accuracy: 0.5855 - val_opt_loss: 0.4544 - val_sar_loss: 0.1278 - val_fusion_loss: 0.2689 - val_loss: 0.8512
#
# Epoch 00020: val_sar_loss did not improve from 0.10773
# Epoch 21/100
# 108/108 [==============================] - 17s 160ms/step - opt_accuracy: 0.4243 - sar_accuracy: 0.8638 - fus_accuracy: 0.5895 - opt_loss: 0.4086 - sar_loss: 0.0703 - fusion_loss: 0.3088 - loss: 0.7877 - val_opt_accuracy: 0.3937 - val_sar_accuracy: 0.8104 - val_fus_accuracy: 0.5901 - val_opt_loss: 0.4431 - val_sar_loss: 0.1397 - val_fusion_loss: 0.2758 - val_loss: 0.8587
#
# Epoch 00021: val_sar_loss did not improve from 0.10773
# Epoch 22/100
# 108/108 [==============================] - 17s 162ms/step - opt_accuracy: 0.4272 - sar_accuracy: 0.8637 - fus_accuracy: 0.5897 - opt_loss: 0.4022 - sar_loss: 0.0701 - fusion_loss: 0.3093 - loss: 0.7816 - val_opt_accuracy: 0.3939 - val_sar_accuracy: 0.8177 - val_fus_accuracy: 0.6053 - val_opt_loss: 0.4312 - val_sar_loss: 0.1247 - val_fusion_loss: 0.2585 - val_loss: 0.8144
#
# Epoch 00022: val_sar_loss did not improve from 0.10773
# Epoch 00022: early stopping
# time:  3
# Model: "model_3_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 21s 174ms/step - opt_accuracy: 0.5978 - sar_accuracy: 0.7594 - fus_accuracy: 0.6205 - opt_loss: 0.2133 - sar_loss: 0.1348 - fusion_loss: 0.2012 - loss: 0.5494 - val_opt_accuracy: 0.5617 - val_sar_accuracy: 0.7720 - val_fus_accuracy: 0.6275 - val_opt_loss: 0.2372 - val_sar_loss: 0.1257 - val_fusion_loss: 0.2024 - val_loss: 0.5653
#
# Epoch 00001: val_sar_loss improved from inf to 0.12570, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 2/100
# 108/108 [==============================] - 18s 168ms/step - opt_accuracy: 0.5726 - sar_accuracy: 0.8007 - fus_accuracy: 0.6514 - opt_loss: 0.2366 - sar_loss: 0.1155 - fusion_loss: 0.1933 - loss: 0.5454 - val_opt_accuracy: 0.5444 - val_sar_accuracy: 0.7888 - val_fus_accuracy: 0.6693 - val_opt_loss: 0.2715 - val_sar_loss: 0.1319 - val_fusion_loss: 0.1692 - val_loss: 0.5726
#
# Epoch 00002: val_sar_loss did not improve from 0.12570
# Epoch 3/100
# 108/108 [==============================] - 18s 168ms/step - opt_accuracy: 0.5618 - sar_accuracy: 0.8164 - fus_accuracy: 0.6666 - opt_loss: 0.2725 - sar_loss: 0.1058 - fusion_loss: 0.1733 - loss: 0.5515 - val_opt_accuracy: 0.5358 - val_sar_accuracy: 0.7942 - val_fus_accuracy: 0.6755 - val_opt_loss: 0.3104 - val_sar_loss: 0.1196 - val_fusion_loss: 0.1682 - val_loss: 0.5982
#
# Epoch 00003: val_sar_loss improved from 0.12570 to 0.11959, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 4/100
# 108/108 [==============================] - 18s 171ms/step - opt_accuracy: 0.5511 - sar_accuracy: 0.8231 - fus_accuracy: 0.6710 - opt_loss: 0.2937 - sar_loss: 0.0997 - fusion_loss: 0.1755 - loss: 0.5690 - val_opt_accuracy: 0.5211 - val_sar_accuracy: 0.7971 - val_fus_accuracy: 0.6746 - val_opt_loss: 0.3289 - val_sar_loss: 0.1221 - val_fusion_loss: 0.1681 - val_loss: 0.6190
#
# Epoch 00004: val_sar_loss did not improve from 0.11959
# Epoch 5/100
# 108/108 [==============================] - 18s 172ms/step - opt_accuracy: 0.5382 - sar_accuracy: 0.8315 - fus_accuracy: 0.6804 - opt_loss: 0.3085 - sar_loss: 0.0956 - fusion_loss: 0.1721 - loss: 0.5762 - val_opt_accuracy: 0.5171 - val_sar_accuracy: 0.8082 - val_fus_accuracy: 0.7105 - val_opt_loss: 0.3312 - val_sar_loss: 0.1216 - val_fusion_loss: 0.1624 - val_loss: 0.6152
#
# Epoch 00005: val_sar_loss did not improve from 0.11959
# Epoch 6/100
# 108/108 [==============================] - 19s 175ms/step - opt_accuracy: 0.5380 - sar_accuracy: 0.8341 - fus_accuracy: 0.6870 - opt_loss: 0.3071 - sar_loss: 0.0936 - fusion_loss: 0.1714 - loss: 0.5721 - val_opt_accuracy: 0.5154 - val_sar_accuracy: 0.7991 - val_fus_accuracy: 0.6831 - val_opt_loss: 0.3301 - val_sar_loss: 0.1176 - val_fusion_loss: 0.1678 - val_loss: 0.6155
#
# Epoch 00006: val_sar_loss improved from 0.11959 to 0.11765, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 7/100
# 108/108 [==============================] - 19s 175ms/step - opt_accuracy: 0.5368 - sar_accuracy: 0.8350 - fus_accuracy: 0.6871 - opt_loss: 0.3049 - sar_loss: 0.0921 - fusion_loss: 0.1728 - loss: 0.5698 - val_opt_accuracy: 0.5087 - val_sar_accuracy: 0.8048 - val_fus_accuracy: 0.6981 - val_opt_loss: 0.3276 - val_sar_loss: 0.1198 - val_fusion_loss: 0.1656 - val_loss: 0.6131
#
# Epoch 00007: val_sar_loss did not improve from 0.11765
# Epoch 8/100
# 108/108 [==============================] - 19s 178ms/step - opt_accuracy: 0.5314 - sar_accuracy: 0.8372 - fus_accuracy: 0.6925 - opt_loss: 0.2978 - sar_loss: 0.0907 - fusion_loss: 0.1716 - loss: 0.5601 - val_opt_accuracy: 0.4964 - val_sar_accuracy: 0.8045 - val_fus_accuracy: 0.6945 - val_opt_loss: 0.3250 - val_sar_loss: 0.1146 - val_fusion_loss: 0.1663 - val_loss: 0.6058
#
# Epoch 00008: val_sar_loss improved from 0.11765 to 0.11457, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 9/100
# 108/108 [==============================] - 19s 177ms/step - opt_accuracy: 0.5241 - sar_accuracy: 0.8404 - fus_accuracy: 0.6890 - opt_loss: 0.2904 - sar_loss: 0.0890 - fusion_loss: 0.1745 - loss: 0.5539 - val_opt_accuracy: 0.4923 - val_sar_accuracy: 0.7989 - val_fus_accuracy: 0.6849 - val_opt_loss: 0.3033 - val_sar_loss: 0.1176 - val_fusion_loss: 0.1730 - val_loss: 0.5938
#
# Epoch 00009: val_sar_loss did not improve from 0.11457
# Epoch 10/100
# 108/108 [==============================] - 19s 181ms/step - opt_accuracy: 0.5153 - sar_accuracy: 0.8419 - fus_accuracy: 0.6840 - opt_loss: 0.2845 - sar_loss: 0.0870 - fusion_loss: 0.1775 - loss: 0.5491 - val_opt_accuracy: 0.4814 - val_sar_accuracy: 0.8085 - val_fus_accuracy: 0.6875 - val_opt_loss: 0.2962 - val_sar_loss: 0.1172 - val_fusion_loss: 0.1711 - val_loss: 0.5845
#
# Epoch 00010: val_sar_loss did not improve from 0.11457
# Epoch 11/100
# 108/108 [==============================] - 20s 184ms/step - opt_accuracy: 0.5060 - sar_accuracy: 0.8436 - fus_accuracy: 0.6895 - opt_loss: 0.2738 - sar_loss: 0.0869 - fusion_loss: 0.1748 - loss: 0.5354 - val_opt_accuracy: 0.4829 - val_sar_accuracy: 0.8055 - val_fus_accuracy: 0.6932 - val_opt_loss: 0.2949 - val_sar_loss: 0.1108 - val_fusion_loss: 0.1668 - val_loss: 0.5725
#
# Epoch 00011: val_sar_loss improved from 0.11457 to 0.11085, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 12/100
# 108/108 [==============================] - 20s 184ms/step - opt_accuracy: 0.5039 - sar_accuracy: 0.8450 - fus_accuracy: 0.6807 - opt_loss: 0.2750 - sar_loss: 0.0848 - fusion_loss: 0.1787 - loss: 0.5385 - val_opt_accuracy: 0.4831 - val_sar_accuracy: 0.8081 - val_fus_accuracy: 0.6746 - val_opt_loss: 0.2855 - val_sar_loss: 0.1198 - val_fusion_loss: 0.1794 - val_loss: 0.5847
#
# Epoch 00012: val_sar_loss did not improve from 0.11085
# Epoch 13/100
# 108/108 [==============================] - 20s 186ms/step - opt_accuracy: 0.5032 - sar_accuracy: 0.8474 - fus_accuracy: 0.6713 - opt_loss: 0.2681 - sar_loss: 0.0829 - fusion_loss: 0.1826 - loss: 0.5336 - val_opt_accuracy: 0.4907 - val_sar_accuracy: 0.8048 - val_fus_accuracy: 0.6672 - val_opt_loss: 0.2751 - val_sar_loss: 0.1322 - val_fusion_loss: 0.1815 - val_loss: 0.5889
#
# Epoch 00013: val_sar_loss did not improve from 0.11085
# Epoch 14/100
# 108/108 [==============================] - 20s 188ms/step - opt_accuracy: 0.5055 - sar_accuracy: 0.8470 - fus_accuracy: 0.6679 - opt_loss: 0.2639 - sar_loss: 0.0833 - fusion_loss: 0.1844 - loss: 0.5316 - val_opt_accuracy: 0.4905 - val_sar_accuracy: 0.8116 - val_fus_accuracy: 0.6648 - val_opt_loss: 0.2749 - val_sar_loss: 0.1273 - val_fusion_loss: 0.1836 - val_loss: 0.5858
#
# Epoch 00014: val_sar_loss did not improve from 0.11085
# Epoch 15/100
# 108/108 [==============================] - 21s 193ms/step - opt_accuracy: 0.5040 - sar_accuracy: 0.8507 - fus_accuracy: 0.6577 - opt_loss: 0.2652 - sar_loss: 0.0800 - fusion_loss: 0.1890 - loss: 0.5343 - val_opt_accuracy: 0.4888 - val_sar_accuracy: 0.8002 - val_fus_accuracy: 0.6295 - val_opt_loss: 0.2761 - val_sar_loss: 0.1355 - val_fusion_loss: 0.1976 - val_loss: 0.6092
#
# Epoch 00015: val_sar_loss did not improve from 0.11085
# Epoch 16/100
# 108/108 [==============================] - 21s 192ms/step - opt_accuracy: 0.5126 - sar_accuracy: 0.8514 - fus_accuracy: 0.6534 - opt_loss: 0.2566 - sar_loss: 0.0803 - fusion_loss: 0.1916 - loss: 0.5285 - val_opt_accuracy: 0.4952 - val_sar_accuracy: 0.8127 - val_fus_accuracy: 0.6637 - val_opt_loss: 0.2723 - val_sar_loss: 0.1319 - val_fusion_loss: 0.1877 - val_loss: 0.5919
#
# Epoch 00016: val_sar_loss did not improve from 0.11085
# Epoch 17/100
# 108/108 [==============================] - 21s 193ms/step - opt_accuracy: 0.5059 - sar_accuracy: 0.8539 - fus_accuracy: 0.6490 - opt_loss: 0.2638 - sar_loss: 0.0782 - fusion_loss: 0.1936 - loss: 0.5356 - val_opt_accuracy: 0.4907 - val_sar_accuracy: 0.8157 - val_fus_accuracy: 0.6542 - val_opt_loss: 0.2743 - val_sar_loss: 0.1193 - val_fusion_loss: 0.1894 - val_loss: 0.5830
#
# Epoch 00017: val_sar_loss did not improve from 0.11085
# Epoch 18/100
# 108/108 [==============================] - 22s 207ms/step - opt_accuracy: 0.5156 - sar_accuracy: 0.8559 - fus_accuracy: 0.6493 - opt_loss: 0.2571 - sar_loss: 0.0770 - fusion_loss: 0.1938 - loss: 0.5278 - val_opt_accuracy: 0.5386 - val_sar_accuracy: 0.8155 - val_fus_accuracy: 0.6572 - val_opt_loss: 0.2512 - val_sar_loss: 0.1356 - val_fusion_loss: 0.1901 - val_loss: 0.5768
# Epoch 00018: val_sar_loss did not improve from 0.11085
# Epoch 19/100
# 108/108 [==============================] - 23s 213ms/step - opt_accuracy: 0.5201 - sar_accuracy: 0.8577 - fus_accuracy: 0.6449 - opt_loss: 0.2559 - sar_loss: 0.0745 - fusion_loss: 0.1952 - loss: 0.5256 - val_opt_accuracy: 0.5134 - val_sar_accuracy: 0.8128 - val_fus_accuracy: 0.6374 - val_opt_loss: 0.2683 - val_sar_loss: 0.1372 - val_fusion_loss: 0.1957 - val_loss: 0.6013
#
# Epoch 00019: val_sar_loss did not improve from 0.11085
# Epoch 20/100
# 108/108 [==============================] - 22s 205ms/step - opt_accuracy: 0.5220 - sar_accuracy: 0.8595 - fus_accuracy: 0.6393 - opt_loss: 0.2579 - sar_loss: 0.0732 - fusion_loss: 0.1985 - loss: 0.5296 - val_opt_accuracy: 0.5120 - val_sar_accuracy: 0.8141 - val_fus_accuracy: 0.6293 - val_opt_loss: 0.2715 - val_sar_loss: 0.1194 - val_fusion_loss: 0.1994 - val_loss: 0.5903
#
# Epoch 00020: val_sar_loss did not improve from 0.11085
# Epoch 21/100
# 108/108 [==============================] - 23s 216ms/step - opt_accuracy: 0.5406 - sar_accuracy: 0.8630 - fus_accuracy: 0.6422 - opt_loss: 0.2551 - sar_loss: 0.0707 - fusion_loss: 0.1975 - loss: 0.5233 - val_opt_accuracy: 0.5360 - val_sar_accuracy: 0.8145 - val_fus_accuracy: 0.6192 - val_opt_loss: 0.2656 - val_sar_loss: 0.1239 - val_fusion_loss: 0.2016 - val_loss: 0.5911
#
# Epoch 00021: val_sar_loss did not improve from 0.11085
# Epoch 00021: early stopping
# time:  4
# Model: "model_3_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 24s 212ms/step - opt_accuracy: 0.7050 - sar_accuracy: 0.7341 - fus_accuracy: 0.6389 - opt_loss: 0.1648 - sar_loss: 0.1366 - fusion_loss: 0.1574 - loss: 0.4588 - val_opt_accuracy: 0.6957 - val_sar_accuracy: 0.7831 - val_fus_accuracy: 0.6363 - val_opt_loss: 0.1716 - val_sar_loss: 0.1167 - val_fusion_loss: 0.1402 - val_loss: 0.4284
#
# Epoch 00001: val_sar_loss improved from inf to 0.11669, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 2/100
# 108/108 [==============================] - 22s 205ms/step - opt_accuracy: 0.6890 - sar_accuracy: 0.7968 - fus_accuracy: 0.6209 - opt_loss: 0.1778 - sar_loss: 0.1160 - fusion_loss: 0.1644 - loss: 0.4582 - val_opt_accuracy: 0.6981 - val_sar_accuracy: 0.7814 - val_fus_accuracy: 0.6241 - val_opt_loss: 0.1726 - val_sar_loss: 0.1217 - val_fusion_loss: 0.1523 - val_loss: 0.4466
#
# Epoch 00002: val_sar_loss did not improve from 0.11669
# Epoch 3/100
# 108/108 [==============================] - 23s 211ms/step - opt_accuracy: 0.6783 - sar_accuracy: 0.8105 - fus_accuracy: 0.6225 - opt_loss: 0.1866 - sar_loss: 0.1073 - fusion_loss: 0.1619 - loss: 0.4558 - val_opt_accuracy: 0.6681 - val_sar_accuracy: 0.7906 - val_fus_accuracy: 0.6219 - val_opt_loss: 0.1977 - val_sar_loss: 0.1188 - val_fusion_loss: 0.1435 - val_loss: 0.4600
#
# Epoch 00003: val_sar_loss did not improve from 0.11669
# Epoch 4/100
# 108/108 [==============================] - 23s 213ms/step - opt_accuracy: 0.6430 - sar_accuracy: 0.8171 - fus_accuracy: 0.6208 - opt_loss: 0.2080 - sar_loss: 0.1031 - fusion_loss: 0.1643 - loss: 0.4755 - val_opt_accuracy: 0.6447 - val_sar_accuracy: 0.7874 - val_fus_accuracy: 0.6085 - val_opt_loss: 0.2062 - val_sar_loss: 0.1206 - val_fusion_loss: 0.1553 - val_loss: 0.4821
#
# Epoch 00004: val_sar_loss did not improve from 0.11669
# Epoch 5/100
# 108/108 [==============================] - 23s 214ms/step - opt_accuracy: 0.6270 - sar_accuracy: 0.8235 - fus_accuracy: 0.6203 - opt_loss: 0.2142 - sar_loss: 0.0986 - fusion_loss: 0.1642 - loss: 0.4770 - val_opt_accuracy: 0.6175 - val_sar_accuracy: 0.7912 - val_fus_accuracy: 0.6215 - val_opt_loss: 0.2202 - val_sar_loss: 0.1165 - val_fusion_loss: 0.1386 - val_loss: 0.4753
#
# Epoch 00005: val_sar_loss improved from 0.11669 to 0.11648, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 6/100
# 108/108 [==============================] - 23s 214ms/step - opt_accuracy: 0.5890 - sar_accuracy: 0.8309 - fus_accuracy: 0.6211 - opt_loss: 0.2306 - sar_loss: 0.0953 - fusion_loss: 0.1649 - loss: 0.4907 - val_opt_accuracy: 0.5718 - val_sar_accuracy: 0.7802 - val_fus_accuracy: 0.6394 - val_opt_loss: 0.2350 - val_sar_loss: 0.1172 - val_fusion_loss: 0.1258 - val_loss: 0.4780
#
# Epoch 00006: val_sar_loss did not improve from 0.11648
# Epoch 7/100
# 108/108 [==============================] - 24s 222ms/step - opt_accuracy: 0.5781 - sar_accuracy: 0.8327 - fus_accuracy: 0.6225 - opt_loss: 0.2349 - sar_loss: 0.0939 - fusion_loss: 0.1663 - loss: 0.4952 - val_opt_accuracy: 0.5614 - val_sar_accuracy: 0.8066 - val_fus_accuracy: 0.6288 - val_opt_loss: 0.2379 - val_sar_loss: 0.1136 - val_fusion_loss: 0.1324 - val_loss: 0.4838
#
# Epoch 00007: val_sar_loss improved from 0.11648 to 0.11358, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 8/100
# 108/108 [==============================] - 23s 218ms/step - opt_accuracy: 0.5408 - sar_accuracy: 0.8384 - fus_accuracy: 0.6231 - opt_loss: 0.2485 - sar_loss: 0.0905 - fusion_loss: 0.1726 - loss: 0.5116 - val_opt_accuracy: 0.5388 - val_sar_accuracy: 0.8063 - val_fus_accuracy: 0.6170 - val_opt_loss: 0.2472 - val_sar_loss: 0.1202 - val_fusion_loss: 0.1490 - val_loss: 0.5164
#
# Epoch 00008: val_sar_loss did not improve from 0.11358
# Epoch 9/100
# 108/108 [==============================] - 24s 221ms/step - opt_accuracy: 0.5454 - sar_accuracy: 0.8385 - fus_accuracy: 0.6171 - opt_loss: 0.2485 - sar_loss: 0.0897 - fusion_loss: 0.1794 - loss: 0.5176 - val_opt_accuracy: 0.5303 - val_sar_accuracy: 0.8016 - val_fus_accuracy: 0.6208 - val_opt_loss: 0.2527 - val_sar_loss: 0.1146 - val_fusion_loss: 0.1409 - val_loss: 0.5082
#
# Epoch 00009: val_sar_loss did not improve from 0.11358
# Epoch 10/100
# 108/108 [==============================] - 24s 224ms/step - opt_accuracy: 0.5145 - sar_accuracy: 0.8432 - fus_accuracy: 0.6164 - opt_loss: 0.2640 - sar_loss: 0.0869 - fusion_loss: 0.1832 - loss: 0.5341 - val_opt_accuracy: 0.4877 - val_sar_accuracy: 0.8086 - val_fus_accuracy: 0.6139 - val_opt_loss: 0.2754 - val_sar_loss: 0.1161 - val_fusion_loss: 0.1524 - val_loss: 0.5439
#
# Epoch 00010: val_sar_loss did not improve from 0.11358
# Epoch 11/100
# 108/108 [==============================] - 25s 230ms/step - opt_accuracy: 0.5065 - sar_accuracy: 0.8445 - fus_accuracy: 0.6137 - opt_loss: 0.2674 - sar_loss: 0.0856 - fusion_loss: 0.1928 - loss: 0.5458 - val_opt_accuracy: 0.5251 - val_sar_accuracy: 0.8009 - val_fus_accuracy: 0.6182 - val_opt_loss: 0.2588 - val_sar_loss: 0.1149 - val_fusion_loss: 0.1577 - val_loss: 0.5314
#
# Epoch 00011: val_sar_loss did not improve from 0.11358
# Epoch 12/100
# 108/108 [==============================] - 25s 229ms/step - opt_accuracy: 0.5249 - sar_accuracy: 0.8459 - fus_accuracy: 0.6147 - opt_loss: 0.2592 - sar_loss: 0.0843 - fusion_loss: 0.1906 - loss: 0.5340 - val_opt_accuracy: 0.5100 - val_sar_accuracy: 0.8053 - val_fus_accuracy: 0.6280 - val_opt_loss: 0.2639 - val_sar_loss: 0.1100 - val_fusion_loss: 0.1503 - val_loss: 0.5242
#
# Epoch 00012: val_sar_loss improved from 0.11358 to 0.11001, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 13/100
# 108/108 [==============================] - 25s 236ms/step - opt_accuracy: 0.5195 - sar_accuracy: 0.8475 - fus_accuracy: 0.6098 - opt_loss: 0.2626 - sar_loss: 0.0841 - fusion_loss: 0.1968 - loss: 0.5435 - val_opt_accuracy: 0.4893 - val_sar_accuracy: 0.8067 - val_fus_accuracy: 0.6225 - val_opt_loss: 0.2745 - val_sar_loss: 0.1152 - val_fusion_loss: 0.1574 - val_loss: 0.5471
#
# Epoch 00013: val_sar_loss did not improve from 0.11001
# Epoch 14/100
# 108/108 [==============================] - 25s 231ms/step - opt_accuracy: 0.5000 - sar_accuracy: 0.8487 - fus_accuracy: 0.6118 - opt_loss: 0.2752 - sar_loss: 0.0814 - fusion_loss: 0.1978 - loss: 0.5543 - val_opt_accuracy: 0.5037 - val_sar_accuracy: 0.8087 - val_fus_accuracy: 0.6099 - val_opt_loss: 0.2734 - val_sar_loss: 0.1250 - val_fusion_loss: 0.1889 - val_loss: 0.5873
#
# Epoch 00014: val_sar_loss did not improve from 0.11001
# Epoch 15/100
# 108/108 [==============================] - 26s 239ms/step - opt_accuracy: 0.4986 - sar_accuracy: 0.8519 - fus_accuracy: 0.6088 - opt_loss: 0.2769 - sar_loss: 0.0798 - fusion_loss: 0.2042 - loss: 0.5609 - val_opt_accuracy: 0.4832 - val_sar_accuracy: 0.8072 - val_fus_accuracy: 0.6102 - val_opt_loss: 0.2791 - val_sar_loss: 0.1252 - val_fusion_loss: 0.1762 - val_loss: 0.5804
#
# Epoch 00015: val_sar_loss did not improve from 0.11001
# Epoch 16/100
# 108/108 [==============================] - 25s 236ms/step - opt_accuracy: 0.4948 - sar_accuracy: 0.8524 - fus_accuracy: 0.6138 - opt_loss: 0.2804 - sar_loss: 0.0793 - fusion_loss: 0.2030 - loss: 0.5626 - val_opt_accuracy: 0.4709 - val_sar_accuracy: 0.8071 - val_fus_accuracy: 0.6049 - val_opt_loss: 0.2887 - val_sar_loss: 0.1293 - val_fusion_loss: 0.1854 - val_loss: 0.6035ss:
#
# Epoch 00016: val_sar_loss did not improve from 0.11001
# Epoch 17/100
# 108/108 [==============================] - 26s 239ms/step - opt_accuracy: 0.4693 - sar_accuracy: 0.8553 - fus_accuracy: 0.6112 - opt_loss: 0.3026 - sar_loss: 0.0769 - fusion_loss: 0.2079 - loss: 0.5873 - val_opt_accuracy: 0.4390 - val_sar_accuracy: 0.7933 - val_fus_accuracy: 0.6089 - val_opt_loss: 0.3238 - val_sar_loss: 0.1403 - val_fusion_loss: 0.2041 - val_loss: 0.6683
#
# Epoch 00017: val_sar_loss did not improve from 0.11001
# Epoch 18/100
# 108/108 [==============================] - 26s 244ms/step - opt_accuracy: 0.4563 - sar_accuracy: 0.8570 - fus_accuracy: 0.6105 - opt_loss: 0.3209 - sar_loss: 0.0760 - fusion_loss: 0.2087 - loss: 0.6056 - val_opt_accuracy: 0.4460 - val_sar_accuracy: 0.8129 - val_fus_accuracy: 0.6051 - val_opt_loss: 0.3196 - val_sar_loss: 0.1219 - val_fusion_loss: 0.1930 - val_loss: 0.6345accuracy: 0.8531 - fus_accuracy: 0.6091 - opt_loss: 0.3152 - sar - ETA: 7s - opt_accuracy: 0.4574 - sar_accuracy: 0.8565 - fus_accurac
#
# Epoch 00018: val_sar_loss did not improve from 0.11001
# Epoch 19/100
# 108/108 [==============================] - 26s 245ms/step - opt_accuracy: 0.4443 - sar_accuracy: 0.8607 - fus_accuracy: 0.6116 - opt_loss: 0.3442 - sar_loss: 0.0731 - fusion_loss: 0.2147 - loss: 0.6320 - val_opt_accuracy: 0.4205 - val_sar_accuracy: 0.8042 - val_fus_accuracy: 0.6063 - val_opt_loss: 0.3572 - val_sar_loss: 0.1328 - val_fusion_loss: 0.2146 - val_loss: 0.7046
#
# Epoch 00019: val_sar_loss did not improve from 0.11001
# Epoch 20/100
# 108/108 [==============================] - 26s 243ms/step - opt_accuracy: 0.4354 - sar_accuracy: 0.8634 - fus_accuracy: 0.6105 - opt_loss: 0.3657 - sar_loss: 0.0711 - fusion_loss: 0.2153 - loss: 0.6522 - val_opt_accuracy: 0.4151 - val_sar_accuracy: 0.8110 - val_fus_accuracy: 0.6119 - val_opt_loss: 0.3687 - val_sar_loss: 0.1285 - val_fusion_loss: 0.1971 - val_loss: 0.6943
#
# Epoch 00020: val_sar_loss did not improve from 0.11001
# Epoch 21/100
# 108/108 [==============================] - 27s 252ms/step - opt_accuracy: 0.4382 - sar_accuracy: 0.8609 - fus_accuracy: 0.6098 - opt_loss: 0.3679 - sar_loss: 0.0727 - fusion_loss: 0.2171 - loss: 0.6577 - val_opt_accuracy: 0.4154 - val_sar_accuracy: 0.8141 - val_fus_accuracy: 0.6026 - val_opt_loss: 0.3891 - val_sar_loss: 0.1310 - val_fusion_loss: 0.2301 - val_loss: 0.7502
#
# Epoch 00021: val_sar_loss did not improve from 0.11001
# Epoch 22/100
# 108/108 [==============================] - 28s 261ms/step - opt_accuracy: 0.4311 - sar_accuracy: 0.8657 - fus_accuracy: 0.6103 - opt_loss: 0.3870 - sar_loss: 0.0697 - fusion_loss: 0.2238 - loss: 0.6805 - val_opt_accuracy: 0.4054 - val_sar_accuracy: 0.8087 - val_fus_accuracy: 0.6129 - val_opt_loss: 0.3985 - val_sar_loss: 0.1296 - val_fusion_loss: 0.2083 - val_loss: 0.7364
#
# Epoch 00022: val_sar_loss did not improve from 0.11001
# Epoch 00022: early stopping

# %%
# Test loop
time_ts = []
n_pool = 3
n_rows = 5
n_cols = 4
rows, cols = image_array.shape[:2]
pad_rows = rows - np.ceil(rows/(n_rows*2**n_pool))*n_rows*2**n_pool
pad_cols = cols - np.ceil(cols/(n_cols*2**n_pool))*n_cols*2**n_pool
print(pad_rows, pad_cols)

npad = ((0, int(abs(pad_rows))), (0, int(abs(pad_cols))), (0, 0))
image1_pad = np.pad(image_array, pad_width=npad, mode='reflect')

h, w, c = image1_pad.shape
patch_size_rows = h//n_rows
patch_size_cols = w//n_cols
num_patches_x = int(h/patch_size_rows)
num_patches_y = int(w/patch_size_cols)

input_shape=(patch_size_rows,patch_size_cols, c)

#if method == 'unet':
#   new_model = build_unet(input_shape, nb_filters, number_class)

#if method == 'resunet':
#   new_model = build_resunet(input_shape, nb_filters, number_class)

new_model = Model_3(nb_filters, number_class, n_opt_layers)
new_model.build((None,)+input_shape)
adam = Adam(lr = 1e-4 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
new_model.compile(optimizer=adam, loss=loss, metrics=['accuracy'], run_eagerly=True)

for tm in range(0,times):
    print('time: ', tm)
    #model = load_model(path_models+ '/' + method +'_'+str(tm)+'.h5', compile=False)
    
    #for l in range(1, len(model.layers)):
    #    new_model.layers[l].set_weights(model.layers[l].get_weights())
    new_model.load_weights(path_models+ '/' + method +'_'+str(tm)+'.h5')
    
    start_test = time.time()
    patch_opt = []
    patch_sar = []
    patch_fus = []
    patch_comb = []
    
    for i in range(0,num_patches_y):
        for j in range(0,num_patches_x):
            patch = image1_pad[patch_size_rows*j:patch_size_rows*(j+1), patch_size_cols*i:patch_size_cols*(i+1), :]
            pred_opt, pred_sar, pred_fus, pred_comb = new_model.predict(np.expand_dims(patch, axis=0))
            del patch 
            patch_opt.append(pred_opt[:,:,:,1])
            patch_sar.append(pred_sar[:,:,:,1])
            patch_fus.append(pred_fus[:,:,:,1])
            patch_comb.append(pred_comb[:,:,:,1])
            del pred_opt, pred_sar, pred_fus, pred_comb
    end_test =  time.time() - start_test

    patches_pred_opt = np.asarray(patch_opt).astype(np.float32)
    patches_pred_sar = np.asarray(patch_sar).astype(np.float32)
    patches_pred_fus = np.asarray(patch_fus).astype(np.float32)
    patches_pred_comb = np.asarray(patch_comb).astype(np.float32)

    prob_recontructed_opt = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_opt)
    prob_recontructed_sar = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_sar)
    prob_recontructed_fus = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_fus)
    prob_recontructed_comb = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_comb)

    del patches_pred_opt, patches_pred_sar, patches_pred_fus, patches_pred_comb
    np.save(path_maps+'/'+'prob_opt_'+str(tm)+'.npy',prob_recontructed_opt) 
    np.save(path_maps+'/'+'prob_sar_'+str(tm)+'.npy',prob_recontructed_sar) 
    np.save(path_maps+'/'+'prob_fus_'+str(tm)+'.npy',prob_recontructed_fus) 
    np.save(path_maps+'/'+'prob_comb_'+str(tm)+'.npy',prob_recontructed_comb) 

    time_ts.append(end_test)
    del prob_recontructed_opt, prob_recontructed_sar, prob_recontructed_fus, prob_recontructed_comb
    #del model
time_ts_array = np.asarray(time_ts)
# Save test time
np.save(path_exp+'/metrics_ts.npy', time_ts_array)
# Out:
# 0.0 -8.0
# time:  0
# time:  1
# time:  2
# time:  3
# time:  4

# %%
# Compute mean of the tm predictions maps
prob_rec_opt = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_sar = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_fus = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_comb = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))

for tm in range (0, times):
    print(tm)
    prob_rec_opt[:,:,tm] = np.load(path_maps+'/'+'prob_opt_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_sar[:,:,tm] = np.load(path_maps+'/'+'prob_sar_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_fus[:,:,tm] = np.load(path_maps+'/'+'prob_fus_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_comb[:,:,tm] = np.load(path_maps+'/'+'prob_comb_'+str(tm)+'.npy').astype(np.float32)

mean_prob_opt = np.mean(prob_rec_opt, axis = -1)
mean_prob_sar = np.mean(prob_rec_sar, axis = -1)
mean_prob_fus = np.mean(prob_rec_fus, axis = -1)
mean_prob_comb = np.mean(prob_rec_comb, axis = -1)

np.save(path_maps+'/prob_mean_opt.npy', mean_prob_opt)
np.save(path_maps+'/prob_mean_sar.npy', mean_prob_sar)
np.save(path_maps+'/prob_mean_fus.npy', mean_prob_fus)
np.save(path_maps+'/prob_mean_comb.npy', mean_prob_comb)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Plot mean map and reference
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(151)
plt.title('OPT Prediction')
ax1.imshow(mean_prob_opt, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(152)
plt.title('SAR Prediction')
ax1.imshow(mean_prob_sar, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(153)
plt.title('FUSION Prediction')
ax1.imshow(mean_prob_fus, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(154)
plt.title('COMBINATION Prediction')
ax1.imshow(mean_prob_comb, cmap ='jet')
ax1.axis('off')

ax2 = fig.add_subplot(155)
plt.title('Reference')
ax2.imshow(tf.keras.utils.to_categorical(final_mask1, 3)[:,:,1], cmap ='jet')
ax2.axis('off')
# Out:
# (-0.5, 6999.5, 9999.5, -0.5)

# %%
# Computing metrics
mean_prob_opt = mean_prob_opt[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_sar = mean_prob_sar[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_fus = mean_prob_fus[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_comb = mean_prob_comb[:final_mask1.shape[0], :final_mask1.shape[1]]

ref1 = np.ones_like(final_mask1).astype(np.float32)

ref1 [final_mask1 == 2] = 0
TileMask = mask_amazon_ts * ref1
GTTruePositives = final_mask1==1
    
Npoints = 10

Pmax_opt = np.max(mean_prob_opt[GTTruePositives * TileMask ==1])
ProbList_opt = np.linspace(Pmax_opt,0,Npoints)

Pmax_sar = np.max(mean_prob_sar[GTTruePositives * TileMask ==1])
ProbList_sar = np.linspace(Pmax_sar,0,Npoints)

Pmax_fus = np.max(mean_prob_fus[GTTruePositives * TileMask ==1])
ProbList_fus = np.linspace(Pmax_fus,0,Npoints)

Pmax_comb = np.max(mean_prob_comb[GTTruePositives * TileMask ==1])
ProbList_comb = np.linspace(Pmax_comb,0,Npoints)


from multiprocessing.pool import Pool
pool = Pool(processes=4)

#async_result_opt = pool.apply_async(matrics_AA_recall, (ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625))
async_result_sar = pool.apply_async(matrics_AA_recall, (ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625))
#async_result_fus = pool.apply_async(matrics_AA_recall, (ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625))
#async_result_comb = pool.apply_async(matrics_AA_recall, (ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625))

#metrics_opt = async_result_opt.get()
metrics_sar = async_result_sar.get()
#metrics_fus = async_result_fus.get()
#metrics_comb = async_result_comb.get()
    
#metrics_opt = matrics_AA_recall(ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625)
#metrics_sar = matrics_AA_recall(ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625)
#metrics_fus = matrics_AA_recall(ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625)
#metrics_comb = matrics_AA_recall(ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625)

#np.save(path_exp+'/acc_metrics_opt.npy',metrics_opt)
np.save(path_exp+'/acc_metrics_sar.npy',metrics_sar)
#np.save(path_exp+'/acc_metrics_fus.npy',metrics_fus)
#np.save(path_exp+'/acc_metrics_comb.npy',metrics_comb)

# %%
# Complete NaN values
#metrics_copy_opt = metrics_opt.copy()
#metrics_copy_opt = complete_nan_values(metrics_copy_opt)

metrics_copy_sar = metrics_sar.copy()
metrics_copy_sar = complete_nan_values(metrics_copy_sar)

#metrics_copy_fus = metrics_fus.copy()
#metrics_copy_fus = complete_nan_values(metrics_copy_fus)

#metrics_copy_comb = metrics_comb.copy()
#metrics_copy_comb = complete_nan_values(metrics_copy_comb)

# %%
# Comput Mean Average Precision (mAP) score 
#Recall_opt = metrics_copy_opt[:,0]
#Precision_opt = metrics_copy_opt[:,1]
#AA_opt = metrics_copy_opt[:,2]

Recall_sar = metrics_copy_sar[:,0]
Precision_sar = metrics_copy_sar[:,1]
AA_sar = metrics_copy_sar[:,2]

#Recall_fus = metrics_copy_fus[:,0]
#Precision_fus = metrics_copy_fus[:,1]
#AA_fus = metrics_copy_fus[:,2]

#Recall_comb = metrics_copy_comb[:,0]
#Precision_comb = metrics_copy_comb[:,1]
#AA_comb = metrics_copy_comb[:,2]
    
#DeltaR_opt = Recall_opt[1:]-Recall_opt[:-1]
#AP_opt = np.sum(Precision_opt[:-1]*DeltaR_opt)
#print('OPT mAP', AP_opt)

DeltaR_sar = Recall_sar[1:]-Recall_sar[:-1]
AP_sar = np.sum(Precision_sar[:-1]*DeltaR_sar)
print('SAR mAP', AP_sar)

#DeltaR_fus = Recall_fus[1:]-Recall_fus[:-1]
#AP_fus = np.sum(Precision_fus[:-1]*DeltaR_fus)
#print('FUSION mAP', AP_fus)

#DeltaR_comb = Recall_comb[1:]-Recall_comb[:-1]
#AP_comb = np.sum(Precision_comb[:-1]*DeltaR_comb)
#print('COMBINATION mAP', AP_comb)

# Plot Recall vs. Precision curve
plt.figure(figsize=(7,7))
#plt.plot(metrics_copy_opt[:,0],metrics_copy_opt[:,1], 'r-', label = f'OPT (AP: {AP_opt:.4f})')
plt.plot(metrics_copy_sar[:,0],metrics_copy_sar[:,1], 'g-', label = f'SAR (AP: {AP_sar:.4f})')
#plt.plot(metrics_copy_fus[:,0],metrics_copy_fus[:,1], 'b-', label = f'FUSION (AP: {AP_fus:.4f})')
#plt.plot(metrics_copy_comb[:,0],metrics_copy_comb[:,1], 'k-', label = f'COMBINATION (AP: {AP_comb:.4f})')
plt.legend(loc="lower left")
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([0,1])
#plt.plot(metrics_copy[:,0],metrics_copy[:,2])
plt.grid()
# Out:
# SAR mAP 0.8517279414918357
