# %%
# %load_ext autoreload
# %autoreload 2

# %%
#%autoreload # When utils.py is updated
from utils_unet_resunet import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
root_path = 'imgs/'

# %%
# Define data type (L8-Landsat8, S2-Sentinel2, S1-Sentinel1)
img_type = 'S1'

if img_type == 'L8':
    # Load images
    ref_2019 = load_tif_image(root_path+'New_Images/References/res_10m/r10m_def_2019.tif').astype('float32') # actual 2019
    opt_2018 = load_tif_image(root_path+'New_Images/Landsat8/'+'cut_land8_2018.tif').astype('float32')   
    opt_2019 = load_tif_image(root_path+'New_Images/Landsat8/'+'cut_land8_2019.tif').astype('float32')

    # Resize images
    opt_2018 = resize_image(opt_2018.copy(), ref_2019.shape[0], ref_2019.shape[1])
    opt_2019 = resize_image(opt_2019.copy(), ref_2019.shape[0], ref_2019.shape[1])  

    # Filter outliers
    opt_2018 = filter_outliers(opt_2018.copy()) 
    opt_2019 = filter_outliers(opt_2019.copy())
    
    image_stack = np.concatenate((opt_2018, opt_2019), axis=-1)
    print('landsat_resize:', image_stack.shape)
    del opt_2018, opt_2019

if img_type == 'S2':
    # Load images
    sent2_2018_1 = load_tif_image(root_path+'New_Images/Sentinel2/'+'2018_10m_b2348.tif').astype('float32')
    #sent2_2018_2 = load_tif_image(root_path+'New_Images/Sentinel2/'+'2018_20m_b5678a1112.tif').astype('float32')
    
    # Resize bands of 20m
    #sent2_2018_2 = resize_image(sent2_2018_2.copy(), sent2_2018_1.shape[0], sent2_2018_1.shape[1])
    #sent2_2018 = np.concatenate((sent2_2018_1, sent2_2018_2), axis=-1)
    sent2_2018 = sent2_2018_1.copy()
    del sent2_2018_1#, sent2_2018_2
    
    sent2_2019_1 = load_tif_image(root_path+'New_Images/Sentinel2/'+'2019_10m_b2348.tif').astype('float32')
    #sent2_2019_2 = load_tif_image(root_path+'New_Images/Sentinel2/'+'2019_20m_b5678a1112.tif').astype('float32')   
    
    # Resize bands of 20m
    #sent2_2019_2 = resize_image(sent2_2019_2.copy(), sent2_2019_1.shape[0], sent2_2019_1.shape[1])
    #sent2_2019 = np.concatenate((sent2_2019_1, sent2_2019_2), axis=-1)
    sent2_2019 = sent2_2019_1.copy()
    del sent2_2019_1#, sent2_2019_2
    
    # Filter outliers
    sent2_2018 = filter_outliers(sent2_2018.copy()) 
    sent2_2019 = filter_outliers(sent2_2019.copy()) 
    
    image_stack = np.concatenate((sent2_2018, sent2_2019), axis=-1)
    print('Image stack:', image_stack.shape)
    del sent2_2018, sent2_2019

if img_type == 'S1':
    # Load images
    sar_2018_vh = np.expand_dims(load_SAR_image(root_path+'New_Images/Sentinel1/'+'cut_sent1_vh_2018.tif').astype('float32'), axis = -1)
    sar_2018_vv = np.expand_dims(load_SAR_image(root_path+'New_Images/Sentinel1/'+'cut_sent1_vv_2018.tif').astype('float32'), axis = -1)
    sar_2019_vh = np.expand_dims(load_SAR_image(root_path+'New_Images/Sentinel1/'+'cut_sent1_vh_2019.tif').astype('float32'), axis = -1)
    sar_2019_vv = np.expand_dims(load_SAR_image(root_path+'New_Images/Sentinel1/'+'cut_sent1_vv_2019.tif').astype('float32'), axis = -1)
    
    sar_2018 = np.concatenate((sar_2018_vh, sar_2018_vv), axis=-1)
    sar_2019 = np.concatenate((sar_2019_vh, sar_2019_vv), axis=-1)
    del sar_2018_vh, sar_2018_vv, sar_2019_vh, sar_2019_vv
    
    # Filter outliers
    sar_2018 = filter_outliers(sar_2018.copy()) 
    sar_2019 = filter_outliers(sar_2019.copy()) 

    image_stack = np.concatenate((sar_2018, sar_2019), axis=-1)
    print('Image stack:', image_stack.shape)
    del sar_2018, sar_2019

# load references     
# Load current reference 
#ref_2019 = load_tif_image(root_path+'New_Images/References/res_10m/r10m_def_2019.tif').astype('float32') # actual 2019
# Load past references
#past_ref = np.load(root_path+'New_Images/References/past_ref_and_clouds.npy').astype('float32')
#past_ref1 = load_tif_image(root_path+'New_Images/References/res_10m/r10m_def_1988_2007.tif').astype('float32') # 1988_2007
#past_ref2 = load_tif_image(root_path+'New_Images/References/res_10m/r10m_def_2008_2018.tif').astype('float32') # 2008_2018
#clouds_2018 = load_tif_image(root_path+'New_Images/References/cut_b10_2018.tif').astype('float32')
#clouds_2018 = resize_image(np.expand_dims(clouds_2018.copy(), axis = -1), ref_2019.shape[0], ref_2019.shape[1])
#clouds_2018 = binary_mask_cloud(clouds_2018.copy(), 50)
#clouds_2019 = load_tif_image(root_path+'New_Images/References/cut_b10_2019.tif').astype('float32') 
#clouds_2019 = resize_image(np.expand_dims(clouds_2019.copy(), axis = -1), ref_2019.shape[0], ref_2019.shape[1])
#clouds_2019 = binary_mask_cloud(clouds_2019.copy(), 50)
# Out:
# imgs/New_Images/Sentinel1/cut_sent1_vh_2018.tif
# imgs/New_Images/Sentinel1/cut_sent1_vv_2018.tif
# imgs/New_Images/Sentinel1/cut_sent1_vh_2019.tif
# imgs/New_Images/Sentinel1/cut_sent1_vv_2019.tif
# Image stack: (17729, 9202, 4)

# %%
# Create label mask
#past_ref = past_ref1 + past_ref2 + clouds_2018 + clouds_2019
#past_ref[past_ref>=1] = 1
#buffer = 2
#final_mask1 = mask_no_considered(ref_2019, buffer, past_ref)
#del past_ref1, past_ref2, clouds_2018, clouds_2019
final_mask1 = np.load(root_path+'New_Images/ref/'+'labels.npy')

lim_x = 10000
lim_y = 7000
image_stack = image_stack[:lim_x, :lim_y, :]
final_mask1 = final_mask1[:lim_x, :lim_y]
#ref_2019 = ref_2019[:lim_x, :lim_y]

h_, w_, channels = image_stack.shape
print('image stack size: ', image_stack.shape)

# Normalization
type_norm = 1
image_array = normalization(image_stack.copy(), type_norm)
print(np.min(image_array), np.max(image_array))
del image_stack

# Print pertengate of each class (whole image)
print('Total no-deforestaion class is {}'.format(len(final_mask1[final_mask1==0])))
print('Total deforestaion class is {}'.format(len(final_mask1[final_mask1==1])))
print('Total past deforestaion class is {}'.format(len(final_mask1[final_mask1==2])))
print('Percentage of deforestaion class is {:.2f}'.format((len(final_mask1[final_mask1==1])*100)/len(final_mask1[final_mask1==0])))
# Out:
# image stack size:  (10000, 7000, 4)
# -1.3673552 6.424306
# Total no-deforestaion class is 36326397
# Total deforestaion class is 1048775
# Total past deforestaion class is 32624828
# Percentage of deforestaion class is 2.89

# %%
# Create tile mask
mask_tiles = create_mask(final_mask1.shape[0], final_mask1.shape[1], grid_size=(5, 4))
image_array = image_array[:mask_tiles.shape[0], :mask_tiles.shape[1],:]
final_mask1 = final_mask1[:mask_tiles.shape[0], :mask_tiles.shape[1]]

print('mask: ',mask_tiles.shape)
print('image stack: ', image_array.shape)
print('ref :', final_mask1.shape)
#plt.imshow(mask_tiles)
# Out:
# Tiles size:  2000 1750
# Mask size:  (10000, 7000)
# mask:  (10000, 7000)
# image stack:  (10000, 7000, 4)
# ref : (10000, 7000)

# %%
plt.figure(figsize=(10,5))
plt.imshow(final_mask1, cmap = 'jet')

# %%
# Define tiles for training, validation, and test sets
tiles_tr = [1,3,5,8,11,13,14,20]
tiles_val = [6,19]
tiles_ts = (list(set(np.arange(20)+1)-set(tiles_tr)-set(tiles_val)))

mask_tr_val = np.zeros((mask_tiles.shape)).astype('float32')
# Training and validation mask
for tr_ in tiles_tr:
    mask_tr_val[mask_tiles == tr_] = 1

for val_ in tiles_val:
    mask_tr_val[mask_tiles == val_] = 2

mask_amazon_ts = np.zeros((mask_tiles.shape)).astype('float32')
for ts_ in tiles_ts:
    mask_amazon_ts[mask_tiles == ts_] = 1

# %%
# Create ixd image to extract patches
overlap = 0.7
patch_size = 128
batch_size = 32
im_idx = create_idx_image(final_mask1)
patches_idx = extract_patches(im_idx, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1,patch_size, patch_size)
patches_mask = extract_patches(mask_tr_val, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1, patch_size, patch_size)
del im_idx

# %%
# Selecting index trn val and test patches idx
idx_trn = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==patch_size**2))
idx_val = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==2*patch_size**2))
del patches_mask

patches_idx_trn = patches_idx[idx_trn]
patches_idx_val = patches_idx[idx_val]
del idx_trn, idx_val

print('Number of training patches:  ', len(patches_idx_trn), 'Number of validation patches', len(patches_idx_val))
# Out:
# Number of training patches:   17110 Number of validation patches 4116

# %%
# Extract patches with at least 2% of deforestation class
X_train = retrieve_idx_percentage(final_mask1, patches_idx_trn, patch_size, pertentage = 2)
X_valid = retrieve_idx_percentage(final_mask1, patches_idx_val, patch_size, pertentage = 2)
print(X_train.shape, X_valid.shape)
del patches_idx_trn, patches_idx_val
# Out:
# (1158, 128, 128) (341, 128, 128)

# %%
def batch_generator(batches, image, reference, target_size, number_class):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    image = image.reshape(-1, image.shape[-1])
    reference = reference.reshape(final_mask1.shape[0]*final_mask1.shape[1])
    while True:
        batch_x, batch_y = next(batches)
        batch_x = np.squeeze(batch_x.astype('int64'))
        #print(batch_x.shape)
        batch_img = np.zeros((batch_x.shape[0], target_size, target_size, image.shape[-1]))
        batch_ref = np.zeros((batch_x.shape[0], target_size, target_size, number_class))
        
        for i in range(batch_x.shape[0]):
            if np.random.rand()>0.5:
                batch_x[i] = np.rot90(batch_x[i], 1)
            batch_img[i] = image[batch_x[i]] 
            batch_ref[i] = tf.keras.utils.to_categorical(reference[batch_x[i]] , number_class)
                       
        yield (batch_img, batch_ref)

train_datagen = ImageDataGenerator(horizontal_flip = True,
                                   vertical_flip = True)
valid_datagen = ImageDataGenerator(horizontal_flip = True, 
                                   vertical_flip = True)

y_train = np.zeros((len(X_train)))
y_valid = np.zeros((len(X_valid)))

train_gen = train_datagen.flow(np.expand_dims(X_train, axis = -1), y_train,
                              batch_size=batch_size,
                              shuffle=True)

valid_gen = valid_datagen.flow(np.expand_dims(X_valid, axis = -1), y_valid,
                              batch_size=batch_size,
                              shuffle=False)

number_class = 3
train_gen_crops = batch_generator(train_gen, image_array, final_mask1, patch_size, number_class)
valid_gen_crops = batch_generator(valid_gen, image_array, final_mask1, patch_size, number_class)

# %%
exp = 1
path_exp = root_path+'experiments/exp'+str(exp)
path_models = path_exp+'/models'
path_maps = path_exp+'/pred_maps'

if not os.path.exists(path_exp):
    os.makedirs(path_exp)   
if not os.path.exists(path_models):
    os.makedirs(path_models)   
if not os.path.exists(path_maps):
    os.makedirs(path_maps)

# %%
# Define model
input_shape = (patch_size, patch_size, channels)
nb_filters = [32, 64, 128]

method = 'resunet'
if method == 'unet':
   model = build_unet(input_shape, nb_filters, number_class)

if method == 'resunet':
   model = build_resunet(input_shape, nb_filters, number_class)

# %%
# Parameters of the model
weights = [0.2, 0.8, 0]
adam = Adam(lr = 1e-3 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)

# %%
metrics_all = []
times=5
for tm in range(0,times):
    print('time: ', tm)

    rows = patch_size
    cols = patch_size
    adam = Adam(lr = 1e-3 , beta_1=0.9)
    
    loss = weighted_categorical_crossentropy(weights)

    #model = build_unet((rows, cols, channels), nb_filters, number_class)
    model = build_resunet((rows, cols, channels), nb_filters, number_class)
    
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    model.summary()

    earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
    #earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min') ---- val_accuracy
    checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    lr_reduce = ReduceLROnPlateau(factor=0.9, min_delta=0.0001, patience=5, verbose=1)
    callbacks_list = [earlystop, checkpoint]
    # train the model
    start_training = time.time()
    history = model.fit_generator(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    end_training = time.time() - start_training
    metrics_all.append(end_training)
    del model, history
# Out:
# time:  0
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_enc_net (InputLayer)      [(None, 128, 128, 4) 0
# __________________________________________________________________________________________________
# res1_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# drop_net1 (Dropout)             (None, 128, 128, 32) 0           res1_net1[0][0]
# __________________________________________________________________________________________________
# res2_net1 (Conv2D)              (None, 128, 128, 32) 9248        drop_net1[0][0]
# __________________________________________________________________________________________________
# res3_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 128, 128, 32) 0           res2_net1[0][0]
#                                                                  res3_net1[0][0]
# __________________________________________________________________________________________________
# pool_net1 (MaxPooling2D)        (None, 64, 64, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# res1_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# drop_net2 (Dropout)             (None, 64, 64, 64)   0           res1_net2[0][0]
# __________________________________________________________________________________________________
# res2_net2 (Conv2D)              (None, 64, 64, 64)   36928       drop_net2[0][0]
# __________________________________________________________________________________________________
# res3_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 64)   0           res2_net2[0][0]
#                                                                  res3_net2[0][0]
# __________________________________________________________________________________________________
# pool_net2 (MaxPooling2D)        (None, 32, 32, 64)   0           add_7[0][0]
# __________________________________________________________________________________________________
# res1_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# drop_net3 (Dropout)             (None, 32, 32, 128)  0           res1_net3[0][0]
# __________________________________________________________________________________________________
# res2_net3 (Conv2D)              (None, 32, 32, 128)  147584      drop_net3[0][0]
# __________________________________________________________________________________________________
# res3_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 128)  0           res2_net3[0][0]
#                                                                  res3_net3[0][0]
# __________________________________________________________________________________________________
# pool_net3 (MaxPooling2D)        (None, 16, 16, 128)  0           add_8[0][0]
# __________________________________________________________________________________________________
# res1_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# drop_net4 (Dropout)             (None, 16, 16, 128)  0           res1_net4[0][0]
# __________________________________________________________________________________________________
# res2_net4 (Conv2D)              (None, 16, 16, 128)  147584      drop_net4[0][0]
# __________________________________________________________________________________________________
# res3_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 128)  0           res2_net4[0][0]
#                                                                  res3_net4[0][0]
# __________________________________________________________________________________________________
# res1_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_9[0][0]
# __________________________________________________________________________________________________
# drop_net5 (Dropout)             (None, 16, 16, 128)  0           res1_net5[0][0]
# __________________________________________________________________________________________________
# res2_net5 (Conv2D)              (None, 16, 16, 128)  147584      drop_net5[0][0]
# __________________________________________________________________________________________________
# res3_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_9[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 128)  0           res2_net5[0][0]
#                                                                  res3_net5[0][0]
# __________________________________________________________________________________________________
# res1_net6 (Conv2D)              (None, 16, 16, 128)  147584      add_10[0][0]
# __________________________________________________________________________________________________
# drop_net6 (Dropout)             (None, 16, 16, 128)  0           res1_net6[0][0]
# __________________________________________________________________________________________________
# res2_net6 (Conv2D)              (None, 16, 16, 128)  147584      drop_net6[0][0]
# __________________________________________________________________________________________________
# res3_net6 (Conv2D)              (None, 16, 16, 128)  147584      add_10[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 128)  0           res2_net6[0][0]
#                                                                  res3_net6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# upsampling_net3 (Conv2D)        (None, 32, 32, 128)  147584      up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate3 (Concatenate)      (None, 32, 32, 256)  0           add_8[0][0]
#                                                                  upsampling_net3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 256)  0           concatenate3[0][0]
# __________________________________________________________________________________________________
# upsampling_net2 (Conv2D)        (None, 64, 64, 64)   147520      up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate2 (Concatenate)      (None, 64, 64, 128)  0           add_7[0][0]
#                                                                  upsampling_net2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 128 0           concatenate2[0][0]
# __________________________________________________________________________________________________
# upsampling_net1 (Conv2D)        (None, 128, 128, 32) 36896       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate1 (Concatenate)      (None, 128, 128, 64) 0           add_6[0][0]
#                                                                  upsampling_net1[0][0]
# __________________________________________________________________________________________________
# output (Conv2D)                 (None, 128, 128, 3)  195         concatenate1[0][0]
# ==================================================================================================
# Total params: 2,041,283
# Trainable params: 2,041,283
# Non-trainable params: 0
# __________________________________________________________________________________________________
# C:\Users\felferrari\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 108/108 [==============================] - 12s 71ms/step - loss: 0.1730 - accuracy: 0.5680 - val_loss: 0.1184 - val_accuracy: 0.6795
#
# Epoch 00001: val_loss improved from inf to 0.11842, saving model to imgs/experiments/exp1/models\resunet_0.h5
# Epoch 2/100
# 108/108 [==============================] - 6s 58ms/step - loss: 0.1199 - accuracy: 0.6784 - val_loss: 0.1168 - val_accuracy: 0.6680
#
# Epoch 00002: val_loss improved from 0.11842 to 0.11684, saving model to imgs/experiments/exp1/models\resunet_0.h5
# Epoch 3/100
# 108/108 [==============================] - 6s 58ms/step - loss: 0.1037 - accuracy: 0.7278 - val_loss: 0.1123 - val_accuracy: 0.6936
#
# Epoch 00003: val_loss improved from 0.11684 to 0.11232, saving model to imgs/experiments/exp1/models\resunet_0.h5
# Epoch 4/100
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0968 - accuracy: 0.7357 - val_loss: 0.1073 - val_accuracy: 0.6847
#
# Epoch 00004: val_loss improved from 0.11232 to 0.10729, saving model to imgs/experiments/exp1/models\resunet_0.h5
# Epoch 5/100
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0976 - accuracy: 0.7333 - val_loss: 0.1127 - val_accuracy: 0.6768
#
# Epoch 00005: val_loss did not improve from 0.10729
# Epoch 6/100
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0941 - accuracy: 0.7429 - val_loss: 0.1205 - val_accuracy: 0.7043
#
# Epoch 00006: val_loss did not improve from 0.10729
# Epoch 7/100
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0889 - accuracy: 0.7554 - val_loss: 0.1187 - val_accuracy: 0.6975
#
# Epoch 00007: val_loss did not improve from 0.10729
# Epoch 8/100
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0875 - accuracy: 0.7546 - val_loss: 0.1211 - val_accuracy: 0.7027
#
# Epoch 00008: val_loss did not improve from 0.10729
# Epoch 9/100
# 108/108 [==============================] - 6s 60ms/step - loss: 0.0852 - accuracy: 0.7603 - val_loss: 0.1166 - val_accuracy: 0.7071
#
# Epoch 00009: val_loss did not improve from 0.10729
# Epoch 10/100
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0806 - accuracy: 0.7731 - val_loss: 0.1225 - val_accuracy: 0.7072
#
# Epoch 00010: val_loss did not improve from 0.10729
# Epoch 11/100
# 108/108 [==============================] - 7s 62ms/step - loss: 0.0786 - accuracy: 0.7745 - val_loss: 0.1241 - val_accuracy: 0.7157
#
# Epoch 00011: val_loss did not improve from 0.10729
# Epoch 12/100
# 108/108 [==============================] - 7s 62ms/step - loss: 0.0762 - accuracy: 0.7818 - val_loss: 0.1213 - val_accuracy: 0.7099
#
# Epoch 00012: val_loss did not improve from 0.10729
# Epoch 13/100
# 108/108 [==============================] - 7s 63ms/step - loss: 0.0722 - accuracy: 0.7885 - val_loss: 0.1157 - val_accuracy: 0.7088
#
# Epoch 00013: val_loss did not improve from 0.10729
# Epoch 14/100
# 108/108 [==============================] - 7s 64ms/step - loss: 0.0724 - accuracy: 0.7892 - val_loss: 0.1218 - val_accuracy: 0.6956
#
# Epoch 00014: val_loss did not improve from 0.10729
# Epoch 00014: early stopping
# time:  1
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_enc_net (InputLayer)      [(None, 128, 128, 4) 0
# __________________________________________________________________________________________________
# res1_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# drop_net1 (Dropout)             (None, 128, 128, 32) 0           res1_net1[0][0]
# __________________________________________________________________________________________________
# res2_net1 (Conv2D)              (None, 128, 128, 32) 9248        drop_net1[0][0]
# __________________________________________________________________________________________________
# res3_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 128, 128, 32) 0           res2_net1[0][0]
#                                                                  res3_net1[0][0]
# __________________________________________________________________________________________________
# pool_net1 (MaxPooling2D)        (None, 64, 64, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res1_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# drop_net2 (Dropout)             (None, 64, 64, 64)   0           res1_net2[0][0]
# __________________________________________________________________________________________________
# res2_net2 (Conv2D)              (None, 64, 64, 64)   36928       drop_net2[0][0]
# __________________________________________________________________________________________________
# res3_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 64)   0           res2_net2[0][0]
#                                                                  res3_net2[0][0]
# __________________________________________________________________________________________________
# pool_net2 (MaxPooling2D)        (None, 32, 32, 64)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res1_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# drop_net3 (Dropout)             (None, 32, 32, 128)  0           res1_net3[0][0]
# __________________________________________________________________________________________________
# res2_net3 (Conv2D)              (None, 32, 32, 128)  147584      drop_net3[0][0]
# __________________________________________________________________________________________________
# res3_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 32, 128)  0           res2_net3[0][0]
#                                                                  res3_net3[0][0]
# __________________________________________________________________________________________________
# pool_net3 (MaxPooling2D)        (None, 16, 16, 128)  0           add_14[0][0]
# __________________________________________________________________________________________________
# res1_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# drop_net4 (Dropout)             (None, 16, 16, 128)  0           res1_net4[0][0]
# __________________________________________________________________________________________________
# res2_net4 (Conv2D)              (None, 16, 16, 128)  147584      drop_net4[0][0]
# __________________________________________________________________________________________________
# res3_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 16, 16, 128)  0           res2_net4[0][0]
#                                                                  res3_net4[0][0]
# __________________________________________________________________________________________________
# res1_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_15[0][0]
# __________________________________________________________________________________________________
# drop_net5 (Dropout)             (None, 16, 16, 128)  0           res1_net5[0][0]
# __________________________________________________________________________________________________
# res2_net5 (Conv2D)              (None, 16, 16, 128)  147584      drop_net5[0][0]
# __________________________________________________________________________________________________
# res3_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_15[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 16, 16, 128)  0           res2_net5[0][0]
#                                                                  res3_net5[0][0]
# __________________________________________________________________________________________________
# res1_net6 (Conv2D)              (None, 16, 16, 128)  147584      add_16[0][0]
# __________________________________________________________________________________________________
# drop_net6 (Dropout)             (None, 16, 16, 128)  0           res1_net6[0][0]
# __________________________________________________________________________________________________
# res2_net6 (Conv2D)              (None, 16, 16, 128)  147584      drop_net6[0][0]
# __________________________________________________________________________________________________
# res3_net6 (Conv2D)              (None, 16, 16, 128)  147584      add_16[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 16, 16, 128)  0           res2_net6[0][0]
#                                                                  res3_net6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 32, 32, 128)  0           add_17[0][0]
# __________________________________________________________________________________________________
# upsampling_net3 (Conv2D)        (None, 32, 32, 128)  147584      up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate3 (Concatenate)      (None, 32, 32, 256)  0           add_14[0][0]
#                                                                  upsampling_net3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 256)  0           concatenate3[0][0]
# __________________________________________________________________________________________________
# upsampling_net2 (Conv2D)        (None, 64, 64, 64)   147520      up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate2 (Concatenate)      (None, 64, 64, 128)  0           add_13[0][0]
#                                                                  upsampling_net2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 128 0           concatenate2[0][0]
# __________________________________________________________________________________________________
# upsampling_net1 (Conv2D)        (None, 128, 128, 32) 36896       up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate1 (Concatenate)      (None, 128, 128, 64) 0           add_12[0][0]
#                                                                  upsampling_net1[0][0]
# __________________________________________________________________________________________________
# output (Conv2D)                 (None, 128, 128, 3)  195         concatenate1[0][0]
# ==================================================================================================
# Total params: 2,041,283
# Trainable params: 2,041,283
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 8s 66ms/step - loss: 0.1775 - accuracy: 0.5785 - val_loss: 0.1134 - val_accuracy: 0.6732
#
# Epoch 00001: val_loss improved from inf to 0.11342, saving model to imgs/experiments/exp1/models\resunet_1.h5
# Epoch 2/100
# 108/108 [==============================] - 7s 65ms/step - loss: 0.1190 - accuracy: 0.6806 - val_loss: 0.1134 - val_accuracy: 0.6854
#
# Epoch 00002: val_loss improved from 0.11342 to 0.11338, saving model to imgs/experiments/exp1/models\resunet_1.h5
# Epoch 3/100
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1053 - accuracy: 0.7118 - val_loss: 0.1266 - val_accuracy: 0.6446
#
# Epoch 00003: val_loss did not improve from 0.11338
# Epoch 4/100
# 108/108 [==============================] - 7s 68ms/step - loss: 0.1027 - accuracy: 0.7159 - val_loss: 0.1174 - val_accuracy: 0.6917
#
# Epoch 00004: val_loss did not improve from 0.11338
# Epoch 5/100
# 108/108 [==============================] - 8s 70ms/step - loss: 0.0958 - accuracy: 0.7365 - val_loss: 0.1162 - val_accuracy: 0.7048
#
# Epoch 00005: val_loss did not improve from 0.11338
# Epoch 6/100
# 108/108 [==============================] - 8s 72ms/step - loss: 0.0921 - accuracy: 0.7456 - val_loss: 0.1163 - val_accuracy: 0.6972
#
# Epoch 00006: val_loss did not improve from 0.11338
# Epoch 7/100
# 108/108 [==============================] - 8s 73ms/step - loss: 0.0892 - accuracy: 0.7462 - val_loss: 0.1163 - val_accuracy: 0.7128
#
# Epoch 00007: val_loss did not improve from 0.11338
# Epoch 8/100
# 108/108 [==============================] - 8s 75ms/step - loss: 0.0875 - accuracy: 0.7546 - val_loss: 0.1122 - val_accuracy: 0.7175
#
# Epoch 00008: val_loss improved from 0.11338 to 0.11217, saving model to imgs/experiments/exp1/models\resunet_1.h5
# Epoch 9/100
# 108/108 [==============================] - 8s 79ms/step - loss: 0.0839 - accuracy: 0.7611 - val_loss: 0.1162 - val_accuracy: 0.7123
#
# Epoch 00009: val_loss did not improve from 0.11217
# Epoch 10/100
# 108/108 [==============================] - 9s 79ms/step - loss: 0.0805 - accuracy: 0.7689 - val_loss: 0.1182 - val_accuracy: 0.7245
#
# Epoch 00010: val_loss did not improve from 0.11217
# Epoch 11/100
# 108/108 [==============================] - 9s 82ms/step - loss: 0.0773 - accuracy: 0.7763 - val_loss: 0.1331 - val_accuracy: 0.7238loss: 0.0774 - ac - ETA: 3s - loss: 0.0774 -  - ETA: 2s - loss: 0.0774 - accu - ETA: 2s
#
# Epoch 00011: val_loss did not improve from 0.11217
# Epoch 12/100
# 108/108 [==============================] - 9s 84ms/step - loss: 0.0761 - accuracy: 0.7777 - val_loss: 0.1130 - val_accuracy: 0.7240- loss: 0.0765 - accuracy: 0. - ETA: 1s - loss: 0.076 - ETA: 0s - loss: 0.0763 -  - ETA: 0s - loss: 0.0762 - accura
#
# Epoch 00012: val_loss did not improve from 0.11217
# Epoch 13/100
# 108/108 [==============================] - 9s 85ms/step - loss: 0.0733 - accuracy: 0.7875 - val_loss: 0.1143 - val_accuracy: 0.7244: 0.0731  - ETA: 2s - loss: 0.0733 - accu - ETA: 0s - loss:
#
# Epoch 00013: val_loss did not improve from 0.11217
# Epoch 14/100
# 108/108 [==============================] - 9s 86ms/step - loss: 0.0687 - accuracy: 0.7961 - val_loss: 0.1350 - val_accuracy: 0.7205
#
# Epoch 00014: val_loss did not improve from 0.11217
# Epoch 15/100
# 108/108 [==============================] - 10s 89ms/step - loss: 0.0687 - accuracy: 0.7961 - val_loss: 0.1173 - val_accuracy: 0.7286
#
# Epoch 00015: val_loss did not improve from 0.11217
# Epoch 16/100
# 108/108 [==============================] - 10s 89ms/step - loss: 0.0643 - accuracy: 0.8094 - val_loss: 0.1376 - val_accuracy: 0.7131
#
# Epoch 00016: val_loss did not improve from 0.11217
# Epoch 17/100
# 108/108 [==============================] - 10s 91ms/step - loss: 0.0621 - accuracy: 0.8134 - val_loss: 0.1465 - val_accuracy: 0.7169
#
# Epoch 00017: val_loss did not improve from 0.11217
# Epoch 18/100
# 108/108 [==============================] - 10s 91ms/step - loss: 0.0603 - accuracy: 0.8174 - val_loss: 0.1428 - val_accuracy: 0.7056
#
# Epoch 00018: val_loss did not improve from 0.11217
# Epoch 00018: early stopping
# time:  2
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_enc_net (InputLayer)      [(None, 128, 128, 4) 0
# __________________________________________________________________________________________________
# res1_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# drop_net1 (Dropout)             (None, 128, 128, 32) 0           res1_net1[0][0]
# __________________________________________________________________________________________________
# res2_net1 (Conv2D)              (None, 128, 128, 32) 9248        drop_net1[0][0]
# __________________________________________________________________________________________________
# res3_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 128, 128, 32) 0           res2_net1[0][0]
#                                                                  res3_net1[0][0]
# __________________________________________________________________________________________________
# pool_net1 (MaxPooling2D)        (None, 64, 64, 32)   0           add_18[0][0]
# __________________________________________________________________________________________________
# res1_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# drop_net2 (Dropout)             (None, 64, 64, 64)   0           res1_net2[0][0]
# __________________________________________________________________________________________________
# res2_net2 (Conv2D)              (None, 64, 64, 64)   36928       drop_net2[0][0]
# __________________________________________________________________________________________________
# res3_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 64, 64, 64)   0           res2_net2[0][0]
#                                                                  res3_net2[0][0]
# __________________________________________________________________________________________________
# pool_net2 (MaxPooling2D)        (None, 32, 32, 64)   0           add_19[0][0]
# __________________________________________________________________________________________________
# res1_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# drop_net3 (Dropout)             (None, 32, 32, 128)  0           res1_net3[0][0]
# __________________________________________________________________________________________________
# res2_net3 (Conv2D)              (None, 32, 32, 128)  147584      drop_net3[0][0]
# __________________________________________________________________________________________________
# res3_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 128)  0           res2_net3[0][0]
#                                                                  res3_net3[0][0]
# __________________________________________________________________________________________________
# pool_net3 (MaxPooling2D)        (None, 16, 16, 128)  0           add_20[0][0]
# __________________________________________________________________________________________________
# res1_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# drop_net4 (Dropout)             (None, 16, 16, 128)  0           res1_net4[0][0]
# __________________________________________________________________________________________________
# res2_net4 (Conv2D)              (None, 16, 16, 128)  147584      drop_net4[0][0]
# __________________________________________________________________________________________________
# res3_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 16, 16, 128)  0           res2_net4[0][0]
#                                                                  res3_net4[0][0]
# __________________________________________________________________________________________________
# res1_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_21[0][0]
# __________________________________________________________________________________________________
# drop_net5 (Dropout)             (None, 16, 16, 128)  0           res1_net5[0][0]
# __________________________________________________________________________________________________
# res2_net5 (Conv2D)              (None, 16, 16, 128)  147584      drop_net5[0][0]
# __________________________________________________________________________________________________
# res3_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_21[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 128)  0           res2_net5[0][0]
#                                                                  res3_net5[0][0]
# __________________________________________________________________________________________________
# res1_net6 (Conv2D)              (None, 16, 16, 128)  147584      add_22[0][0]
# __________________________________________________________________________________________________
# drop_net6 (Dropout)             (None, 16, 16, 128)  0           res1_net6[0][0]
# __________________________________________________________________________________________________
# res2_net6 (Conv2D)              (None, 16, 16, 128)  147584      drop_net6[0][0]
# __________________________________________________________________________________________________
# res3_net6 (Conv2D)              (None, 16, 16, 128)  147584      add_22[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 128)  0           res2_net6[0][0]
#                                                                  res3_net6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 32, 32, 128)  0           add_23[0][0]
# __________________________________________________________________________________________________
# upsampling_net3 (Conv2D)        (None, 32, 32, 128)  147584      up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate3 (Concatenate)      (None, 32, 32, 256)  0           add_20[0][0]
#                                                                  upsampling_net3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 64, 64, 256)  0           concatenate3[0][0]
# __________________________________________________________________________________________________
# upsampling_net2 (Conv2D)        (None, 64, 64, 64)   147520      up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate2 (Concatenate)      (None, 64, 64, 128)  0           add_19[0][0]
#                                                                  upsampling_net2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 128, 128, 128 0           concatenate2[0][0]
# __________________________________________________________________________________________________
# upsampling_net1 (Conv2D)        (None, 128, 128, 32) 36896       up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate1 (Concatenate)      (None, 128, 128, 64) 0           add_18[0][0]
#                                                                  upsampling_net1[0][0]
# __________________________________________________________________________________________________
# output (Conv2D)                 (None, 128, 128, 3)  195         concatenate1[0][0]
# ==================================================================================================
# Total params: 2,041,283
# Trainable params: 2,041,283
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 11s 94ms/step - loss: 0.1655 - accuracy: 0.5550 - val_loss: 0.1219 - val_accuracy: 0.6646
#
# Epoch 00001: val_loss improved from inf to 0.12188, saving model to imgs/experiments/exp1/models\resunet_2.h5
# Epoch 2/100
# 108/108 [==============================] - 10s 96ms/step - loss: 0.1249 - accuracy: 0.6659 - val_loss: 0.1227 - val_accuracy: 0.6484
#
# Epoch 00002: val_loss did not improve from 0.12188
# Epoch 3/100
# 108/108 [==============================] - 10s 93ms/step - loss: 0.1116 - accuracy: 0.7116 - val_loss: 0.1165 - val_accuracy: 0.6607
#
# Epoch 00003: val_loss improved from 0.12188 to 0.11647, saving model to imgs/experiments/exp1/models\resunet_2.h5
# Epoch 4/100
# 108/108 [==============================] - 10s 96ms/step - loss: 0.1026 - accuracy: 0.7317 - val_loss: 0.1115 - val_accuracy: 0.6969
#
# Epoch 00004: val_loss improved from 0.11647 to 0.11147, saving model to imgs/experiments/exp1/models\resunet_2.h5
# Epoch 5/100
# 108/108 [==============================] - 10s 97ms/step - loss: 0.0969 - accuracy: 0.7405 - val_loss: 0.1059 - val_accuracy: 0.7083
#
# Epoch 00005: val_loss improved from 0.11147 to 0.10590, saving model to imgs/experiments/exp1/models\resunet_2.h5
# Epoch 6/100
# 108/108 [==============================] - 11s 98ms/step - loss: 0.0941 - accuracy: 0.7481 - val_loss: 0.1130 - val_accuracy: 0.7076
#
# Epoch 00006: val_loss did not improve from 0.10590
# Epoch 7/100
# 108/108 [==============================] - 10s 98ms/step - loss: 0.0895 - accuracy: 0.7543 - val_loss: 0.1264 - val_accuracy: 0.7004
#
# Epoch 00007: val_loss did not improve from 0.10590
# Epoch 8/100
# 108/108 [==============================] - 10s 97ms/step - loss: 0.0866 - accuracy: 0.7622 - val_loss: 0.1246 - val_accuracy: 0.6880
#
# Epoch 00008: val_loss did not improve from 0.10590
# Epoch 9/100
# 108/108 [==============================] - 11s 98ms/step - loss: 0.0849 - accuracy: 0.7654 - val_loss: 0.1198 - val_accuracy: 0.7133
#
# Epoch 00009: val_loss did not improve from 0.10590
# Epoch 10/100
# 108/108 [==============================] - 11s 100ms/step - loss: 0.0832 - accuracy: 0.7618 - val_loss: 0.1150 - val_accuracy: 0.7226
#
# Epoch 00010: val_loss did not improve from 0.10590
# Epoch 11/100
# 108/108 [==============================] - 11s 102ms/step - loss: 0.0806 - accuracy: 0.7709 - val_loss: 0.1323 - val_accuracy: 0.7243
#
# Epoch 00011: val_loss did not improve from 0.10590
# Epoch 12/100
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0826 - accuracy: 0.7669 - val_loss: 0.1217 - val_accuracy: 0.7140
#
# Epoch 00012: val_loss did not improve from 0.10590
# Epoch 13/100
# 108/108 [==============================] - 11s 100ms/step - loss: 0.0791 - accuracy: 0.7744 - val_loss: 0.1199 - val_accuracy: 0.7090
#
# Epoch 00013: val_loss did not improve from 0.10590
# Epoch 14/100
# 108/108 [==============================] - 11s 100ms/step - loss: 0.0741 - accuracy: 0.7835 - val_loss: 0.1231 - val_accuracy: 0.6976
#
# Epoch 00014: val_loss did not improve from 0.10590
# Epoch 15/100
# 108/108 [==============================] - 11s 100ms/step - loss: 0.0723 - accuracy: 0.7878 - val_loss: 0.1252 - val_accuracy: 0.7131
#
# Epoch 00015: val_loss did not improve from 0.10590
# Epoch 00015: early stopping
# time:  3
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_enc_net (InputLayer)      [(None, 128, 128, 4) 0
# __________________________________________________________________________________________________
# res1_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# drop_net1 (Dropout)             (None, 128, 128, 32) 0           res1_net1[0][0]
# __________________________________________________________________________________________________
# res2_net1 (Conv2D)              (None, 128, 128, 32) 9248        drop_net1[0][0]
# __________________________________________________________________________________________________
# res3_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 128, 128, 32) 0           res2_net1[0][0]
#                                                                  res3_net1[0][0]
# __________________________________________________________________________________________________
# pool_net1 (MaxPooling2D)        (None, 64, 64, 32)   0           add_24[0][0]
# __________________________________________________________________________________________________
# res1_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# drop_net2 (Dropout)             (None, 64, 64, 64)   0           res1_net2[0][0]
# __________________________________________________________________________________________________
# res2_net2 (Conv2D)              (None, 64, 64, 64)   36928       drop_net2[0][0]
# __________________________________________________________________________________________________
# res3_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 64, 64, 64)   0           res2_net2[0][0]
#                                                                  res3_net2[0][0]
# __________________________________________________________________________________________________
# pool_net2 (MaxPooling2D)        (None, 32, 32, 64)   0           add_25[0][0]
# __________________________________________________________________________________________________
# res1_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# drop_net3 (Dropout)             (None, 32, 32, 128)  0           res1_net3[0][0]
# __________________________________________________________________________________________________
# res2_net3 (Conv2D)              (None, 32, 32, 128)  147584      drop_net3[0][0]
# __________________________________________________________________________________________________
# res3_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 32, 32, 128)  0           res2_net3[0][0]
#                                                                  res3_net3[0][0]
# __________________________________________________________________________________________________
# pool_net3 (MaxPooling2D)        (None, 16, 16, 128)  0           add_26[0][0]
# __________________________________________________________________________________________________
# res1_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# drop_net4 (Dropout)             (None, 16, 16, 128)  0           res1_net4[0][0]
# __________________________________________________________________________________________________
# res2_net4 (Conv2D)              (None, 16, 16, 128)  147584      drop_net4[0][0]
# __________________________________________________________________________________________________
# res3_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 16, 16, 128)  0           res2_net4[0][0]
#                                                                  res3_net4[0][0]
# __________________________________________________________________________________________________
# res1_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_27[0][0]
# __________________________________________________________________________________________________
# drop_net5 (Dropout)             (None, 16, 16, 128)  0           res1_net5[0][0]
# __________________________________________________________________________________________________
# res2_net5 (Conv2D)              (None, 16, 16, 128)  147584      drop_net5[0][0]
# __________________________________________________________________________________________________
# res3_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_27[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 16, 16, 128)  0           res2_net5[0][0]
#                                                                  res3_net5[0][0]
# __________________________________________________________________________________________________
# res1_net6 (Conv2D)              (None, 16, 16, 128)  147584      add_28[0][0]
# __________________________________________________________________________________________________
# drop_net6 (Dropout)             (None, 16, 16, 128)  0           res1_net6[0][0]
# __________________________________________________________________________________________________
# res2_net6 (Conv2D)              (None, 16, 16, 128)  147584      drop_net6[0][0]
# ...
# Epoch 7/100
# 108/108 [==============================] - 11s 106ms/step - loss: 0.0897 - accuracy: 0.7513 - val_loss: 0.1103 - val_accuracy: 0.7025
#
# Epoch 00007: val_loss did not improve from 0.10805
# Epoch 8/100
# 108/108 [==============================] - 11s 106ms/step - loss: 0.0881 - accuracy: 0.7543 - val_loss: 0.1171 - val_accuracy: 0.6982
#
# Epoch 00008: val_loss did not improve from 0.10805
# Epoch 9/100
# 108/108 [==============================] - 12s 107ms/step - loss: 0.0869 - accuracy: 0.7570 - val_loss: 0.1163 - val_accuracy: 0.7096
#
# Epoch 00009: val_loss did not improve from 0.10805
# Epoch 10/100
# 108/108 [==============================] - 12s 108ms/step - loss: 0.0861 - accuracy: 0.7559 - val_loss: 0.1136 - val_accuracy: 0.7187
#
# Epoch 00010: val_loss did not improve from 0.10805
# Epoch 11/100
# 108/108 [==============================] - 12s 108ms/step - loss: 0.0817 - accuracy: 0.7689 - val_loss: 0.1068 - val_accuracy: 0.7076
#
# Epoch 00011: val_loss improved from 0.10805 to 0.10679, saving model to imgs/experiments/exp1/models\resunet_3.h5
# Epoch 12/100
# 108/108 [==============================] - 12s 111ms/step - loss: 0.0816 - accuracy: 0.7697 - val_loss: 0.1066 - val_accuracy: 0.7096
#
# Epoch 00012: val_loss improved from 0.10679 to 0.10658, saving model to imgs/experiments/exp1/models\resunet_3.h5
# Epoch 13/100
# 108/108 [==============================] - 12s 113ms/step - loss: 0.0764 - accuracy: 0.7780 - val_loss: 0.1152 - val_accuracy: 0.7207
#
# Epoch 00013: val_loss did not improve from 0.10658
# Epoch 14/100
# 108/108 [==============================] - 12s 109ms/step - loss: 0.0720 - accuracy: 0.7885 - val_loss: 0.1286 - val_accuracy: 0.7228
#
# Epoch 00014: val_loss did not improve from 0.10658
# Epoch 15/100
# 108/108 [==============================] - 12s 110ms/step - loss: 0.0715 - accuracy: 0.7916 - val_loss: 0.1261 - val_accuracy: 0.6945
#
# Epoch 00015: val_loss did not improve from 0.10658
# Epoch 16/100
# 108/108 [==============================] - 12s 111ms/step - loss: 0.0687 - accuracy: 0.7972 - val_loss: 0.1347 - val_accuracy: 0.7212
#
# Epoch 00016: val_loss did not improve from 0.10658
# Epoch 17/100
# 108/108 [==============================] - 12s 111ms/step - loss: 0.0643 - accuracy: 0.8085 - val_loss: 0.1248 - val_accuracy: 0.7263
#
# Epoch 00017: val_loss did not improve from 0.10658
# Epoch 18/100
# 108/108 [==============================] - 12s 111ms/step - loss: 0.0615 - accuracy: 0.8152 - val_loss: 0.1399 - val_accuracy: 0.7288
#
# Epoch 00018: val_loss did not improve from 0.10658
# Epoch 19/100
# 108/108 [==============================] - 12s 111ms/step - loss: 0.0584 - accuracy: 0.8213 - val_loss: 0.1359 - val_accuracy: 0.7168
#
# Epoch 00019: val_loss did not improve from 0.10658
# Epoch 20/100
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0585 - accuracy: 0.8182 - val_loss: 0.1341 - val_accuracy: 0.7251
#
# Epoch 00020: val_loss did not improve from 0.10658
# Epoch 21/100
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0544 - accuracy: 0.8295 - val_loss: 0.1388 - val_accuracy: 0.7266
#
# Epoch 00021: val_loss did not improve from 0.10658
# Epoch 22/100
# 108/108 [==============================] - 12s 113ms/step - loss: 0.0521 - accuracy: 0.8339 - val_loss: 0.1282 - val_accuracy: 0.7224
#
# Epoch 00022: val_loss did not improve from 0.10658
# Epoch 00022: early stopping
# time:  4
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_enc_net (InputLayer)      [(None, 128, 128, 4) 0
# __________________________________________________________________________________________________
# res1_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# drop_net1 (Dropout)             (None, 128, 128, 32) 0           res1_net1[0][0]
# __________________________________________________________________________________________________
# res2_net1 (Conv2D)              (None, 128, 128, 32) 9248        drop_net1[0][0]
# __________________________________________________________________________________________________
# res3_net1 (Conv2D)              (None, 128, 128, 32) 1184        input_enc_net[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 128, 128, 32) 0           res2_net1[0][0]
#                                                                  res3_net1[0][0]
# __________________________________________________________________________________________________
# pool_net1 (MaxPooling2D)        (None, 64, 64, 32)   0           add_30[0][0]
# __________________________________________________________________________________________________
# res1_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# drop_net2 (Dropout)             (None, 64, 64, 64)   0           res1_net2[0][0]
# __________________________________________________________________________________________________
# res2_net2 (Conv2D)              (None, 64, 64, 64)   36928       drop_net2[0][0]
# __________________________________________________________________________________________________
# res3_net2 (Conv2D)              (None, 64, 64, 64)   18496       pool_net1[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 64, 64, 64)   0           res2_net2[0][0]
#                                                                  res3_net2[0][0]
# __________________________________________________________________________________________________
# pool_net2 (MaxPooling2D)        (None, 32, 32, 64)   0           add_31[0][0]
# __________________________________________________________________________________________________
# res1_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# drop_net3 (Dropout)             (None, 32, 32, 128)  0           res1_net3[0][0]
# __________________________________________________________________________________________________
# res2_net3 (Conv2D)              (None, 32, 32, 128)  147584      drop_net3[0][0]
# __________________________________________________________________________________________________
# res3_net3 (Conv2D)              (None, 32, 32, 128)  73856       pool_net2[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32, 32, 128)  0           res2_net3[0][0]
#                                                                  res3_net3[0][0]
# __________________________________________________________________________________________________
# pool_net3 (MaxPooling2D)        (None, 16, 16, 128)  0           add_32[0][0]
# __________________________________________________________________________________________________
# res1_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# drop_net4 (Dropout)             (None, 16, 16, 128)  0           res1_net4[0][0]
# __________________________________________________________________________________________________
# res2_net4 (Conv2D)              (None, 16, 16, 128)  147584      drop_net4[0][0]
# __________________________________________________________________________________________________
# res3_net4 (Conv2D)              (None, 16, 16, 128)  147584      pool_net3[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 16, 16, 128)  0           res2_net4[0][0]
#                                                                  res3_net4[0][0]
# __________________________________________________________________________________________________
# res1_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_33[0][0]
# __________________________________________________________________________________________________
# drop_net5 (Dropout)             (None, 16, 16, 128)  0           res1_net5[0][0]
# __________________________________________________________________________________________________
# res2_net5 (Conv2D)              (None, 16, 16, 128)  147584      drop_net5[0][0]
# __________________________________________________________________________________________________
# res3_net5 (Conv2D)              (None, 16, 16, 128)  147584      add_33[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 16, 16, 128)  0           res2_net5[0][0]
#                                                                  res3_net5[0][0]
# __________________________________________________________________________________________________
# res1_net6 (Conv2D)              (None, 16, 16, 128)  147584      add_34[0][0]
# __________________________________________________________________________________________________
# drop_net6 (Dropout)             (None, 16, 16, 128)  0           res1_net6[0][0]
# __________________________________________________________________________________________________
# res2_net6 (Conv2D)              (None, 16, 16, 128)  147584      drop_net6[0][0]
# __________________________________________________________________________________________________
# res3_net6 (Conv2D)              (None, 16, 16, 128)  147584      add_34[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 16, 16, 128)  0           res2_net6[0][0]
#                                                                  res3_net6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 32, 32, 128)  0           add_35[0][0]
# __________________________________________________________________________________________________
# upsampling_net3 (Conv2D)        (None, 32, 32, 128)  147584      up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate3 (Concatenate)      (None, 32, 32, 256)  0           add_32[0][0]
#                                                                  upsampling_net3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 64, 64, 256)  0           concatenate3[0][0]
# __________________________________________________________________________________________________
# upsampling_net2 (Conv2D)        (None, 64, 64, 64)   147520      up_sampling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate2 (Concatenate)      (None, 64, 64, 128)  0           add_31[0][0]
#                                                                  upsampling_net2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 128, 128, 128 0           concatenate2[0][0]
# __________________________________________________________________________________________________
# upsampling_net1 (Conv2D)        (None, 128, 128, 32) 36896       up_sampling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate1 (Concatenate)      (None, 128, 128, 64) 0           add_30[0][0]
#                                                                  upsampling_net1[0][0]
# __________________________________________________________________________________________________
# output (Conv2D)                 (None, 128, 128, 3)  195         concatenate1[0][0]
# ==================================================================================================
# Total params: 2,041,283
# Trainable params: 2,041,283
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 13s 115ms/step - loss: 0.1732 - accuracy: 0.5812 - val_loss: 0.1127 - val_accuracy: 0.6704
#
# Epoch 00001: val_loss improved from inf to 0.11269, saving model to imgs/experiments/exp1/models\resunet_4.h5
# Epoch 2/100
# 108/108 [==============================] - 12s 116ms/step - loss: 0.1187 - accuracy: 0.6830 - val_loss: 0.1087 - val_accuracy: 0.6883
#
# Epoch 00002: val_loss improved from 0.11269 to 0.10867, saving model to imgs/experiments/exp1/models\resunet_4.h5
# Epoch 3/100
# 108/108 [==============================] - 12s 115ms/step - loss: 0.1049 - accuracy: 0.7221 - val_loss: 0.1114 - val_accuracy: 0.6974
#
# Epoch 00003: val_loss did not improve from 0.10867
# Epoch 4/100
# 108/108 [==============================] - 12s 111ms/step - loss: 0.0985 - accuracy: 0.7374 - val_loss: 0.1116 - val_accuracy: 0.6992
#
# Epoch 00004: val_loss did not improve from 0.10867
# Epoch 5/100
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0927 - accuracy: 0.7504 - val_loss: 0.1109 - val_accuracy: 0.7143
#
# Epoch 00005: val_loss did not improve from 0.10867
# Epoch 6/100
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0901 - accuracy: 0.7536 - val_loss: 0.1121 - val_accuracy: 0.7167
#
# Epoch 00006: val_loss did not improve from 0.10867
# Epoch 7/100
# 108/108 [==============================] - 12s 113ms/step - loss: 0.0879 - accuracy: 0.7565 - val_loss: 0.1153 - val_accuracy: 0.7105
#
# Epoch 00007: val_loss did not improve from 0.10867
# Epoch 8/100
# 108/108 [==============================] - 12s 113ms/step - loss: 0.0844 - accuracy: 0.7659 - val_loss: 0.1140 - val_accuracy: 0.7191
#
# Epoch 00008: val_loss did not improve from 0.10867
# Epoch 9/100
# 108/108 [==============================] - 12s 113ms/step - loss: 0.0811 - accuracy: 0.7715 - val_loss: 0.1127 - val_accuracy: 0.7194
#
# Epoch 00009: val_loss did not improve from 0.10867
# Epoch 10/100
# 108/108 [==============================] - 12s 113ms/step - loss: 0.0793 - accuracy: 0.7749 - val_loss: 0.1305 - val_accuracy: 0.7214
#
# Epoch 00010: val_loss did not improve from 0.10867
# Epoch 11/100
# 108/108 [==============================] - 12s 114ms/step - loss: 0.0761 - accuracy: 0.7797 - val_loss: 0.1187 - val_accuracy: 0.7238
#
# Epoch 00011: val_loss did not improve from 0.10867
# Epoch 12/100
# 108/108 [==============================] - 12s 114ms/step - loss: 0.0762 - accuracy: 0.7818 - val_loss: 0.1255 - val_accuracy: 0.7236
#
# Epoch 00012: val_loss did not improve from 0.10867
# Epoch 00012: early stopping

# %%
# Test loop
time_ts = []
n_pool = 3
n_rows = 5
n_cols = 4
rows, cols = image_array.shape[:2]
pad_rows = rows - np.ceil(rows/(n_rows*2**n_pool))*n_rows*2**n_pool
pad_cols = cols - np.ceil(cols/(n_cols*2**n_pool))*n_cols*2**n_pool
print(pad_rows, pad_cols)

npad = ((0, int(abs(pad_rows))), (0, int(abs(pad_cols))), (0, 0))
image1_pad = np.pad(image_array, pad_width=npad, mode='reflect')

h, w, c = image1_pad.shape
patch_size_rows = h//n_rows
patch_size_cols = w//n_cols
num_patches_x = int(h/patch_size_rows)
num_patches_y = int(w/patch_size_cols)

input_shape=(patch_size_rows,patch_size_cols, c)

if method == 'unet':
   new_model = build_unet(input_shape, nb_filters, number_class)

if method == 'resunet':
   new_model = build_resunet(input_shape, nb_filters, number_class)

for tm in range(0,times):
    print('time: ', tm)
    model = load_model(path_models+ '/' + method +'_'+str(tm)+'.h5', compile=False)
    
    for l in range(1, len(model.layers)):
        new_model.layers[l].set_weights(model.layers[l].get_weights())
    
    start_test = time.time()
    patch_t = []
    
    for i in range(0,num_patches_y):
        for j in range(0,num_patches_x):
            patch = image1_pad[patch_size_rows*j:patch_size_rows*(j+1), patch_size_cols*i:patch_size_cols*(i+1), :]
            predictions_ = new_model.predict(np.expand_dims(patch, axis=0))
            del patch 
            patch_t.append(predictions_[:,:,:,1])
            del predictions_
    end_test =  time.time() - start_test
    patches_pred = np.asarray(patch_t).astype(np.float32)

    prob_recontructed = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred)
    np.save(path_maps+'/'+'prob_'+str(tm)+'.npy',prob_recontructed) 

    time_ts.append(end_test)
    del prob_recontructed, model, patches_pred
time_ts_array = np.asarray(time_ts)
# Save test time
np.save(path_exp+'/metrics_ts.npy', time_ts_array)
# Out:
# 0.0 -8.0
# time:  0
# time:  1
# time:  2
# time:  3
# time:  4

# %%
# Compute mean of the tm predictions maps
prob_rec = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))

for tm in range (0, times):
    print(tm)
    prob_rec[:,:,tm] = np.load(path_maps+'/'+'prob_'+str(tm)+'.npy').astype(np.float32)

mean_prob = np.mean(prob_rec, axis = -1)
np.save(path_maps+'/prob_mean.npy', mean_prob)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Plot mean map and reference
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(121)
plt.title('Prediction')
ax1.imshow(mean_prob, cmap ='jet')
ax1.axis('off')

ax2 = fig.add_subplot(122)
plt.title('Reference')
ax2.imshow(final_mask1, cmap ='jet')
ax2.axis('off')
# Out:
# (-0.5, 6999.5, 9999.5, -0.5)

# %%
# Computing metrics
mean_prob = mean_prob[:final_mask1.shape[0], :final_mask1.shape[1]]
ref1 = np.ones_like(final_mask1).astype(np.float32)

ref1 [final_mask1 == 2] = 0
TileMask = mask_amazon_ts * ref1
GTTruePositives = final_mask1==1
    
Npoints = 10
Pmax = np.max(mean_prob[GTTruePositives * TileMask ==1])
ProbList = np.linspace(Pmax,0,Npoints)
    
metrics_ = matrics_AA_recall(ProbList, mean_prob, final_mask1, mask_amazon_ts, 625)
np.save(path_exp+'/acc_metrics.npy',metrics_)
# Out:
# 0.9616587638854981
# D:\Ferrari\proj_1\projeto\utils_unet_resunet.py:200: RuntimeWarning: invalid value encountered in longlong_scalars
#   precision_ = TP/(TP+FP)
# 0.8548077901204427
# 0.7479568163553874
# 0.6411058425903321
# 0.5342548688252767
# 0.42740389506022136
# 0.3205529212951661
# 0.21370194753011074
# 0.10685097376505537
# 0.0

# %%
# Complete NaN values
metrics_copy = metrics_.copy()
metrics_copy = complete_nan_values(metrics_copy)

# %%
# Comput Mean Average Precision (mAP) score 
Recall = metrics_copy[:,0]
Precision = metrics_copy[:,1]
AA = metrics_copy[:,2]
    
DeltaR = Recall[1:]-Recall[:-1]
AP = np.sum(Precision[:-1]*DeltaR)
print('mAP', AP)

# Plot Recall vs. Precision curve
plt.close('all')
plt.plot(metrics_copy[:,0],metrics_copy[:,1])
plt.plot(metrics_copy[:,0],metrics_copy[:,2])
plt.grid()
# Out:
# mAP 0.8760511839232595
