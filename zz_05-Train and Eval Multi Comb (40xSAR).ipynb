# %%
# %load_ext autoreload
# %autoreload 2

# %%
#%autoreload # When utils.py is updated
from utils_unet_resunet import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from model.models import Model_3
from model.losses import WBCE
from model.callbacks import UpdateWeights
from multiprocessing.pool import Pool

root_path = 'imgs/'

# %%
# Define data type 
img_type = 'FUSION'

if img_type == 'FUSION':
    image_array = np.load(root_path+'New_Images/fus_stack.npy')
    

if img_type == 'OPT':
    image_array = np.load(root_path+'New_Images/opt_stack.npy')
    
    
if img_type == 'SAR':
    image_array = np.load(root_path+'New_Images/sar_stack.npy')
print('Image stack:', image_array.shape)

final_mask1 = np.load(root_path+'New_Images/'+'final_mask1.npy')
print('Labels stack:', final_mask1.shape)

h_, w_, channels = image_array.shape
n_opt_layers = 20
# Out:
# Image stack: (10000, 7000, 24)
# Labels stack: (10000, 7000)

# %%
# Create tile mask
mask_tiles = create_mask(final_mask1.shape[0], final_mask1.shape[1], grid_size=(5, 4))
image_array = image_array[:mask_tiles.shape[0], :mask_tiles.shape[1],:]
final_mask1 = final_mask1[:mask_tiles.shape[0], :mask_tiles.shape[1]]

print('mask: ',mask_tiles.shape)
print('image stack: ', image_array.shape)
print('ref :', final_mask1.shape)
#plt.imshow(mask_tiles)
# Out:
# Tiles size:  2000 1750
# Mask size:  (10000, 7000)
# mask:  (10000, 7000)
# image stack:  (10000, 7000, 24)
# ref : (10000, 7000)

# %%
plt.figure(figsize=(10,5))
plt.imshow(final_mask1, cmap = 'jet')

# %%
# Define tiles for training, validation, and test sets
tiles_tr = [1,3,5,8,11,13,14,20]
tiles_val = [6,19]
tiles_ts = (list(set(np.arange(20)+1)-set(tiles_tr)-set(tiles_val)))

mask_tr_val = np.zeros((mask_tiles.shape)).astype('float32')
# Training and validation mask
for tr_ in tiles_tr:
    mask_tr_val[mask_tiles == tr_] = 1

for val_ in tiles_val:
    mask_tr_val[mask_tiles == val_] = 2

mask_amazon_ts = np.zeros((mask_tiles.shape)).astype('float32')
for ts_ in tiles_ts:
    mask_amazon_ts[mask_tiles == ts_] = 1

# %%
# Create ixd image to extract patches
overlap = 0.7
patch_size = 128
batch_size = 32
im_idx = create_idx_image(final_mask1)
patches_idx = extract_patches(im_idx, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1,patch_size, patch_size)
patches_mask = extract_patches(mask_tr_val, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1, patch_size, patch_size)
del im_idx

# %%
# Selecting index trn val and test patches idx
idx_trn = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==patch_size**2))
idx_val = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==2*patch_size**2))
del patches_mask

patches_idx_trn = patches_idx[idx_trn]
patches_idx_val = patches_idx[idx_val]
del idx_trn, idx_val

print('Number of training patches:  ', len(patches_idx_trn), 'Number of validation patches', len(patches_idx_val))
# Out:
# Number of training patches:   17110 Number of validation patches 4116

# %%
# Extract patches with at least 2% of deforestation class
X_train = retrieve_idx_percentage(final_mask1, patches_idx_trn, patch_size, pertentage = 2)
X_valid = retrieve_idx_percentage(final_mask1, patches_idx_val, patch_size, pertentage = 2)
print(X_train.shape, X_valid.shape)
del patches_idx_trn, patches_idx_val
# Out:
# (1158, 128, 128) (341, 128, 128)

# %%
def batch_generator(batches, image, reference, target_size, number_class):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    image = image.reshape(-1, image.shape[-1])
    reference = reference.reshape(final_mask1.shape[0]*final_mask1.shape[1])
    while True:
        batch_x, batch_y = next(batches)
        batch_x = np.squeeze(batch_x.astype('int64'))
        #print(batch_x.shape)
        batch_img = np.zeros((batch_x.shape[0], target_size, target_size, image.shape[-1]))
        batch_ref = np.zeros((batch_x.shape[0], target_size, target_size, number_class))
        
        for i in range(batch_x.shape[0]):
            if np.random.rand()>0.5:
                batch_x[i] = np.rot90(batch_x[i], 1)
            batch_img[i] = image[batch_x[i]] 
            batch_ref[i] = tf.keras.utils.to_categorical(reference[batch_x[i]] , number_class)
                       
        yield (batch_img, batch_ref)

train_datagen = ImageDataGenerator(horizontal_flip = True,
                                   vertical_flip = True)
valid_datagen = ImageDataGenerator(horizontal_flip = True, 
                                   vertical_flip = True)

y_train = np.zeros((len(X_train)))
y_valid = np.zeros((len(X_valid)))

train_gen = train_datagen.flow(np.expand_dims(X_train, axis = -1), y_train,
                              batch_size=batch_size,
                              shuffle=True)

valid_gen = valid_datagen.flow(np.expand_dims(X_valid, axis = -1), y_valid,
                              batch_size=batch_size,
                              shuffle=False)

number_class = 3
train_gen_crops = batch_generator(train_gen, image_array, final_mask1, patch_size, number_class)
valid_gen_crops = batch_generator(valid_gen, image_array, final_mask1, patch_size, number_class)

# %%
exp = 3
path_exp = root_path+'experiments/exp'+str(exp)
path_models = path_exp+'/models'
path_maps = path_exp+'/pred_maps'

if not os.path.exists(path_exp):
    os.makedirs(path_exp)   
if not os.path.exists(path_models):
    os.makedirs(path_models)   
if not os.path.exists(path_maps):
    os.makedirs(path_maps)

# %%
# Define model
input_shape = (patch_size, patch_size, channels)
nb_filters = [32, 64, 128]

method = 'unet'
if method == 'unet':
   model = build_unet(input_shape, nb_filters, number_class)

if method == 'resunet':
   model = build_resunet(input_shape, nb_filters, number_class)

model = Model_3(nb_filters, number_class, n_opt_layers)

# %%
# Parameters of the model
weights = [0.2, 0.8, 0]
adam = Adam(lr = 5e-5 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
#loss = WBCE(weights = weights)
#loss = WBCE(weights = weights, class_indexes = [0, 1])

# %%
metrics_all = []
times=5
for tm in range(0,times):
    print('time: ', tm)

    rows = patch_size
    cols = patch_size
    adam = Adam(lr = 5e-5 , beta_1=0.9)
    
    loss = weighted_categorical_crossentropy(weights)
    #loss = WBCE(weights = weights)
    #loss = WBCE(weights = weights, class_indexes = [0, 1])

    #if method == 'unet':
    #   model = build_unet(input_shape, nb_filters, number_class)

    #if method == 'resunet':
    #   model = build_resunet(input_shape, nb_filters, number_class)
    
    model = Model_3(nb_filters, number_class, n_opt_layers)
    model.build((None,)+input_shape)
    
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    model.summary()

    earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
    #earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min') ---- val_accuracy
    #checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
    lr_reduce = ReduceLROnPlateau(factor=0.9, min_delta=0.0001, patience=5, verbose=1)
    updateWeights = UpdateWeights()
    callbacks_list = [earlystop, checkpoint, updateWeights]
    # train the model
    start_training = time.time()
    history = model.fit(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    end_training = time.time() - start_training
    metrics_all.append(end_training)
    del model, history
# Out:
# time:  0
# Model: "model_3_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 12s - opt_accuracy: 0.5999 - sar_accuracy: 0.5807 - fus_accuracy: 0.5890 - opt_loss: 0.1881 - sar_loss: 9.1810 - fusion_loss: 0.2382 - loss: 9.6074WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0553s vs `on_train_batch_end` time: 0.0573s). Check your callbacks.
# 108/108 [==============================] - 27s 167ms/step - opt_accuracy: 0.7451 - sar_accuracy: 0.6475 - fus_accuracy: 0.7109 - opt_loss: 0.1254 - sar_loss: 6.9744 - fusion_loss: 0.1506 - loss: 7.2504 - val_opt_accuracy: 0.8548 - val_sar_accuracy: 0.7242 - val_fus_accuracy: 0.8523 - val_opt_loss: 0.1076 - val_sar_loss: 5.1002 - val_fusion_loss: 0.1110 - val_loss: 5.3189
#
# Epoch 00001: val_loss improved from inf to 5.31885, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 2/100
# 108/108 [==============================] - 15s 142ms/step - opt_accuracy: 0.8287 - sar_accuracy: 0.6957 - fus_accuracy: 0.7799 - opt_loss: 0.0911 - sar_loss: 6.0483 - fusion_loss: 0.1150 - loss: 6.2544 - val_opt_accuracy: 0.8554 - val_sar_accuracy: 0.7639 - val_fus_accuracy: 0.8552 - val_opt_loss: 0.1063 - val_sar_loss: 5.0157 - val_fusion_loss: 0.1207 - val_loss: 5.2428
#
# Epoch 00002: val_loss improved from 5.31885 to 5.24277, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 3/100
# 108/108 [==============================] - 15s 143ms/step - opt_accuracy: 0.8438 - sar_accuracy: 0.7250 - fus_accuracy: 0.7989 - opt_loss: 0.0835 - sar_loss: 5.6160 - fusion_loss: 0.1069 - loss: 5.8064 - val_opt_accuracy: 0.8619 - val_sar_accuracy: 0.7821 - val_fus_accuracy: 0.8603 - val_opt_loss: 0.0950 - val_sar_loss: 4.8727 - val_fusion_loss: 0.1137 - val_loss: 5.0814
#
# Epoch 00003: val_loss improved from 5.24277 to 5.08139, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 4/100
# 108/108 [==============================] - 15s 142ms/step - opt_accuracy: 0.8545 - sar_accuracy: 0.7405 - fus_accuracy: 0.8124 - opt_loss: 0.0788 - sar_loss: 5.4189 - fusion_loss: 0.1013 - loss: 5.5989 - val_opt_accuracy: 0.8596 - val_sar_accuracy: 0.7870 - val_fus_accuracy: 0.8594 - val_opt_loss: 0.0933 - val_sar_loss: 4.6725 - val_fusion_loss: 0.1102 - val_loss: 4.8760
#
# Epoch 00004: val_loss improved from 5.08139 to 4.87596, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 5/100
# 108/108 [==============================] - 15s 142ms/step - opt_accuracy: 0.8654 - sar_accuracy: 0.7527 - fus_accuracy: 0.8247 - opt_loss: 0.0746 - sar_loss: 5.2284 - fusion_loss: 0.0949 - loss: 5.3979 - val_opt_accuracy: 0.8587 - val_sar_accuracy: 0.7918 - val_fus_accuracy: 0.8578 - val_opt_loss: 0.1027 - val_sar_loss: 4.6448 - val_fusion_loss: 0.1201 - val_loss: 4.8675
#
# Epoch 00005: val_loss improved from 4.87596 to 4.86751, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 6/100
# 108/108 [==============================] - 15s 143ms/step - opt_accuracy: 0.8703 - sar_accuracy: 0.7586 - fus_accuracy: 0.8338 - opt_loss: 0.0721 - sar_loss: 5.1420 - fusion_loss: 0.0895 - loss: 5.3037 - val_opt_accuracy: 0.8480 - val_sar_accuracy: 0.7978 - val_fus_accuracy: 0.8465 - val_opt_loss: 0.1292 - val_sar_loss: 4.6581 - val_fusion_loss: 0.1558 - val_loss: 4.9432
#
# Epoch 00006: val_loss did not improve from 4.86751
# Epoch 7/100
# 108/108 [==============================] - 15s 143ms/step - opt_accuracy: 0.8752 - sar_accuracy: 0.7663 - fus_accuracy: 0.8421 - opt_loss: 0.0705 - sar_loss: 5.0432 - fusion_loss: 0.0866 - loss: 5.2003 - val_opt_accuracy: 0.8530 - val_sar_accuracy: 0.7783 - val_fus_accuracy: 0.8536 - val_opt_loss: 0.1286 - val_sar_loss: 4.9897 - val_fusion_loss: 0.1456 - val_loss: 5.2640
#
# Epoch 00007: val_loss did not improve from 4.86751
# Epoch 8/100
# 108/108 [==============================] - 16s 144ms/step - opt_accuracy: 0.8778 - sar_accuracy: 0.7675 - fus_accuracy: 0.8460 - opt_loss: 0.0687 - sar_loss: 4.9942 - fusion_loss: 0.0835 - loss: 5.1464 - val_opt_accuracy: 0.8618 - val_sar_accuracy: 0.8032 - val_fus_accuracy: 0.8597 - val_opt_loss: 0.1215 - val_sar_loss: 4.6910 - val_fusion_loss: 0.1465 - val_loss: 4.9590
#
# Epoch 00008: val_loss did not improve from 4.86751
# Epoch 9/100
# 108/108 [==============================] - 15s 144ms/step - opt_accuracy: 0.8819 - sar_accuracy: 0.7724 - fus_accuracy: 0.8521 - opt_loss: 0.0657 - sar_loss: 4.8842 - fusion_loss: 0.0793 - loss: 5.0292 - val_opt_accuracy: 0.8631 - val_sar_accuracy: 0.7982 - val_fus_accuracy: 0.8628 - val_opt_loss: 0.1282 - val_sar_loss: 4.6172 - val_fusion_loss: 0.1463 - val_loss: 4.8917
#
# Epoch 00009: val_loss did not improve from 4.86751
# Epoch 10/100
# 108/108 [==============================] - 15s 144ms/step - opt_accuracy: 0.8837 - sar_accuracy: 0.7731 - fus_accuracy: 0.8567 - opt_loss: 0.0645 - sar_loss: 4.8493 - fusion_loss: 0.0769 - loss: 4.9907 - val_opt_accuracy: 0.8581 - val_sar_accuracy: 0.8099 - val_fus_accuracy: 0.8554 - val_opt_loss: 0.1322 - val_sar_loss: 4.5510 - val_fusion_loss: 0.1582 - val_loss: 4.8414
#
# Epoch 00010: val_loss improved from 4.86751 to 4.84138, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 11/100
# 108/108 [==============================] - 16s 145ms/step - opt_accuracy: 0.8861 - sar_accuracy: 0.7759 - fus_accuracy: 0.8621 - opt_loss: 0.0633 - sar_loss: 4.8377 - fusion_loss: 0.0746 - loss: 4.9756 - val_opt_accuracy: 0.8587 - val_sar_accuracy: 0.8049 - val_fus_accuracy: 0.8593 - val_opt_loss: 0.1392 - val_sar_loss: 5.0483 - val_fusion_loss: 0.1629 - val_loss: 5.3504
#
# Epoch 00011: val_loss did not improve from 4.84138
# Epoch 12/100
# 108/108 [==============================] - 16s 146ms/step - opt_accuracy: 0.8874 - sar_accuracy: 0.7735 - fus_accuracy: 0.8651 - opt_loss: 0.0621 - sar_loss: 4.8542 - fusion_loss: 0.0726 - loss: 4.9890 - val_opt_accuracy: 0.8601 - val_sar_accuracy: 0.8096 - val_fus_accuracy: 0.8612 - val_opt_loss: 0.1433 - val_sar_loss: 4.4987 - val_fusion_loss: 0.1616 - val_loss: 4.8036
#
# Epoch 00012: val_loss improved from 4.84138 to 4.80357, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 13/100
# 108/108 [==============================] - 16s 145ms/step - opt_accuracy: 0.8895 - sar_accuracy: 0.7739 - fus_accuracy: 0.8687 - opt_loss: 0.0604 - sar_loss: 4.8378 - fusion_loss: 0.0702 - loss: 4.9684 - val_opt_accuracy: 0.8631 - val_sar_accuracy: 0.8068 - val_fus_accuracy: 0.8654 - val_opt_loss: 0.1346 - val_sar_loss: 4.6825 - val_fusion_loss: 0.1542 - val_loss: 4.9712
#
# Epoch 00013: val_loss did not improve from 4.80357
# Epoch 14/100
#
# Epoch 00025: val_loss did not improve from 4.62542
# Epoch 26/100
# 108/108 [==============================] - 16s 149ms/step - opt_accuracy: 0.9109 - sar_accuracy: 0.7718 - fus_accuracy: 0.9010 - opt_loss: 0.0441 - sar_loss: 4.6780 - fusion_loss: 0.0482 - loss: 4.7703 - val_opt_accuracy: 0.8566 - val_sar_accuracy: 0.8027 - val_fus_accuracy: 0.8561 - val_opt_loss: 0.1440 - val_sar_loss: 4.5203 - val_fusion_loss: 0.1542 - val_loss: 4.8185
#
# Epoch 00026: val_loss did not improve from 4.62542
# Epoch 00026: early stopping
# time:  1
# Model: "model_3_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 11s - opt_accuracy: 0.6295 - sar_accuracy: 0.6630 - fus_accuracy: 0.5955 - opt_loss: 0.1896 - sar_loss: 6.7535 - fusion_loss: 0.1832 - loss: 7.1263WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0551s vs `on_train_batch_end` time: 0.0624s). Check your callbacks.
# 108/108 [==============================] - 18s 153ms/step - opt_accuracy: 0.7604 - sar_accuracy: 0.6896 - fus_accuracy: 0.7352 - opt_loss: 0.1316 - sar_loss: 6.0198 - fusion_loss: 0.1407 - loss: 6.2921 - val_opt_accuracy: 0.8518 - val_sar_accuracy: 0.7666 - val_fus_accuracy: 0.8473 - val_opt_loss: 0.0898 - val_sar_loss: 4.8016 - val_fusion_loss: 0.0933 - val_loss: 4.9847
#
# Epoch 00001: val_loss improved from inf to 4.98469, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 2/100
# 108/108 [==============================] - 16s 150ms/step - opt_accuracy: 0.8386 - sar_accuracy: 0.7369 - fus_accuracy: 0.8111 - opt_loss: 0.0962 - sar_loss: 5.5560 - fusion_loss: 0.1056 - loss: 5.7578 - val_opt_accuracy: 0.8585 - val_sar_accuracy: 0.7787 - val_fus_accuracy: 0.8611 - val_opt_loss: 0.0946 - val_sar_loss: 4.8208 - val_fusion_loss: 0.0958 - val_loss: 5.0111
#
# Epoch 00002: val_loss did not improve from 4.98469
# Epoch 3/100
# 108/108 [==============================] - 16s 150ms/step - opt_accuracy: 0.8524 - sar_accuracy: 0.7486 - fus_accuracy: 0.8301 - opt_loss: 0.0873 - sar_loss: 5.3298 - fusion_loss: 0.0948 - loss: 5.5119 - val_opt_accuracy: 0.8533 - val_sar_accuracy: 0.7786 - val_fus_accuracy: 0.8574 - val_opt_loss: 0.1021 - val_sar_loss: 4.8597 - val_fusion_loss: 0.0995 - val_loss: 5.0613
#
# Epoch 00003: val_loss did not improve from 4.98469
# Epoch 4/100
# 108/108 [==============================] - 16s 150ms/step - opt_accuracy: 0.8597 - sar_accuracy: 0.7530 - fus_accuracy: 0.8396 - opt_loss: 0.0834 - sar_loss: 5.2584 - fusion_loss: 0.0904 - loss: 5.4321 - val_opt_accuracy: 0.8588 - val_sar_accuracy: 0.7847 - val_fus_accuracy: 0.8618 - val_opt_loss: 0.1026 - val_sar_loss: 4.7346 - val_fusion_loss: 0.1029 - val_loss: 4.9400
#
# Epoch 00004: val_loss improved from 4.98469 to 4.94005, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 5/100
# 108/108 [==============================] - 16s 150ms/step - opt_accuracy: 0.8663 - sar_accuracy: 0.7620 - fus_accuracy: 0.8449 - opt_loss: 0.0791 - sar_loss: 5.0042 - fusion_loss: 0.0866 - loss: 5.1699 - val_opt_accuracy: 0.8637 - val_sar_accuracy: 0.7848 - val_fus_accuracy: 0.8652 - val_opt_loss: 0.0969 - val_sar_loss: 4.7174 - val_fusion_loss: 0.0968 - val_loss: 4.9111
#
# Epoch 00005: val_loss improved from 4.94005 to 4.91106, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 6/100
# 108/108 [==============================] - 16s 152ms/step - opt_accuracy: 0.8700 - sar_accuracy: 0.7638 - fus_accuracy: 0.8491 - opt_loss: 0.0758 - sar_loss: 4.9794 - fusion_loss: 0.0839 - loss: 5.1391 - val_opt_accuracy: 0.8631 - val_sar_accuracy: 0.7889 - val_fus_accuracy: 0.8638 - val_opt_loss: 0.0947 - val_sar_loss: 4.7113 - val_fusion_loss: 0.0986 - val_loss: 4.9046
#
# Epoch 00006: val_loss improved from 4.91106 to 4.90457, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 7/100
# 108/108 [==============================] - 16s 152ms/step - opt_accuracy: 0.8728 - sar_accuracy: 0.7705 - fus_accuracy: 0.8519 - opt_loss: 0.0735 - sar_loss: 4.8326 - fusion_loss: 0.0822 - loss: 4.9883 - val_opt_accuracy: 0.8661 - val_sar_accuracy: 0.7956 - val_fus_accuracy: 0.8658 - val_opt_loss: 0.0896 - val_sar_loss: 4.6169 - val_fusion_loss: 0.0947 - val_loss: 4.8012
#
# Epoch 00007: val_loss improved from 4.90457 to 4.80121, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 8/100
# 108/108 [==============================] - 17s 154ms/step - opt_accuracy: 0.8765 - sar_accuracy: 0.7755 - fus_accuracy: 0.8552 - opt_loss: 0.0704 - sar_loss: 4.6888 - fusion_loss: 0.0795 - loss: 4.8386 - val_opt_accuracy: 0.8623 - val_sar_accuracy: 0.7989 - val_fus_accuracy: 0.8636 - val_opt_loss: 0.0965 - val_sar_loss: 4.4648 - val_fusion_loss: 0.0999 - val_loss: 4.6612
#
# Epoch 00008: val_loss improved from 4.80121 to 4.66116, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 9/100
#
# Epoch 00020: val_loss did not improve from 4.41513
# Epoch 21/100
# 108/108 [==============================] - 17s 159ms/step - opt_accuracy: 0.9063 - sar_accuracy: 0.8007 - fus_accuracy: 0.8947 - opt_loss: 0.0476 - sar_loss: 4.1811 - fusion_loss: 0.0521 - loss: 4.2809 - val_opt_accuracy: 0.8656 - val_sar_accuracy: 0.8010 - val_fus_accuracy: 0.8658 - val_opt_loss: 0.1377 - val_sar_loss: 4.7823 - val_fusion_loss: 0.1363 - val_loss: 5.0563
#
# Epoch 00021: val_loss did not improve from 4.41513
# Epoch 00021: early stopping
# time:  2
# Model: "model_3_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 13s - opt_accuracy: 0.5896 - sar_accuracy: 0.6242 - fus_accuracy: 0.5478 - opt_loss: 0.2232 - sar_loss: 8.4133 - fusion_loss: 0.2955 - loss: 8.9321WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0635s vs `on_train_batch_end` time: 0.0704s). Check your callbacks.
# 108/108 [==============================] - 20s 166ms/step - opt_accuracy: 0.7435 - sar_accuracy: 0.6719 - fus_accuracy: 0.6782 - opt_loss: 0.1411 - sar_loss: 6.6532 - fusion_loss: 0.1942 - loss: 6.9886 - val_opt_accuracy: 0.8601 - val_sar_accuracy: 0.7780 - val_fus_accuracy: 0.8496 - val_opt_loss: 0.0829 - val_sar_loss: 4.6270 - val_fusion_loss: 0.0920 - val_loss: 4.8019
#
# Epoch 00001: val_loss improved from inf to 4.80189, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 2/100
# 108/108 [==============================] - 17s 161ms/step - opt_accuracy: 0.8345 - sar_accuracy: 0.7310 - fus_accuracy: 0.7863 - opt_loss: 0.0977 - sar_loss: 5.7443 - fusion_loss: 0.1292 - loss: 5.9712 - val_opt_accuracy: 0.8638 - val_sar_accuracy: 0.7686 - val_fus_accuracy: 0.8563 - val_opt_loss: 0.0800 - val_sar_loss: 4.9347 - val_fusion_loss: 0.0901 - val_loss: 5.1048
#
# Epoch 00002: val_loss did not improve from 4.80189
# Epoch 3/100
# 108/108 [==============================] - 17s 162ms/step - opt_accuracy: 0.8433 - sar_accuracy: 0.7446 - fus_accuracy: 0.8064 - opt_loss: 0.0912 - sar_loss: 5.4310 - fusion_loss: 0.1149 - loss: 5.6370 - val_opt_accuracy: 0.8615 - val_sar_accuracy: 0.7909 - val_fus_accuracy: 0.8570 - val_opt_loss: 0.0922 - val_sar_loss: 4.7850 - val_fusion_loss: 0.1081 - val_loss: 4.9854
#
# Epoch 00009: val_loss improved from 4.80189 to 4.79618, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 10/100
# 108/108 [==============================] - 18s 167ms/step - opt_accuracy: 0.8796 - sar_accuracy: 0.7811 - fus_accuracy: 0.8571 - opt_loss: 0.0690 - sar_loss: 4.6897 - fusion_loss: 0.0811 - loss: 4.8398 - val_opt_accuracy: 0.8645 - val_sar_accuracy: 0.8049 - val_fus_accuracy: 0.8650 - val_opt_loss: 0.1127 - val_sar_loss: 4.4644 - val_fusion_loss: 0.1187 - val_loss: 4.6958
#
# Epoch 00010: val_loss improved from 4.79618 to 4.69577, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 11/100
# 108/108 [==============================] - 18s 168ms/step - opt_accuracy: 0.8815 - sar_accuracy: 0.7795 - fus_accuracy: 0.8604 - opt_loss: 0.0679 - sar_loss: 4.6921 - fusion_loss: 0.0791 - loss: 4.8391 - val_opt_accuracy: 0.8669 - val_sar_accuracy: 0.8022 - val_fus_accuracy: 0.8663 - val_opt_loss: 0.1050 - val_sar_loss: 4.4067 - val_fusion_loss: 0.1084 - val_loss: 4.6200
#
# Epoch 00011: val_loss improved from 4.69577 to 4.62003, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 12/100
# 108/108 [==============================] - 18s 169ms/step - opt_accuracy: 0.8835 - sar_accuracy: 0.7820 - fus_accuracy: 0.8624 - opt_loss: 0.0666 - sar_loss: 4.6503 - fusion_loss: 0.0776 - loss: 4.7945 - val_opt_accuracy: 0.8639 - val_sar_accuracy: 0.8012 - val_fus_accuracy: 0.8643 - val_opt_loss: 0.1028 - val_sar_loss: 4.2885 - val_fusion_loss: 0.1063 - val_loss: 4.4976
#
# Epoch 00012: val_loss improved from 4.62003 to 4.49759, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 13/100
# 108/108 [==============================] - 18s 170ms/step - opt_accuracy: 0.8875 - sar_accuracy: 0.7866 - fus_accuracy: 0.8673 - opt_loss: 0.0640 - sar_loss: 4.5916 - fusion_loss: 0.0745 - loss: 4.7301 - val_opt_accuracy: 0.8586 - val_sar_accuracy: 0.7974 - val_fus_accuracy: 0.8595 - val_opt_loss: 0.1185 - val_sar_loss: 4.4294 - val_fusion_loss: 0.1210 - val_loss: 4.6689
#
# Epoch 00013: val_loss did not improve from 4.49759
# Epoch 14/100
# 108/108 [==============================] - 18s 171ms/step - opt_accuracy: 0.8884 - sar_accuracy: 0.7871 - fus_accuracy: 0.8693 - opt_loss: 0.0636 - sar_loss: 4.5875 - fusion_loss: 0.0737 - loss: 4.7247 - val_opt_accuracy: 0.8556 - val_sar_accuracy: 0.7974 - val_fus_accuracy: 0.8563 - val_opt_loss: 0.1166 - val_sar_loss: 4.6848 - val_fusion_loss: 0.1210 - val_loss: 4.9224
#
# Epoch 00014: val_loss did not improve from 4.49759
# Epoch 15/100
# Epoch 00020: val_loss did not improve from 4.49759
# Epoch 21/100
# 108/108 [==============================] - 19s 176ms/step - opt_accuracy: 0.9017 - sar_accuracy: 0.7988 - fus_accuracy: 0.8879 - opt_loss: 0.0520 - sar_loss: 4.3074 - fusion_loss: 0.0590 - loss: 4.4184 - val_opt_accuracy: 0.8627 - val_sar_accuracy: 0.8111 - val_fus_accuracy: 0.8631 - val_opt_loss: 0.1355 - val_sar_loss: 4.4375 - val_fusion_loss: 0.1370 - val_loss: 4.7101
#
# Epoch 00021: val_loss did not improve from 4.49759
# Epoch 22/100
# 108/108 [==============================] - 19s 176ms/step - opt_accuracy: 0.9024 - sar_accuracy: 0.7985 - fus_accuracy: 0.8889 - opt_loss: 0.0517 - sar_loss: 4.3191 - fusion_loss: 0.0584 - loss: 4.4292 - val_opt_accuracy: 0.8658 - val_sar_accuracy: 0.8100 - val_fus_accuracy: 0.8659 - val_opt_loss: 0.1185 - val_sar_loss: 4.9315 - val_fusion_loss: 0.1311 - val_loss: 5.1811
#
# Epoch 00022: val_loss did not improve from 4.49759
# Epoch 00022: early stopping
# time:  3
# Model: "model_3_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 23s 190ms/step - opt_accuracy: 0.7743 - sar_accuracy: 0.7175 - fus_accuracy: 0.6877 - opt_loss: 0.1226 - sar_loss: 6.0588 - fusion_loss: 0.1548 - loss: 6.3362 - val_opt_accuracy: 0.8597 - val_sar_accuracy: 0.7854 - val_fus_accuracy: 0.7886 - val_opt_loss: 0.0919 - val_sar_loss: 4.7198 - val_fusion_loss: 0.1056 - val_loss: 4.9172
#
# Epoch 00001: val_loss improved from inf to 4.91723, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 2/100
# 108/108 [==============================] - 19s 179ms/step - opt_accuracy: 0.8327 - sar_accuracy: 0.7448 - fus_accuracy: 0.7701 - opt_loss: 0.0953 - sar_loss: 5.4652 - fusion_loss: 0.1116 - loss: 5.6720 - val_opt_accuracy: 0.8662 - val_sar_accuracy: 0.7817 - val_fus_accuracy: 0.8418 - val_opt_loss: 0.0938 - val_sar_loss: 4.7586 - val_fusion_loss: 0.1028 - val_loss: 4.9552
#
# Epoch 00002: val_loss did not improve from 4.91723
# Epoch 3/100
# 108/108 [==============================] - 20s 181ms/step - opt_accuracy: 0.8441 - sar_accuracy: 0.7539 - fus_accuracy: 0.8058 - opt_loss: 0.0896 - sar_loss: 5.2320 - fusion_loss: 0.0997 - loss: 5.4213 - val_opt_accuracy: 0.8613 - val_sar_accuracy: 0.7891 - val_fus_accuracy: 0.8518 - val_opt_loss: 0.1179 - val_sar_loss: 4.7315 - val_fusion_loss: 0.1153 - val_loss: 4.9648
#
# Epoch 00003: val_loss did not improve from 4.91723
# Epoch 4/100
# 108/108 [==============================] - 20s 182ms/step - opt_accuracy: 0.8535 - sar_accuracy: 0.7644 - fus_accuracy: 0.8270 - opt_loss: 0.0839 - sar_loss: 5.0450 - fusion_loss: 0.0917 - loss: 5.2206 - val_opt_accuracy: 0.8648 - val_sar_accuracy: 0.7923 - val_fus_accuracy: 0.8613 - val_opt_loss: 0.1131 - val_sar_loss: 4.7359 - val_fusion_loss: 0.1106 - val_loss: 4.9596
#
# Epoch 00004: val_loss did not improve from 4.91723
# Epoch 5/100
# 108/108 [==============================] - 20s 188ms/step - opt_accuracy: 0.8578 - sar_accuracy: 0.7670 - fus_accuracy: 0.8368 - opt_loss: 0.0809 - sar_loss: 4.9680 - fusion_loss: 0.0870 - loss: 5.1359 - val_opt_accuracy: 0.8626 - val_sar_accuracy: 0.7987 - val_fus_accuracy: 0.8619 - val_opt_loss: 0.1355 - val_sar_loss: 4.7100 - val_fusion_loss: 0.1292 - val_loss: 4.9746
#
# Epoch 00005: val_loss did not improve from 4.91723
# Epoch 6/100
# 108/108 [==============================] - 20s 183ms/step - opt_accuracy: 0.8618 - sar_accuracy: 0.7741 - fus_accuracy: 0.8443 - opt_loss: 0.0785 - sar_loss: 4.8357 - fusion_loss: 0.0837 - loss: 4.9979 - val_opt_accuracy: 0.8597 - val_sar_accuracy: 0.8000 - val_fus_accuracy: 0.8605 - val_opt_loss: 0.1439 - val_sar_loss: 4.6314 - val_fusion_loss: 0.1334 - val_loss: 4.9087
#
# Epoch 00006: val_loss improved from 4.91723 to 4.90868, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 7/100
# 108/108 [==============================] - 20s 183ms/step - opt_accuracy: 0.8659 - sar_accuracy: 0.7810 - fus_accuracy: 0.8501 - opt_loss: 0.0751 - sar_loss: 4.6541 - fusion_loss: 0.0800 - loss: 4.8092 - val_opt_accuracy: 0.8642 - val_sar_accuracy: 0.8079 - val_fus_accuracy: 0.8637 - val_opt_loss: 0.1067 - val_sar_loss: 4.7359 - val_fusion_loss: 0.1103 - val_loss: 4.9528
#
# Epoch 00007: val_loss did not improve from 4.90868
# Epoch 8/100
# 108/108 [==============================] - 20s 185ms/step - opt_accuracy: 0.8704 - sar_accuracy: 0.7823 - fus_accuracy: 0.8566 - opt_loss: 0.0726 - sar_loss: 4.6794 - fusion_loss: 0.0770 - loss: 4.8290 - val_opt_accuracy: 0.8658 - val_sar_accuracy: 0.8050 - val_fus_accuracy: 0.8653 - val_opt_loss: 0.1129 - val_sar_loss: 4.5539 - val_fusion_loss: 0.1113 - val_loss: 4.7780
#
# Epoch 00008: val_loss improved from 4.90868 to 4.77805, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 9/100
# 108/108 [==============================] - 21s 199ms/step - opt_accuracy: 0.8890 - sar_accuracy: 0.8020 - fus_accuracy: 0.8791 - opt_loss: 0.0589 - sar_loss: 4.2760 - fusion_loss: 0.0621 - loss: 4.3970 - val_opt_accuracy: 0.8626 - val_sar_accuracy: 0.8055 - val_fus_accuracy: 0.8624 - val_opt_loss: 0.1347 - val_sar_loss: 4.8872 - val_fusion_loss: 0.1313 - val_loss: 5.1533
#
# Epoch 00015: val_loss did not improve from 4.77805
# Epoch 16/100
# 108/108 [==============================] - 21s 199ms/step - opt_accuracy: 0.8905 - sar_accuracy: 0.7956 - fus_accuracy: 0.8811 - opt_loss: 0.0574 - sar_loss: 4.3665 - fusion_loss: 0.0606 - loss: 4.4846 - val_opt_accuracy: 0.8636 - val_sar_accuracy: 0.8104 - val_fus_accuracy: 0.8630 - val_opt_loss: 0.1393 - val_sar_loss: 4.8565 - val_fusion_loss: 0.1353 - val_loss: 5.1310
#
# Epoch 00016: val_loss did not improve from 4.77805
# Epoch 17/100
# 108/108 [==============================] - 22s 204ms/step - opt_accuracy: 0.8928 - sar_accuracy: 0.8020 - fus_accuracy: 0.8833 - opt_loss: 0.0560 - sar_loss: 4.2824 - fusion_loss: 0.0592 - loss: 4.3976 - val_opt_accuracy: 0.8598 - val_sar_accuracy: 0.8072 - val_fus_accuracy: 0.8591 - val_opt_loss: 0.1344 - val_sar_loss: 4.7040 - val_fusion_loss: 0.1313 - val_loss: 4.9697
#
# Epoch 00017: val_loss did not improve from 4.77805
# Epoch 18/100
# 108/108 [==============================] - 22s 206ms/step - opt_accuracy: 0.8946 - sar_accuracy: 0.8067 - fus_accuracy: 0.8855 - opt_loss: 0.0547 - sar_loss: 4.1631 - fusion_loss: 0.0575 - loss: 4.2753 - val_opt_accuracy: 0.8619 - val_sar_accuracy: 0.8084 - val_fus_accuracy: 0.8613 - val_opt_loss: 0.1402 - val_sar_loss: 4.5514 - val_fusion_loss: 0.1310 - val_loss: 4.8226
#
# Epoch 00018: val_loss did not improve from 4.77805
# Epoch 00018: early stopping
# time:  4
# Model: "model_3_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 24s 205ms/step - opt_accuracy: 0.7332 - sar_accuracy: 0.7107 - fus_accuracy: 0.6907 - opt_loss: 0.1362 - sar_loss: 5.9819 - fusion_loss: 0.1637 - loss: 6.2818 - val_opt_accuracy: 0.8577 - val_sar_accuracy: 0.7837 - val_fus_accuracy: 0.8529 - val_opt_loss: 0.1065 - val_sar_loss: 4.6958 - val_fusion_loss: 0.0987 - val_loss: 4.9010
#
# Epoch 00001: val_loss improved from inf to 4.90101, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 2/100
# 108/108 [==============================] - 22s 207ms/step - opt_accuracy: 0.8270 - sar_accuracy: 0.7490 - fus_accuracy: 0.7945 - opt_loss: 0.0975 - sar_loss: 5.4481 - fusion_loss: 0.1102 - loss: 5.6559 - val_opt_accuracy: 0.8618 - val_sar_accuracy: 0.7916 - val_fus_accuracy: 0.8595 - val_opt_loss: 0.0940 - val_sar_loss: 4.7267 - val_fusion_loss: 0.0894 - val_loss: 4.9101
#
# Epoch 00002: val_loss did not improve from 4.90101
# Epoch 3/100
# 108/108 [==============================] - 22s 205ms/step - opt_accuracy: 0.8436 - sar_accuracy: 0.7581 - fus_accuracy: 0.8176 - opt_loss: 0.0889 - sar_loss: 5.1509 - fusion_loss: 0.1006 - loss: 5.3405 - val_opt_accuracy: 0.8653 - val_sar_accuracy: 0.7911 - val_fus_accuracy: 0.8628 - val_opt_loss: 0.0941 - val_sar_loss: 4.6215 - val_fusion_loss: 0.0874 - val_loss: 4.8031
#
# Epoch 00003: val_loss improved from 4.90101 to 4.80305, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 4/100
# 108/108 [==============================] - 23s 213ms/step - opt_accuracy: 0.8525 - sar_accuracy: 0.7644 - fus_accuracy: 0.8301 - opt_loss: 0.0836 - sar_loss: 4.9351 - fusion_loss: 0.0947 - loss: 5.1134 - val_opt_accuracy: 0.8641 - val_sar_accuracy: 0.7943 - val_fus_accuracy: 0.8657 - val_opt_loss: 0.1054 - val_sar_loss: 4.5439 - val_fusion_loss: 0.0888 - val_loss: 4.7381
#
# Epoch 00004: val_loss improved from 4.80305 to 4.73807, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 5/100
# 108/108 [==============================] - 24s 220ms/step - opt_accuracy: 0.8567 - sar_accuracy: 0.7669 - fus_accuracy: 0.8397 - opt_loss: 0.0804 - sar_loss: 4.8971 - fusion_loss: 0.0904 - loss: 5.0679 - val_opt_accuracy: 0.8654 - val_sar_accuracy: 0.7883 - val_fus_accuracy: 0.8641 - val_opt_loss: 0.1043 - val_sar_loss: 4.4290 - val_fusion_loss: 0.0887 - val_loss: 4.6220
#
# Epoch 00005: val_loss improved from 4.73807 to 4.62201, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 6/100
# 108/108 [==============================] - 23s 213ms/step - opt_accuracy: 0.8615 - sar_accuracy: 0.7753 - fus_accuracy: 0.8496 - opt_loss: 0.0768 - sar_loss: 4.7706 - fusion_loss: 0.0851 - loss: 4.9325 - val_opt_accuracy: 0.8642 - val_sar_accuracy: 0.8015 - val_fus_accuracy: 0.8651 - val_opt_loss: 0.1046 - val_sar_loss: 4.4082 - val_fusion_loss: 0.0925 - val_loss: 4.6052
#
# Epoch 00006: val_loss improved from 4.62201 to 4.60519, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 7/100
#
# Epoch 00024: val_loss did not improve from 4.58591
# Epoch 25/100
# 108/108 [==============================] - 28s 261ms/step - opt_accuracy: 0.9020 - sar_accuracy: 0.8060 - fus_accuracy: 0.8963 - opt_loss: 0.0472 - sar_loss: 4.1047 - fusion_loss: 0.0508 - loss: 4.2027 - val_opt_accuracy: 0.8657 - val_sar_accuracy: 0.8027 - val_fus_accuracy: 0.8631 - val_opt_loss: 0.1644 - val_sar_loss: 4.7741 - val_fusion_loss: 0.1498 - val_loss: 5.0882
#
# Epoch 00025: val_loss did not improve from 4.58591
# Epoch 26/100
# 108/108 [==============================] - 29s 272ms/step - opt_accuracy: 0.9036 - sar_accuracy: 0.8059 - fus_accuracy: 0.8978 - opt_loss: 0.0464 - sar_loss: 4.1123 - fusion_loss: 0.0500 - loss: 4.2087 - val_opt_accuracy: 0.8669 - val_sar_accuracy: 0.8047 - val_fus_accuracy: 0.8675 - val_opt_loss: 0.1613 - val_sar_loss: 4.9460 - val_fusion_loss: 0.1516 - val_loss: 5.2588
#
# Epoch 00026: val_loss did not improve from 4.58591
# Epoch 00026: early stopping

# %%
# Test loop
time_ts = []
n_pool = 3
n_rows = 5
n_cols = 4
rows, cols = image_array.shape[:2]
pad_rows = rows - np.ceil(rows/(n_rows*2**n_pool))*n_rows*2**n_pool
pad_cols = cols - np.ceil(cols/(n_cols*2**n_pool))*n_cols*2**n_pool
print(pad_rows, pad_cols)

npad = ((0, int(abs(pad_rows))), (0, int(abs(pad_cols))), (0, 0))
image1_pad = np.pad(image_array, pad_width=npad, mode='reflect')

h, w, c = image1_pad.shape
patch_size_rows = h//n_rows
patch_size_cols = w//n_cols
num_patches_x = int(h/patch_size_rows)
num_patches_y = int(w/patch_size_cols)

input_shape=(patch_size_rows,patch_size_cols, c)

#if method == 'unet':
#   new_model = build_unet(input_shape, nb_filters, number_class)

#if method == 'resunet':
#   new_model = build_resunet(input_shape, nb_filters, number_class)

new_model = Model_3(nb_filters, number_class, n_opt_layers)
new_model.build((None,)+input_shape)
adam = Adam(lr = 5e-5 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
new_model.compile(optimizer=adam, loss=loss, metrics=['accuracy'], run_eagerly=True)

for tm in range(0,times):
    print('time: ', tm)
    #model = load_model(path_models+ '/' + method +'_'+str(tm)+'.h5', compile=False)
    
    #for l in range(1, len(model.layers)):
    #    new_model.layers[l].set_weights(model.layers[l].get_weights())
    new_model.load_weights(path_models+ '/' + method +'_'+str(tm)+'.h5')
    
    start_test = time.time()
    patch_opt = []
    patch_sar = []
    patch_fus = []
    patch_comb = []
    
    for i in range(0,num_patches_y):
        for j in range(0,num_patches_x):
            patch = image1_pad[patch_size_rows*j:patch_size_rows*(j+1), patch_size_cols*i:patch_size_cols*(i+1), :]
            pred_opt, pred_sar, pred_fus, pred_comb = new_model.predict(np.expand_dims(patch, axis=0))
            del patch 
            patch_opt.append(pred_opt[:,:,:,1])
            patch_sar.append(pred_sar[:,:,:,1])
            patch_fus.append(pred_fus[:,:,:,1])
            patch_comb.append(pred_comb[:,:,:,1])
            del pred_opt, pred_sar, pred_fus, pred_comb
    end_test =  time.time() - start_test

    patches_pred_opt = np.asarray(patch_opt).astype(np.float32)
    patches_pred_sar = np.asarray(patch_sar).astype(np.float32)
    patches_pred_fus = np.asarray(patch_fus).astype(np.float32)
    patches_pred_comb = np.asarray(patch_comb).astype(np.float32)

    prob_recontructed_opt = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_opt)
    prob_recontructed_sar = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_sar)
    prob_recontructed_fus = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_fus)
    prob_recontructed_comb = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_comb)

    del patches_pred_opt, patches_pred_sar, patches_pred_fus, patches_pred_comb
    np.save(path_maps+'/'+'prob_opt_'+str(tm)+'.npy',prob_recontructed_opt) 
    np.save(path_maps+'/'+'prob_sar_'+str(tm)+'.npy',prob_recontructed_sar) 
    np.save(path_maps+'/'+'prob_fus_'+str(tm)+'.npy',prob_recontructed_fus) 
    np.save(path_maps+'/'+'prob_comb_'+str(tm)+'.npy',prob_recontructed_comb) 

    time_ts.append(end_test)
    del prob_recontructed_opt, prob_recontructed_sar, prob_recontructed_fus, prob_recontructed_comb
    #del model
time_ts_array = np.asarray(time_ts)
# Save test time
np.save(path_exp+'/metrics_ts.npy', time_ts_array)
# Out:
# 0.0 -8.0
# time:  0
# time:  1
# time:  2
# time:  3
# time:  4

# %%
# Compute mean of the tm predictions maps
prob_rec_opt = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_sar = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_fus = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_comb = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))

for tm in range (0, times):
    print(tm)
    prob_rec_opt[:,:,tm] = np.load(path_maps+'/'+'prob_opt_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_sar[:,:,tm] = np.load(path_maps+'/'+'prob_sar_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_fus[:,:,tm] = np.load(path_maps+'/'+'prob_fus_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_comb[:,:,tm] = np.load(path_maps+'/'+'prob_comb_'+str(tm)+'.npy').astype(np.float32)

mean_prob_opt = np.mean(prob_rec_opt, axis = -1)
mean_prob_sar = np.mean(prob_rec_sar, axis = -1)
mean_prob_fus = np.mean(prob_rec_fus, axis = -1)
mean_prob_comb = np.mean(prob_rec_comb, axis = -1)

np.save(path_maps+'/prob_mean_opt.npy', mean_prob_opt)
np.save(path_maps+'/prob_mean_sar.npy', mean_prob_sar)
np.save(path_maps+'/prob_mean_fus.npy', mean_prob_fus)
np.save(path_maps+'/prob_mean_comb.npy', mean_prob_comb)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Plot mean map and reference
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(151)
plt.title('OPT Prediction')
ax1.imshow(mean_prob_opt, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(152)
plt.title('SAR Prediction')
ax1.imshow(mean_prob_sar, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(153)
plt.title('FUSION Prediction')
ax1.imshow(mean_prob_fus, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(154)
plt.title('COMBINATION Prediction')
ax1.imshow(mean_prob_comb, cmap ='jet')
ax1.axis('off')

ax2 = fig.add_subplot(155)
plt.title('Reference')
ax2.imshow(tf.keras.utils.to_categorical(final_mask1, 3)[:,:,1], cmap ='jet')
ax2.axis('off')
# Out:
# (-0.5, 6999.5, 9999.5, -0.5)

# %%
# Computing metrics
mean_prob_opt = mean_prob_opt[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_sar = mean_prob_sar[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_fus = mean_prob_fus[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_comb = mean_prob_comb[:final_mask1.shape[0], :final_mask1.shape[1]]

ref1 = np.ones_like(final_mask1).astype(np.float32)

ref1 [final_mask1 == 2] = 0
TileMask = mask_amazon_ts * ref1
GTTruePositives = final_mask1==1
    
Npoints = 50

Pmax_opt = np.max(mean_prob_opt[GTTruePositives * TileMask ==1])
ProbList_opt = np.linspace(Pmax_opt,0,Npoints)

Pmax_sar = np.max(mean_prob_sar[GTTruePositives * TileMask ==1])
ProbList_sar = np.linspace(Pmax_sar,0,Npoints)

Pmax_fus = np.max(mean_prob_fus[GTTruePositives * TileMask ==1])
ProbList_fus = np.linspace(Pmax_fus,0,Npoints)

Pmax_comb = np.max(mean_prob_comb[GTTruePositives * TileMask ==1])
ProbList_comb = np.linspace(Pmax_comb,0,Npoints)


from multiprocessing.pool import Pool
pool = Pool(processes=4)

async_result_opt = pool.apply_async(matrics_AA_recall, (ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625))
async_result_sar = pool.apply_async(matrics_AA_recall, (ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625))
async_result_fus = pool.apply_async(matrics_AA_recall, (ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625))
async_result_comb = pool.apply_async(matrics_AA_recall, (ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625))

metrics_opt = async_result_opt.get()
metrics_sar = async_result_sar.get()
metrics_fus = async_result_fus.get()
metrics_comb = async_result_comb.get()
    
#metrics_opt = matrics_AA_recall(ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625)
#metrics_sar = matrics_AA_recall(ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625)
#metrics_fus = matrics_AA_recall(ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625)
#metrics_comb = matrics_AA_recall(ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625)

np.save(path_exp+'/acc_metrics_opt.npy',metrics_opt)
np.save(path_exp+'/acc_metrics_sar.npy',metrics_sar)
np.save(path_exp+'/acc_metrics_fus.npy',metrics_fus)
np.save(path_exp+'/acc_metrics_comb.npy',metrics_comb)

# %%
# Complete NaN values
metrics_copy_opt = metrics_opt.copy()
metrics_copy_opt = complete_nan_values(metrics_copy_opt)

metrics_copy_sar = metrics_sar.copy()
metrics_copy_sar = complete_nan_values(metrics_copy_sar)

metrics_copy_fus = metrics_fus.copy()
metrics_copy_fus = complete_nan_values(metrics_copy_fus)

metrics_copy_comb = metrics_comb.copy()
metrics_copy_comb = complete_nan_values(metrics_copy_comb)

# %%
# Comput Mean Average Precision (mAP) score 
Recall_opt = metrics_copy_opt[:,0]
Precision_opt = metrics_copy_opt[:,1]
AA_opt = metrics_copy_opt[:,2]

Recall_sar = metrics_copy_sar[:,0]
Precision_sar = metrics_copy_sar[:,1]
AA_sar = metrics_copy_sar[:,2]

Recall_fus = metrics_copy_fus[:,0]
Precision_fus = metrics_copy_fus[:,1]
AA_fus = metrics_copy_fus[:,2]

Recall_comb = metrics_copy_comb[:,0]
Precision_comb = metrics_copy_comb[:,1]
AA_comb = metrics_copy_comb[:,2]
    
DeltaR_opt = Recall_opt[1:]-Recall_opt[:-1]
AP_opt = np.sum(Precision_opt[:-1]*DeltaR_opt)
print('OPT mAP', AP_opt)

DeltaR_sar = Recall_sar[1:]-Recall_sar[:-1]
AP_sar = np.sum(Precision_sar[:-1]*DeltaR_sar)
print('SAR mAP', AP_sar)

DeltaR_fus = Recall_fus[1:]-Recall_fus[:-1]
AP_fus = np.sum(Precision_fus[:-1]*DeltaR_fus)
print('FUSION mAP', AP_fus)

DeltaR_comb = Recall_comb[1:]-Recall_comb[:-1]
AP_comb = np.sum(Precision_comb[:-1]*DeltaR_comb)
print('COMBINATION mAP', AP_comb)

# Plot Recall vs. Precision curve
plt.figure(figsize=(7,7))
plt.plot(metrics_copy_opt[:,0],metrics_copy_opt[:,1], 'r-', label = f'OPT (AP: {AP_opt:.4f})')
plt.plot(metrics_copy_sar[:,0],metrics_copy_sar[:,1], 'g-', label = f'SAR (AP: {AP_sar:.4f})')
plt.plot(metrics_copy_fus[:,0],metrics_copy_fus[:,1], 'b-', label = f'FUSION (AP: {AP_fus:.4f})')
plt.plot(metrics_copy_comb[:,0],metrics_copy_comb[:,1], 'k-', label = f'COMBINATION (AP: {AP_comb:.4f})')
plt.legend(loc="lower left")
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([0,1])
#plt.plot(metrics_copy[:,0],metrics_copy[:,2])
plt.grid()
# Out:
# OPT mAP 0.9204032619962218
# SAR mAP 0.8044263079607911
# FUSION mAP 0.9318719851989037
# COMBINATION mAP 0.934239109183772
