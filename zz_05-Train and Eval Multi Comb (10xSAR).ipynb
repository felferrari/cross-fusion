# %%
# %load_ext autoreload
# %autoreload 2

# %%
#%autoreload # When utils.py is updated
from utils_unet_resunet import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from model.models import Model_3
from model.losses import WBCE
from model.callbacks import UpdateWeights
from multiprocessing.pool import Pool

root_path = 'imgs/'

# %%
# Define data type 
img_type = 'FUSION'

if img_type == 'FUSION':
    image_array = np.load(root_path+'New_Images/fus_stack.npy')
    

if img_type == 'OPT':
    image_array = np.load(root_path+'New_Images/opt_stack.npy')
    
    
if img_type == 'SAR':
    image_array = np.load(root_path+'New_Images/sar_stack.npy')
print('Image stack:', image_array.shape)

final_mask1 = np.load(root_path+'New_Images/'+'final_mask1.npy')
print('Labels stack:', final_mask1.shape)

h_, w_, channels = image_array.shape
n_opt_layers = 20
# Out:
# Image stack: (10000, 7000, 24)
# Labels stack: (10000, 7000)

# %%
# Create tile mask
mask_tiles = create_mask(final_mask1.shape[0], final_mask1.shape[1], grid_size=(5, 4))
image_array = image_array[:mask_tiles.shape[0], :mask_tiles.shape[1],:]
final_mask1 = final_mask1[:mask_tiles.shape[0], :mask_tiles.shape[1]]

print('mask: ',mask_tiles.shape)
print('image stack: ', image_array.shape)
print('ref :', final_mask1.shape)
#plt.imshow(mask_tiles)
# Out:
# Tiles size:  2000 1750
# Mask size:  (10000, 7000)
# mask:  (10000, 7000)
# image stack:  (10000, 7000, 24)
# ref : (10000, 7000)

# %%
plt.figure(figsize=(10,5))
plt.imshow(final_mask1, cmap = 'jet')

# %%
# Define tiles for training, validation, and test sets
tiles_tr = [1,3,5,8,11,13,14,20]
tiles_val = [6,19]
tiles_ts = (list(set(np.arange(20)+1)-set(tiles_tr)-set(tiles_val)))

mask_tr_val = np.zeros((mask_tiles.shape)).astype('float32')
# Training and validation mask
for tr_ in tiles_tr:
    mask_tr_val[mask_tiles == tr_] = 1

for val_ in tiles_val:
    mask_tr_val[mask_tiles == val_] = 2

mask_amazon_ts = np.zeros((mask_tiles.shape)).astype('float32')
for ts_ in tiles_ts:
    mask_amazon_ts[mask_tiles == ts_] = 1

# %%
# Create ixd image to extract patches
overlap = 0.7
patch_size = 128
batch_size = 32
im_idx = create_idx_image(final_mask1)
patches_idx = extract_patches(im_idx, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1,patch_size, patch_size)
patches_mask = extract_patches(mask_tr_val, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1, patch_size, patch_size)
del im_idx

# %%
# Selecting index trn val and test patches idx
idx_trn = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==patch_size**2))
idx_val = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==2*patch_size**2))
del patches_mask

patches_idx_trn = patches_idx[idx_trn]
patches_idx_val = patches_idx[idx_val]
del idx_trn, idx_val

print('Number of training patches:  ', len(patches_idx_trn), 'Number of validation patches', len(patches_idx_val))
# Out:
# Number of training patches:   17110 Number of validation patches 4116

# %%
# Extract patches with at least 2% of deforestation class
X_train = retrieve_idx_percentage(final_mask1, patches_idx_trn, patch_size, pertentage = 2)
X_valid = retrieve_idx_percentage(final_mask1, patches_idx_val, patch_size, pertentage = 2)
print(X_train.shape, X_valid.shape)
del patches_idx_trn, patches_idx_val
# Out:
# (1158, 128, 128) (341, 128, 128)

# %%
def batch_generator(batches, image, reference, target_size, number_class):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    image = image.reshape(-1, image.shape[-1])
    reference = reference.reshape(final_mask1.shape[0]*final_mask1.shape[1])
    while True:
        batch_x, batch_y = next(batches)
        batch_x = np.squeeze(batch_x.astype('int64'))
        #print(batch_x.shape)
        batch_img = np.zeros((batch_x.shape[0], target_size, target_size, image.shape[-1]))
        batch_ref = np.zeros((batch_x.shape[0], target_size, target_size, number_class))
        
        for i in range(batch_x.shape[0]):
            if np.random.rand()>0.5:
                batch_x[i] = np.rot90(batch_x[i], 1)
            batch_img[i] = image[batch_x[i]] 
            batch_ref[i] = tf.keras.utils.to_categorical(reference[batch_x[i]] , number_class)
                       
        yield (batch_img, batch_ref)

train_datagen = ImageDataGenerator(horizontal_flip = True,
                                   vertical_flip = True)
valid_datagen = ImageDataGenerator(horizontal_flip = True, 
                                   vertical_flip = True)

y_train = np.zeros((len(X_train)))
y_valid = np.zeros((len(X_valid)))

train_gen = train_datagen.flow(np.expand_dims(X_train, axis = -1), y_train,
                              batch_size=batch_size,
                              shuffle=True)

valid_gen = valid_datagen.flow(np.expand_dims(X_valid, axis = -1), y_valid,
                              batch_size=batch_size,
                              shuffle=False)

number_class = 3
train_gen_crops = batch_generator(train_gen, image_array, final_mask1, patch_size, number_class)
valid_gen_crops = batch_generator(valid_gen, image_array, final_mask1, patch_size, number_class)

# %%
exp = 3
path_exp = root_path+'experiments/exp'+str(exp)
path_models = path_exp+'/models'
path_maps = path_exp+'/pred_maps'

if not os.path.exists(path_exp):
    os.makedirs(path_exp)   
if not os.path.exists(path_models):
    os.makedirs(path_models)   
if not os.path.exists(path_maps):
    os.makedirs(path_maps)

# %%
# Define model
input_shape = (patch_size, patch_size, channels)
nb_filters = [32, 64, 128]

method = 'unet'
if method == 'unet':
   model = build_unet(input_shape, nb_filters, number_class)

if method == 'resunet':
   model = build_resunet(input_shape, nb_filters, number_class)

model = Model_3(nb_filters, number_class, n_opt_layers)

# %%
# Parameters of the model
weights = [0.2, 0.8, 0]
adam = Adam(lr = 1e-5 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
#loss = WBCE(weights = weights)
#loss = WBCE(weights = weights, class_indexes = [0, 1])

# %%
metrics_all = []
times=5
for tm in range(0,times):
    print('time: ', tm)

    rows = patch_size
    cols = patch_size
    adam = Adam(lr = 1e-5 , beta_1=0.9)
    
    loss = weighted_categorical_crossentropy(weights)
    #loss = WBCE(weights = weights)
    #loss = WBCE(weights = weights, class_indexes = [0, 1])

    #if method == 'unet':
    #   model = build_unet(input_shape, nb_filters, number_class)

    #if method == 'resunet':
    #   model = build_resunet(input_shape, nb_filters, number_class)
    
    model = Model_3(nb_filters, number_class, n_opt_layers)
    model.build((None,)+input_shape)
    
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    model.summary()

    earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
    #earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min') ---- val_accuracy
    #checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
    lr_reduce = ReduceLROnPlateau(factor=0.9, min_delta=0.0001, patience=5, verbose=1)
    updateWeights = UpdateWeights()
    callbacks_list = [earlystop, checkpoint, updateWeights]
    # train the model
    start_training = time.time()
    history = model.fit(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    end_training = time.time() - start_training
    metrics_all.append(end_training)
    del model, history
# Out:
# time:  0
# Model: "model_3_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 27s 168ms/step - opt_accuracy: 0.6570 - sar_accuracy: 0.6618 - fus_accuracy: 0.6918 - opt_loss: 0.1793 - sar_loss: 1.6411 - fusion_loss: 0.1638 - loss: 1.9841 - val_opt_accuracy: 0.7668 - val_sar_accuracy: 0.7062 - val_fus_accuracy: 0.8334 - val_opt_loss: 0.1202 - val_sar_loss: 1.3224 - val_fusion_loss: 0.1090 - val_loss: 1.5517
#
# Epoch 00001: val_loss improved from inf to 1.55168, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 2/100
# 108/108 [==============================] - 15s 142ms/step - opt_accuracy: 0.7304 - sar_accuracy: 0.6773 - fus_accuracy: 0.7592 - opt_loss: 0.1327 - sar_loss: 1.5556 - fusion_loss: 0.1287 - loss: 1.8170 - val_opt_accuracy: 0.8469 - val_sar_accuracy: 0.7189 - val_fus_accuracy: 0.8448 - val_opt_loss: 0.0925 - val_sar_loss: 1.2899 - val_fusion_loss: 0.0969 - val_loss: 1.4793
#
# Epoch 00002: val_loss improved from 1.55168 to 1.47935, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 3/100
# 108/108 [==============================] - 15s 142ms/step - opt_accuracy: 0.7799 - sar_accuracy: 0.7004 - fus_accuracy: 0.7882 - opt_loss: 0.1097 - sar_loss: 1.5120 - fusion_loss: 0.1119 - loss: 1.7336 - val_opt_accuracy: 0.8555 - val_sar_accuracy: 0.7595 - val_fus_accuracy: 0.8500 - val_opt_loss: 0.0873 - val_sar_loss: 1.2405 - val_fusion_loss: 0.0946 - val_loss: 1.4225
#
#
# Epoch 00009: val_loss did not improve from 1.36350
# Epoch 10/100
# 108/108 [==============================] - 16s 145ms/step - opt_accuracy: 0.8343 - sar_accuracy: 0.7448 - fus_accuracy: 0.8144 - opt_loss: 0.0893 - sar_loss: 1.3604 - fusion_loss: 0.0974 - loss: 1.5471 - val_opt_accuracy: 0.8640 - val_sar_accuracy: 0.7790 - val_fus_accuracy: 0.8596 - val_opt_loss: 0.0936 - val_sar_loss: 1.2083 - val_fusion_loss: 0.1019 - val_loss: 1.4038
#
# Epoch 00010: val_loss did not improve from 1.36350
# Epoch 11/100
# 108/108 [==============================] - 16s 145ms/step - opt_accuracy: 0.8360 - sar_accuracy: 0.7471 - fus_accuracy: 0.8162 - opt_loss: 0.0874 - sar_loss: 1.3389 - fusion_loss: 0.0955 - loss: 1.5219 - val_opt_accuracy: 0.8633 - val_sar_accuracy: 0.7855 - val_fus_accuracy: 0.8587 - val_opt_loss: 0.0964 - val_sar_loss: 1.1943 - val_fusion_loss: 0.1055 - val_loss: 1.3962
#
# Epoch 00011: val_loss did not improve from 1.36350
# Epoch 12/100
# 108/108 [==============================] - 16s 145ms/step - opt_accuracy: 0.8381 - sar_accuracy: 0.7493 - fus_accuracy: 0.8187 - opt_loss: 0.0867 - sar_loss: 1.3321 - fusion_loss: 0.0949 - loss: 1.5136 - val_opt_accuracy: 0.8633 - val_sar_accuracy: 0.7847 - val_fus_accuracy: 0.8580 - val_opt_loss: 0.1009 - val_sar_loss: 1.1897 - val_fusion_loss: 0.1133 - val_loss: 1.4039
#
# Epoch 00012: val_loss did not improve from 1.36350
# Epoch 13/100
# 108/108 [==============================] - 16s 146ms/step - opt_accuracy: 0.8395 - sar_accuracy: 0.7512 - fus_accuracy: 0.8207 - opt_loss: 0.0855 - sar_loss: 1.3251 - fusion_loss: 0.0937 - loss: 1.5043 - val_opt_accuracy: 0.8651 - val_sar_accuracy: 0.7862 - val_fus_accuracy: 0.8606 - val_opt_loss: 0.0991 - val_sar_loss: 1.1899 - val_fusion_loss: 0.1103 - val_loss: 1.3994
#
# Epoch 00013: val_loss did not improve from 1.36350
# Epoch 14/100
# 108/108 [==============================] - 16s 146ms/step - opt_accuracy: 0.8407 - sar_accuracy: 0.7525 - fus_accuracy: 0.8219 - opt_loss: 0.0854 - sar_loss: 1.3213 - fusion_loss: 0.0934 - loss: 1.5002 - val_opt_accuracy: 0.8661 - val_sar_accuracy: 0.7839 - val_fus_accuracy: 0.8614 - val_opt_loss: 0.1002 - val_sar_loss: 1.1822 - val_fusion_loss: 0.1131 - val_loss: 1.3955
#
# Epoch 00014: val_loss did not improve from 1.36350
# Epoch 00014: early stopping
# time:  1
# Model: "model_3_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 11s - opt_accuracy: 0.6206 - sar_accuracy: 0.5687 - fus_accuracy: 0.5113 - opt_loss: 0.2014 - sar_loss: 2.4878 - fusion_loss: 0.3744 - loss: 3.0636WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0575s vs `on_train_batch_end` time: 0.0584s). Check your callbacks.
# 108/108 [==============================] - 18s 150ms/step - opt_accuracy: 0.6728 - sar_accuracy: 0.6213 - fus_accuracy: 0.6149 - opt_loss: 0.1618 - sar_loss: 1.9379 - fusion_loss: 0.2298 - loss: 2.3295 - val_opt_accuracy: 0.7915 - val_sar_accuracy: 0.6713 - val_fus_accuracy: 0.8036 - val_opt_loss: 0.1045 - val_sar_loss: 1.3660 - val_fusion_loss: 0.1115 - val_loss: 1.5820
#
# Epoch 00001: val_loss improved from inf to 1.58200, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 2/100
# 108/108 [==============================] - 16s 146ms/step - opt_accuracy: 0.7529 - sar_accuracy: 0.6617 - fus_accuracy: 0.6990 - opt_loss: 0.1220 - sar_loss: 1.6639 - fusion_loss: 0.1682 - loss: 1.9542 - val_opt_accuracy: 0.8476 - val_sar_accuracy: 0.7240 - val_fus_accuracy: 0.8472 - val_opt_loss: 0.0923 - val_sar_loss: 1.2854 - val_fusion_loss: 0.0935 - val_loss: 1.4713
#
# Epoch 00002: val_loss improved from 1.58200 to 1.47125, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 3/100
# 108/108 [==============================] - 16s 146ms/step - opt_accuracy: 0.8092 - sar_accuracy: 0.6899 - fus_accuracy: 0.7555 - opt_loss: 0.1010 - sar_loss: 1.5874 - fusion_loss: 0.1394 - loss: 1.8278 - val_opt_accuracy: 0.8552 - val_sar_accuracy: 0.7422 - val_fus_accuracy: 0.8532 - val_opt_loss: 0.1030 - val_sar_loss: 1.2739 - val_fusion_loss: 0.0960 - val_loss: 1.4729
#
# Epoch 00003: val_loss did not improve from 1.47125
# Epoch 4/100
# 108/108 [==============================] - 16s 147ms/step - opt_accuracy: 0.8279 - sar_accuracy: 0.7023 - fus_accuracy: 0.7797 - opt_loss: 0.0959 - sar_loss: 1.5417 - fusion_loss: 0.1281 - loss: 1.7658 - val_opt_accuracy: 0.8561 - val_sar_accuracy: 0.7479 - val_fus_accuracy: 0.8541 - val_opt_loss: 0.0968 - val_sar_loss: 1.2739 - val_fusion_loss: 0.0942 - val_loss: 1.4649
#
# Epoch 00004: val_loss improved from 1.47125 to 1.46486, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 5/100
# 108/108 [==============================] - 16s 148ms/step - opt_accuracy: 0.8345 - sar_accuracy: 0.7089 - fus_accuracy: 0.7919 - opt_loss: 0.0920 - sar_loss: 1.5025 - fusion_loss: 0.1214 - loss: 1.7159 - val_opt_accuracy: 0.8597 - val_sar_accuracy: 0.7548 - val_fus_accuracy: 0.8583 - val_opt_loss: 0.1027 - val_sar_loss: 1.2286 - val_fusion_loss: 0.0957 - val_loss: 1.4270
#
# Epoch 00005: val_loss improved from 1.46486 to 1.42703, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 6/100
# 108/108 [==============================] - 16s 148ms/step - opt_accuracy: 0.8349 - sar_accuracy: 0.7113 - fus_accuracy: 0.7972 - opt_loss: 0.0913 - sar_loss: 1.4818 - fusion_loss: 0.1186 - loss: 1.6917 - val_opt_accuracy: 0.8595 - val_sar_accuracy: 0.7593 - val_fus_accuracy: 0.8584 - val_opt_loss: 0.0973 - val_sar_loss: 1.2144 - val_fusion_loss: 0.0941 - val_loss: 1.4058
#
# Epoch 00006: val_loss improved from 1.42703 to 1.40578, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 7/100
# 108/108 [==============================] - 16s 149ms/step - opt_accuracy: 0.8385 - sar_accuracy: 0.7160 - fus_accuracy: 0.8048 - opt_loss: 0.0902 - sar_loss: 1.4657 - fusion_loss: 0.1150 - loss: 1.6709 - val_opt_accuracy: 0.8618 - val_sar_accuracy: 0.7634 - val_fus_accuracy: 0.8597 - val_opt_loss: 0.0945 - val_sar_loss: 1.2130 - val_fusion_loss: 0.0929 - val_loss: 1.4004
#
# Epoch 00007: val_loss improved from 1.40578 to 1.40044, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 8/100
# 108/108 [==============================] - 16s 149ms/step - opt_accuracy: 0.8394 - sar_accuracy: 0.7190 - fus_accuracy: 0.8079 - opt_loss: 0.0895 - sar_loss: 1.4523 - fusion_loss: 0.1136 - loss: 1.6555 - val_opt_accuracy: 0.8621 - val_sar_accuracy: 0.7716 - val_fus_accuracy: 0.8604 - val_opt_loss: 0.1002 - val_sar_loss: 1.1981 - val_fusion_loss: 0.0951 - val_loss: 1.3934
#
# Epoch 00008: val_loss improved from 1.40044 to 1.39337, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 9/100
# 108/108 [==============================] - 16s 149ms/step - opt_accuracy: 0.8441 - sar_accuracy: 0.7224 - fus_accuracy: 0.8128 - opt_loss: 0.0874 - sar_loss: 1.4357 - fusion_loss: 0.1105 - loss: 1.6336 - val_opt_accuracy: 0.8605 - val_sar_accuracy: 0.7663 - val_fus_accuracy: 0.8591 - val_opt_loss: 0.0944 - val_sar_loss: 1.2073 - val_fusion_loss: 0.0913 - val_loss: 1.3930
#
# Epoch 00009: val_loss improved from 1.39337 to 1.39301, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 10/100
# 108/108 [==============================] - 16s 150ms/step - opt_accuracy: 0.8454 - sar_accuracy: 0.7220 - fus_accuracy: 0.8151 - opt_loss: 0.0865 - sar_loss: 1.4178 - fusion_loss: 0.1082 - loss: 1.6125 - val_opt_accuracy: 0.8635 - val_sar_accuracy: 0.7690 - val_fus_accuracy: 0.8619 - val_opt_loss: 0.0983 - val_sar_loss: 1.1970 - val_fusion_loss: 0.0932 - val_loss: 1.3884
#
# Epoch 00010: val_loss improved from 1.39301 to 1.38844, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 11/100
# 108/108 [==============================] - 16s 150ms/step - opt_accuracy: 0.8469 - sar_accuracy: 0.7237 - fus_accuracy: 0.8184 - opt_loss: 0.0866 - sar_loss: 1.4108 - fusion_loss: 0.1070 - loss: 1.6044 - val_opt_accuracy: 0.8640 - val_sar_accuracy: 0.7683 - val_fus_accuracy: 0.8622 - val_opt_loss: 0.0910 - val_sar_loss: 1.1962 - val_fusion_loss: 0.0887 - val_loss: 1.3758
#
# Epoch 00011: val_loss improved from 1.38844 to 1.37582, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 12/100
# 108/108 [==============================] - 16s 151ms/step - opt_accuracy: 0.8485 - sar_accuracy: 0.7260 - fus_accuracy: 0.8215 - opt_loss: 0.0849 - sar_loss: 1.3949 - fusion_loss: 0.1043 - loss: 1.5841 - val_opt_accuracy: 0.8650 - val_sar_accuracy: 0.7681 - val_fus_accuracy: 0.8632 - val_opt_loss: 0.0849 - val_sar_loss: 1.1765 - val_fusion_loss: 0.0841 - val_loss: 1.3455
#
# Epoch 00012: val_loss improved from 1.37582 to 1.34546, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 13/100
# 108/108 [==============================] - 16s 151ms/step - opt_accuracy: 0.8485 - sar_accuracy: 0.7274 - fus_accuracy: 0.8235 - opt_loss: 0.0847 - sar_loss: 1.3926 - fusion_loss: 0.1035 - loss: 1.5808 - val_opt_accuracy: 0.8646 - val_sar_accuracy: 0.7620 - val_fus_accuracy: 0.8632 - val_opt_loss: 0.0934 - val_sar_loss: 1.2224 - val_fusion_loss: 0.0888 - val_loss: 1.4046
#
# Epoch 00013: val_loss did not improve from 1.34546
# Epoch 14/100
# 108/108 [==============================] - 16s 152ms/step - opt_accuracy: 0.8493 - sar_accuracy: 0.7302 - fus_accuracy: 0.8271 - opt_loss: 0.0839 - sar_loss: 1.3807 - fusion_loss: 0.1017 - loss: 1.5663 - val_opt_accuracy: 0.8588 - val_sar_accuracy: 0.7770 - val_fus_accuracy: 0.8590 - val_opt_loss: 0.0969 - val_sar_loss: 1.1975 - val_fusion_loss: 0.0929 - val_loss: 1.3873
#
# Epoch 00014: val_loss did not improve from 1.34546
# Epoch 15/100
# 108/108 [==============================] - 16s 152ms/step - opt_accuracy: 0.8500 - sar_accuracy: 0.7309 - fus_accuracy: 0.8296 - opt_loss: 0.0838 - sar_loss: 1.3809 - fusion_loss: 0.1012 - loss: 1.5659 - val_opt_accuracy: 0.8597 - val_sar_accuracy: 0.7721 - val_fus_accuracy: 0.8599 - val_opt_loss: 0.1025 - val_sar_loss: 1.2237 - val_fusion_loss: 0.0952 - val_loss: 1.4215
#
# Epoch 00015: val_loss did not improve from 1.34546
# Epoch 16/100
# 108/108 [==============================] - 17s 156ms/step - opt_accuracy: 0.8611 - sar_accuracy: 0.7444 - fus_accuracy: 0.8437 - opt_loss: 0.0776 - sar_loss: 1.2942 - fusion_loss: 0.0918 - loss: 1.4635 - val_opt_accuracy: 0.8617 - val_sar_accuracy: 0.7899 - val_fus_accuracy: 0.8614 - val_opt_loss: 0.1177 - val_sar_loss: 1.1666 - val_fusion_loss: 0.1040 - val_loss: 1.3883
#
# Epoch 00022: val_loss did not improve from 1.34546
# Epoch 00022: early stopping
# time:  2
# Model: "model_3_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 19s 159ms/step - opt_accuracy: 0.6975 - sar_accuracy: 0.6802 - fus_accuracy: 0.6884 - opt_loss: 0.1546 - sar_loss: 1.5469 - fusion_loss: 0.1657 - loss: 1.8672 - val_opt_accuracy: 0.8196 - val_sar_accuracy: 0.7552 - val_fus_accuracy: 0.7936 - val_opt_loss: 0.1136 - val_sar_loss: 1.2101 - val_fusion_loss: 0.1071 - val_loss: 1.4308
#
# Epoch 00001: val_loss improved from inf to 1.43081, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 2/100
# 108/108 [==============================] - 17s 157ms/step - opt_accuracy: 0.7546 - sar_accuracy: 0.7175 - fus_accuracy: 0.7348 - opt_loss: 0.1290 - sar_loss: 1.4564 - fusion_loss: 0.1400 - loss: 1.7254 - val_opt_accuracy: 0.8536 - val_sar_accuracy: 0.7728 - val_fus_accuracy: 0.8310 - val_opt_loss: 0.0936 - val_sar_loss: 1.1911 - val_fusion_loss: 0.0941 - val_loss: 1.3788
#
# Epoch 00002: val_loss improved from 1.43081 to 1.37875, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 3/100
# 108/108 [==============================] - 17s 157ms/step - opt_accuracy: 0.8015 - sar_accuracy: 0.7344 - fus_accuracy: 0.7629 - opt_loss: 0.1072 - sar_loss: 1.4118 - fusion_loss: 0.1248 - loss: 1.6438 - val_opt_accuracy: 0.8578 - val_sar_accuracy: 0.7801 - val_fus_accuracy: 0.8480 - val_opt_loss: 0.0877 - val_sar_loss: 1.2000 - val_fusion_loss: 0.0918 - val_loss: 1.3796
#
# Epoch 00003: val_loss did not improve from 1.37875
# Epoch 4/100
# 108/108 [==============================] - 17s 157ms/step - opt_accuracy: 0.8215 - sar_accuracy: 0.7426 - fus_accuracy: 0.7787 - opt_loss: 0.0988 - sar_loss: 1.3860 - fusion_loss: 0.1183 - loss: 1.6031 - val_opt_accuracy: 0.8586 - val_sar_accuracy: 0.7840 - val_fus_accuracy: 0.8551 - val_opt_loss: 0.0868 - val_sar_loss: 1.2067 - val_fusion_loss: 0.0930 - val_loss: 1.3865
#
# Epoch 00004: val_loss did not improve from 1.37875
# Epoch 5/100
# 108/108 [==============================] - 17s 159ms/step - opt_accuracy: 0.8318 - sar_accuracy: 0.7463 - fus_accuracy: 0.7872 - opt_loss: 0.0951 - sar_loss: 1.3732 - fusion_loss: 0.1154 - loss: 1.5836 - val_opt_accuracy: 0.8618 - val_sar_accuracy: 0.7869 - val_fus_accuracy: 0.8562 - val_opt_loss: 0.0857 - val_sar_loss: 1.1937 - val_fusion_loss: 0.0924 - val_loss: 1.3717
#
# Epoch 00005: val_loss improved from 1.37875 to 1.37174, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 6/100
# 108/108 [==============================] - 17s 158ms/step - opt_accuracy: 0.8379 - sar_accuracy: 0.7489 - fus_accuracy: 0.7935 - opt_loss: 0.0921 - sar_loss: 1.3583 - fusion_loss: 0.1122 - loss: 1.5626 - val_opt_accuracy: 0.8618 - val_sar_accuracy: 0.7823 - val_fus_accuracy: 0.8576 - val_opt_loss: 0.0861 - val_sar_loss: 1.2106 - val_fusion_loss: 0.0895 - val_loss: 1.3862
#
# Epoch 00006: val_loss did not improve from 1.37174
# Epoch 7/100
# 108/108 [==============================] - 17s 159ms/step - opt_accuracy: 0.8423 - sar_accuracy: 0.7513 - fus_accuracy: 0.8000 - opt_loss: 0.0893 - sar_loss: 1.3408 - fusion_loss: 0.1089 - loss: 1.5390 - val_opt_accuracy: 0.8630 - val_sar_accuracy: 0.7894 - val_fus_accuracy: 0.8596 - val_opt_loss: 0.0868 - val_sar_loss: 1.1899 - val_fusion_loss: 0.0920 - val_loss: 1.3686
#
# Epoch 00007: val_loss improved from 1.37174 to 1.36864, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 8/100
# 108/108 [==============================] - 17s 160ms/step - opt_accuracy: 0.8467 - sar_accuracy: 0.7544 - fus_accuracy: 0.8052 - opt_loss: 0.0879 - sar_loss: 1.3379 - fusion_loss: 0.1067 - loss: 1.5325 - val_opt_accuracy: 0.8636 - val_sar_accuracy: 0.7917 - val_fus_accuracy: 0.8598 - val_opt_loss: 0.0875 - val_sar_loss: 1.1787 - val_fusion_loss: 0.0946 - val_loss: 1.3608
#
# Epoch 00008: val_loss improved from 1.36864 to 1.36081, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 9/100
# 108/108 [==============================] - 18s 166ms/step - opt_accuracy: 0.8489 - sar_accuracy: 0.7567 - fus_accuracy: 0.8072 - opt_loss: 0.0867 - sar_loss: 1.3337 - fusion_loss: 0.1056 - loss: 1.5260 - val_opt_accuracy: 0.8634 - val_sar_accuracy: 0.7915 - val_fus_accuracy: 0.8603 - val_opt_loss: 0.0884 - val_sar_loss: 1.1748 - val_fusion_loss: 0.0940 - val_loss: 1.3572
#
# Epoch 00009: val_loss improved from 1.36081 to 1.35724, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 10/100
# Epoch 22/100
# 108/108 [==============================] - 18s 170ms/step - opt_accuracy: 0.8671 - sar_accuracy: 0.7736 - fus_accuracy: 0.8379 - opt_loss: 0.0748 - sar_loss: 1.2435 - fusion_loss: 0.0891 - loss: 1.4074 - val_opt_accuracy: 0.8596 - val_sar_accuracy: 0.7988 - val_fus_accuracy: 0.8595 - val_opt_loss: 0.0947 - val_sar_loss: 1.1556 - val_fusion_loss: 0.0985 - val_loss: 1.3488
#
# Epoch 00022: val_loss did not improve from 1.30053
# Epoch 00022: early stopping
# time:  3
# Model: "model_3_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 22s 181ms/step - opt_accuracy: 0.6600 - sar_accuracy: 0.6285 - fus_accuracy: 0.6047 - opt_loss: 0.1738 - sar_loss: 1.9664 - fusion_loss: 0.1905 - loss: 2.3306 - val_opt_accuracy: 0.7459 - val_sar_accuracy: 0.7147 - val_fus_accuracy: 0.6898 - val_opt_loss: 0.1131 - val_sar_loss: 1.4938 - val_fusion_loss: 0.1204 - val_loss: 1.7272
#
# Epoch 00001: val_loss improved from inf to 1.72717, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 2/100
# 108/108 [==============================] - 19s 173ms/step - opt_accuracy: 0.7522 - sar_accuracy: 0.6621 - fus_accuracy: 0.6957 - opt_loss: 0.1288 - sar_loss: 1.7155 - fusion_loss: 0.1491 - loss: 1.9933 - val_opt_accuracy: 0.8502 - val_sar_accuracy: 0.7166 - val_fus_accuracy: 0.8346 - val_opt_loss: 0.0905 - val_sar_loss: 1.4297 - val_fusion_loss: 0.0939 - val_loss: 1.6140
#
# Epoch 00002: val_loss improved from 1.72717 to 1.61401, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 3/100
# 108/108 [==============================] - 19s 172ms/step - opt_accuracy: 0.7943 - sar_accuracy: 0.6853 - fus_accuracy: 0.7543 - opt_loss: 0.1077 - sar_loss: 1.6093 - fusion_loss: 0.1249 - loss: 1.8419 - val_opt_accuracy: 0.8529 - val_sar_accuracy: 0.7419 - val_fus_accuracy: 0.8448 - val_opt_loss: 0.0904 - val_sar_loss: 1.3638 - val_fusion_loss: 0.0937 - val_loss: 1.5479
#
# Epoch 00003: val_loss improved from 1.61401 to 1.54786, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 4/100
# 108/108 [==============================] - 19s 174ms/step - opt_accuracy: 0.8050 - sar_accuracy: 0.7002 - fus_accuracy: 0.7681 - opt_loss: 0.1012 - sar_loss: 1.5400 - fusion_loss: 0.1179 - loss: 1.7591 - val_opt_accuracy: 0.8527 - val_sar_accuracy: 0.7607 - val_fus_accuracy: 0.8481 - val_opt_loss: 0.0906 - val_sar_loss: 1.3230 - val_fusion_loss: 0.0933 - val_loss: 1.5070
#
# Epoch 00004: val_loss improved from 1.54786 to 1.50697, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 5/100
# 108/108 [==============================] - 19s 174ms/step - opt_accuracy: 0.8116 - sar_accuracy: 0.7085 - fus_accuracy: 0.7758 - opt_loss: 0.0980 - sar_loss: 1.4878 - fusion_loss: 0.1145 - loss: 1.7003 - val_opt_accuracy: 0.8564 - val_sar_accuracy: 0.7677 - val_fus_accuracy: 0.8514 - val_opt_loss: 0.0896 - val_sar_loss: 1.2927 - val_fusion_loss: 0.0928 - val_loss: 1.4751
#
# Epoch 00005: val_loss improved from 1.50697 to 1.47507, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 6/100
# 108/108 [==============================] - 19s 175ms/step - opt_accuracy: 0.8182 - sar_accuracy: 0.7135 - fus_accuracy: 0.7833 - opt_loss: 0.0947 - sar_loss: 1.4552 - fusion_loss: 0.1110 - loss: 1.6610 - val_opt_accuracy: 0.8594 - val_sar_accuracy: 0.7738 - val_fus_accuracy: 0.8554 - val_opt_loss: 0.0906 - val_sar_loss: 1.2664 - val_fusion_loss: 0.0952 - val_loss: 1.4522
#
# Epoch 00006: val_loss improved from 1.47507 to 1.45222, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 7/100
# 108/108 [==============================] - 20s 183ms/step - opt_accuracy: 0.8234 - sar_accuracy: 0.7174 - fus_accuracy: 0.7897 - opt_loss: 0.0925 - sar_loss: 1.4303 - fusion_loss: 0.1086 - loss: 1.6315 - val_opt_accuracy: 0.8574 - val_sar_accuracy: 0.7772 - val_fus_accuracy: 0.8565 - val_opt_loss: 0.0920 - val_sar_loss: 1.2614 - val_fusion_loss: 0.0942 - val_loss: 1.4476
#
# Epoch 00007: val_loss improved from 1.45222 to 1.44756, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 8/100
# 108/108 [==============================] - 19s 178ms/step - opt_accuracy: 0.8270 - sar_accuracy: 0.7208 - fus_accuracy: 0.7958 - opt_loss: 0.0911 - sar_loss: 1.4143 - fusion_loss: 0.1069 - loss: 1.6123 - val_opt_accuracy: 0.8625 - val_sar_accuracy: 0.7796 - val_fus_accuracy: 0.8593 - val_opt_loss: 0.0918 - val_sar_loss: 1.2483 - val_fusion_loss: 0.0958 - val_loss: 1.4359
#
# Epoch 00008: val_loss improved from 1.44756 to 1.43591, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 9/100
# 108/108 [==============================] - 19s 180ms/step - opt_accuracy: 0.8318 - sar_accuracy: 0.7242 - fus_accuracy: 0.8020 - opt_loss: 0.0892 - sar_loss: 1.3978 - fusion_loss: 0.1046 - loss: 1.5916 - val_opt_accuracy: 0.8629 - val_sar_accuracy: 0.7804 - val_fus_accuracy: 0.8589 - val_opt_loss: 0.0922 - val_sar_loss: 1.2381 - val_fusion_loss: 0.0963 - val_loss: 1.4265
#
# Epoch 00009: val_loss improved from 1.43591 to 1.42653, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 10/100
# 108/108 [==============================] - 19s 179ms/step - opt_accuracy: 0.8354 - sar_accuracy: 0.7252 - fus_accuracy: 0.8052 - opt_loss: 0.0871 - sar_loss: 1.3923 - fusion_loss: 0.1028 - loss: 1.5821 - val_opt_accuracy: 0.8647 - val_sar_accuracy: 0.7813 - val_fus_accuracy: 0.8617 - val_opt_loss: 0.0911 - val_sar_loss: 1.2367 - val_fusion_loss: 0.0949 - val_loss: 1.4228
#
# Epoch 00010: val_loss improved from 1.42653 to 1.42276, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 11/100
# 108/108 [==============================] - 19s 180ms/step - opt_accuracy: 0.8372 - sar_accuracy: 0.7271 - fus_accuracy: 0.8073 - opt_loss: 0.0867 - sar_loss: 1.3765 - fusion_loss: 0.1022 - loss: 1.5654 - val_opt_accuracy: 0.8661 - val_sar_accuracy: 0.7831 - val_fus_accuracy: 0.8620 - val_opt_loss: 0.0893 - val_sar_loss: 1.2172 - val_fusion_loss: 0.0928 - val_loss: 1.3993
#
# Epoch 00011: val_loss improved from 1.42276 to 1.39925, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 12/100
# 108/108 [==============================] - 20s 182ms/step - opt_accuracy: 0.8411 - sar_accuracy: 0.7301 - fus_accuracy: 0.8119 - opt_loss: 0.0851 - sar_loss: 1.3675 - fusion_loss: 0.1003 - loss: 1.5529 - val_opt_accuracy: 0.8673 - val_sar_accuracy: 0.7809 - val_fus_accuracy: 0.8645 - val_opt_loss: 0.0837 - val_sar_loss: 1.1875 - val_fusion_loss: 0.0860 - val_loss: 1.3571
#
# Epoch 00012: val_loss improved from 1.39925 to 1.35713, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 13/100
# 108/108 [==============================] - 20s 181ms/step - opt_accuracy: 0.8436 - sar_accuracy: 0.7320 - fus_accuracy: 0.8147 - opt_loss: 0.0835 - sar_loss: 1.3529 - fusion_loss: 0.0987 - loss: 1.5351 - val_opt_accuracy: 0.8651 - val_sar_accuracy: 0.7862 - val_fus_accuracy: 0.8641 - val_opt_loss: 0.0882 - val_sar_loss: 1.1830 - val_fusion_loss: 0.0909 - val_loss: 1.3621
#
# Epoch 00013: val_loss did not improve from 1.35713
# Epoch 14/100
# 108/108 [==============================] - 20s 184ms/step - opt_accuracy: 0.8454 - sar_accuracy: 0.7342 - fus_accuracy: 0.8181 - opt_loss: 0.0836 - sar_loss: 1.3572 - fusion_loss: 0.0983 - loss: 1.5391 - val_opt_accuracy: 0.8622 - val_sar_accuracy: 0.7850 - val_fus_accuracy: 0.8598 - val_opt_loss: 0.0930 - val_sar_loss: 1.2244 - val_fusion_loss: 0.0951 - val_loss: 1.4125
#
# Epoch 00014: val_loss did not improve from 1.35713
# Epoch 15/100
# 108/108 [==============================] - 21s 194ms/step - opt_accuracy: 0.8560 - sar_accuracy: 0.7478 - fus_accuracy: 0.8319 - opt_loss: 0.0776 - sar_loss: 1.2957 - fusion_loss: 0.0918 - loss: 1.4651 - val_opt_accuracy: 0.8672 - val_sar_accuracy: 0.7920 - val_fus_accuracy: 0.8666 - val_opt_loss: 0.0951 - val_sar_loss: 1.1951 - val_fusion_loss: 0.0978 - val_loss: 1.3880
#
# Epoch 00021: val_loss did not improve from 1.35713
# Epoch 22/100
# 108/108 [==============================] - 21s 196ms/step - opt_accuracy: 0.8567 - sar_accuracy: 0.7490 - fus_accuracy: 0.8322 - opt_loss: 0.0773 - sar_loss: 1.2875 - fusion_loss: 0.0912 - loss: 1.4560 - val_opt_accuracy: 0.8674 - val_sar_accuracy: 0.7913 - val_fus_accuracy: 0.8668 - val_opt_loss: 0.0907 - val_sar_loss: 1.1868 - val_fusion_loss: 0.0955 - val_loss: 1.3730
#
# Epoch 00022: val_loss did not improve from 1.35713
# Epoch 00022: early stopping
# time:  4
# Model: "model_3_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# shared_decoder (UNET_Decoder multiple                  332000
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# fus_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 1,409,786
# Trainable params: 1,409,769
# Non-trainable params: 17
# _________________________________________________________________
# Epoch 1/100
# 108/108 [==============================] - 24s 200ms/step - opt_accuracy: 0.6015 - sar_accuracy: 0.6252 - fus_accuracy: 0.6451 - opt_loss: 0.1753 - sar_loss: 1.9687 - fusion_loss: 0.1768 - loss: 2.3207 - val_opt_accuracy: 0.6887 - val_sar_accuracy: 0.6558 - val_fus_accuracy: 0.7029 - val_opt_loss: 0.1219 - val_sar_loss: 1.5024 - val_fusion_loss: 0.1119 - val_loss: 1.7362
#
# Epoch 00001: val_loss improved from inf to 1.73625, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 2/100
# 108/108 [==============================] - 21s 199ms/step - opt_accuracy: 0.7080 - sar_accuracy: 0.6533 - fus_accuracy: 0.7252 - opt_loss: 0.1281 - sar_loss: 1.7111 - fusion_loss: 0.1350 - loss: 1.9742 - val_opt_accuracy: 0.8327 - val_sar_accuracy: 0.6912 - val_fus_accuracy: 0.8243 - val_opt_loss: 0.1005 - val_sar_loss: 1.3631 - val_fusion_loss: 0.0986 - val_loss: 1.5622
#
# Epoch 00002: val_loss improved from 1.73625 to 1.56218, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 3/100
# 108/108 [==============================] - 22s 202ms/step - opt_accuracy: 0.7695 - sar_accuracy: 0.6865 - fus_accuracy: 0.7782 - opt_loss: 0.1103 - sar_loss: 1.5914 - fusion_loss: 0.1177 - loss: 1.8194 - val_opt_accuracy: 0.8470 - val_sar_accuracy: 0.7077 - val_fus_accuracy: 0.8405 - val_opt_loss: 0.0994 - val_sar_loss: 1.2977 - val_fusion_loss: 0.1010 - val_loss: 1.4981
#
# Epoch 00003: val_loss improved from 1.56218 to 1.49813, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 4/100
# 108/108 [==============================] - 22s 203ms/step - opt_accuracy: 0.7928 - sar_accuracy: 0.6939 - fus_accuracy: 0.7940 - opt_loss: 0.1035 - sar_loss: 1.5344 - fusion_loss: 0.1130 - loss: 1.7509 - val_opt_accuracy: 0.8487 - val_sar_accuracy: 0.7156 - val_fus_accuracy: 0.8427 - val_opt_loss: 0.0970 - val_sar_loss: 1.3013 - val_fusion_loss: 0.0983 - val_loss: 1.4966
#
# Epoch 00004: val_loss improved from 1.49813 to 1.49657, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 5/100
# 108/108 [==============================] - 22s 206ms/step - opt_accuracy: 0.8041 - sar_accuracy: 0.6989 - fus_accuracy: 0.7986 - opt_loss: 0.0988 - sar_loss: 1.4940 - fusion_loss: 0.1094 - loss: 1.7022 - val_opt_accuracy: 0.8501 - val_sar_accuracy: 0.7253 - val_fus_accuracy: 0.8470 - val_opt_loss: 0.0969 - val_sar_loss: 1.2644 - val_fusion_loss: 0.0957 - val_loss: 1.4570
#
# Epoch 00005: val_loss improved from 1.49657 to 1.45703, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 6/100
# 108/108 [==============================] - 23s 209ms/step - opt_accuracy: 0.8176 - sar_accuracy: 0.7025 - fus_accuracy: 0.8038 - opt_loss: 0.0945 - sar_loss: 1.4680 - fusion_loss: 0.1059 - loss: 1.6685 - val_opt_accuracy: 0.8534 - val_sar_accuracy: 0.7221 - val_fus_accuracy: 0.8478 - val_opt_loss: 0.0934 - val_sar_loss: 1.2430 - val_fusion_loss: 0.0973 - val_loss: 1.4337
#
# Epoch 00006: val_loss improved from 1.45703 to 1.43372, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 7/100
# 108/108 [==============================] - 23s 210ms/step - opt_accuracy: 0.8236 - sar_accuracy: 0.7059 - fus_accuracy: 0.8092 - opt_loss: 0.0918 - sar_loss: 1.4440 - fusion_loss: 0.1018 - loss: 1.6376 - val_opt_accuracy: 0.8551 - val_sar_accuracy: 0.7373 - val_fus_accuracy: 0.8510 - val_opt_loss: 0.0931 - val_sar_loss: 1.2305 - val_fusion_loss: 0.0951 - val_loss: 1.4187
#
# Epoch 00007: val_loss improved from 1.43372 to 1.41868, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 8/100
# 108/108 [==============================] - 24s 226ms/step - opt_accuracy: 0.8267 - sar_accuracy: 0.7096 - fus_accuracy: 0.8120 - opt_loss: 0.0906 - sar_loss: 1.4294 - fusion_loss: 0.1003 - loss: 1.6203 - val_opt_accuracy: 0.8569 - val_sar_accuracy: 0.7391 - val_fus_accuracy: 0.8527 - val_opt_loss: 0.0918 - val_sar_loss: 1.2432 - val_fusion_loss: 0.0960 - val_loss: 1.4310
#
# Epoch 00008: val_loss did not improve from 1.41868
# Epoch 9/100
# 108/108 [==============================] - 25s 235ms/step - opt_accuracy: 0.8296 - sar_accuracy: 0.7121 - fus_accuracy: 0.8149 - opt_loss: 0.0896 - sar_loss: 1.4178 - fusion_loss: 0.0992 - loss: 1.6066 - val_opt_accuracy: 0.8564 - val_sar_accuracy: 0.7421 - val_fus_accuracy: 0.8517 - val_opt_loss: 0.0908 - val_sar_loss: 1.2103 - val_fusion_loss: 0.0945 - val_loss: 1.3956
#
# Epoch 00009: val_loss improved from 1.41868 to 1.39562, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 10/100
# 108/108 [==============================] - 25s 232ms/step - opt_accuracy: 0.8323 - sar_accuracy: 0.7149 - fus_accuracy: 0.8168 - opt_loss: 0.0880 - sar_loss: 1.4017 - fusion_loss: 0.0976 - loss: 1.5874 - val_opt_accuracy: 0.8576 - val_sar_accuracy: 0.7467 - val_fus_accuracy: 0.8542 - val_opt_loss: 0.0907 - val_sar_loss: 1.2522 - val_fusion_loss: 0.0927 - val_loss: 1.4356
#
# Epoch 00010: val_loss did not improve from 1.39562
# Epoch 11/100
# 108/108 [==============================] - 24s 225ms/step - opt_accuracy: 0.8348 - sar_accuracy: 0.7180 - fus_accuracy: 0.8197 - opt_loss: 0.0863 - sar_loss: 1.3844 - fusion_loss: 0.0955 - loss: 1.5662 - val_opt_accuracy: 0.8594 - val_sar_accuracy: 0.7483 - val_fus_accuracy: 0.8548 - val_opt_loss: 0.0888 - val_sar_loss: 1.2072 - val_fusion_loss: 0.0917 - val_loss: 1.3877
#
# Epoch 00011: val_loss improved from 1.39562 to 1.38766, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 12/100
# 108/108 [==============================] - 24s 223ms/step - opt_accuracy: 0.8351 - sar_accuracy: 0.7195 - fus_accuracy: 0.8198 - opt_loss: 0.0861 - sar_loss: 1.3772 - fusion_loss: 0.0952 - loss: 1.5585 - val_opt_accuracy: 0.8625 - val_sar_accuracy: 0.7511 - val_fus_accuracy: 0.8576 - val_opt_loss: 0.0823 - val_sar_loss: 1.1705 - val_fusion_loss: 0.0857 - val_loss: 1.3384
# Epoch 00012: val_loss improved from 1.38766 to 1.33845, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 13/100
# 108/108 [==============================] - 24s 223ms/step - opt_accuracy: 0.8382 - sar_accuracy: 0.7241 - fus_accuracy: 0.8238 - opt_loss: 0.0838 - sar_loss: 1.3560 - fusion_loss: 0.0928 - loss: 1.5326 - val_opt_accuracy: 0.8619 - val_sar_accuracy: 0.7523 - val_fus_accuracy: 0.8574 - val_opt_loss: 0.0852 - val_sar_loss: 1.1840 - val_fusion_loss: 0.0895 - val_loss: 1.3587
#
# Epoch 00013: val_loss did not improve from 1.33845
# Epoch 14/100
# 108/108 [==============================] - 25s 229ms/step - opt_accuracy: 0.8401 - sar_accuracy: 0.7254 - fus_accuracy: 0.8256 - opt_loss: 0.0836 - sar_loss: 1.3435 - fusion_loss: 0.0924 - loss: 1.5196 - val_opt_accuracy: 0.8578 - val_sar_accuracy: 0.7572 - val_fus_accuracy: 0.8546 - val_opt_loss: 0.0902 - val_sar_loss: 1.2047 - val_fusion_loss: 0.0958 - val_loss: 1.3907
#
# Epoch 00014: val_loss did not improve from 1.33845
# Epoch 15/100
# 108/108 [==============================] - 25s 228ms/step - opt_accuracy: 0.8431 - sar_accuracy: 0.7268 - fus_accuracy: 0.8269 - opt_loss: 0.0823 - sar_loss: 1.3382 - fusion_loss: 0.0914 - loss: 1.5119 - val_opt_accuracy: 0.8576 - val_sar_accuracy: 0.7587 - val_fus_accuracy: 0.8546 - val_opt_loss: 0.0903 - val_sar_loss: 1.1981 - val_fusion_loss: 0.0953 - val_loss: 1.3837
#
# Epoch 00015: val_loss did not improve from 1.33845
# Epoch 16/100
# 108/108 [==============================] - 25s 233ms/step - opt_accuracy: 0.8439 - sar_accuracy: 0.7318 - fus_accuracy: 0.8268 - opt_loss: 0.0823 - sar_loss: 1.3302 - fusion_loss: 0.0913 - loss: 1.5037 - val_opt_accuracy: 0.8582 - val_sar_accuracy: 0.7632 - val_fus_accuracy: 0.8562 - val_opt_loss: 0.0906 - val_sar_loss: 1.2171 - val_fusion_loss: 0.0955 - val_loss: 1.4032
#
# Epoch 00016: val_loss did not improve from 1.33845
# Epoch 17/100
# 108/108 [==============================] - 26s 237ms/step - opt_accuracy: 0.8463 - sar_accuracy: 0.7357 - fus_accuracy: 0.8291 - opt_loss: 0.0817 - sar_loss: 1.3224 - fusion_loss: 0.0907 - loss: 1.4949 - val_opt_accuracy: 0.8584 - val_sar_accuracy: 0.7683 - val_fus_accuracy: 0.8567 - val_opt_loss: 0.0906 - val_sar_loss: 1.1956 - val_fusion_loss: 0.0954 - val_loss: 1.3815
#
# Epoch 00017: val_loss did not improve from 1.33845
# Epoch 18/100
# 108/108 [==============================] - 25s 236ms/step - opt_accuracy: 0.8480 - sar_accuracy: 0.7385 - fus_accuracy: 0.8307 - opt_loss: 0.0802 - sar_loss: 1.3087 - fusion_loss: 0.0892 - loss: 1.4782 - val_opt_accuracy: 0.8594 - val_sar_accuracy: 0.7700 - val_fus_accuracy: 0.8589 - val_opt_loss: 0.0893 - val_sar_loss: 1.1815 - val_fusion_loss: 0.0961 - val_loss: 1.3669.7381 - fus_accuracy: 0.8305 - op - ETA: 5s - opt_accuracy: 0.8476 - sar_accuracy: 0.7381 - fus_accuracy: 0.8302 - opt_loss:
#
# Epoch 00018: val_loss did not improve from 1.33845
# Epoch 19/100
# 108/108 [==============================] - 26s 238ms/step - opt_accuracy: 0.8495 - sar_accuracy: 0.7410 - fus_accuracy: 0.8319 - opt_loss: 0.0791 - sar_loss: 1.2892 - fusion_loss: 0.0883 - loss: 1.4567 - val_opt_accuracy: 0.8588 - val_sar_accuracy: 0.7732 - val_fus_accuracy: 0.8579 - val_opt_loss: 0.0894 - val_sar_loss: 1.1688 - val_fusion_loss: 0.0945 - val_loss: 1.3526
#
# Epoch 00019: val_loss did not improve from 1.33845
# Epoch 20/100
# 108/108 [==============================] - 26s 240ms/step - opt_accuracy: 0.8506 - sar_accuracy: 0.7431 - fus_accuracy: 0.8339 - opt_loss: 0.0782 - sar_loss: 1.2886 - fusion_loss: 0.0872 - loss: 1.4540 - val_opt_accuracy: 0.8608 - val_sar_accuracy: 0.7756 - val_fus_accuracy: 0.8580 - val_opt_loss: 0.0887 - val_sar_loss: 1.1556 - val_fusion_loss: 0.0964 - val_loss: 1.3406
#
# Epoch 00020: val_loss did not improve from 1.33845
# Epoch 21/100
# 108/108 [==============================] - 26s 244ms/step - opt_accuracy: 0.8512 - sar_accuracy: 0.7447 - fus_accuracy: 0.8354 - opt_loss: 0.0777 - sar_loss: 1.2767 - fusion_loss: 0.0864 - loss: 1.4408 - val_opt_accuracy: 0.8602 - val_sar_accuracy: 0.7760 - val_fus_accuracy: 0.8584 - val_opt_loss: 0.0890 - val_sar_loss: 1.1845 - val_fusion_loss: 0.0940 - val_loss: 1.3674
#
# Epoch 00021: val_loss did not improve from 1.33845
# Epoch 22/100
# 108/108 [==============================] - 26s 245ms/step - opt_accuracy: 0.8527 - sar_accuracy: 0.7463 - fus_accuracy: 0.8374 - opt_loss: 0.0769 - sar_loss: 1.2693 - fusion_loss: 0.0854 - loss: 1.4316 - val_opt_accuracy: 0.8616 - val_sar_accuracy: 0.7732 - val_fus_accuracy: 0.8595 - val_opt_loss: 0.0869 - val_sar_loss: 1.1646 - val_fusion_loss: 0.0921 - val_loss: 1.34372708 - fusion
#
# Epoch 00022: val_loss did not improve from 1.33845
# Epoch 00022: early stopping

# %%
# Test loop
time_ts = []
n_pool = 3
n_rows = 5
n_cols = 4
rows, cols = image_array.shape[:2]
pad_rows = rows - np.ceil(rows/(n_rows*2**n_pool))*n_rows*2**n_pool
pad_cols = cols - np.ceil(cols/(n_cols*2**n_pool))*n_cols*2**n_pool
print(pad_rows, pad_cols)

npad = ((0, int(abs(pad_rows))), (0, int(abs(pad_cols))), (0, 0))
image1_pad = np.pad(image_array, pad_width=npad, mode='reflect')

h, w, c = image1_pad.shape
patch_size_rows = h//n_rows
patch_size_cols = w//n_cols
num_patches_x = int(h/patch_size_rows)
num_patches_y = int(w/patch_size_cols)

input_shape=(patch_size_rows,patch_size_cols, c)

#if method == 'unet':
#   new_model = build_unet(input_shape, nb_filters, number_class)

#if method == 'resunet':
#   new_model = build_resunet(input_shape, nb_filters, number_class)

new_model = Model_3(nb_filters, number_class, n_opt_layers)
new_model.build((None,)+input_shape)
adam = Adam(lr = 1e-5 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
new_model.compile(optimizer=adam, loss=loss, metrics=['accuracy'], run_eagerly=True)

for tm in range(0,times):
    print('time: ', tm)
    #model = load_model(path_models+ '/' + method +'_'+str(tm)+'.h5', compile=False)
    
    #for l in range(1, len(model.layers)):
    #    new_model.layers[l].set_weights(model.layers[l].get_weights())
    new_model.load_weights(path_models+ '/' + method +'_'+str(tm)+'.h5')
    
    start_test = time.time()
    patch_opt = []
    patch_sar = []
    patch_fus = []
    patch_comb = []
    
    for i in range(0,num_patches_y):
        for j in range(0,num_patches_x):
            patch = image1_pad[patch_size_rows*j:patch_size_rows*(j+1), patch_size_cols*i:patch_size_cols*(i+1), :]
            pred_opt, pred_sar, pred_fus, pred_comb = new_model.predict(np.expand_dims(patch, axis=0))
            del patch 
            patch_opt.append(pred_opt[:,:,:,1])
            patch_sar.append(pred_sar[:,:,:,1])
            patch_fus.append(pred_fus[:,:,:,1])
            patch_comb.append(pred_comb[:,:,:,1])
            del pred_opt, pred_sar, pred_fus, pred_comb
    end_test =  time.time() - start_test

    patches_pred_opt = np.asarray(patch_opt).astype(np.float32)
    patches_pred_sar = np.asarray(patch_sar).astype(np.float32)
    patches_pred_fus = np.asarray(patch_fus).astype(np.float32)
    patches_pred_comb = np.asarray(patch_comb).astype(np.float32)

    prob_recontructed_opt = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_opt)
    prob_recontructed_sar = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_sar)
    prob_recontructed_fus = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_fus)
    prob_recontructed_comb = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_comb)

    del patches_pred_opt, patches_pred_sar, patches_pred_fus, patches_pred_comb
    np.save(path_maps+'/'+'prob_opt_'+str(tm)+'.npy',prob_recontructed_opt) 
    np.save(path_maps+'/'+'prob_sar_'+str(tm)+'.npy',prob_recontructed_sar) 
    np.save(path_maps+'/'+'prob_fus_'+str(tm)+'.npy',prob_recontructed_fus) 
    np.save(path_maps+'/'+'prob_comb_'+str(tm)+'.npy',prob_recontructed_comb) 

    time_ts.append(end_test)
    del prob_recontructed_opt, prob_recontructed_sar, prob_recontructed_fus, prob_recontructed_comb
    #del model
time_ts_array = np.asarray(time_ts)
# Save test time
np.save(path_exp+'/metrics_ts.npy', time_ts_array)
# Out:
# 0.0 -8.0
# time:  0
# time:  1
# time:  2
# time:  3
# time:  4

# %%
# Compute mean of the tm predictions maps
prob_rec_opt = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_sar = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_fus = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_comb = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))

for tm in range (0, times):
    print(tm)
    prob_rec_opt[:,:,tm] = np.load(path_maps+'/'+'prob_opt_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_sar[:,:,tm] = np.load(path_maps+'/'+'prob_sar_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_fus[:,:,tm] = np.load(path_maps+'/'+'prob_fus_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_comb[:,:,tm] = np.load(path_maps+'/'+'prob_comb_'+str(tm)+'.npy').astype(np.float32)

mean_prob_opt = np.mean(prob_rec_opt, axis = -1)
mean_prob_sar = np.mean(prob_rec_sar, axis = -1)
mean_prob_fus = np.mean(prob_rec_fus, axis = -1)
mean_prob_comb = np.mean(prob_rec_comb, axis = -1)

np.save(path_maps+'/prob_mean_opt.npy', mean_prob_opt)
np.save(path_maps+'/prob_mean_sar.npy', mean_prob_sar)
np.save(path_maps+'/prob_mean_fus.npy', mean_prob_fus)
np.save(path_maps+'/prob_mean_comb.npy', mean_prob_comb)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Plot mean map and reference
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(151)
plt.title('OPT Prediction')
ax1.imshow(mean_prob_opt, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(152)
plt.title('SAR Prediction')
ax1.imshow(mean_prob_sar, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(153)
plt.title('FUSION Prediction')
ax1.imshow(mean_prob_fus, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(154)
plt.title('COMBINATION Prediction')
ax1.imshow(mean_prob_comb, cmap ='jet')
ax1.axis('off')

ax2 = fig.add_subplot(155)
plt.title('Reference')
ax2.imshow(tf.keras.utils.to_categorical(final_mask1, 3)[:,:,1], cmap ='jet')
ax2.axis('off')
# Out:
# (-0.5, 6999.5, 9999.5, -0.5)

# %%
# Computing metrics
mean_prob_opt = mean_prob_opt[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_sar = mean_prob_sar[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_fus = mean_prob_fus[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_comb = mean_prob_comb[:final_mask1.shape[0], :final_mask1.shape[1]]

ref1 = np.ones_like(final_mask1).astype(np.float32)

ref1 [final_mask1 == 2] = 0
TileMask = mask_amazon_ts * ref1
GTTruePositives = final_mask1==1
    
Npoints = 50

Pmax_opt = np.max(mean_prob_opt[GTTruePositives * TileMask ==1])
ProbList_opt = np.linspace(Pmax_opt,0,Npoints)

Pmax_sar = np.max(mean_prob_sar[GTTruePositives * TileMask ==1])
ProbList_sar = np.linspace(Pmax_sar,0,Npoints)

Pmax_fus = np.max(mean_prob_fus[GTTruePositives * TileMask ==1])
ProbList_fus = np.linspace(Pmax_fus,0,Npoints)

Pmax_comb = np.max(mean_prob_comb[GTTruePositives * TileMask ==1])
ProbList_comb = np.linspace(Pmax_comb,0,Npoints)


from multiprocessing.pool import Pool
pool = Pool(processes=4)

async_result_opt = pool.apply_async(matrics_AA_recall, (ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625))
async_result_sar = pool.apply_async(matrics_AA_recall, (ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625))
async_result_fus = pool.apply_async(matrics_AA_recall, (ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625))
async_result_comb = pool.apply_async(matrics_AA_recall, (ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625))

metrics_opt = async_result_opt.get()
metrics_sar = async_result_sar.get()
metrics_fus = async_result_fus.get()
metrics_comb = async_result_comb.get()
    
#metrics_opt = matrics_AA_recall(ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625)
#metrics_sar = matrics_AA_recall(ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625)
#metrics_fus = matrics_AA_recall(ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625)
#metrics_comb = matrics_AA_recall(ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625)

np.save(path_exp+'/acc_metrics_opt.npy',metrics_opt)
np.save(path_exp+'/acc_metrics_sar.npy',metrics_sar)
np.save(path_exp+'/acc_metrics_fus.npy',metrics_fus)
np.save(path_exp+'/acc_metrics_comb.npy',metrics_comb)

# %%
# Complete NaN values
metrics_copy_opt = metrics_opt.copy()
metrics_copy_opt = complete_nan_values(metrics_copy_opt)

metrics_copy_sar = metrics_sar.copy()
metrics_copy_sar = complete_nan_values(metrics_copy_sar)

metrics_copy_fus = metrics_fus.copy()
metrics_copy_fus = complete_nan_values(metrics_copy_fus)

metrics_copy_comb = metrics_comb.copy()
metrics_copy_comb = complete_nan_values(metrics_copy_comb)

# %%
# Comput Mean Average Precision (mAP) score 
Recall_opt = metrics_copy_opt[:,0]
Precision_opt = metrics_copy_opt[:,1]
AA_opt = metrics_copy_opt[:,2]

Recall_sar = metrics_copy_sar[:,0]
Precision_sar = metrics_copy_sar[:,1]
AA_sar = metrics_copy_sar[:,2]

Recall_fus = metrics_copy_fus[:,0]
Precision_fus = metrics_copy_fus[:,1]
AA_fus = metrics_copy_fus[:,2]

Recall_comb = metrics_copy_comb[:,0]
Precision_comb = metrics_copy_comb[:,1]
AA_comb = metrics_copy_comb[:,2]
    
DeltaR_opt = Recall_opt[1:]-Recall_opt[:-1]
AP_opt = np.sum(Precision_opt[:-1]*DeltaR_opt)
print('OPT mAP', AP_opt)

DeltaR_sar = Recall_sar[1:]-Recall_sar[:-1]
AP_sar = np.sum(Precision_sar[:-1]*DeltaR_sar)
print('SAR mAP', AP_sar)

DeltaR_fus = Recall_fus[1:]-Recall_fus[:-1]
AP_fus = np.sum(Precision_fus[:-1]*DeltaR_fus)
print('FUSION mAP', AP_fus)

DeltaR_comb = Recall_comb[1:]-Recall_comb[:-1]
AP_comb = np.sum(Precision_comb[:-1]*DeltaR_comb)
print('COMBINATION mAP', AP_comb)

# Plot Recall vs. Precision curve
plt.figure(figsize=(7,7))
plt.plot(metrics_copy_opt[:,0],metrics_copy_opt[:,1], 'r-', label = f'OPT (AP: {AP_opt:.4f})')
plt.plot(metrics_copy_sar[:,0],metrics_copy_sar[:,1], 'g-', label = f'SAR (AP: {AP_sar:.4f})')
plt.plot(metrics_copy_fus[:,0],metrics_copy_fus[:,1], 'b-', label = f'FUSION (AP: {AP_fus:.4f})')
plt.plot(metrics_copy_comb[:,0],metrics_copy_comb[:,1], 'k-', label = f'COMBINATION (AP: {AP_comb:.4f})')
plt.legend(loc="lower left")
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([0,1])
#plt.plot(metrics_copy[:,0],metrics_copy[:,2])
plt.grid()
# Out:
# OPT mAP 0.9234625468561005
# SAR mAP 0.5385262784456949
# FUSION mAP 0.9296012356025389
# COMBINATION mAP 0.930463690882062
