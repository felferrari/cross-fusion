# %%
# %load_ext autoreload
# %autoreload 2

# %%
#%autoreload # When utils.py is updated
from utils_unet_resunet import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from model.models import Model_4
from model.losses import WBCE
from model.callbacks import UpdateWeights

root_path = 'imgs/'

# %%
# Define data type 
img_type = 'FUSION'

if img_type == 'FUSION':
    image_array = np.load(root_path+'New_Images/fus_stack.npy')
    

if img_type == 'OPT':
    image_array = np.load(root_path+'New_Images/opt_stack.npy')
    
    
if img_type == 'SAR':
    image_array = np.load(root_path+'New_Images/sar_stack.npy')
print('Image stack:', image_array.shape)

final_mask1 = np.load(root_path+'New_Images/'+'final_mask1.npy')
print('Labels stack:', final_mask1.shape)

h_, w_, channels = image_array.shape
n_opt_layers = 20
# Out:
# Image stack: (10000, 7000, 24)
# Labels stack: (10000, 7000)

# %%
# Create tile mask
mask_tiles = create_mask(final_mask1.shape[0], final_mask1.shape[1], grid_size=(5, 4))
image_array = image_array[:mask_tiles.shape[0], :mask_tiles.shape[1],:]
final_mask1 = final_mask1[:mask_tiles.shape[0], :mask_tiles.shape[1]]

print('mask: ',mask_tiles.shape)
print('image stack: ', image_array.shape)
print('ref :', final_mask1.shape)
#plt.imshow(mask_tiles)
# Out:
# Tiles size:  2000 1750
# Mask size:  (10000, 7000)
# mask:  (10000, 7000)
# image stack:  (10000, 7000, 24)
# ref : (10000, 7000)

# %%
plt.figure(figsize=(10,5))
plt.imshow(final_mask1, cmap = 'jet')

# %%
# Define tiles for training, validation, and test sets
tiles_tr = [1,3,5,8,11,13,14,20]
tiles_val = [6,19]
tiles_ts = (list(set(np.arange(20)+1)-set(tiles_tr)-set(tiles_val)))

mask_tr_val = np.zeros((mask_tiles.shape)).astype('float32')
# Training and validation mask
for tr_ in tiles_tr:
    mask_tr_val[mask_tiles == tr_] = 1

for val_ in tiles_val:
    mask_tr_val[mask_tiles == val_] = 2

mask_amazon_ts = np.zeros((mask_tiles.shape)).astype('float32')
for ts_ in tiles_ts:
    mask_amazon_ts[mask_tiles == ts_] = 1

# %%
# Create ixd image to extract patches
overlap = 0.7
patch_size = 128
batch_size = 32
im_idx = create_idx_image(final_mask1)
patches_idx = extract_patches(im_idx, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1,patch_size, patch_size)
patches_mask = extract_patches(mask_tr_val, patch_size=(patch_size, patch_size), overlap=overlap).reshape(-1, patch_size, patch_size)
del im_idx

# %%
# Selecting index trn val and test patches idx
idx_trn = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==patch_size**2))
idx_val = np.squeeze(np.where(patches_mask.sum(axis=(1, 2))==2*patch_size**2))
del patches_mask

patches_idx_trn = patches_idx[idx_trn]
patches_idx_val = patches_idx[idx_val]
del idx_trn, idx_val

print('Number of training patches:  ', len(patches_idx_trn), 'Number of validation patches', len(patches_idx_val))
# Out:
# Number of training patches:   17110 Number of validation patches 4116

# %%
# Extract patches with at least 2% of deforestation class
X_train = retrieve_idx_percentage(final_mask1, patches_idx_trn, patch_size, pertentage = 2)
X_valid = retrieve_idx_percentage(final_mask1, patches_idx_val, patch_size, pertentage = 2)
print(X_train.shape, X_valid.shape)
del patches_idx_trn, patches_idx_val
# Out:
# (1158, 128, 128) (341, 128, 128)

# %%
def batch_generator(batches, image, reference, target_size, number_class):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    image = image.reshape(-1, image.shape[-1])
    reference = reference.reshape(final_mask1.shape[0]*final_mask1.shape[1])
    while True:
        batch_x, batch_y = next(batches)
        batch_x = np.squeeze(batch_x.astype('int64'))
        #print(batch_x.shape)
        batch_img = np.zeros((batch_x.shape[0], target_size, target_size, image.shape[-1]))
        batch_ref = np.zeros((batch_x.shape[0], target_size, target_size, number_class))
        
        for i in range(batch_x.shape[0]):
            if np.random.rand()>0.5:
                batch_x[i] = np.rot90(batch_x[i], 1)
            batch_img[i] = image[batch_x[i]] 
            batch_ref[i] = tf.keras.utils.to_categorical(reference[batch_x[i]] , number_class)
                       
        yield (batch_img, batch_ref)

train_datagen = ImageDataGenerator(horizontal_flip = True,
                                   vertical_flip = True)
valid_datagen = ImageDataGenerator(horizontal_flip = True, 
                                   vertical_flip = True)

y_train = np.zeros((len(X_train)))
y_valid = np.zeros((len(X_valid)))

train_gen = train_datagen.flow(np.expand_dims(X_train, axis = -1), y_train,
                              batch_size=batch_size,
                              shuffle=True)

valid_gen = valid_datagen.flow(np.expand_dims(X_valid, axis = -1), y_valid,
                              batch_size=batch_size,
                              shuffle=False)

number_class = 3
train_gen_crops = batch_generator(train_gen, image_array, final_mask1, patch_size, number_class)
valid_gen_crops = batch_generator(valid_gen, image_array, final_mask1, patch_size, number_class)

# %%
exp = 3
path_exp = root_path+'experiments/exp'+str(exp)
path_models = path_exp+'/models'
path_maps = path_exp+'/pred_maps'

if not os.path.exists(path_exp):
    os.makedirs(path_exp)   
if not os.path.exists(path_models):
    os.makedirs(path_models)   
if not os.path.exists(path_maps):
    os.makedirs(path_maps)

# %%
# Define model
input_shape = (patch_size, patch_size, channels)
nb_filters = [32, 64, 128]

method = 'unet'
if method == 'unet':
   model = build_unet(input_shape, nb_filters, number_class)

if method == 'resunet':
   model = build_resunet(input_shape, nb_filters, number_class)

model = Model_4(nb_filters, number_class, n_opt_layers)

# %%
# Parameters of the model
weights = [0.2, 0.8, 0]
adam = Adam(lr = 1e-4 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
#loss = WBCE(weights = weights)
#loss = WBCE(weights = weights, class_indexes = [0, 1])

# %%
metrics_all = []
times=5
for tm in range(0,times):
    print('time: ', tm)

    rows = patch_size
    cols = patch_size
    adam = Adam(lr = 1e-4 , beta_1=0.9)
    
    loss = weighted_categorical_crossentropy(weights)
    #loss = WBCE(weights = weights)
    #loss = WBCE(weights = weights, class_indexes = [0, 1])

    #if method == 'unet':
    #   model = build_unet(input_shape, nb_filters, number_class)

    #if method == 'resunet':
    #   model = build_resunet(input_shape, nb_filters, number_class)
    
    model = Model_4(nb_filters, number_class, n_opt_layers)
    model.build((None,)+input_shape)
    
    model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
    model.summary()

    earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
    #earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min') ---- val_accuracy
    #checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    checkpoint = ModelCheckpoint(path_models+ '/' + method +'_'+str(tm)+'.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min')
    lr_reduce = ReduceLROnPlateau(factor=0.9, min_delta=0.0001, patience=5, verbose=1)
    updateWeights = UpdateWeights()
    callbacks_list = [earlystop, checkpoint, updateWeights]
    # train the model
    start_training = time.time()
    history = model.fit(train_gen_crops,
                              steps_per_epoch=len(X_train)*3//train_gen.batch_size,
                              validation_data=valid_gen_crops,
                              validation_steps=len(X_valid)*3//valid_gen.batch_size,
                              epochs=100,
                              callbacks=callbacks_list)
    end_training = time.time() - start_training
    metrics_all.append(end_training)
    del model, history
# Out:
# time:  0
# Model: "model_4_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 33s - opt_accuracy: 0.7127 - sar_accuracy: 0.6321 - fus_accuracy: 0.5710 - opt_loss: 0.1490 - sar_loss: 0.1973 - fusion_loss: 0.9529 - loss: 1.2992WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1180s vs `on_train_batch_end` time: 0.1762s). Check your callbacks.
# 108/108 [==============================] - 48s 379ms/step - opt_accuracy: 0.8577 - sar_accuracy: 0.7317 - fus_accuracy: 0.6497 - opt_loss: 0.0877 - sar_loss: 0.1397 - fusion_loss: 0.2956 - loss: 0.5230 - val_opt_accuracy: 0.8554 - val_sar_accuracy: 0.7885 - val_fus_accuracy: 0.7082 - val_opt_loss: 0.1063 - val_sar_loss: 0.1210 - val_fusion_loss: 0.2394 - val_loss: 0.4666
#
# Epoch 00001: val_loss improved from inf to 0.46665, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 2/100
# 108/108 [==============================] - 38s 353ms/step - opt_accuracy: 0.8858 - sar_accuracy: 0.7940 - fus_accuracy: 0.6988 - opt_loss: 0.0688 - sar_loss: 0.1210 - fusion_loss: 0.1543 - loss: 0.3441 - val_opt_accuracy: 0.8589 - val_sar_accuracy: 0.7862 - val_fus_accuracy: 0.7429 - val_opt_loss: 0.0981 - val_sar_loss: 0.1211 - val_fusion_loss: 0.2017 - val_loss: 0.4210
#
# Epoch 00002: val_loss improved from 0.46665 to 0.42096, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 3/100
# 108/108 [==============================] - 38s 355ms/step - opt_accuracy: 0.8894 - sar_accuracy: 0.8105 - fus_accuracy: 0.7893 - opt_loss: 0.0648 - sar_loss: 0.1090 - fusion_loss: 0.1379 - loss: 0.3116 - val_opt_accuracy: 0.8580 - val_sar_accuracy: 0.7871 - val_fus_accuracy: 0.8146 - val_opt_loss: 0.0981 - val_sar_loss: 0.1236 - val_fusion_loss: 0.1923 - val_loss: 0.4139
#
# Epoch 00003: val_loss improved from 0.42096 to 0.41394, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 4/100
# 108/108 [==============================] - 38s 356ms/step - opt_accuracy: 0.8913 - sar_accuracy: 0.8190 - fus_accuracy: 0.8170 - opt_loss: 0.0629 - sar_loss: 0.1046 - fusion_loss: 0.1312 - loss: 0.2986 - val_opt_accuracy: 0.8655 - val_sar_accuracy: 0.7969 - val_fus_accuracy: 0.8208 - val_opt_loss: 0.0852 - val_sar_loss: 0.1107 - val_fusion_loss: 0.1576 - val_loss: 0.3534
#
# Epoch 00004: val_loss improved from 0.41394 to 0.35342, saving model to imgs/experiments/exp3/models\unet_0.h5
# Epoch 5/100
# 108/108 [==============================] - 39s 357ms/step - opt_accuracy: 0.8934 - sar_accuracy: 0.8239 - fus_accuracy: 0.8266 - opt_loss: 0.0610 - sar_loss: 0.1002 - fusion_loss: 0.1280 - loss: 0.2893 - val_opt_accuracy: 0.8657 - val_sar_accuracy: 0.8041 - val_fus_accuracy: 0.8395 - val_opt_loss: 0.0909 - val_sar_loss: 0.1151 - val_fusion_loss: 0.1761 - val_loss: 0.3821
#
# Epoch 00005: val_loss did not improve from 0.35342
# Epoch 6/100
# 108/108 [==============================] - 39s 358ms/step - opt_accuracy: 0.8951 - sar_accuracy: 0.8339 - fus_accuracy: 0.8378 - opt_loss: 0.0597 - sar_loss: 0.0950 - fusion_loss: 0.1231 - loss: 0.2779 - val_opt_accuracy: 0.8552 - val_sar_accuracy: 0.8031 - val_fus_accuracy: 0.8382 - val_opt_loss: 0.1083 - val_sar_loss: 0.1132 - val_fusion_loss: 0.1816 - val_loss: 0.4031
#
# Epoch 00006: val_loss did not improve from 0.35342
# Epoch 7/100
# 108/108 [==============================] - 39s 358ms/step - opt_accuracy: 0.8959 - sar_accuracy: 0.8370 - fus_accuracy: 0.8408 - opt_loss: 0.0587 - sar_loss: 0.0921 - fusion_loss: 0.1215 - loss: 0.2724 - val_opt_accuracy: 0.8621 - val_sar_accuracy: 0.8022 - val_fus_accuracy: 0.8417 - val_opt_loss: 0.1026 - val_sar_loss: 0.1091 - val_fusion_loss: 0.1808 - val_loss: 0.3926
#
# Epoch 00007: val_loss did not improve from 0.35342
# Epoch 8/100
# 108/108 [==============================] - 39s 359ms/step - opt_accuracy: 0.9089 - sar_accuracy: 0.8585 - fus_accuracy: 0.8644 - opt_loss: 0.0468 - sar_loss: 0.0773 - fusion_loss: 0.1063 - loss: 0.2304 - val_opt_accuracy: 0.8671 - val_sar_accuracy: 0.8147 - val_fus_accuracy: 0.8451 - val_opt_loss: 0.1097 - val_sar_loss: 0.1220 - val_fusion_loss: 0.2083 - val_loss: 0.4400
#
# Epoch 00014: val_loss did not improve from 0.35342
# Epoch 00014: early stopping
# time:  1
# Model: "model_4_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 29s - opt_accuracy: 0.5842 - sar_accuracy: 0.6733 - fus_accuracy: 0.5586 - opt_loss: 0.1578 - sar_loss: 0.1559 - fusion_loss: 0.9467 - loss: 1.2603WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1041s vs `on_train_batch_end` time: 0.1929s). Check your callbacks.
# 108/108 [==============================] - 42s 363ms/step - opt_accuracy: 0.8327 - sar_accuracy: 0.7613 - fus_accuracy: 0.6611 - opt_loss: 0.0907 - sar_loss: 0.1320 - fusion_loss: 0.2805 - loss: 0.5032 - val_opt_accuracy: 0.8664 - val_sar_accuracy: 0.7830 - val_fus_accuracy: 0.7191 - val_opt_loss: 0.0928 - val_sar_loss: 0.1167 - val_fusion_loss: 0.2762 - val_loss: 0.4856
#
# Epoch 00001: val_loss improved from inf to 0.48563, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 2/100
# 108/108 [==============================] - 39s 358ms/step - opt_accuracy: 0.8830 - sar_accuracy: 0.8003 - fus_accuracy: 0.7185 - opt_loss: 0.0699 - sar_loss: 0.1142 - fusion_loss: 0.1488 - loss: 0.3329 - val_opt_accuracy: 0.8662 - val_sar_accuracy: 0.7912 - val_fus_accuracy: 0.7500 - val_opt_loss: 0.0949 - val_sar_loss: 0.1176 - val_fusion_loss: 0.2462 - val_loss: 0.4586
#
# Epoch 00002: val_loss improved from 0.48563 to 0.45859, saving model to imgs/experiments/exp3/models\unet_1.h5
# Epoch 3/100
# 108/108 [==============================] - 39s 359ms/step - opt_accuracy: 0.8869 - sar_accuracy: 0.8103 - fus_accuracy: 0.7813 - opt_loss: 0.0678 - sar_loss: 0.1083 - fusion_loss: 0.1361 - loss: 0.3122 - val_opt_accuracy: 0.8524 - val_sar_accuracy: 0.7891 - val_fus_accuracy: 0.7813 - val_opt_loss: 0.1262 - val_sar_loss: 0.1179 - val_fusion_loss: 0.1751 - val_loss: 0.4192
#
# Epoch 00009: val_loss did not improve from 0.41921
# Epoch 10/100
# 108/108 [==============================] - 39s 359ms/step - opt_accuracy: 0.9026 - sar_accuracy: 0.8486 - fus_accuracy: 0.8561 - opt_loss: 0.0522 - sar_loss: 0.0845 - fusion_loss: 0.1123 - loss: 0.2491 - val_opt_accuracy: 0.8627 - val_sar_accuracy: 0.8175 - val_fus_accuracy: 0.8451 - val_opt_loss: 0.1469 - val_sar_loss: 0.1197 - val_fusion_loss: 0.2396 - val_loss: 0.5061
#
# Epoch 00010: val_loss did not improve from 0.41921
# Epoch 11/100
# 108/108 [==============================] - 39s 359ms/step - opt_accuracy: 0.9033 - sar_accuracy: 0.8516 - fus_accuracy: 0.8585 - opt_loss: 0.0515 - sar_loss: 0.0816 - fusion_loss: 0.1103 - loss: 0.2434 - val_opt_accuracy: 0.8637 - val_sar_accuracy: 0.8160 - val_fus_accuracy: 0.8424 - val_opt_loss: 0.1404 - val_sar_loss: 0.1203 - val_fusion_loss: 0.2437 - val_loss: 0.5043
#
# Epoch 00011: val_loss did not improve from 0.41921
# Epoch 12/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.9053 - sar_accuracy: 0.8555 - fus_accuracy: 0.8610 - opt_loss: 0.0496 - sar_loss: 0.0798 - fusion_loss: 0.1081 - loss: 0.2375 - val_opt_accuracy: 0.8573 - val_sar_accuracy: 0.8083 - val_fus_accuracy: 0.8361 - val_opt_loss: 0.1236 - val_sar_loss: 0.1243 - val_fusion_loss: 0.2655 - val_loss: 0.5134
#
# Epoch 00012: val_loss did not improve from 0.41921
# Epoch 13/100
# 108/108 [==============================] - 39s 359ms/step - opt_accuracy: 0.9074 - sar_accuracy: 0.8570 - fus_accuracy: 0.8615 - opt_loss: 0.0474 - sar_loss: 0.0780 - fusion_loss: 0.1067 - loss: 0.2321 - val_opt_accuracy: 0.8630 - val_sar_accuracy: 0.8189 - val_fus_accuracy: 0.8433 - val_opt_loss: 0.1181 - val_sar_loss: 0.1148 - val_fusion_loss: 0.2720 - val_loss: 0.5048
#
# Epoch 00013: val_loss did not improve from 0.41921
# Epoch 00013: early stopping
# time:  2
# Model: "model_4_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 29s - opt_accuracy: 0.7023 - sar_accuracy: 0.6685 - fus_accuracy: 0.6209 - opt_loss: 0.1583 - sar_loss: 0.1632 - fusion_loss: 1.0331 - loss: 1.3546WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1057s vs `on_train_batch_end` time: 0.1892s). Check your callbacks.
# 108/108 [==============================] - 42s 363ms/step - opt_accuracy: 0.8567 - sar_accuracy: 0.7659 - fus_accuracy: 0.6798 - opt_loss: 0.0880 - sar_loss: 0.1335 - fusion_loss: 0.2878 - loss: 0.5093 - val_opt_accuracy: 0.8572 - val_sar_accuracy: 0.7813 - val_fus_accuracy: 0.7216 - val_opt_loss: 0.1046 - val_sar_loss: 0.1293 - val_fusion_loss: 0.2438 - val_loss: 0.4777
#
# Epoch 00001: val_loss improved from inf to 0.47775, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 2/100
# 108/108 [==============================] - 39s 359ms/step - opt_accuracy: 0.8832 - sar_accuracy: 0.8007 - fus_accuracy: 0.7583 - opt_loss: 0.0692 - sar_loss: 0.1173 - fusion_loss: 0.1438 - loss: 0.3303 - val_opt_accuracy: 0.8603 - val_sar_accuracy: 0.7906 - val_fus_accuracy: 0.7220 - val_opt_loss: 0.1048 - val_sar_loss: 0.1337 - val_fusion_loss: 0.1863 - val_loss: 0.4247
#
# Epoch 00002: val_loss improved from 0.47775 to 0.42474, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 3/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.8875 - sar_accuracy: 0.8180 - fus_accuracy: 0.8115 - opt_loss: 0.0656 - sar_loss: 0.1043 - fusion_loss: 0.1310 - loss: 0.3008 - val_opt_accuracy: 0.8577 - val_sar_accuracy: 0.7932 - val_fus_accuracy: 0.8180 - val_opt_loss: 0.1050 - val_sar_loss: 0.1200 - val_fusion_loss: 0.2093 - val_loss: 0.4343
#
# Epoch 00003: val_loss did not improve from 0.42474
# Epoch 4/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.8901 - sar_accuracy: 0.8278 - fus_accuracy: 0.8315 - opt_loss: 0.0630 - sar_loss: 0.0983 - fusion_loss: 0.1252 - loss: 0.2866 - val_opt_accuracy: 0.8620 - val_sar_accuracy: 0.8100 - val_fus_accuracy: 0.8321 - val_opt_loss: 0.1135 - val_sar_loss: 0.1173 - val_fusion_loss: 0.1769 - val_loss: 0.4077
#
# Epoch 00004: val_loss improved from 0.42474 to 0.40768, saving model to imgs/experiments/exp3/models\unet_2.h5
# Epoch 5/100
# 108/108 [==============================] - 39s 359ms/step - opt_accuracy: 0.8930 - sar_accuracy: 0.8346 - fus_accuracy: 0.8400 - opt_loss: 0.0610 - sar_loss: 0.0933 - fusion_loss: 0.1209 - loss: 0.2752 - val_opt_accuracy: 0.8570 - val_sar_accuracy: 0.8095 - val_fus_accuracy: 0.8368 - val_opt_loss: 0.1093 - val_sar_loss: 0.1123 - val_fusion_loss: 0.2163 - val_loss: 0.4379
#
# Epoch 00005: val_loss did not improve from 0.40768
#
# Epoch 00011: val_loss did not improve from 0.40768
# Epoch 12/100
# 108/108 [==============================] - 40s 373ms/step - opt_accuracy: 0.9048 - sar_accuracy: 0.8538 - fus_accuracy: 0.8606 - opt_loss: 0.0503 - sar_loss: 0.0815 - fusion_loss: 0.1079 - loss: 0.2397 - val_opt_accuracy: 0.8579 - val_sar_accuracy: 0.8136 - val_fus_accuracy: 0.8424 - val_opt_loss: 0.1334 - val_sar_loss: 0.1133 - val_fusion_loss: 0.2275 - val_loss: 0.4742
#
# Epoch 00012: val_loss did not improve from 0.40768
# Epoch 13/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.9080 - sar_accuracy: 0.8562 - fus_accuracy: 0.8632 - opt_loss: 0.0474 - sar_loss: 0.0793 - fusion_loss: 0.1057 - loss: 0.2324 - val_opt_accuracy: 0.8542 - val_sar_accuracy: 0.8101 - val_fus_accuracy: 0.8402 - val_opt_loss: 0.1537 - val_sar_loss: 0.1202 - val_fusion_loss: 0.2565 - val_loss: 0.5305
#
# Epoch 00013: val_loss did not improve from 0.40768
# Epoch 14/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.9102 - sar_accuracy: 0.8586 - fus_accuracy: 0.8644 - opt_loss: 0.0457 - sar_loss: 0.0778 - fusion_loss: 0.1039 - loss: 0.2274 - val_opt_accuracy: 0.8532 - val_sar_accuracy: 0.8185 - val_fus_accuracy: 0.8425 - val_opt_loss: 0.1239 - val_sar_loss: 0.1207 - val_fusion_loss: 0.2442 - val_loss: 0.4888
#
# Epoch 00014: val_loss did not improve from 0.40768
# Epoch 00014: early stopping
# time:  3
# Model: "model_4_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 34s - opt_accuracy: 0.7314 - sar_accuracy: 0.6672 - fus_accuracy: 0.5729 - opt_loss: 0.1505 - sar_loss: 0.1586 - fusion_loss: 1.1594 - loss: 1.4686WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1209s vs `on_train_batch_end` time: 0.2171s). Check your callbacks.
# 108/108 [==============================] - 42s 364ms/step - opt_accuracy: 0.8501 - sar_accuracy: 0.7601 - fus_accuracy: 0.6608 - opt_loss: 0.0924 - sar_loss: 0.1345 - fusion_loss: 0.3423 - loss: 0.5691 - val_opt_accuracy: 0.8588 - val_sar_accuracy: 0.7901 - val_fus_accuracy: 0.7593 - val_opt_loss: 0.0944 - val_sar_loss: 0.1219 - val_fusion_loss: 0.3445 - val_loss: 0.5609
#
# Epoch 00001: val_loss improved from inf to 0.56091, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 2/100
# 108/108 [==============================] - 39s 359ms/step - opt_accuracy: 0.8804 - sar_accuracy: 0.7945 - fus_accuracy: 0.7474 - opt_loss: 0.0699 - sar_loss: 0.1181 - fusion_loss: 0.1571 - loss: 0.3450 - val_opt_accuracy: 0.8573 - val_sar_accuracy: 0.7860 - val_fus_accuracy: 0.7988 - val_opt_loss: 0.0946 - val_sar_loss: 0.1278 - val_fusion_loss: 0.2174 - val_loss: 0.4398
#
# Epoch 00002: val_loss improved from 0.56091 to 0.43983, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 3/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.8871 - sar_accuracy: 0.8113 - fus_accuracy: 0.7768 - opt_loss: 0.0650 - sar_loss: 0.1091 - fusion_loss: 0.1397 - loss: 0.3137 - val_opt_accuracy: 0.8613 - val_sar_accuracy: 0.7949 - val_fus_accuracy: 0.7967 - val_opt_loss: 0.0927 - val_sar_loss: 0.1164 - val_fusion_loss: 0.1930 - val_loss: 0.4021
#
# Epoch 00003: val_loss improved from 0.43983 to 0.40205, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 4/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.8912 - sar_accuracy: 0.8212 - fus_accuracy: 0.7955 - opt_loss: 0.0618 - sar_loss: 0.1024 - fusion_loss: 0.1321 - loss: 0.2963 - val_opt_accuracy: 0.8604 - val_sar_accuracy: 0.7946 - val_fus_accuracy: 0.8236 - val_opt_loss: 0.0998 - val_sar_loss: 0.1131 - val_fusion_loss: 0.1842 - val_loss: 0.3972
#
# Epoch 00004: val_loss improved from 0.40205 to 0.39720, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 5/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.8936 - sar_accuracy: 0.8267 - fus_accuracy: 0.8097 - opt_loss: 0.0603 - sar_loss: 0.0990 - fusion_loss: 0.1273 - loss: 0.2866 - val_opt_accuracy: 0.8652 - val_sar_accuracy: 0.8073 - val_fus_accuracy: 0.8204 - val_opt_loss: 0.0933 - val_sar_loss: 0.1153 - val_fusion_loss: 0.1854 - val_loss: 0.3940
#
# Epoch 00005: val_loss improved from 0.39720 to 0.39399, saving model to imgs/experiments/exp3/models\unet_3.h5
# Epoch 6/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.8954 - sar_accuracy: 0.8346 - fus_accuracy: 0.8253 - opt_loss: 0.0582 - sar_loss: 0.0942 - fusion_loss: 0.1237 - loss: 0.2760 - val_opt_accuracy: 0.8611 - val_sar_accuracy: 0.8067 - val_fus_accuracy: 0.8327 - val_opt_loss: 0.1051 - val_sar_loss: 0.1146 - val_fusion_loss: 0.1917 - val_loss: 0.4113
#
#
# Epoch 00012: val_loss did not improve from 0.37312
# Epoch 13/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.9078 - sar_accuracy: 0.8552 - fus_accuracy: 0.8598 - opt_loss: 0.0480 - sar_loss: 0.0799 - fusion_loss: 0.1086 - loss: 0.2365 - val_opt_accuracy: 0.8612 - val_sar_accuracy: 0.8194 - val_fus_accuracy: 0.8437 - val_opt_loss: 0.1202 - val_sar_loss: 0.1162 - val_fusion_loss: 0.2218 - val_loss: 0.4582
#
# Epoch 00013: val_loss did not improve from 0.37312
# Epoch 14/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.9094 - sar_accuracy: 0.8559 - fus_accuracy: 0.8611 - opt_loss: 0.0471 - sar_loss: 0.0801 - fusion_loss: 0.1079 - loss: 0.2351 - val_opt_accuracy: 0.8608 - val_sar_accuracy: 0.8216 - val_fus_accuracy: 0.8449 - val_opt_loss: 0.1007 - val_sar_loss: 0.1123 - val_fusion_loss: 0.2010 - val_loss: 0.4141
#
# Epoch 00014: val_loss did not improve from 0.37312
# Epoch 15/100
# 108/108 [==============================] - 39s 361ms/step - opt_accuracy: 0.9097 - sar_accuracy: 0.8573 - fus_accuracy: 0.8630 - opt_loss: 0.0458 - sar_loss: 0.0787 - fusion_loss: 0.1062 - loss: 0.2307 - val_opt_accuracy: 0.8567 - val_sar_accuracy: 0.8238 - val_fus_accuracy: 0.8404 - val_opt_loss: 0.1201 - val_sar_loss: 0.1172 - val_fusion_loss: 0.2255 - val_loss: 0.4629
#
# Epoch 00015: val_loss did not improve from 0.37312
# Epoch 16/100
# 108/108 [==============================] - 39s 361ms/step - opt_accuracy: 0.9123 - sar_accuracy: 0.8613 - fus_accuracy: 0.8654 - opt_loss: 0.0438 - sar_loss: 0.0749 - fusion_loss: 0.1037 - loss: 0.2224 - val_opt_accuracy: 0.8654 - val_sar_accuracy: 0.8171 - val_fus_accuracy: 0.8475 - val_opt_loss: 0.0990 - val_sar_loss: 0.1112 - val_fusion_loss: 0.2015 - val_loss: 0.4116
#
# Epoch 00016: val_loss did not improve from 0.37312
# Epoch 17/100
# 108/108 [==============================] - 39s 361ms/step - opt_accuracy: 0.9134 - sar_accuracy: 0.8628 - fus_accuracy: 0.8674 - opt_loss: 0.0430 - sar_loss: 0.0743 - fusion_loss: 0.1029 - loss: 0.2203 - val_opt_accuracy: 0.8621 - val_sar_accuracy: 0.8156 - val_fus_accuracy: 0.8408 - val_opt_loss: 0.1113 - val_sar_loss: 0.1324 - val_fusion_loss: 0.2249 - val_loss: 0.4687
#
# Epoch 00017: val_loss did not improve from 0.37312
# Epoch 00017: early stopping
# time:  4
# Model: "model_4_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# opt_encoder (UNET_Encoder)   multiple                  540896
# _________________________________________________________________
# sar_encoder (UNET_Encoder)   multiple                  536288
# _________________________________________________________________
# opt_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# sar_decoder (UNET_Decoder)   multiple                  332000
# _________________________________________________________________
# fus_cross (CrossFusion)      multiple                  518531
# _________________________________________________________________
# opt_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# sar_classifier (Classifier)  multiple                  195
# _________________________________________________________________
# combination (CombinationLaye multiple                  3
# =================================================================
# Total params: 2,260,122
# Trainable params: 2,259,209
# Non-trainable params: 913
# _________________________________________________________________
# Epoch 1/100
#   6/108 [>.............................] - ETA: 34s - opt_accuracy: 0.7038 - sar_accuracy: 0.6993 - fus_accuracy: 0.6489 - opt_loss: 0.1570 - sar_loss: 0.1556 - fusion_loss: 0.9367 - loss: 1.2492WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1251s vs `on_train_batch_end` time: 0.2140s). Check your callbacks.
# 108/108 [==============================] - 42s 368ms/step - opt_accuracy: 0.8427 - sar_accuracy: 0.7579 - fus_accuracy: 0.7067 - opt_loss: 0.0926 - sar_loss: 0.1343 - fusion_loss: 0.2739 - loss: 0.5007 - val_opt_accuracy: 0.8626 - val_sar_accuracy: 0.7750 - val_fus_accuracy: 0.7178 - val_opt_loss: 0.0885 - val_sar_loss: 0.1171 - val_fusion_loss: 0.2409 - val_loss: 0.4466
#
# Epoch 00001: val_loss improved from inf to 0.44658, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 2/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.8816 - sar_accuracy: 0.7963 - fus_accuracy: 0.7225 - opt_loss: 0.0691 - sar_loss: 0.1200 - fusion_loss: 0.1445 - loss: 0.3335 - val_opt_accuracy: 0.8652 - val_sar_accuracy: 0.7867 - val_fus_accuracy: 0.7294 - val_opt_loss: 0.0858 - val_sar_loss: 0.1135 - val_fusion_loss: 0.1924 - val_loss: 0.3917
#
# Epoch 00002: val_loss improved from 0.44658 to 0.39167, saving model to imgs/experiments/exp3/models\unet_4.h5
# Epoch 3/100
# 108/108 [==============================] - 39s 361ms/step - opt_accuracy: 0.8873 - sar_accuracy: 0.8148 - fus_accuracy: 0.7548 - opt_loss: 0.0653 - sar_loss: 0.1076 - fusion_loss: 0.1333 - loss: 0.3062 - val_opt_accuracy: 0.8614 - val_sar_accuracy: 0.8014 - val_fus_accuracy: 0.7721 - val_opt_loss: 0.0938 - val_sar_loss: 0.1217 - val_fusion_loss: 0.1911 - val_loss: 0.4067
#
# Epoch 00003: val_loss did not improve from 0.39167
# Epoch 4/100
# 108/108 [==============================] - 39s 360ms/step - opt_accuracy: 0.8896 - sar_accuracy: 0.8259 - fus_accuracy: 0.8124 - opt_loss: 0.0631 - sar_loss: 0.0993 - fusion_loss: 0.1265 - loss: 0.2888 - val_opt_accuracy: 0.8575 - val_sar_accuracy: 0.8024 - val_fus_accuracy: 0.7901 - val_opt_loss: 0.0992 - val_sar_loss: 0.1156 - val_fusion_loss: 0.2026 - val_loss: 0.4175
#
# Epoch 00004: val_loss did not improve from 0.39167
# Epoch 5/100
# 108/108 [==============================] - 39s 361ms/step - opt_accuracy: 0.8923 - sar_accuracy: 0.8339 - fus_accuracy: 0.8339 - opt_loss: 0.0615 - sar_loss: 0.0938 - fusion_loss: 0.1230 - loss: 0.2783 - val_opt_accuracy: 0.8644 - val_sar_accuracy: 0.8077 - val_fus_accuracy: 0.8275 - val_opt_loss: 0.1059 - val_sar_loss: 0.1232 - val_fusion_loss: 0.2047 - val_loss: 0.4338
#
# Epoch 00005: val_loss did not improve from 0.39167
# Epoch 6/100
# 108/108 [==============================] - 39s 364ms/step - opt_accuracy: 0.8943 - sar_accuracy: 0.8369 - fus_accuracy: 0.8423 - opt_loss: 0.0602 - sar_loss: 0.0931 - fusion_loss: 0.1200 - loss: 0.2733 - val_opt_accuracy: 0.8602 - val_sar_accuracy: 0.8060 - val_fus_accuracy: 0.8210 - val_opt_loss: 0.1089 - val_sar_loss: 0.1144 - val_fusion_loss: 0.2065 - val_loss: 0.4298
#
# Epoch 00006: val_loss did not improve from 0.39167
# Epoch 7/100
# 108/108 [==============================] - 39s 361ms/step - opt_accuracy: 0.8971 - sar_accuracy: 0.8416 - fus_accuracy: 0.8468 - opt_loss: 0.0580 - sar_loss: 0.0899 - fusion_loss: 0.1180 - loss: 0.2659 - val_opt_accuracy: 0.8582 - val_sar_accuracy: 0.8122 - val_fus_accuracy: 0.8339 - val_opt_loss: 0.1155 - val_sar_loss: 0.1222 - val_fusion_loss: 0.2032 - val_loss: 0.4408
#
# Epoch 00007: val_loss did not improve from 0.39167
# Epoch 8/100
# 108/108 [==============================] - 39s 362ms/step - opt_accuracy: 0.8986 - sar_accuracy: 0.8458 - fus_accuracy: 0.8514 - opt_loss: 0.0565 - sar_loss: 0.0865 - fusion_loss: 0.1154 - loss: 0.2583 - val_opt_accuracy: 0.8647 - val_sar_accuracy: 0.8136 - val_fus_accuracy: 0.8375 - val_opt_loss: 0.1040 - val_sar_loss: 0.1098 - val_fusion_loss: 0.2341 - val_loss: 0.4480
#
# Epoch 00008: val_loss did not improve from 0.39167
# Epoch 9/100
# 108/108 [==============================] - 39s 363ms/step - opt_accuracy: 0.8988 - sar_accuracy: 0.8469 - fus_accuracy: 0.8532 - opt_loss: 0.0560 - sar_loss: 0.0861 - fusion_loss: 0.1134 - loss: 0.2555 - val_opt_accuracy: 0.8627 - val_sar_accuracy: 0.8176 - val_fus_accuracy: 0.8419 - val_opt_loss: 0.1030 - val_sar_loss: 0.1169 - val_fusion_loss: 0.2210 - val_loss: 0.4409
#
# Epoch 00009: val_loss did not improve from 0.39167
# Epoch 10/100
# 108/108 [==============================] - 40s 372ms/step - opt_accuracy: 0.9013 - sar_accuracy: 0.8494 - fus_accuracy: 0.8562 - opt_loss: 0.0540 - sar_loss: 0.0845 - fusion_loss: 0.1114 - loss: 0.2499 - val_opt_accuracy: 0.8589 - val_sar_accuracy: 0.8200 - val_fus_accuracy: 0.8441 - val_opt_loss: 0.1021 - val_sar_loss: 0.1112 - val_fusion_loss: 0.2003 - val_loss: 0.4136
#
# Epoch 00010: val_loss did not improve from 0.39167
# Epoch 11/100
# 108/108 [==============================] - 39s 364ms/step - opt_accuracy: 0.9030 - sar_accuracy: 0.8536 - fus_accuracy: 0.8580 - opt_loss: 0.0527 - sar_loss: 0.0820 - fusion_loss: 0.1101 - loss: 0.2448 - val_opt_accuracy: 0.8663 - val_sar_accuracy: 0.8186 - val_fus_accuracy: 0.8454 - val_opt_loss: 0.0996 - val_sar_loss: 0.1122 - val_fusion_loss: 0.2263 - val_loss: 0.4380
#
# Epoch 00011: val_loss did not improve from 0.39167
# Epoch 12/100
# 108/108 [==============================] - 39s 364ms/step - opt_accuracy: 0.9043 - sar_accuracy: 0.8565 - fus_accuracy: 0.8610 - opt_loss: 0.0511 - sar_loss: 0.0799 - fusion_loss: 0.1079 - loss: 0.2389 - val_opt_accuracy: 0.8632 - val_sar_accuracy: 0.8131 - val_fus_accuracy: 0.8455 - val_opt_loss: 0.0984 - val_sar_loss: 0.1061 - val_fusion_loss: 0.2408 - val_loss: 0.4453
#
# Epoch 00012: val_loss did not improve from 0.39167
# Epoch 00012: early stopping

# %%
# Test loop
time_ts = []
n_pool = 3
n_rows = 20 #5
n_cols = 16 #4
rows, cols = image_array.shape[:2]
pad_rows = rows - np.ceil(rows/(n_rows*2**n_pool))*n_rows*2**n_pool
pad_cols = cols - np.ceil(cols/(n_cols*2**n_pool))*n_cols*2**n_pool
print(pad_rows, pad_cols)

npad = ((0, int(abs(pad_rows))), (0, int(abs(pad_cols))), (0, 0))
image1_pad = np.pad(image_array, pad_width=npad, mode='reflect')

h, w, c = image1_pad.shape
patch_size_rows = h//n_rows
patch_size_cols = w//n_cols
num_patches_x = int(h/patch_size_rows)
num_patches_y = int(w/patch_size_cols)

input_shape=(patch_size_rows,patch_size_cols, c)

#if method == 'unet':
#   new_model = build_unet(input_shape, nb_filters, number_class)

#if method == 'resunet':
#   new_model = build_resunet(input_shape, nb_filters, number_class)

new_model = Model_4(nb_filters, number_class, n_opt_layers)
new_model.build((None,)+input_shape)
adam = Adam(lr = 1e-3 , beta_1=0.9)
loss = weighted_categorical_crossentropy(weights)
new_model.compile(optimizer=adam, loss=loss, metrics=['accuracy'], run_eagerly=True)

for tm in range(0,times):
    print('time: ', tm)
    #model = load_model(path_models+ '/' + method +'_'+str(tm)+'.h5', compile=False)
    
    #for l in range(1, len(model.layers)):
    #    new_model.layers[l].set_weights(model.layers[l].get_weights())
    new_model.load_weights(path_models+ '/' + method +'_'+str(tm)+'.h5')
    
    start_test = time.time()
    patch_opt = []
    patch_sar = []
    patch_fus = []
    patch_comb = []
    
    for i in range(0,num_patches_y):
        for j in range(0,num_patches_x):
            patch = image1_pad[patch_size_rows*j:patch_size_rows*(j+1), patch_size_cols*i:patch_size_cols*(i+1), :]
            pred_opt, pred_sar, pred_fus, pred_comb = new_model.predict(np.expand_dims(patch, axis=0))
            del patch 
            patch_opt.append(pred_opt[:,:,:,1])
            patch_sar.append(pred_sar[:,:,:,1])
            patch_fus.append(pred_fus[:,:,:,1])
            patch_comb.append(pred_comb[:,:,:,1])
            del pred_opt, pred_sar, pred_fus, pred_comb
    end_test =  time.time() - start_test

    patches_pred_opt = np.asarray(patch_opt).astype(np.float32)
    patches_pred_sar = np.asarray(patch_sar).astype(np.float32)
    patches_pred_fus = np.asarray(patch_fus).astype(np.float32)
    patches_pred_comb = np.asarray(patch_comb).astype(np.float32)

    prob_recontructed_opt = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_opt)
    prob_recontructed_sar = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_sar)
    prob_recontructed_fus = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_fus)
    prob_recontructed_comb = pred_reconctruct(h, w, num_patches_x, num_patches_y, patch_size_rows, patch_size_cols, patches_pred_comb)

    del patches_pred_opt, patches_pred_sar, patches_pred_fus, patches_pred_comb
    np.save(path_maps+'/'+'prob_opt_'+str(tm)+'.npy',prob_recontructed_opt) 
    np.save(path_maps+'/'+'prob_sar_'+str(tm)+'.npy',prob_recontructed_sar) 
    np.save(path_maps+'/'+'prob_fus_'+str(tm)+'.npy',prob_recontructed_fus) 
    np.save(path_maps+'/'+'prob_comb_'+str(tm)+'.npy',prob_recontructed_comb) 

    time_ts.append(end_test)
    del prob_recontructed_opt, prob_recontructed_sar, prob_recontructed_fus, prob_recontructed_comb
    #del model
time_ts_array = np.asarray(time_ts)
# Save test time
np.save(path_exp+'/metrics_ts.npy', time_ts_array)
# Out:
# -80.0 -40.0
# time:  0
# time:  1
# time:  2
# time:  3
# time:  4

# %%
# Compute mean of the tm predictions maps
prob_rec_opt = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_sar = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_fus = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))
prob_rec_comb = np.zeros((image1_pad.shape[0],image1_pad.shape[1], times))

for tm in range (0, times):
    print(tm)
    prob_rec_opt[:,:,tm] = np.load(path_maps+'/'+'prob_opt_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_sar[:,:,tm] = np.load(path_maps+'/'+'prob_sar_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_fus[:,:,tm] = np.load(path_maps+'/'+'prob_fus_'+str(tm)+'.npy').astype(np.float32)
    prob_rec_comb[:,:,tm] = np.load(path_maps+'/'+'prob_comb_'+str(tm)+'.npy').astype(np.float32)

mean_prob_opt = np.mean(prob_rec_opt, axis = -1)
mean_prob_sar = np.mean(prob_rec_sar, axis = -1)
mean_prob_fus = np.mean(prob_rec_fus, axis = -1)
mean_prob_comb = np.mean(prob_rec_comb, axis = -1)

np.save(path_maps+'/prob_mean_opt.npy', mean_prob_opt)
np.save(path_maps+'/prob_mean_sar.npy', mean_prob_sar)
np.save(path_maps+'/prob_mean_fus.npy', mean_prob_fus)
np.save(path_maps+'/prob_mean_comb.npy', mean_prob_comb)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Plot mean map and reference
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(151)
plt.title('OPT Prediction')
ax1.imshow(mean_prob_opt, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(152)
plt.title('SAR Prediction')
ax1.imshow(mean_prob_sar, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(153)
plt.title('FUSION Prediction')
ax1.imshow(mean_prob_fus, cmap ='jet')
ax1.axis('off')

ax1 = fig.add_subplot(154)
plt.title('COMBINATION Prediction')
ax1.imshow(mean_prob_comb, cmap ='jet')
ax1.axis('off')

ax2 = fig.add_subplot(155)
plt.title('Reference')
ax2.imshow(tf.keras.utils.to_categorical(final_mask1, 3)[:,:,1], cmap ='jet')
ax2.axis('off')
# Out:
# (-0.5, 6999.5, 9999.5, -0.5)

# %%
# Computing metrics
mean_prob_opt = mean_prob_opt[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_sar = mean_prob_sar[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_fus = mean_prob_fus[:final_mask1.shape[0], :final_mask1.shape[1]]
mean_prob_comb = mean_prob_comb[:final_mask1.shape[0], :final_mask1.shape[1]]

ref1 = np.ones_like(final_mask1).astype(np.float32)

ref1 [final_mask1 == 2] = 0
TileMask = mask_amazon_ts * ref1
GTTruePositives = final_mask1==1
    
Npoints = 50

Pmax_opt = np.max(mean_prob_opt[GTTruePositives * TileMask ==1])
ProbList_opt = np.linspace(Pmax_opt,0,Npoints)

Pmax_sar = np.max(mean_prob_sar[GTTruePositives * TileMask ==1])
ProbList_sar = np.linspace(Pmax_sar,0,Npoints)

Pmax_fus = np.max(mean_prob_fus[GTTruePositives * TileMask ==1])
ProbList_fus = np.linspace(Pmax_fus,0,Npoints)

Pmax_comb = np.max(mean_prob_comb[GTTruePositives * TileMask ==1])
ProbList_comb = np.linspace(Pmax_comb,0,Npoints)


from multiprocessing.pool import Pool
pool = Pool(processes=4)

async_result_opt = pool.apply_async(matrics_AA_recall, (ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625))
async_result_sar = pool.apply_async(matrics_AA_recall, (ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625))
async_result_fus = pool.apply_async(matrics_AA_recall, (ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625))
async_result_comb = pool.apply_async(matrics_AA_recall, (ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625))

metrics_opt = async_result_opt.get()
metrics_sar = async_result_sar.get()
metrics_fus = async_result_fus.get()
metrics_comb = async_result_comb.get()
    
#metrics_opt = matrics_AA_recall(ProbList_opt, mean_prob_opt, final_mask1, mask_amazon_ts, 625)
#metrics_sar = matrics_AA_recall(ProbList_sar, mean_prob_sar, final_mask1, mask_amazon_ts, 625)
#metrics_fus = matrics_AA_recall(ProbList_fus, mean_prob_fus, final_mask1, mask_amazon_ts, 625)
#metrics_comb = matrics_AA_recall(ProbList_comb, mean_prob_comb, final_mask1, mask_amazon_ts, 625)

np.save(path_exp+'/acc_metrics_opt.npy',metrics_opt)
np.save(path_exp+'/acc_metrics_sar.npy',metrics_sar)
np.save(path_exp+'/acc_metrics_fus.npy',metrics_fus)
np.save(path_exp+'/acc_metrics_comb.npy',metrics_comb)

# %%
# Complete NaN values
metrics_copy_opt = metrics_opt.copy()
metrics_copy_opt = complete_nan_values(metrics_copy_opt)

metrics_copy_sar = metrics_sar.copy()
metrics_copy_sar = complete_nan_values(metrics_copy_sar)

metrics_copy_fus = metrics_fus.copy()
metrics_copy_fus = complete_nan_values(metrics_copy_fus)

metrics_copy_comb = metrics_comb.copy()
metrics_copy_comb = complete_nan_values(metrics_copy_comb)

# %%
# Comput Mean Average Precision (mAP) score 
Recall_opt = metrics_copy_opt[:,0]
Precision_opt = metrics_copy_opt[:,1]
AA_opt = metrics_copy_opt[:,2]

Recall_sar = metrics_copy_sar[:,0]
Precision_sar = metrics_copy_sar[:,1]
AA_sar = metrics_copy_sar[:,2]

Recall_fus = metrics_copy_fus[:,0]
Precision_fus = metrics_copy_fus[:,1]
AA_fus = metrics_copy_fus[:,2]

Recall_comb = metrics_copy_comb[:,0]
Precision_comb = metrics_copy_comb[:,1]
AA_comb = metrics_copy_comb[:,2]
    
DeltaR_opt = Recall_opt[1:]-Recall_opt[:-1]
AP_opt = np.sum(Precision_opt[:-1]*DeltaR_opt)
print('OPT mAP', AP_opt)

DeltaR_sar = Recall_sar[1:]-Recall_sar[:-1]
AP_sar = np.sum(Precision_sar[:-1]*DeltaR_sar)
print('SAR mAP', AP_sar)

DeltaR_fus = Recall_fus[1:]-Recall_fus[:-1]
AP_fus = np.sum(Precision_fus[:-1]*DeltaR_fus)
print('FUSION mAP', AP_fus)

DeltaR_comb = Recall_comb[1:]-Recall_comb[:-1]
AP_comb = np.sum(Precision_comb[:-1]*DeltaR_comb)
print('COMBINATION mAP', AP_comb)

# Plot Recall vs. Precision curve
plt.figure(figsize=(7,7))
plt.plot(metrics_copy_opt[:,0],metrics_copy_opt[:,1], 'r-', label = f'OPT (AP: {AP_opt:.4f})')
plt.plot(metrics_copy_sar[:,0],metrics_copy_sar[:,1], 'g-', label = f'SAR (AP: {AP_sar:.4f})')
plt.plot(metrics_copy_fus[:,0],metrics_copy_fus[:,1], 'b-', label = f'FUSION (AP: {AP_fus:.4f})')
plt.plot(metrics_copy_comb[:,0],metrics_copy_comb[:,1], 'k-', label = f'COMBINATION (AP: {AP_comb:.4f})')
plt.legend(loc="lower left")
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([0,1])
#plt.plot(metrics_copy[:,0],metrics_copy[:,2])
plt.grid()
# Out:
# OPT mAP 0.9368713108829204
# SAR mAP 0.7782169066500971
# FUSION mAP 0.9277572240851688
# COMBINATION mAP 0.9402025840605477
